# %%
# %matplotlib inline
import random
import os
import json
import sys
import string
import unicodedata
from tqdm import tqdm
import numpy as np
import pandas as pd
import seaborn as sns
import itertools
import matplotlib.pyplot as plt
import matplotlib.ticker as mtick

# %%
#Given local path, find full path
def PathFinder(path):
    script_dir = os.path.dirname('__file__')
    fullpath = os.path.join(script_dir,path)
    return fullpath

#Read Data for Deep Learning
def ReadData(path):
    fullpath=PathFinder(path)
    return np.loadtxt(fullpath,delimiter=',')

# %%
learning1=ReadData('../DATA/VIZ/HVAC_learning_rate/log1.txt')
learning01=ReadData('../DATA/VIZ/HVAC_learning_rate/log01.txt')
learning001=ReadData('../DATA/VIZ/HVAC_learning_rate/log001.txt')
learning0001=ReadData('../DATA/VIZ/HVAC_learning_rate/log0001.txt')

# %%
data = np.stack((learning1[:,1], learning01[:,1],learning001[:,1],learning0001[:,1]),axis=-1)

# %%
data
# Out:
# array([[-665798.38 , -665650.94 , -665898.75 , -665802.75 ],
#        [-307249.25 , -642996.81 , -663720.25 , -665585.62 ],
#        [-350363.84 , -624822.81 , -662124.56 , -665428.   ],
#        ...,
#        [-178760.31 ,  -40469.656,  -25419.836, -143320.16 ],
#        [-172467.14 ,  -40544.441,  -25432.42 , -143148.08 ],
#        [-180664.66 ,  -40670.203,  -25411.43 , -142976.12 ]])

# %%
df = pd.DataFrame(data, columns=['Learning_Rate:1','Learning_Rate:0.1','Learning_Rate:0.01','Learning_Rate:0.001'])

# %%
df
# Out:
#       Learning_Rate:1  Learning_Rate:0.1  Learning_Rate:0.01  \
# 0          -665798.38        -665650.940         -665898.750
# 1          -307249.25        -642996.810         -663720.250
# 2          -350363.84        -624822.810         -662124.560
# 3          -535163.06        -608365.810         -660778.810
# 4          -391229.44        -592724.620         -659576.810
# 5          -177490.12        -577454.560         -658469.440
# 6          -132265.20        -562308.810         -657429.060
# 7          -112404.97        -547123.060         -656438.750
# 8          -135395.52        -531779.190         -655487.060
# 9          -160555.81        -516187.160         -654565.690
# 10         -152963.27        -500280.560         -653668.690
# 11         -174532.28        -484001.280         -652791.250
# 12         -172750.81        -467299.720         -651930.190
# 13         -214898.92        -450143.160         -651082.250
# 14         -193740.92        -432499.810         -650245.560
# 15         -210624.31        -414352.970         -649418.190
# 16         -198083.30        -395693.750         -648598.560
# 17         -197321.41        -376524.000         -647785.500
# 18         -188242.42        -356873.190         -646977.810
# 19         -192476.59        -336778.810         -646174.500
# 20         -177582.59        -316368.470         -645374.810
# 21         -180224.19        -295795.470         -644578.060
# 22         -171127.36        -275214.590         -643783.620
# 23         -177520.44        -254797.080         -642991.060
# 24         -171934.52        -234716.590         -642199.810
# 25         -186453.00        -215160.000         -641409.500
# 26         -170607.34        -196316.120         -640619.750
# 27         -182817.72        -178382.200         -639830.310
# 28         -181679.42        -161542.840         -639040.940
# 29         -196827.80        -145989.020         -638251.500
# ...               ...                ...                 ...
# 3971       -181485.59         -40687.566          -25460.463
# 3972       -174723.64         -40573.699          -25437.439
# 3973       -171547.19         -40790.203          -25462.080
# 3974       -179666.86         -40583.703          -25434.385
# 3975       -182905.88         -40709.262          -25458.422
# 3976       -185691.52         -40613.324          -25436.971
# 3977       -188639.36         -40717.047          -25457.609
# 3978       -179201.77         -40537.145          -25433.117
# 3979       -165550.27         -40656.969          -25457.814
# 3980       -169464.78         -40543.523          -25430.914
# 3981       -172814.88         -40641.199          -25455.160
# 3982       -172966.84         -40563.215          -25430.539
# 3983       -175555.02         -40624.352          -25456.965
# 3984       -171228.05         -40482.246          -25436.318
# 3985       -180524.72         -40672.438          -25450.408
# 3986       -171295.88         -40611.230          -25425.234
# 3987       -177840.69         -40756.371          -25450.051
# 3988       -171571.95         -40585.125          -25426.664
# 3989       -181832.05         -40601.578          -25444.945
# 3990       -177145.44         -40609.605          -25423.025
# 3991       -191080.95         -40622.684          -25442.082
# 3992       -182381.36         -40626.934          -25427.047
# 3993       -180924.02         -40598.418          -25445.113
# 3994       -191437.44         -40708.934          -25422.914
# 3995       -181009.52         -40704.484          -25440.895
# 3996       -185080.94         -40684.266          -25420.535
# 3997       -167915.36         -40680.051          -25439.783
# 3998       -178760.31         -40469.656          -25419.836
# 3999       -172467.14         -40544.441          -25432.420
# 4000       -180664.66         -40670.203          -25411.430
#
#       Learning_Rate:0.001
# 0              -665802.75
# 1              -665585.62
# 2              -665428.00
# 3              -665295.94
# 4              -665178.69
# 5              -665071.06
# 6              -664970.50
# 7              -664875.12
# 8              -664783.75
# 9              -664695.69
# 10             -664610.19
# 11             -664526.81
# 12             -664445.38
# 13             -664365.38
# 14             -664286.75
# 15             -664209.19
# 16             -664132.56
# 17             -664056.81
# 18             -663981.81
# 19             -663907.38
# 20             -663833.50
# 21             -663760.19
# 22             -663687.19
# 23             -663614.69
# 24             -663542.38
# 25             -663470.50
# 26             -663398.81
# 27             -663327.38
# 28             -663256.06
# 29             -663184.94
# ...                   ...
# 3971           -148015.55
# 3972           -147840.05
# 3973           -147664.69
# 3974           -147489.45
# 3975           -147314.31
# 3976           -147139.34
# 3977           -146964.45
# 3978           -146789.70
# 3979           -146615.08
# 3980           -146440.58
# 3981           -146266.16
# 3982           -146091.86
# 3983           -145917.70
# 3984           -145743.66
# 3985           -145569.69
# 3986           -145395.88
# 3987           -145222.19
# 3988           -145048.64
# 3989           -144875.19
# 3990           -144701.88
# 3991           -144528.66
# 3992           -144355.59
# 3993           -144182.64
# 3994           -144009.84
# 3995           -143837.22
# 3996           -143664.72
# 3997           -143492.36
# 3998           -143320.16
# 3999           -143148.08
# 4000           -142976.12
#
# [4001 rows x 4 columns]

# %%
current_palette = sns.color_palette("Set2", 10)
ax=df.plot(color=current_palette,figsize=(4,4))
ax.yaxis.tick_right()
ax.yaxis.set_major_formatter(mtick.FormatStrFormatter('%.1e'))
plt.ylabel('Total Reward')
plt.xlabel('Epoch')
plt.tight_layout()
plt.legend(fancybox=True,loc='upper right', prop={'size':10})
plt.gca().invert_yaxis()
plt.savefig('../PLOTS/HVAC_Learning_Rate.eps',format='eps')
