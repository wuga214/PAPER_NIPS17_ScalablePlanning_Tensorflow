# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import tensorflow as tf
import numpy as np
from sklearn.metrics import confusion_matrix
import time
from datetime import timedelta
import math
import os
import pandas as pd
#Functional coding
import functools
from functools import partial
from tensorflow.python.ops import array_ops

# %%
#Data Path..
Datapath="DATA/Reservoir/Reservoir_Data.txt"
Labelpath="DATA/Reservoir/Reservoir_Label.txt"
Rewardpath="DATA/Reservoir/Reservoir_Reward.txt"

# %%
#Given local path, find full path
def PathFinder(path):
    #python 2
    #script_dir = os.path.dirname('__file__')
    #fullpath = os.path.join(script_dir,path)
    #python 3
    fullpath=os.path.abspath(path)
    print(fullpath)
    return fullpath

#Read Data for Deep Learning
def ReadData(path):
    fullpath=PathFinder(path)
    return pd.read_csv(fullpath, sep=',', header=0)

# %%
S_A_pd = ReadData(Datapath)
SP_pd = ReadData(Labelpath)
R_pd = ReadData(Rewardpath)
S_A_matrix=S_A_pd.as_matrix()
SP_matrix=SP_pd.as_matrix()
R_matrix=R_pd.as_matrix()
# Out:
# /home/wuga/Documents/Notebook/VAE-PLANNING/DATA/Reservoir/Reservoir_Data.txt
# /home/wuga/Documents/Notebook/VAE-PLANNING/DATA/Reservoir/Reservoir_Label.txt
# /home/wuga/Documents/Notebook/VAE-PLANNING/DATA/Reservoir/Reservoir_Reward.txt

# %%
default_settings = {
    "max_cap"          : [100, 200, 400, 500],
    "high_bound"       : [80, 180, 380, 480],
    "low_bound"        : [20, 30, 40, 60],
    "rain"             : [5, 10, 20, 30],
    "downstream"       : [[1,2],[2,3],[3,4]],
    "downtosea"        : [4],
    "biggestmaxcap"    : 1000,
    "reservoirs"    : [1,2,3,4],
    "init_state"       : [75,50,50,50]
   }

# %%
class RESERVOIR(object):
    def __init__(self, 
                 batch_size,
                 default_settings):
        self.batch_size = batch_size
        self.reservoirs = default_settings['reservoirs']
        self.reservoir_num = len(default_settings['reservoirs'])
        self.biggestmaxcap = tf.constant(default_settings["biggestmaxcap"],dtype=tf.float32)
        self.zero = tf.constant(0,shape=[self.batch_size,self.reservoir_num],dtype=tf.float32)
        self._high_bounds(default_settings["high_bound"])
        self._low_bounds(default_settings["low_bound"])
        self._rains(default_settings["rain"])
        self._max_cap(default_settings["max_cap"])
        self._downstream(default_settings["downstream"])
        self._downtosea(default_settings["downtosea"])
        
    def _max_cap(self, max_cap_list):
        self.max_cap = tf.constant(max_cap_list,dtype=tf.float32)
    
    def _high_bounds(self, high_bound_list):
        self.high_bound = tf.constant(high_bound_list,dtype=tf.float32)
            
    def _low_bounds(self, low_bound_list):
        self.low_bound = tf.constant(low_bound_list,dtype=tf.float32)
            
    def _rains(self, rain_list):
        self.rain = tf.constant(rain_list,dtype=tf.float32)
        
    def _downstream(self, downstream):
        np_downstream = np.zeros((self.reservoir_num,self.reservoir_num))
        for i in downstream:
            m = self.reservoirs.index(i[0])
            n = self.reservoirs.index(i[1])
            np_downstream[m,n] = 1
        self.downstream = tf.constant(np_downstream,dtype=tf.float32)
        
    def _downtosea(self, downtosea):
        np_downtosea = np.zeros((self.reservoir_num,))
        for i in downtosea:
            m = self.reservoirs.index(i)
            np_downtosea[m] = 1
        self.downtosea =  tf.constant(np_downtosea,dtype=tf.float32)
            
    def MAXCAP(self):
        return self.max_cap
    
    def HIGH_BOUND(self):
        return self.high_bound
    
    def LOW_BOUND(self):
        return self.low_bound
    
    def RAIN(self):
        return self.rain
    
    def DOWNSTREAM(self):
        return self.downstream
    
    def DOWNTOSEA(self):
        return self.downtosea
        
    def BIGGESTMAXCAP(self):
        return self.biggestmaxcap
    
    def Transition(self, states, actions):
        previous_state = states
        vaporated = 0.5*tf.sin(previous_state/self.BIGGESTMAXCAP())*previous_state
        upstreamflow = tf.transpose(tf.matmul(tf.transpose(self.DOWNSTREAM()),tf.transpose(actions)))
        new_state = previous_state + self.RAIN()-vaporated-actions+ upstreamflow                        
        return new_state
    
    #Reward for Reservoir is computed on 'Next State'
    def Reward(self, states):
        new_rewards = tf.select(tf.logical_and(tf.greater_equal(states,self.LOW_BOUND()),tf.less_equal(states,self.HIGH_BOUND())),\
                                 self.zero,\
                                tf.select(tf.less(states,self.LOW_BOUND()),\
                                          -5*(self.LOW_BOUND()-states),\
                                         -100*(states-self.HIGH_BOUND()))\
                               )
        new_rewards+=tf.abs(((self.HIGH_BOUND()+self.LOW_BOUND())/2.0)-states)*(-0.1)
        return tf.reduce_sum(new_rewards,1,keep_dims=True)

# %%
# States
states = tf.placeholder(tf.float32,[10, 4],name="States")

# Actions
actions = tf.placeholder(tf.float32,[10, 4],name="Actions")

# %%
reservoir_inst = RESERVOIR(10, default_settings)

# %%
states_list=tf.unpack(states)
actions_list = tf.unpack(actions)
sess = tf.InteractiveSession()
sess.run(tf.global_variables_initializer())
feed_dict={states:S_A_matrix[:10,4:], actions:S_A_matrix[:10,:4]}
new_state = reservoir_inst.Transition(states,actions)
print(sess.run([new_state], feed_dict=feed_dict))
# Out:
# [array([[  34.2109375 ,   98.94076538,   70.70948792,   79.58050537],
#        [  29.57379913,  105.29424286,   68.97597504,  121.5150528 ],
#        [  30.76093674,   61.79491806,  125.72145844,  117.12879944],
#        [  31.53264618,   47.34428787,  159.31442261,  142.84954834],
#        [  34.37532425,   53.70756912,  153.4153595 ,  173.37290955],
#        [  29.43461418,   63.54294586,  123.92326355,  192.53741455],
#        [  25.87185097,   59.27878571,  152.45231628,  135.31620789],
#        [  24.97044945,   56.14728165,  131.0018158 ,  143.20846558],
#        [  26.93314552,   61.22503662,   68.16318512,  211.58776855],
#        [  29.30649757,   50.83280182,  100.35129547,  114.01165771]], dtype=float32)]

# %%
new_rewards = reservoir_inst.Reward(states)

# %%
feed_dict={states:S_A_matrix[:10,4:], actions:S_A_matrix[:10,:4]}
sess.run(new_rewards,feed_dict=feed_dict )
# Out:
# array([[-96.        ],
#        [-35.15583038],
#        [-31.02294159],
#        [-29.95938873],
#        [-25.39591026],
#        [-22.01288414],
#        [-22.55617905],
#        [-26.20808601],
#        [-27.96719742],
#        [-26.70908737]], dtype=float32)

# %%
class RESERVOIRCell(tf.nn.rnn_cell.RNNCell):

    def __init__(self, batch_size,default_settings):
        self._num_state_units = len(default_settings["reservoirs"])
        self._num_reward_units = self._num_state_units +1
        self.reservoir = RESERVOIR(batch_size,default_settings)

    @property
    def state_size(self):
        return self._num_state_units

    @property
    def output_size(self):
        return self._num_reward_units

    def __call__(self, inputs, state, scope=None):
        next_state =  self.reservoir.Transition(state, inputs)
        reward = self.reservoir.Reward(next_state)   
        return tf.concat(1,[reward,next_state]), next_state

# %%
class ActionOptimizer(object):
    def __init__(self,
                a, # Actions
                num_step, # Number of RNN step, this is a fixed step RNN sequence, 12 for navigation
                num_act, # Number of actions
                batch_size, #Batch Size
                learning_rate=0.1): 
        self.action = a
        print(self.action)
        self.batch_size = batch_size
        self.num_step = num_step
        self.learning_rate = learning_rate
        self._p_create_rnn_graph()
        self._p_Q_loss()
        self.sess = tf.InteractiveSession()
        self.sess.run(tf.global_variables_initializer())
    
    def _p_create_rnn_graph(self):
        cell = RESERVOIRCell(self.batch_size, default_settings)
        initial_state = cell.zero_state(self.batch_size, dtype=tf.float32)+tf.constant([default_settings["init_state"]],dtype=tf.float32)
        print('action batch size:{0}'.format(array_ops.shape(self.action)[0]))
        print('Initial_state shape:{0}'.format(initial_state))
        rnn_outputs, state = tf.nn.dynamic_rnn(cell, self.action, dtype=tf.float32,initial_state=initial_state)
        #need output intermediate states as well
        concated = tf.concat(0,rnn_outputs)
        print('concated shape:{0}'.format(concated.get_shape()))
        something_unpacked =  tf.unpack(concated, axis=2)
        self.outputs = tf.reshape(something_unpacked[0],[-1,self.num_step,1])
        print(' self.outputs:{0}'.format(self.outputs.get_shape()))
        self.intern_states = tf.pack([something_unpacked[i+1] for i in range(len(default_settings["reservoirs"]))], axis=2)
        self.last_state = state
        self.pred = tf.reduce_sum(self.outputs,1)
        self.average_pred = tf.reduce_mean(self.pred)
        print("self.pred:{0}".format(self.pred))
            
    def _p_create_loss(self):

        objective = tf.reduce_mean(self.pred) 
        self.loss = -objective
        print(self.loss.get_shape())
        #self.loss = -objective
        self.optimizer = tf.train.RMSPropOptimizer(self.learning_rate).minimize(self.loss, var_list=[a])
        
    def _p_Q_loss(self):
        objective = tf.constant(0.0, shape=[self.batch_size, 1])
        for i in range(self.num_step):
            Rt = self.outputs[:,i]
            SumRj=tf.constant(0.0, shape=[self.batch_size, 1])
            #SumRk=tf.constant(0.0, shape=[self.batch_size, 1])
            if i<(self.num_step-1):
                j = i+1
                SumRj = tf.reduce_sum(self.outputs[:,j:],1)
            #if i<(self.num_step-1):
                #k= i+1
                #SumRk = tf.reduce_sum(self.outputs[:,k:],1)
            objective+=(Rt*SumRj+tf.square(Rt))*(self.num_step-i)/np.square(self.num_step)
        self.loss = tf.log(tf.reduce_mean(tf.square(objective)))
        self.optimizer = tf.train.RMSPropOptimizer(self.learning_rate).minimize(self.loss, var_list=[a])
        
    def Optimize(self,epoch=100):
        
        new_loss = self.sess.run([self.average_pred])
        print('Loss in epoch {0}: {1}'.format("Initial", new_loss)) 
        for epoch in range(epoch):
            training = self.sess.run([self.optimizer])
            action_upperbound=self.sess.run(self.intern_states)
            self.sess.run(tf.assign(self.action, tf.clip_by_value(self.action, 0, action_upperbound)))
            if True:
                new_loss = self.sess.run([self.average_pred])
                print('Loss in epoch {0}: {1}'.format(epoch, new_loss))  
        minimum_costs_id=self.sess.run(tf.argmax(self.pred,0))
        print(minimum_costs_id)
        best_action = self.sess.run(self.action)[minimum_costs_id[0]]
        print('Optimal Action Squence:{0}'.format(best_action))
        pred_list = self.sess.run(self.pred)
        pred_list=np.sort(pred_list.flatten())[::-1]
        pred_list=pred_list[:5]
        pred_mean = np.mean(pred_list)
        pred_std = np.std(pred_list)
        print('Best Cost: {0}'.format(pred_list[0]))
        print('Sorted Costs:{0}'.format(pred_list))
        print('MEAN: {0}, STD:{1}'.format(pred_mean,pred_std))
        print('The last state:{0}'.format(self.sess.run(self.last_state)))
        print('The last state:{0}'.format(self.sess.run(self.last_state)[minimum_costs_id[0]]))
        print('Rewards each time step:{0}'.format(self.sess.run(self.outputs)[minimum_costs_id[0]]))
        print('Intermediate states:{0}'.format(self.sess.run(self.intern_states)[minimum_costs_id[0]]))

# %%
a = tf.Variable(tf.truncated_normal(shape=[100,120,4],mean=0.0, stddev=0.5),name="action")
rnn_inst = ActionOptimizer(a, 120,4,100)
# Out:
# Tensor("action/read:0", shape=(100, 120, 4), dtype=float32)
# action batch size:Tensor("strided_slice:0", shape=(), dtype=int32)
# Initial_state shape:Tensor("add_4:0", shape=(100, 4), dtype=float32)
# concated shape:(100, 120, 5)
#  self.outputs:(100, 120, 1)
# self.pred:Tensor("Sum_1:0", shape=(100, 1), dtype=float32)

# %%
rnn_inst.Optimize(1000)
# Out:
# Loss in epoch Initial: [-218543.2]
# Loss in epoch 0: [-197794.36]
# Loss in epoch 1: [-197791.73]
# Loss in epoch 2: [-197789.0]
# Loss in epoch 3: [-197786.09]
# Loss in epoch 4: [-197783.06]
# Loss in epoch 5: [-197779.84]
# Loss in epoch 6: [-197776.45]
# Loss in epoch 7: [-197772.88]
# Loss in epoch 8: [-197769.08]
# Loss in epoch 9: [-197765.12]
# Loss in epoch 10: [-197760.94]
# Loss in epoch 11: [-197756.52]
# Loss in epoch 12: [-197751.88]
# Loss in epoch 13: [-197746.95]
# Loss in epoch 14: [-197741.8]
# Loss in epoch 15: [-197736.34]
# Loss in epoch 16: [-197730.59]
# Loss in epoch 17: [-197724.55]
# Loss in epoch 18: [-197718.14]
# Loss in epoch 19: [-197711.42]
# Loss in epoch 20: [-197704.34]
# Loss in epoch 21: [-197696.84]
# Loss in epoch 22: [-197688.95]
# Loss in epoch 23: [-197680.64]
# Loss in epoch 24: [-197671.88]
# Loss in epoch 25: [-197662.64]
# Loss in epoch 26: [-197652.91]
# Loss in epoch 27: [-197642.66]
# Loss in epoch 28: [-197631.81]
# Loss in epoch 29: [-197620.41]
# Loss in epoch 30: [-197608.41]
# Loss in epoch 31: [-197595.72]
# Loss in epoch 32: [-197582.36]
# Loss in epoch 33: [-197568.23]
# Loss in epoch 34: [-197553.44]
# Loss in epoch 35: [-197537.77]
# Loss in epoch 36: [-197521.27]
# Loss in epoch 37: [-197503.84]
# Loss in epoch 38: [-197485.5]
# Loss in epoch 39: [-197466.19]
# Loss in epoch 40: [-197445.8]
# Loss in epoch 41: [-197424.3]
# Loss in epoch 42: [-197401.62]
# Loss in epoch 43: [-197377.77]
# Loss in epoch 44: [-197352.56]
# Loss in epoch 45: [-197326.02]
# Loss in epoch 46: [-197298.0]
# Loss in epoch 47: [-197268.48]
# Loss in epoch 48: [-197237.41]
# Loss in epoch 49: [-197204.56]
# Loss in epoch 50: [-197169.98]
# Loss in epoch 51: [-197133.52]
# Loss in epoch 52: [-197095.05]
# Loss in epoch 53: [-197054.5]
# Loss in epoch 54: [-197011.77]
# Loss in epoch 55: [-196966.69]
# Loss in epoch 56: [-196919.16]
# Loss in epoch 57: [-196869.02]
# Loss in epoch 58: [-196816.2]
# Loss in epoch 59: [-196760.44]
# Loss in epoch 60: [-196701.69]
# Loss in epoch 61: [-196639.72]
# Loss in epoch 62: [-196574.36]
# Loss in epoch 63: [-196505.45]
# Loss in epoch 64: [-196432.77]
# Loss in epoch 65: [-196356.12]
# Loss in epoch 66: [-196275.28]
# Loss in epoch 67: [-196190.05]
# Loss in epoch 68: [-196100.12]
# Loss in epoch 69: [-196005.23]
# Loss in epoch 70: [-195905.19]
# Loss in epoch 71: [-195799.64]
# Loss in epoch 72: [-195688.28]
# Loss in epoch 73: [-195570.84]
# Loss in epoch 74: [-195446.94]
# Loss in epoch 75: [-195316.2]
# Loss in epoch 76: [-195178.28]
# Loss in epoch 77: [-195032.77]
# Loss in epoch 78: [-194879.2]
# Loss in epoch 79: [-194717.14]
# Loss in epoch 80: [-194546.16]
# Loss in epoch 81: [-194365.64]
# Loss in epoch 82: [-194175.16]
# Loss in epoch 83: [-193974.09]
# Loss in epoch 84: [-193761.84]
# Loss in epoch 85: [-193537.73]
# Loss in epoch 86: [-193301.14]
# Loss in epoch 87: [-193051.31]
# Loss in epoch 88: [-192787.52]
# Loss in epoch 89: [-192508.84]
# Loss in epoch 90: [-192214.56]
# Loss in epoch 91: [-191903.69]
# Loss in epoch 92: [-191575.23]
# Loss in epoch 93: [-191228.2]
# Loss in epoch 94: [-190861.52]
# Loss in epoch 95: [-190473.95]
# Loss in epoch 96: [-190064.28]
# Loss in epoch 97: [-189631.16]
# Loss in epoch 98: [-189173.23]
# Loss in epoch 99: [-188688.92]
# Loss in epoch 100: [-188176.72]
# Loss in epoch 101: [-187634.81]
# Loss in epoch 102: [-187061.45]
# Loss in epoch 103: [-186454.7]
# Loss in epoch 104: [-185812.27]
# Loss in epoch 105: [-185132.05]
# Loss in epoch 106: [-184411.62]
# Loss in epoch 107: [-183648.3]
# Loss in epoch 108: [-182839.27]
# Loss in epoch 109: [-181981.41]
# Loss in epoch 110: [-181071.64]
# Loss in epoch 111: [-180106.56]
# Loss in epoch 112: [-179082.23]
# Loss in epoch 113: [-177994.52]
# Loss in epoch 114: [-176838.91]
# Loss in epoch 115: [-175610.5]
# Loss in epoch 116: [-174303.91]
# Loss in epoch 117: [-172913.38]
# Loss in epoch 118: [-171432.81]
# Loss in epoch 119: [-169855.52]
# Loss in epoch 120: [-168173.78]
# Loss in epoch 121: [-166379.98]
# Loss in epoch 122: [-164464.55]
# Loss in epoch 123: [-162416.3]
# Loss in epoch 124: [-160223.64]
# Loss in epoch 125: [-157875.0]
# Loss in epoch 126: [-155355.34]
# Loss in epoch 127: [-152648.62]
# Loss in epoch 128: [-149737.41]
# Loss in epoch 129: [-146603.05]
# Loss in epoch 130: [-143221.12]
# Loss in epoch 131: [-139563.23]
# Loss in epoch 132: [-135598.0]
# Loss in epoch 133: [-131288.34]
# Loss in epoch 134: [-126591.08]
# Loss in epoch 135: [-121455.18]
# Loss in epoch 136: [-115815.7]
# Loss in epoch 137: [-109600.43]
# Loss in epoch 138: [-102709.93]
# Loss in epoch 139: [-95024.102]
# Loss in epoch 140: [-86394.844]
# Loss in epoch 141: [-76665.602]
# Loss in epoch 142: [-65733.703]
# Loss in epoch 143: [-53688.559]
# Loss in epoch 144: [-40992.562]
# Loss in epoch 145: [-28354.785]
# Loss in epoch 146: [-16880.105]
# Loss in epoch 147: [-8656.4033]
# Loss in epoch 148: [-4318.605]
# Loss in epoch 149: [-2354.7737]
# Loss in epoch 150: [-1595.9531]
# Loss in epoch 151: [-1437.063]
# Loss in epoch 152: [-1428.8002]
# Loss in epoch 153: [-1427.1765]
# Loss in epoch 154: [-1425.4644]
# Loss in epoch 155: [-1423.6589]
# Loss in epoch 156: [-1421.7556]
# Loss in epoch 157: [-1419.7488]
# Loss in epoch 158: [-1417.6334]
# Loss in epoch 159: [-1415.403]
# Loss in epoch 160: [-1413.0519]
# Loss in epoch 161: [-1410.5737]
# Loss in epoch 162: [-1407.9615]
# Loss in epoch 163: [-1405.2081]
# Loss in epoch 164: [-1402.3069]
# Loss in epoch 165: [-1399.2496]
# Loss in epoch 166: [-1396.0284]
# Loss in epoch 167: [-1392.635]
# Loss in epoch 168: [-1389.0613]
# Loss in epoch 169: [-1385.2979]
# Loss in epoch 170: [-1381.3356]
# Loss in epoch 171: [-1377.1652]
# Loss in epoch 172: [-1372.7756]
# Loss in epoch 173: [-1368.1569]
# Loss in epoch 174: [-1363.2987]
# Loss in epoch 175: [-1358.1913]
# Loss in epoch 176: [-1352.8237]
# Loss in epoch 177: [-1347.1852]
# Loss in epoch 178: [-1341.264]
# Loss in epoch 179: [-1335.05]
# Loss in epoch 180: [-1328.5303]
# Loss in epoch 181: [-1321.6953]
# Loss in epoch 182: [-1314.5342]
# Loss in epoch 183: [-1307.0376]
# Loss in epoch 184: [-1299.1943]
# Loss in epoch 185: [-1290.9951]
# Loss in epoch 186: [-1282.4287]
# Loss in epoch 187: [-1273.4867]
# Loss in epoch 188: [-1264.1622]
# Loss in epoch 189: [-1254.4485]
# Loss in epoch 190: [-1244.3354]
# Loss in epoch 191: [-1233.8157]
# Loss in epoch 192: [-1222.8839]
# Loss in epoch 193: [-1211.5386]
# Loss in epoch 194: [-1199.7937]
# Loss in epoch 195: [-1187.7041]
# Loss in epoch 196: [-1175.4292]
# Loss in epoch 197: [-1163.1578]
# Loss in epoch 198: [-1151.0043]
# Loss in epoch 199: [-1139.0133]
# Loss in epoch 200: [-1127.1553]
# Loss in epoch 201: [-1115.3785]
# Loss in epoch 202: [-1103.6118]
# Loss in epoch 203: [-1091.7496]
# Loss in epoch 204: [-1079.6125]
# Loss in epoch 205: [-1067.1333]
# Loss in epoch 206: [-1054.1879]
# Loss in epoch 207: [-1040.7711]
# Loss in epoch 208: [-1026.7618]
# Loss in epoch 209: [-1012.2263]
# Loss in epoch 210: [-996.92126]
# Loss in epoch 211: [-981.03021]
# Loss in epoch 212: [-964.29077]
# Loss in epoch 213: [-946.80164]
# Loss in epoch 214: [-929.3808]
# Loss in epoch 215: [-913.90735]
# Loss in epoch 216: [-899.39435]
# Loss in epoch 217: [-885.93494]
# Loss in epoch 218: [-872.77435]
# Loss in epoch 219: [-858.78094]
# Loss in epoch 220: [-845.30017]
# Loss in epoch 221: [-831.16992]
# Loss in epoch 222: [-818.33362]
# Loss in epoch 223: [-805.39655]
# Loss in epoch 224: [-792.51422]
# Loss in epoch 225: [-779.03247]
# Loss in epoch 226: [-766.11084]
# Loss in epoch 227: [-754.1474]
# Loss in epoch 228: [-741.44983]
# Loss in epoch 229: [-729.13055]
# Loss in epoch 230: [-716.33344]
# Loss in epoch 231: [-704.3446]
# Loss in epoch 232: [-691.36188]
# Loss in epoch 233: [-678.79999]
# Loss in epoch 234: [-667.56702]
# Loss in epoch 235: [-653.95306]
# Loss in epoch 236: [-641.4046]
# Loss in epoch 237: [-629.74597]
# Loss in epoch 238: [-616.39069]
# Loss in epoch 239: [-603.91205]
# Loss in epoch 240: [-591.73608]
# Loss in epoch 241: [-578.46661]
# Loss in epoch 242: [-566.6344]
# Loss in epoch 243: [-553.96509]
# Loss in epoch 244: [-541.77283]
# Loss in epoch 245: [-529.15753]
# Loss in epoch 246: [-516.69568]
# Loss in epoch 247: [-504.52725]
# Loss in epoch 248: [-491.70593]
# Loss in epoch 249: [-478.39508]
# Loss in epoch 250: [-466.76364]
# Loss in epoch 251: [-454.29718]
# Loss in epoch 252: [-441.11414]
# Loss in epoch 253: [-429.00406]
# Loss in epoch 254: [-415.88907]
# Loss in epoch 255: [-402.03528]
# Loss in epoch 256: [-391.49374]
# Loss in epoch 257: [-378.24008]
# Loss in epoch 258: [-364.0004]
# Loss in epoch 259: [-351.89413]
# Loss in epoch 260: [-338.96359]
# Loss in epoch 261: [-325.42917]
# Loss in epoch 262: [-312.62671]
# Loss in epoch 263: [-298.64685]
# Loss in epoch 264: [-285.96808]
# Loss in epoch 265: [-275.71213]
# Loss in epoch 266: [-265.43616]
# Loss in epoch 267: [-254.85738]
# Loss in epoch 268: [-246.85255]
# Loss in epoch 269: [-243.13684]
# Loss in epoch 270: [-240.94633]
# Loss in epoch 271: [-237.68036]
# Loss in epoch 272: [-235.94022]
# Loss in epoch 273: [-234.5752]
# Loss in epoch 274: [-233.78398]
# Loss in epoch 275: [-231.54953]
# Loss in epoch 276: [-230.9675]
# Loss in epoch 277: [-229.00426]
# Loss in epoch 278: [-228.2337]
# Loss in epoch 279: [-226.75293]
# Loss in epoch 280: [-226.24973]
# Loss in epoch 281: [-224.73186]
# Loss in epoch 282: [-224.22371]
# Loss in epoch 283: [-223.18808]
# Loss in epoch 284: [-222.85469]
# Loss in epoch 285: [-221.71532]
# Loss in epoch 286: [-221.4818]
# Loss in epoch 287: [-220.82925]
# Loss in epoch 288: [-220.77841]
# Loss in epoch 289: [-219.66902]
# Loss in epoch 290: [-219.87816]
# Loss in epoch 291: [-219.27917]
# Loss in epoch 292: [-219.40819]
# Loss in epoch 293: [-218.313]
# Loss in epoch 294: [-218.64165]
# Loss in epoch 295: [-218.10277]
# Loss in epoch 296: [-218.11894]
# Loss in epoch 297: [-217.3298]
# Loss in epoch 298: [-217.90173]
# Loss in epoch 299: [-217.12367]
# Loss in epoch 300: [-217.42465]
# Loss in epoch 301: [-216.60516]
# Loss in epoch 302: [-217.18025]
# Loss in epoch 303: [-216.44734]
# Loss in epoch 304: [-217.00699]
# Loss in epoch 305: [-215.84059]
# Loss in epoch 306: [-217.09206]
# Loss in epoch 307: [-215.88762]
# Loss in epoch 308: [-216.75706]
# Loss in epoch 309: [-215.52127]
# Loss in epoch 310: [-216.59778]
# Loss in epoch 311: [-215.11327]
# Loss in epoch 312: [-216.35757]
# Loss in epoch 313: [-214.86894]
# Loss in epoch 314: [-216.54016]
# Loss in epoch 315: [-214.58473]
# Loss in epoch 316: [-216.34219]
# Loss in epoch 317: [-214.19818]
# Loss in epoch 318: [-216.6559]
# Loss in epoch 319: [-213.70699]
# Loss in epoch 320: [-216.47504]
# Loss in epoch 321: [-213.38559]
# Loss in epoch 322: [-216.75691]
# Loss in epoch 323: [-213.00023]
# Loss in epoch 324: [-216.7818]
# Loss in epoch 325: [-212.72847]
# Loss in epoch 326: [-217.12004]
# Loss in epoch 327: [-212.05536]
# Loss in epoch 328: [-217.24998]
# Loss in epoch 329: [-211.54402]
# Loss in epoch 330: [-217.88643]
# Loss in epoch 331: [-210.98175]
# Loss in epoch 332: [-218.06622]
# Loss in epoch 333: [-210.51926]
# Loss in epoch 334: [-218.65041]
# Loss in epoch 335: [-209.91522]
# Loss in epoch 336: [-218.96561]
# Loss in epoch 337: [-209.24551]
# Loss in epoch 338: [-219.46198]
# Loss in epoch 339: [-208.51416]
# Loss in epoch 340: [-219.44719]
# Loss in epoch 341: [-208.45578]
# Loss in epoch 342: [-220.0477]
# Loss in epoch 343: [-207.72769]
# Loss in epoch 344: [-220.41043]
# Loss in epoch 345: [-207.02405]
# Loss in epoch 346: [-220.41287]
# Loss in epoch 347: [-206.87105]
# Loss in epoch 348: [-221.13942]
# Loss in epoch 349: [-206.40057]
# Loss in epoch 350: [-221.2571]
# Loss in epoch 351: [-206.04266]
# Loss in epoch 352: [-222.05009]
# Loss in epoch 353: [-204.84653]
# Loss in epoch 354: [-221.69942]
# Loss in epoch 355: [-205.29922]
# Loss in epoch 356: [-222.30988]
# Loss in epoch 357: [-204.56543]
# Loss in epoch 358: [-223.12961]
# Loss in epoch 359: [-203.62038]
# Loss in epoch 360: [-222.19469]
# Loss in epoch 361: [-204.43149]
# Loss in epoch 362: [-223.1875]
# Loss in epoch 363: [-203.39946]
# Loss in epoch 364: [-223.96046]
# Loss in epoch 365: [-202.56726]
# Loss in epoch 366: [-223.53642]
# Loss in epoch 367: [-202.80589]
# Loss in epoch 368: [-224.17444]
# Loss in epoch 369: [-201.97789]
# Loss in epoch 370: [-223.78273]
# Loss in epoch 371: [-202.39984]
# Loss in epoch 372: [-224.96805]
# Loss in epoch 373: [-201.30844]
# Loss in epoch 374: [-224.60089]
# Loss in epoch 375: [-201.08748]
# Loss in epoch 376: [-225.14169]
# Loss in epoch 377: [-200.70268]
# Loss in epoch 378: [-225.37624]
# Loss in epoch 379: [-200.48903]
# Loss in epoch 380: [-225.02467]
# Loss in epoch 381: [-200.80872]
# Loss in epoch 382: [-225.35191]
# Loss in epoch 383: [-200.14172]
# Loss in epoch 384: [-226.11031]
# Loss in epoch 385: [-199.45703]
# Loss in epoch 386: [-225.45789]
# Loss in epoch 387: [-199.98199]
# Loss in epoch 388: [-225.98602]
# Loss in epoch 389: [-199.5515]
# Loss in epoch 390: [-225.54651]
# Loss in epoch 391: [-199.92238]
# Loss in epoch 392: [-226.31688]
# Loss in epoch 393: [-198.89]
# Loss in epoch 394: [-225.73563]
# Loss in epoch 395: [-199.52071]
# Loss in epoch 396: [-226.44]
# Loss in epoch 397: [-198.7216]
# Loss in epoch 398: [-227.20987]
# Loss in epoch 399: [-197.7662]
# Loss in epoch 400: [-224.62605]
# Loss in epoch 401: [-200.14871]
# Loss in epoch 402: [-226.57329]
# Loss in epoch 403: [-198.37172]
# Loss in epoch 404: [-227.04988]
# Loss in epoch 405: [-197.65359]
# Loss in epoch 406: [-226.32985]
# Loss in epoch 407: [-198.63602]
# Loss in epoch 408: [-226.5961]
# Loss in epoch 409: [-198.0443]
# Loss in epoch 410: [-227.60008]
# Loss in epoch 411: [-197.09566]
# Loss in epoch 412: [-225.8782]
# Loss in epoch 413: [-198.68559]
# Loss in epoch 414: [-227.49231]
# Loss in epoch 415: [-197.29207]
# Loss in epoch 416: [-226.75668]
# Loss in epoch 417: [-197.45509]
# Loss in epoch 418: [-227.58028]
# Loss in epoch 419: [-196.79094]
# Loss in epoch 420: [-225.45338]
# Loss in epoch 421: [-198.9061]
# Loss in epoch 422: [-227.28476]
# Loss in epoch 423: [-197.32625]
# Loss in epoch 424: [-226.25369]
# Loss in epoch 425: [-198.09445]
# Loss in epoch 426: [-227.04059]
# Loss in epoch 427: [-197.17258]
# Loss in epoch 428: [-227.05586]
# Loss in epoch 429: [-197.04106]
# Loss in epoch 430: [-227.30664]
# Loss in epoch 431: [-197.09068]
# Loss in epoch 432: [-225.86893]
# Loss in epoch 433: [-198.16699]
# Loss in epoch 434: [-226.58246]
# Loss in epoch 435: [-197.67445]
# Loss in epoch 436: [-226.7149]
# Loss in epoch 437: [-197.37889]
# Loss in epoch 438: [-227.16246]
# Loss in epoch 439: [-196.75496]
# Loss in epoch 440: [-226.60844]
# Loss in epoch 441: [-197.30051]
# Loss in epoch 442: [-226.69279]
# Loss in epoch 443: [-197.32159]
# Loss in epoch 444: [-226.43338]
# Loss in epoch 445: [-197.39764]
# Loss in epoch 446: [-226.4852]
# Loss in epoch 447: [-197.38426]
# Loss in epoch 448: [-226.51688]
# Loss in epoch 449: [-196.81956]
# Loss in epoch 450: [-226.62433]
# Loss in epoch 451: [-196.89523]
# Loss in epoch 452: [-226.51495]
# Loss in epoch 453: [-197.06105]
# Loss in epoch 454: [-227.01509]
# Loss in epoch 455: [-196.26778]
# Loss in epoch 456: [-226.41757]
# Loss in epoch 457: [-197.09094]
# Loss in epoch 458: [-226.42908]
# Loss in epoch 459: [-197.36058]
# Loss in epoch 460: [-226.86891]
# Loss in epoch 461: [-196.52203]
# Loss in epoch 462: [-226.98941]
# Loss in epoch 463: [-196.52191]
# Loss in epoch 464: [-224.78062]
# Loss in epoch 465: [-198.21564]
# Loss in epoch 466: [-226.97348]
# Loss in epoch 467: [-196.75183]
# Loss in epoch 468: [-227.0659]
# Loss in epoch 469: [-196.29282]
# Loss in epoch 470: [-225.789]
# Loss in epoch 471: [-197.37575]
# Loss in epoch 472: [-226.2896]
# Loss in epoch 473: [-197.17148]
# Loss in epoch 474: [-227.60269]
# Loss in epoch 475: [-195.70703]
# Loss in epoch 476: [-225.33087]
# Loss in epoch 477: [-197.52866]
# Loss in epoch 478: [-225.98647]
# Loss in epoch 479: [-196.7798]
# Loss in epoch 480: [-226.91602]
# Loss in epoch 481: [-196.32848]
# Loss in epoch 482: [-225.48152]
# Loss in epoch 483: [-197.4612]
# Loss in epoch 484: [-226.51642]
# Loss in epoch 485: [-196.41168]
# Loss in epoch 486: [-226.3434]
# Loss in epoch 487: [-196.56621]
# Loss in epoch 488: [-224.85089]
# Loss in epoch 489: [-197.91791]
# Loss in epoch 490: [-226.70795]
# Loss in epoch 491: [-196.18715]
# Loss in epoch 492: [-226.21986]
# Loss in epoch 493: [-196.71025]
# Loss in epoch 494: [-226.91229]
# Loss in epoch 495: [-195.60672]
# Loss in epoch 496: [-224.54372]
# Loss in epoch 497: [-197.7652]
# Loss in epoch 498: [-227.10464]
# Loss in epoch 499: [-195.40721]
# Loss in epoch 500: [-226.09703]
# Loss in epoch 501: [-196.17102]
# Loss in epoch 502: [-225.6284]
# Loss in epoch 503: [-196.46555]
# Loss in epoch 504: [-226.92787]
# Loss in epoch 505: [-195.60754]
# Loss in epoch 506: [-223.87006]
# Loss in epoch 507: [-198.13051]
# Loss in epoch 508: [-226.52847]
# Loss in epoch 509: [-195.76656]
# Loss in epoch 510: [-226.09]
# Loss in epoch 511: [-196.3089]
# Loss in epoch 512: [-224.89986]
# Loss in epoch 513: [-197.43555]
# Loss in epoch 514: [-225.53224]
# Loss in epoch 515: [-196.79485]
# Loss in epoch 516: [-225.64696]
# Loss in epoch 517: [-196.74667]
# Loss in epoch 518: [-226.69496]
# Loss in epoch 519: [-195.82193]
# Loss in epoch 520: [-225.13126]
# Loss in epoch 521: [-197.11217]
# Loss in epoch 522: [-226.22375]
# Loss in epoch 523: [-196.10762]
# Loss in epoch 524: [-226.85161]
# Loss in epoch 525: [-195.63702]
# Loss in epoch 526: [-223.61322]
# Loss in epoch 527: [-197.97621]
# Loss in epoch 528: [-226.60109]
# Loss in epoch 529: [-195.524]
# Loss in epoch 530: [-225.69226]
# Loss in epoch 531: [-196.22336]
# Loss in epoch 532: [-225.53384]
# Loss in epoch 533: [-196.40498]
# Loss in epoch 534: [-224.75943]
# Loss in epoch 535: [-197.21863]
# Loss in epoch 536: [-225.85562]
# Loss in epoch 537: [-196.58669]
# Loss in epoch 538: [-226.40938]
# Loss in epoch 539: [-195.55624]
# Loss in epoch 540: [-224.84673]
# Loss in epoch 541: [-196.93394]
# Loss in epoch 542: [-225.69078]
# Loss in epoch 543: [-196.10629]
# Loss in epoch 544: [-226.20998]
# Loss in epoch 545: [-195.81175]
# Loss in epoch 546: [-224.65549]
# Loss in epoch 547: [-196.91754]
# Loss in epoch 548: [-226.67207]
# Loss in epoch 549: [-195.36285]
# Loss in epoch 550: [-225.61983]
# Loss in epoch 551: [-195.99223]
# Loss in epoch 552: [-225.19797]
# Loss in epoch 553: [-196.35649]
# Loss in epoch 554: [-225.04839]
# Loss in epoch 555: [-196.2459]
# Loss in epoch 556: [-226.05586]
# Loss in epoch 557: [-195.88429]
# Loss in epoch 558: [-225.0966]
# Loss in epoch 559: [-196.85254]
# Loss in epoch 560: [-226.18106]
# Loss in epoch 561: [-195.91805]
# Loss in epoch 562: [-224.97728]
# Loss in epoch 563: [-196.19562]
# Loss in epoch 564: [-224.32205]
# Loss in epoch 565: [-196.86772]
# Loss in epoch 566: [-226.70282]
# Loss in epoch 567: [-195.0289]
# Loss in epoch 568: [-224.03706]
# Loss in epoch 569: [-197.31219]
# Loss in epoch 570: [-224.66586]
# Loss in epoch 571: [-196.64584]
# Loss in epoch 572: [-226.06583]
# Loss in epoch 573: [-195.43163]
# Loss in epoch 574: [-224.9756]
# Loss in epoch 575: [-195.96996]
# Loss in epoch 576: [-225.3918]
# Loss in epoch 577: [-195.69443]
# Loss in epoch 578: [-224.17049]
# Loss in epoch 579: [-196.64435]
# Loss in epoch 580: [-225.41258]
# Loss in epoch 581: [-195.23624]
# Loss in epoch 582: [-225.30869]
# Loss in epoch 583: [-195.619]
# Loss in epoch 584: [-224.89516]
# Loss in epoch 585: [-196.41866]
# Loss in epoch 586: [-225.33076]
# Loss in epoch 587: [-195.77827]
# Loss in epoch 588: [-225.32751]
# Loss in epoch 589: [-195.41441]
# Loss in epoch 590: [-225.6405]
# Loss in epoch 591: [-195.65656]
# Loss in epoch 592: [-223.6579]
# Loss in epoch 593: [-197.09215]
# Loss in epoch 594: [-225.44307]
# Loss in epoch 595: [-195.4482]
# Loss in epoch 596: [-226.17387]
# Loss in epoch 597: [-195.04469]
# Loss in epoch 598: [-224.3028]
# Loss in epoch 599: [-196.55363]
# Loss in epoch 600: [-224.72295]
# Loss in epoch 601: [-196.27289]
# Loss in epoch 602: [-225.39626]
# Loss in epoch 603: [-195.68924]
# Loss in epoch 604: [-223.87988]
# Loss in epoch 605: [-196.58211]
# Loss in epoch 606: [-224.89664]
# Loss in epoch 607: [-195.81708]
# Loss in epoch 608: [-225.9007]
# Loss in epoch 609: [-194.88416]
# Loss in epoch 610: [-223.58742]
# Loss in epoch 611: [-196.84059]
# Loss in epoch 612: [-225.80321]
# Loss in epoch 613: [-194.8651]
# Loss in epoch 614: [-224.07945]
# Loss in epoch 615: [-196.11752]
# Loss in epoch 616: [-224.88078]
# Loss in epoch 617: [-195.91011]
# Loss in epoch 618: [-225.51297]
# Loss in epoch 619: [-195.35236]
# Loss in epoch 620: [-223.56723]
# Loss in epoch 621: [-197.25148]
# Loss in epoch 622: [-225.01889]
# Loss in epoch 623: [-195.76282]
# Loss in epoch 624: [-225.70215]
# Loss in epoch 625: [-195.11063]
# Loss in epoch 626: [-224.76279]
# Loss in epoch 627: [-195.65558]
# Loss in epoch 628: [-224.9248]
# Loss in epoch 629: [-195.56737]
# Loss in epoch 630: [-224.97055]
# Loss in epoch 631: [-195.42426]
# Loss in epoch 632: [-225.10217]
# Loss in epoch 633: [-195.54074]
# Loss in epoch 634: [-224.82106]
# Loss in epoch 635: [-195.22546]
# Loss in epoch 636: [-224.95927]
# Loss in epoch 637: [-195.38277]
# Loss in epoch 638: [-223.46375]
# Loss in epoch 639: [-196.80322]
# Loss in epoch 640: [-225.21492]
# Loss in epoch 641: [-195.39601]
# Loss in epoch 642: [-224.34634]
# Loss in epoch 643: [-195.92807]
# Loss in epoch 644: [-224.74312]
# Loss in epoch 645: [-196.03764]
# Loss in epoch 646: [-225.40645]
# Loss in epoch 647: [-194.78778]
# Loss in epoch 648: [-224.27432]
# Loss in epoch 649: [-196.09453]
# Loss in epoch 650: [-225.19434]
# Loss in epoch 651: [-195.25761]
# Loss in epoch 652: [-224.70891]
# Loss in epoch 653: [-195.74237]
# Loss in epoch 654: [-224.22766]
# Loss in epoch 655: [-195.78741]
# Loss in epoch 656: [-224.452]
# Loss in epoch 657: [-195.56723]
# Loss in epoch 658: [-225.91957]
# Loss in epoch 659: [-194.25859]
# Loss in epoch 660: [-222.95055]
# Loss in epoch 661: [-196.5403]
# Loss in epoch 662: [-224.16142]
# Loss in epoch 663: [-195.88614]
# Loss in epoch 664: [-226.28813]
# Loss in epoch 665: [-194.32526]
# Loss in epoch 666: [-222.98305]
# Loss in epoch 667: [-196.6689]
# Loss in epoch 668: [-224.69624]
# Loss in epoch 669: [-195.52942]
# Loss in epoch 670: [-225.24847]
# Loss in epoch 671: [-194.92075]
# Loss in epoch 672: [-224.04131]
# Loss in epoch 673: [-195.90477]
# Loss in epoch 674: [-225.52858]
# Loss in epoch 675: [-194.39874]
# Loss in epoch 676: [-223.92012]
# Loss in epoch 677: [-195.74472]
# Loss in epoch 678: [-222.95792]
# Loss in epoch 679: [-196.67082]
# Loss in epoch 680: [-225.45712]
# Loss in epoch 681: [-194.70197]
# Loss in epoch 682: [-224.57687]
# Loss in epoch 683: [-195.03339]
# Loss in epoch 684: [-223.89748]
# Loss in epoch 685: [-195.78271]
# Loss in epoch 686: [-224.4893]
# Loss in epoch 687: [-195.76744]
# Loss in epoch 688: [-225.73886]
# Loss in epoch 689: [-194.32727]
# Loss in epoch 690: [-222.54771]
# Loss in epoch 691: [-197.33649]
# Loss in epoch 692: [-224.93169]
# Loss in epoch 693: [-195.25739]
# Loss in epoch 694: [-225.05579]
# Loss in epoch 695: [-195.11664]
# Loss in epoch 696: [-223.54387]
# Loss in epoch 697: [-195.84731]
# Loss in epoch 698: [-224.75235]
# Loss in epoch 699: [-195.01549]
# Loss in epoch 700: [-224.74196]
# Loss in epoch 701: [-195.20758]
# Loss in epoch 702: [-223.70857]
# Loss in epoch 703: [-196.23129]
# Loss in epoch 704: [-225.01439]
# Loss in epoch 705: [-195.11427]
# Loss in epoch 706: [-224.54974]
# Loss in epoch 707: [-195.00008]
# Loss in epoch 708: [-222.90799]
# Loss in epoch 709: [-196.79254]
# Loss in epoch 710: [-225.29797]
# Loss in epoch 711: [-194.836]
# Loss in epoch 712: [-225.35245]
# Loss in epoch 713: [-194.47549]
# Loss in epoch 714: [-222.68094]
# Loss in epoch 715: [-196.86641]
# Loss in epoch 716: [-224.01111]
# Loss in epoch 717: [-195.78615]
# Loss in epoch 718: [-225.2719]
# Loss in epoch 719: [-194.41899]
# Loss in epoch 720: [-223.65274]
# Loss in epoch 721: [-196.01727]
# Loss in epoch 722: [-224.2049]
# Loss in epoch 723: [-195.88925]
# Loss in epoch 724: [-224.20712]
# Loss in epoch 725: [-195.66505]
# Loss in epoch 726: [-224.40109]
# Loss in epoch 727: [-195.53821]
# Loss in epoch 728: [-225.56294]
# Loss in epoch 729: [-194.25378]
# Loss in epoch 730: [-222.36189]
# Loss in epoch 731: [-196.61302]
# Loss in epoch 732: [-224.03653]
# Loss in epoch 733: [-195.22066]
# Loss in epoch 734: [-224.81223]
# Loss in epoch 735: [-194.42485]
# Loss in epoch 736: [-224.03574]
# Loss in epoch 737: [-195.40758]
# Loss in epoch 738: [-224.71971]
# Loss in epoch 739: [-194.66144]
# Loss in epoch 740: [-223.53008]
# Loss in epoch 741: [-196.04239]
# Loss in epoch 742: [-224.89636]
# Loss in epoch 743: [-195.01004]
# Loss in epoch 744: [-223.90019]
# Loss in epoch 745: [-194.92883]
# Loss in epoch 746: [-224.59215]
# Loss in epoch 747: [-195.23602]
# Loss in epoch 748: [-223.93246]
# Loss in epoch 749: [-195.26019]
# Loss in epoch 750: [-225.21346]
# Loss in epoch 751: [-194.1559]
# Loss in epoch 752: [-223.39986]
# Loss in epoch 753: [-195.18898]
# Loss in epoch 754: [-224.18646]
# Loss in epoch 755: [-195.05641]
# Loss in epoch 756: [-223.79044]
# Loss in epoch 757: [-195.08337]
# Loss in epoch 758: [-223.46626]
# Loss in epoch 759: [-195.54536]
# Loss in epoch 760: [-224.69656]
# Loss in epoch 761: [-194.99338]
# Loss in epoch 762: [-225.04993]
# Loss in epoch 763: [-194.69429]
# Loss in epoch 764: [-223.373]
# Loss in epoch 765: [-196.04219]
# Loss in epoch 766: [-224.9444]
# Loss in epoch 767: [-194.48984]
# Loss in epoch 768: [-223.60687]
# Loss in epoch 769: [-195.7496]
# Loss in epoch 770: [-224.73882]
# Loss in epoch 771: [-194.96625]
# Loss in epoch 772: [-224.51582]
# Loss in epoch 773: [-195.44809]
# Loss in epoch 774: [-223.84132]
# Loss in epoch 775: [-195.84352]
# Loss in epoch 776: [-223.43906]
# Loss in epoch 777: [-195.64856]
# Loss in epoch 778: [-224.79874]
# Loss in epoch 779: [-194.61102]
# Loss in epoch 780: [-223.44734]
# Loss in epoch 781: [-195.65401]
# Loss in epoch 782: [-224.53012]
# Loss in epoch 783: [-195.21825]
# Loss in epoch 784: [-225.12628]
# Loss in epoch 785: [-194.34813]
# Loss in epoch 786: [-223.05525]
# Loss in epoch 787: [-195.50812]
# Loss in epoch 788: [-224.31549]
# Loss in epoch 789: [-194.61432]
# Loss in epoch 790: [-223.10992]
# Loss in epoch 791: [-195.77901]
# Loss in epoch 792: [-224.39413]
# Loss in epoch 793: [-194.923]
# Loss in epoch 794: [-223.9742]
# Loss in epoch 795: [-195.24379]
# Loss in epoch 796: [-224.37856]
# Loss in epoch 797: [-195.38129]
# Loss in epoch 798: [-224.05115]
# Loss in epoch 799: [-195.78542]
# Loss in epoch 800: [-224.27953]
# Loss in epoch 801: [-195.49353]
# Loss in epoch 802: [-224.94456]
# Loss in epoch 803: [-194.51387]
# Loss in epoch 804: [-222.00002]
# Loss in epoch 805: [-197.38995]
# Loss in epoch 806: [-224.33832]
# Loss in epoch 807: [-195.11932]
# Loss in epoch 808: [-226.08539]
# Loss in epoch 809: [-193.34097]
# Loss in epoch 810: [-221.08328]
# Loss in epoch 811: [-196.86949]
# Loss in epoch 812: [-222.88148]
# Loss in epoch 813: [-195.9491]
# Loss in epoch 814: [-224.45711]
# Loss in epoch 815: [-194.91588]
# Loss in epoch 816: [-223.67804]
# Loss in epoch 817: [-195.21844]
# Loss in epoch 818: [-224.21532]
# Loss in epoch 819: [-195.13129]
# Loss in epoch 820: [-224.14943]
# Loss in epoch 821: [-194.91318]
# Loss in epoch 822: [-224.07898]
# Loss in epoch 823: [-194.80487]
# Loss in epoch 824: [-223.0882]
# Loss in epoch 825: [-195.65323]
# Loss in epoch 826: [-224.33107]
# Loss in epoch 827: [-195.07832]
# Loss in epoch 828: [-224.7039]
# Loss in epoch 829: [-194.75484]
# Loss in epoch 830: [-222.82559]
# Loss in epoch 831: [-196.07671]
# Loss in epoch 832: [-224.27196]
# Loss in epoch 833: [-194.9747]
# Loss in epoch 834: [-224.19594]
# Loss in epoch 835: [-195.07204]
# Loss in epoch 836: [-224.12042]
# Loss in epoch 837: [-195.42613]
# Loss in epoch 838: [-223.88898]
# Loss in epoch 839: [-194.91434]
# Loss in epoch 840: [-224.81479]
# Loss in epoch 841: [-194.36945]
# Loss in epoch 842: [-223.31047]
# Loss in epoch 843: [-196.00291]
# Loss in epoch 844: [-224.17821]
# Loss in epoch 845: [-195.27161]
# Loss in epoch 846: [-223.82996]
# Loss in epoch 847: [-195.32762]
# Loss in epoch 848: [-223.48953]
# Loss in epoch 849: [-196.04968]
# Loss in epoch 850: [-225.10727]
# Loss in epoch 851: [-194.22195]
# Loss in epoch 852: [-222.95805]
# Loss in epoch 853: [-196.04625]
# Loss in epoch 854: [-224.99809]
# Loss in epoch 855: [-194.52715]
# Loss in epoch 856: [-225.15723]
# Loss in epoch 857: [-193.7984]
# Loss in epoch 858: [-221.8959]
# Loss in epoch 859: [-196.25742]
# Loss in epoch 860: [-223.99974]
# Loss in epoch 861: [-195.30133]
# Loss in epoch 862: [-225.29936]
# Loss in epoch 863: [-193.84868]
# Loss in epoch 864: [-222.52463]
# Loss in epoch 865: [-196.5323]
# Loss in epoch 866: [-223.59297]
# Loss in epoch 867: [-195.03801]
# Loss in epoch 868: [-225.46049]
# Loss in epoch 869: [-193.70911]
# Loss in epoch 870: [-221.8385]
# Loss in epoch 871: [-195.92175]
# Loss in epoch 872: [-224.16379]
# Loss in epoch 873: [-194.05063]
# Loss in epoch 874: [-223.4921]
# Loss in epoch 875: [-195.08258]
# Loss in epoch 876: [-223.85071]
# Loss in epoch 877: [-195.3544]
# Loss in epoch 878: [-224.05391]
# Loss in epoch 879: [-194.95862]
# Loss in epoch 880: [-224.14635]
# Loss in epoch 881: [-194.44594]
# Loss in epoch 882: [-223.40451]
# Loss in epoch 883: [-195.70477]
# Loss in epoch 884: [-224.69945]
# Loss in epoch 885: [-194.70039]
# Loss in epoch 886: [-224.03934]
# Loss in epoch 887: [-194.47696]
# Loss in epoch 888: [-223.11418]
# Loss in epoch 889: [-195.95731]
# Loss in epoch 890: [-224.31473]
# Loss in epoch 891: [-194.90576]
# Loss in epoch 892: [-224.16708]
# Loss in epoch 893: [-194.95424]
# Loss in epoch 894: [-223.70503]
# Loss in epoch 895: [-195.26045]
# Loss in epoch 896: [-224.04773]
# Loss in epoch 897: [-194.83649]
# Loss in epoch 898: [-224.13301]
# Loss in epoch 899: [-194.9705]
# Loss in epoch 900: [-224.50616]
# Loss in epoch 901: [-194.61922]
# Loss in epoch 902: [-222.4115]
# Loss in epoch 903: [-196.24632]
# Loss in epoch 904: [-223.76044]
# Loss in epoch 905: [-195.47459]
# Loss in epoch 906: [-224.03809]
# Loss in epoch 907: [-194.89967]
# Loss in epoch 908: [-223.69955]
# Loss in epoch 909: [-195.57954]
# Loss in epoch 910: [-224.52339]
# Loss in epoch 911: [-194.776]
# Loss in epoch 912: [-223.07777]
# Loss in epoch 913: [-195.5936]
# Loss in epoch 914: [-223.65445]
# Loss in epoch 915: [-195.57721]
# Loss in epoch 916: [-224.25266]
# Loss in epoch 917: [-194.67653]
# Loss in epoch 918: [-224.05943]
# Loss in epoch 919: [-194.95332]
# Loss in epoch 920: [-222.94934]
# Loss in epoch 921: [-195.55809]
# Loss in epoch 922: [-224.94456]
# Loss in epoch 923: [-194.15125]
# Loss in epoch 924: [-223.32666]
# Loss in epoch 925: [-195.21268]
# Loss in epoch 926: [-222.53656]
# Loss in epoch 927: [-195.71255]
# Loss in epoch 928: [-225.35426]
# Loss in epoch 929: [-193.76471]
# Loss in epoch 930: [-222.74684]
# Loss in epoch 931: [-195.28871]
# Loss in epoch 932: [-223.62054]
# Loss in epoch 933: [-194.51848]
# Loss in epoch 934: [-223.23042]
# Loss in epoch 935: [-195.6825]
# Loss in epoch 936: [-223.96848]
# Loss in epoch 937: [-195.23712]
# Loss in epoch 938: [-224.52071]
# Loss in epoch 939: [-194.57625]
# Loss in epoch 940: [-224.19]
# Loss in epoch 941: [-194.73082]
# Loss in epoch 942: [-222.41687]
# Loss in epoch 943: [-196.17067]
# Loss in epoch 944: [-224.89311]
# Loss in epoch 945: [-194.24727]
# Loss in epoch 946: [-224.15102]
# Loss in epoch 947: [-194.50488]
# Loss in epoch 948: [-223.03192]
# Loss in epoch 949: [-195.05107]
# Loss in epoch 950: [-224.60477]
# Loss in epoch 951: [-194.27322]
# Loss in epoch 952: [-223.32912]
# Loss in epoch 953: [-194.78033]
# Loss in epoch 954: [-223.76727]
# Loss in epoch 955: [-194.87215]
# Loss in epoch 956: [-224.13544]
# Loss in epoch 957: [-195.00148]
# Loss in epoch 958: [-223.23689]
# Loss in epoch 959: [-195.38847]
# Loss in epoch 960: [-223.70224]
# Loss in epoch 961: [-194.84723]
# Loss in epoch 962: [-223.46236]
# Loss in epoch 963: [-194.91797]
# Loss in epoch 964: [-223.27399]
# Loss in epoch 965: [-195.58035]
# Loss in epoch 966: [-223.85434]
# Loss in epoch 967: [-195.05602]
# Loss in epoch 968: [-223.72203]
# Loss in epoch 969: [-194.91028]
# Loss in epoch 970: [-224.54095]
# Loss in epoch 971: [-193.98946]
# Loss in epoch 972: [-222.24998]
# Loss in epoch 973: [-195.94739]
# Loss in epoch 974: [-223.4874]
# Loss in epoch 975: [-195.09775]
# Loss in epoch 976: [-224.53911]
# Loss in epoch 977: [-194.10161]
# Loss in epoch 978: [-223.8777]
# Loss in epoch 979: [-194.55623]
# Loss in epoch 980: [-223.19524]
# Loss in epoch 981: [-195.33511]
# Loss in epoch 982: [-223.91551]
# Loss in epoch 983: [-194.92453]
# Loss in epoch 984: [-223.88527]
# Loss in epoch 985: [-194.59335]
# Loss in epoch 986: [-224.76344]
# Loss in epoch 987: [-193.94907]
# Loss in epoch 988: [-222.28915]
# Loss in epoch 989: [-195.77684]
# Loss in epoch 990: [-223.33684]
# Loss in epoch 991: [-194.98628]
# Loss in epoch 992: [-224.49597]
# Loss in epoch 993: [-194.45534]
# Loss in epoch 994: [-223.09871]
# Loss in epoch 995: [-195.61418]
# Loss in epoch 996: [-223.87982]
# Loss in epoch 997: [-194.66156]
# Loss in epoch 998: [-224.89835]
# Loss in epoch 999: [-193.29333]
# [83]
# Optimal Action Squence:[[  2.14708710e+01   2.21544218e+00   0.00000000e+00   0.00000000e+00]
#  [  1.01063099e+01   2.30435085e+00   0.00000000e+00   0.00000000e+00]
#  [  4.89994764e+00   3.09371471e+00   0.00000000e+00   0.00000000e+00]
#  [  3.19478488e+00   4.50019503e+00   0.00000000e+00   0.00000000e+00]
#  [  2.79849100e+00   6.83518887e+00   0.00000000e+00   0.00000000e+00]
#  [  3.53631258e+00   8.05813599e+00   0.00000000e+00   0.00000000e+00]
#  [  3.72515512e+00   8.17008209e+00   0.00000000e+00   0.00000000e+00]
#  [  3.82853651e+00   8.38720322e+00   9.91166010e-03   0.00000000e+00]
#  [  3.88740611e+00   8.43820953e+00   4.21399847e-02   0.00000000e+00]
#  [  3.81189871e+00   8.34243393e+00   1.59930801e+00   0.00000000e+00]
#  [  3.74699950e+00   8.22519684e+00   5.43403625e+00   0.00000000e+00]
#  [  3.76037884e+00   8.27150345e+00   6.51490927e+00   0.00000000e+00]
#  [  3.74257660e+00   8.30310726e+00   6.51296902e+00   0.00000000e+00]
#  [  3.85918856e+00   8.42863560e+00   6.67264462e+00   0.00000000e+00]
#  [  3.78494740e+00   8.37619114e+00   6.61360884e+00   0.00000000e+00]
#  [  3.87155175e+00   8.51641655e+00   6.72613811e+00   0.00000000e+00]
#  [  3.87824893e+00   8.53553486e+00   6.78706884e+00   0.00000000e+00]
#  [  3.91841578e+00   8.55888844e+00   6.80515289e+00   0.00000000e+00]
#  [  3.79945183e+00   8.43170738e+00   6.65470028e+00   0.00000000e+00]
#  [  3.80061913e+00   8.28987408e+00   6.19970226e+00   3.29498723e-02]
#  [  3.55157995e+00   7.96734238e+00   5.97383642e+00   3.06877643e-02]
#  [  3.53626728e+00   7.98184490e+00   5.98960066e+00   2.99396366e-02]
#  [  3.65071344e+00   8.09756470e+00   6.01340580e+00   6.54118657e-02]
#  [  3.49601102e+00   8.01058102e+00   6.08405352e+00   5.32978550e-02]
#  [  3.69837403e+00   8.09902000e+00   6.13800716e+00   5.38050011e-02]
#  [  3.62476373e+00   8.10092258e+00   6.17073822e+00   1.18033871e-01]
#  [  3.77548146e+00   8.31406593e+00   6.42880487e+00   3.98334503e-01]
#  [  3.79690409e+00   8.29667282e+00   6.42680502e+00   3.26530963e-01]
#  [  3.74409318e+00   8.23903179e+00   6.39241838e+00   2.97063053e-01]
#  [  3.70693159e+00   8.21818733e+00   6.37628984e+00   2.51430929e-01]
#  [  3.75256491e+00   8.25520420e+00   6.37936258e+00   2.55131155e-01]
#  [  3.77786660e+00   8.36445141e+00   6.45747280e+00   4.27452445e-01]
#  [  3.68905234e+00   8.16898823e+00   6.26770735e+00   2.09482774e-01]
#  [  3.80736375e+00   8.30984879e+00   6.47762585e+00   4.26975191e-01]
#  [  3.71138692e+00   8.14899158e+00   6.30276823e+00   3.22140634e-01]
#  [  3.82997274e+00   8.33729553e+00   6.52123451e+00   4.73765850e-01]
#  [  3.68208361e+00   8.06450939e+00   6.25839043e+00   1.58538014e-01]
#  [  3.87326384e+00   8.30893707e+00   6.45938778e+00   4.18681413e-01]
#  [  3.73264718e+00   8.22159481e+00   6.40481615e+00   4.02810663e-01]
#  [  3.81206036e+00   8.16423988e+00   6.26030779e+00   1.83593750e-01]
#  [  3.70246696e+00   8.18807030e+00   6.37265205e+00   2.80062854e-01]
#  [  3.94048285e+00   8.33093929e+00   6.44958305e+00   3.81183416e-01]
#  [  3.65745497e+00   8.12009621e+00   6.23308754e+00   2.13227302e-01]
#  [  3.80566382e+00   8.25726032e+00   6.36599636e+00   3.71597886e-01]
#  [  3.80492377e+00   8.23960781e+00   6.36928177e+00   3.91836286e-01]
#  [  3.73431826e+00   8.12682724e+00   6.26872540e+00   2.71375835e-01]
#  [  3.73139334e+00   8.21102333e+00   6.35737753e+00   3.24624985e-01]
#  [  3.87682104e+00   8.35269070e+00   6.52286482e+00   4.86493766e-01]
#  [  3.69046164e+00   8.12178326e+00   6.20386076e+00   2.26942852e-01]
#  [  3.75169277e+00   8.16201305e+00   6.25954533e+00   2.58574545e-01]
#  [  3.82706451e+00   8.32376194e+00   6.42247629e+00   4.33377832e-01]
#  [  3.74330139e+00   8.13591099e+00   6.27739668e+00   2.09127963e-01]
#  [  3.74743867e+00   8.17940426e+00   6.34640074e+00   2.95965314e-01]
#  [  3.82012796e+00   8.27043438e+00   6.38734436e+00   3.90241921e-01]
#  [  3.75285530e+00   8.23281384e+00   6.30876637e+00   3.36369991e-01]
#  [  3.71498609e+00   8.17224312e+00   6.25102663e+00   2.65797853e-01]
#  [  3.74263859e+00   8.20948410e+00   6.27262306e+00   2.91789234e-01]
#  [  3.79717278e+00   8.27606583e+00   6.35644150e+00   3.93121779e-01]
#  [  3.74725366e+00   8.26578808e+00   6.38066006e+00   4.31818366e-01]
#  [  3.93045712e+00   8.35365772e+00   6.44199324e+00   4.32203829e-01]
#  [  3.57943559e+00   8.08553123e+00   6.17548800e+00   2.40674376e-01]
#  [  3.73339248e+00   8.20535755e+00   6.28695917e+00   2.46499106e-01]
#  [  3.76615238e+00   8.31027985e+00   6.44007730e+00   3.82846475e-01]
#  [  3.73439097e+00   8.17558384e+00   6.24783373e+00   1.64862186e-01]
#  [  3.75383830e+00   8.31703377e+00   6.44323826e+00   4.20471609e-01]
#  [  3.77744651e+00   8.29431343e+00   6.38778067e+00   4.29743409e-01]
#  [  3.69939995e+00   8.15946198e+00   6.24199247e+00   2.93089151e-01]
#  [  3.79355001e+00   8.34586620e+00   6.44512224e+00   4.96047795e-01]
#  [  3.69028497e+00   8.19217587e+00   6.27957582e+00   3.39273751e-01]
#  [  3.82675910e+00   8.36744308e+00   6.49574232e+00   4.45265234e-01]
#  [  3.62861419e+00   8.12061024e+00   6.20467043e+00   2.05262274e-01]
#  [  3.87873411e+00   8.44348431e+00   6.59281349e+00   5.70897758e-01]
#  [  3.67774773e+00   8.17115211e+00   6.30843163e+00   2.36140281e-01]
#  [  3.63971090e+00   8.05734921e+00   6.20067787e+00   7.13555887e-02]
#  [  3.80865121e+00   8.45632553e+00   6.66794395e+00   5.42096555e-01]
#  [  3.80393815e+00   8.23784256e+00   6.35180569e+00   2.70807385e-01]
#  [  3.59706521e+00   8.15680981e+00   6.32714367e+00   2.42886335e-01]
#  [  3.78570509e+00   8.30115223e+00   6.39960098e+00   3.38935137e-01]
#  [  3.74768877e+00   8.27232170e+00   6.35220814e+00   3.49268436e-01]
#  [  3.66380930e+00   8.18080616e+00   6.28694248e+00   2.93198615e-01]
#  [  3.93002987e+00   8.38522816e+00   6.44265795e+00   4.45277363e-01]
#  [  3.62819457e+00   8.17059040e+00   6.30714560e+00   3.11243474e-01]
#  [  3.73243141e+00   8.18665600e+00   6.21784687e+00   2.68294305e-01]
#  [  3.82214236e+00   8.28354740e+00   6.36886168e+00   4.54914898e-01]
#  [  3.77996993e+00   8.24975967e+00   6.38396454e+00   4.23997879e-01]
#  [  3.72113395e+00   8.14944077e+00   6.26010752e+00   3.23809445e-01]
#  [  3.74074173e+00   8.18519783e+00   6.29822016e+00   3.34285975e-01]
#  [  3.84076595e+00   8.39199829e+00   6.52446651e+00   5.59578300e-01]
#  [  3.71389842e+00   8.13727474e+00   6.22619438e+00   2.21276671e-01]
#  [  3.77518892e+00   8.26906490e+00   6.41295052e+00   3.73199135e-01]
#  [  3.73273683e+00   8.18044662e+00   6.30713558e+00   2.88010836e-01]
#  [  3.79621387e+00   8.28565788e+00   6.42497349e+00   3.73623371e-01]
#  [  3.72839451e+00   8.20144653e+00   6.29164982e+00   2.94019610e-01]
#  [  3.84036279e+00   8.31068897e+00   6.42088366e+00   3.66879672e-01]
#  [  3.66267109e+00   8.17467308e+00   6.30312347e+00   2.69397140e-01]
#  [  3.81248879e+00   8.34820175e+00   6.46186972e+00   4.26640153e-01]
#  [  3.77951145e+00   8.31939888e+00   6.41064787e+00   4.39651549e-01]
#  [  3.73179078e+00   8.24122810e+00   6.31063843e+00   3.41497004e-01]
#  [  3.74247146e+00   8.23460102e+00   6.31178761e+00   3.25548440e-01]
#  [  3.80402112e+00   8.37744331e+00   6.47373962e+00   5.61052978e-01]
#  [  3.70371103e+00   8.14585876e+00   6.19467545e+00   2.30088070e-01]
#  [  3.79945564e+00   8.35880470e+00   6.41683435e+00   5.04295051e-01]
#  [  3.73006678e+00   8.26306248e+00   6.31401825e+00   3.26047391e-01]
#  [  3.74696279e+00   8.30668449e+00   6.34046745e+00   3.54768723e-01]
#  [  3.79055858e+00   8.33900356e+00   6.36221027e+00   4.08870459e-01]
#  [  3.68932295e+00   8.21910954e+00   6.24128771e+00   3.21161181e-01]
#  [  3.76294184e+00   8.27975464e+00   6.30635595e+00   3.98409188e-01]
#  [  3.78153324e+00   8.34170055e+00   6.36685753e+00   5.16250253e-01]
#  [  3.73837209e+00   8.24954700e+00   6.29457474e+00   3.89944196e-01]
#  [  3.78570008e+00   8.24799347e+00   6.35726976e+00   4.04683292e-01]
#  [  3.80209279e+00   8.27630997e+00   6.36195612e+00   4.57655847e-01]
#  [  3.77068853e+00   8.25114441e+00   6.34048653e+00   3.74972969e-01]
#  [  3.80192089e+00   8.27867889e+00   6.36809301e+00   3.76296818e-01]
#  [  3.80757523e+00   8.31481838e+00   6.32964277e+00   4.28743452e-01]
#  [  3.77588320e+00   8.25227356e+00   6.29553795e+00   2.97601819e-01]
#  [  3.80255413e+00   8.34735012e+00   6.42083693e+00   4.32221591e-01]
#  [  3.74726486e+00   8.28545666e+00   6.29140902e+00   2.78038353e-01]
#  [  3.75092745e+00   8.30006123e+00   6.31303024e+00   3.68372232e-01]
#  [  3.81946230e+00   8.30998230e+00   6.31001806e+00   4.05540198e-01]
#  [  3.78992605e+00   8.28509617e+00   6.35683346e+00   2.89950371e-01]]
# Best Cost: -188.108642578
# Sorted Costs:[-188.10864258 -188.68028259 -188.95237732 -189.21003723 -189.5368042 ]
# MEAN: -188.897628784, STD:0.485567748547
# The last state:[[  49.63904572  105.88245392  209.64901733  270.03189087]
#  [  49.23571396  105.62194061  209.81399536  269.91607666]
#  [  50.63264465  104.32337189  209.96043396  269.92736816]
#  [  50.61523819  104.61148834  210.00765991  269.94210815]
#  [  49.39905548  105.74772644  209.55731201  270.21835327]
#  [  50.13273239  104.87900543  210.0761261   269.85269165]
#  [  48.67738342  106.02648926  209.52288818  270.51004028]
#  [  50.05628967  104.91697693  210.137146    269.775177  ]
#  [  50.28688049  104.8249588   210.08178711  270.00537109]
#  [  50.04629135  105.07762146  209.9331665   269.80633545]
#  [  49.76197815  104.96569061  209.80415344  270.28710938]
#  [  49.59680557  105.44953156  209.43510437  270.37741089]
#  [  49.51702881  105.50782776  210.02645874  270.06176758]
#  [  49.46219635  105.26295471  210.00767517  270.1444397 ]
#  [  50.20175171  104.96167755  209.68832397  270.28747559]
#  [  50.06946182  105.0513382   209.99534607  269.79589844]
#  [  50.26392365  104.88130188  210.44468689  269.54208374]
#  [  49.97319412  104.92068481  210.20744324  269.96020508]
#  [  49.86434174  105.44875336  209.3921814   270.28866577]
#  [  50.62019348  104.5963974   210.21084595  269.62762451]
#  [  50.44047546  104.81347656  210.0324707   269.98117065]
#  [  51.1201973   104.07553864  210.44718933  269.71017456]
#  [  50.34957504  104.87545013  209.85063171  270.11135864]
#  [  50.40451813  104.22563171  210.38717651  269.76486206]
#  [  50.72697067  103.99407959  210.45173645  269.85827637]
#  [  50.13415527  104.91082764  210.28964233  269.45379639]
#  [  49.885849    104.80387878  210.13949585  270.0357666 ]
#  [  48.91387939  105.51080322  209.54804993  270.45230103]
#  [  49.38528061  105.92591858  209.63696289  270.04205322]
#  [  49.06164551  106.23781586  209.18588257  270.25927734]
#  [  49.74272156  105.4703598   209.83537292  270.1703186 ]
#  [  49.77021027  105.10610199  209.83612061  270.35296631]
#  [  49.80630875  105.58233643  209.4425354   269.80462646]
#  [  49.48413467  105.69922638  209.68202209  270.54888916]
#  [  49.7594223   105.37414551  209.82589722  270.09689331]
#  [  50.26599884  104.78209686  209.86392212  270.21975708]
#  [  49.31963348  105.40722656  209.88639832  270.47915649]
#  [  49.96409225  104.94390106  210.24964905  269.96640015]
#  [  49.33453751  105.4537735   209.97245789  270.22488403]
#  [  49.67709732  105.46823883  209.58735657  270.26373291]
#  [  49.98245239  104.7359314   210.1269989   269.96585083]
#  [  49.83798981  105.07759094  209.87049866  270.15820312]
#  [  51.06137085  104.19714355  210.08047485  270.08618164]
#  [  50.270504    105.14907074  210.0247345   269.73190308]
#  [  49.58882904  105.64871979  209.82693481  270.08666992]
#  [  50.35948563  104.70482635  210.39331055  269.67266846]
#  [  49.7460556   105.19794464  209.70243835  270.47460938]
#  [  50.80136108  104.60923767  210.33036804  269.39770508]
#  [  49.64630508  105.34539032  209.73005676  270.25350952]
#  [  49.85109711  105.1523819   209.91429138  269.99923706]
#  [  48.90656662  105.85594177  209.96481323  269.96078491]
#  [  50.35871506  104.40172577  210.28259277  269.89767456]
#  [  49.35237122  105.60366821  209.46266174  270.39624023]
#  [  50.04770279  105.00396729  209.70718384  270.38293457]
#  [  50.43264389  104.73391724  210.28860474  269.70724487]
#  [  49.90965271  105.06413269  209.81755066  270.01477051]
#  [  49.75117493  105.13885498  209.94775391  269.86172485]
#  [  50.91817474  104.38733673  210.45387268  269.60083008]
#  [  49.71806335  105.15263367  209.98312378  270.08892822]
#  [  50.23565674  105.20572662  209.87942505  269.92703247]
#  [  49.97357559  105.40842438  209.69021606  269.93481445]
#  [  49.55743408  105.49931335  209.88897705  270.17111206]
#  [  49.93086624  105.00569153  210.20709229  270.06747437]
#  [  50.34408188  104.91891479  210.36254883  269.53213501]
#  [  50.01202774  104.95429993  209.88702393  270.16824341]
#  [  50.39852142  104.4586792   210.27770996  269.9753418 ]
#  [  50.44600296  104.33283997  210.04147339  270.28726196]
#  [  49.86863708  105.49264526  209.60037231  269.83068848]
#  [  49.70942307  105.4643631   209.67481995  270.1914978 ]
#  [  49.30437851  105.76480103  209.57298279  269.96038818]
#  [  49.94008255  104.85586548  209.98008728  270.26303101]
#  [  49.88486862  105.23453522  209.78237915  269.98812866]
#  [  50.19088745  105.14021301  209.94369507  270.39550781]
#  [  50.25058365  104.46484375  210.30075073  269.64807129]
#  [  50.32645798  104.54293823  210.36146545  270.0715332 ]
#  [  50.82149887  104.39089203  210.18493652  269.90908813]
#  [  49.60002899  105.36067963  209.95185852  269.80029297]
#  [  49.28848648  105.60808563  209.62489319  270.64727783]
#  [  50.19090271  104.57350159  210.24365234  269.43264771]
#  [  50.57379532  104.4417038   210.18737793  270.16156006]
#  [  49.75541687  105.22384644  209.62434387  270.13238525]
#  [  49.75317001  105.23790741  209.56860352  270.43829346]
#  [  50.04744339  105.17188263  210.06584167  269.66369629]
#  [  49.6448822   104.88683319  210.34161377  269.89544678]
#  [  50.01895142  104.85144043  210.33297729  269.56369019]
#  [  49.83654022  105.09913635  209.98257446  270.0446167 ]
#  [  49.70493317  104.93014526  210.05693054  270.2104187 ]
#  [  50.23890686  104.58715057  210.32469177  269.45819092]
#  [  50.53810883  104.98614502  210.01301575  269.7678833 ]
#  [  49.48845291  105.39229584  209.94631958  270.08441162]
#  [  50.26086426  104.64755249  210.34371948  269.70492554]
#  [  50.01129913  104.771492    210.447052    269.98059082]
#  [  50.57660675  104.42121887  210.54743958  269.76779175]
#  [  50.09415436  104.84775543  209.45661926  270.56115723]
#  [  49.65607452  105.50514221  209.824646    270.00152588]
#  [  50.05785751  105.21026611  209.75036621  269.90878296]
#  [  50.14578247  104.74533844  210.01132202  269.87435913]
#  [  49.84786987  104.8662262   210.0869751   269.96853638]
#  [  49.61072159  105.3514328   210.07325745  270.07452393]
#  [  49.46409607  105.56733704  209.22044373  270.54644775]]
# The last state:[  49.6448822   104.88683319  210.34161377  269.89544678]
# Rewards each time step:[[ -3.62996864e+01]
#  [ -2.96762810e+01]
#  [ -2.46946068e+01]
#  [ -2.02560730e+01]
#  [ -1.63788013e+01]
#  [ -1.30630283e+01]
#  [ -1.02902470e+01]
#  [ -8.01308250e+00]
#  [ -6.17261696e+00]
#  [ -4.70448875e+00]
#  [ -3.54648685e+00]
#  [ -2.64709163e+00]
#  [ -1.95928776e+00]
#  [ -1.43857169e+00]
#  [ -1.04989326e+00]
#  [ -7.60771215e-01]
#  [ -5.49332798e-01]
#  [ -3.96549225e-01]
#  [ -2.87816644e-01]
#  [ -2.12034613e-01]
#  [ -1.52983859e-01]
#  [ -1.05301671e-01]
#  [ -1.01265721e-01]
#  [ -7.95494169e-02]
#  [ -6.17301948e-02]
#  [ -6.27151504e-02]
#  [ -5.76702096e-02]
#  [ -5.35839088e-02]
#  [ -5.07793427e-02]
#  [ -5.61691299e-02]
#  [ -6.06521629e-02]
#  [ -5.85136451e-02]
#  [ -5.99964149e-02]
#  [ -5.26302345e-02]
#  [ -4.34600823e-02]
#  [ -4.12075035e-02]
#  [ -5.60848266e-02]
#  [ -4.71057892e-02]
#  [ -4.67700958e-02]
#  [ -5.85258529e-02]
#  [ -6.35475218e-02]
#  [ -8.53530914e-02]
#  [ -6.78688064e-02]
#  [ -6.56246245e-02]
#  [ -6.71306625e-02]
#  [ -7.00866729e-02]
#  [ -6.78459182e-02]
#  [ -8.29452574e-02]
#  [ -6.75785094e-02]
#  [ -6.69715852e-02]
#  [ -6.86420426e-02]
#  [ -7.78862014e-02]
#  [ -8.55522156e-02]
#  [ -8.65161866e-02]
#  [ -7.29492232e-02]
#  [ -6.74224868e-02]
#  [ -7.08889067e-02]
#  [ -7.73578584e-02]
#  [ -7.16747269e-02]
#  [ -9.04987305e-02]
#  [ -7.26219192e-02]
#  [ -6.37634248e-02]
#  [ -4.61837761e-02]
#  [ -5.66398613e-02]
#  [ -4.32353988e-02]
#  [ -3.56655121e-02]
#  [ -3.97338867e-02]
#  [ -4.04296890e-02]
#  [ -3.73798385e-02]
#  [ -2.81978622e-02]
#  [ -1.65733341e-02]
#  [ -2.27241516e-02]
#  [ -1.51191708e-02]
#  [ -2.96577476e-02]
#  [ -4.76295501e-02]
#  [ -4.41112518e-02]
#  [ -5.81504852e-02]
#  [ -4.92183715e-02]
#  [ -3.87672447e-02]
#  [ -4.03739922e-02]
#  [ -2.11921707e-02]
#  [ -2.22675335e-02]
#  [ -2.51144432e-02]
#  [ -2.30262764e-02]
#  [ -2.18151100e-02]
#  [ -3.13522331e-02]
#  [ -3.56647521e-02]
#  [ -3.04134376e-02]
#  [ -3.12911980e-02]
#  [ -2.48615257e-02]
#  [ -2.50652321e-02]
#  [ -2.87349708e-02]
#  [ -2.23930366e-02]
#  [ -3.62361893e-02]
#  [ -2.63031013e-02]
#  [ -2.78194435e-02]
#  [ -1.75418854e-02]
#  [ -1.92977916e-02]
#  [ -2.23464966e-02]
#  [ -3.91880050e-02]
#  [ -3.46073136e-02]
#  [ -5.31158447e-02]
#  [ -5.32341041e-02]
#  [ -5.96939102e-02]
#  [ -7.28637725e-02]
#  [ -7.55741149e-02]
#  [ -8.33885223e-02]
#  [ -1.01540759e-01]
#  [ -9.96917784e-02]
#  [ -8.63983184e-02]
#  [ -8.59859511e-02]
#  [ -7.68508911e-02]
#  [ -6.98715150e-02]
#  [ -8.52020234e-02]
#  [ -7.90603608e-02]
#  [ -8.18695128e-02]
#  [ -8.34434479e-02]
#  [ -9.26506072e-02]
#  [ -1.06267929e-01]
#  [ -9.14451629e-02]]
# Intermediate states:[[  55.7192688    78.00595093   70.96595764   78.7505188 ]
#  [  49.06144714   92.76852417   90.75434113  105.6529007 ]
#  [  47.95846939  100.27793121  109.73552704  130.08200073]
#  [  48.61411667  103.95310974  128.22686768  151.64517212]
#  [  49.6344223   104.52301025  146.86351013  170.1910553 ]
#  [  49.86682892  104.54859924  164.17593384  185.77836609]
#  [  49.89883804  104.64842224  178.92959595  198.6206665 ]
#  [  49.82587051  104.62409973  191.38426208  209.03494263]
#  [  49.69766998  104.61017609  201.57794189  217.38804626]
#  [  49.65135193  104.61797333  208.14155579  225.54423523]
#  [  49.67223358  104.67729187  209.42733765  235.75827026]
#  [  49.67869568  104.69749451  209.41397095  244.73892212]
#  [  49.70264053  104.66618347  209.43690491  251.60139465]
#  [  49.60878372  104.62923431  209.42097473  256.95529175]
#  [  49.59382629  104.57434082  209.41493225  260.91796875]
#  [  49.49300385  104.47153473  209.43782043  263.9899292 ]
#  [  49.39047623  104.36701965  209.41418457  266.33499146]
#  [  49.25284576  104.29019165  209.40068054  268.09078979]
#  [  49.24095917  104.22956848  209.41323853  269.23806763]
#  [  49.22849274  104.31824493  209.73635864  269.59655762]
#  [  49.46568298  104.47119904  209.89610291  269.63717651]
#  [  49.70648956  104.57843018  210.02156067  269.68362427]
#  [  49.82091522  104.67321777  210.21296692  269.70617676]
#  [  50.08435822  104.69039917  210.20710754  269.80557251]
#  [  50.13228607  104.81971741  210.23695374  269.93222046]
#  [  50.2514267   104.8600235   210.22979736  269.99404907]
#  [  50.213871    104.83370209  210.17919922  270.01733398]
#  [  50.15678024  104.84893799  210.12368774  270.10430908]
#  [  50.15536118  104.86741638  210.05639648  270.16345215]
#  [  50.19117737  104.86764526  209.99832153  270.23648071]
#  [  50.17956543  104.87646484  209.98622131  270.28964233]
#  [  50.14323425  104.80042267  210.00776672  270.23455811]
#  [  50.19753647  104.83896637  210.01916504  270.222229  ]
#  [  50.13080215  104.85094452  209.9591217   270.20556641]
#  [  50.16339111  104.92654419  209.92550659  270.1232605 ]
#  [  50.0757637   104.9245224   209.86868286  270.1295166 ]
#  [  50.14041519  105.04761505  209.81367493  270.18649292]
#  [  50.01064682  105.10457611  209.81347656  270.16931152]
#  [  50.02798843  105.10231018  209.7805481   270.11795044]
#  [  49.96504974  105.23704529  209.84158325  270.15484619]
#  [  50.0148468   105.22423553  209.80148315  270.19787598]
#  [  49.82414246  105.30792236  209.83560181  270.20535278]
#  [  49.92597961  105.31064606  209.86833191  270.16235352]
#  [  49.87453079  105.3241272   209.89854431  270.10519409]
#  [  49.82638931  105.35310364  209.90158081  270.0461731 ]
#  [  49.85124969  105.4212265   209.89175415  270.02264404]
#  [  49.87779999  105.39506531  209.8795166   270.04071045]
#  [  49.75759888  105.37541199  209.84597778  270.05761719]
#  [  49.82973862  105.40237427  209.9074707   270.01062012]
#  [  49.83705902  105.44750977  209.9407959   270.00006104]
#  [  49.76864243  105.40151978  209.96604919  269.98040771]
#  [  49.78739166  105.46444702  209.94329834  270.04510498]
#  [  49.80107117  105.48140717  209.8997345   270.07492065]
#  [  49.7413826   105.4782486   209.9152832   270.0435791 ]
#  [  49.75193787  105.44577026  209.96858215  269.99575806]
#  [  49.79983521  105.43940735  210.00801086  269.97335815]
#  [  49.81769943  105.42412567  210.05491638  269.95245361]
#  [  49.78013992  105.39839935  210.07487488  269.91955566]
#  [  49.79436874  105.33573151  210.05621338  269.88082886]
#  [  49.62468338  105.37497711  210.06796265  269.91326904]
#  [  49.8144455   105.32720947  210.07563782  269.86218262]
#  [  49.84082794  105.31858063  210.09008789  269.9302063 ]
#  [  49.83313751  105.23870087  210.05334473  269.99707031]
#  [  49.85758972  105.27013397  210.08177185  270.07208252]
#  [  49.86137772  105.17626953  210.050354    270.06710815]
#  [  49.84136581  105.13857269  210.0581665   269.99871826]
#  [  49.90039825  105.16162872  210.07531738  269.93920898]
#  [  49.86234283  105.09001923  210.07218933  269.89556885]
#  [  49.92944717  105.07633209  210.08155823  269.85464478]
#  [  49.85673141  105.02527618  210.0480957   269.93466187]
#  [  49.98578644  105.02825928  210.0657959   269.9425354 ]
#  [  49.858284    104.95817566  210.01455688  269.97085571]
#  [  49.93812561  104.96677399  209.98599243  270.04208374]
#  [  50.05202484  105.05023193  209.95726013  270.15158081]
#  [  49.99129486  104.89492798  209.86621094  270.22872925]
#  [  49.93831253  104.96963501  209.89163208  270.24069214]
#  [  50.09484863  104.91069794  209.85542297  270.2527771 ]
#  [  50.0549202   104.90221405  209.89859009  270.23806763]
#  [  50.05500793  104.88542938  209.95140076  270.16949463]
#  [  50.13896942  104.8780365   209.96702576  270.10983276]
#  [  49.95250702  104.93321228  210.02812195  270.06951904]
#  [  50.07720566  104.89542389  209.99746704  270.0383606 ]
#  [  50.09143829  104.94976044  210.07852173  269.96905518]
#  [  50.01524353  104.99123383  210.08866882  269.88241577]
#  [  49.98503494  105.01998901  210.04782104  269.86462402]
#  [  50.01516724  105.08720398  210.03897095  269.82781982]
#  [  50.024189    105.13124084  210.02958679  269.82836914]
#  [  49.93273544  105.06389618  210.00271606  269.82974243]
#  [  49.97271729  105.13145447  210.02493286  269.87075806]
#  [  49.9494133   105.1214447   209.9875946   269.93582153]
#  [  49.96972275  105.158638    209.97518921  269.96307373]
#  [  49.92554092  105.15020752  209.95272827  270.01541138]
#  [  49.9513855   105.15904999  209.98400879  270.00027466]
#  [  49.86397171  105.16969299  209.98883057  270.04547119]
#  [  49.95861053  105.13755035  209.97438049  270.05847168]
#  [  49.89870834  105.08506012  209.97773743  270.06958008]
#  [  49.87477493  105.0338974   210.00280762  270.01348877]
#  [  49.89974976  105.01853943  210.04452515  269.97033691]
#  [  49.91280365  105.0220871   210.06983948  269.95565796]
#  [  49.86365891  104.94398499  210.07080078  269.87127686]
#  [  49.91727066  105.00531769  210.11904907  269.86102295]
#  [  49.87246704  104.94303894  210.14808655  269.80142212]
#  [  49.89928436  104.91362     210.17819214  269.83294678]
#  [  49.90786743  104.86054993  210.21923828  269.85388184]
#  [  49.87242889  104.82430267  210.26234436  269.8369751 ]
#  [  49.939991    104.81050873  210.29756165  269.7913208 ]
#  [  49.93056488  104.81112671  210.32106018  269.7454834 ]
#  [  49.90301895  104.76832581  210.34114075  269.65438843]
#  [  49.9200058   104.77898407  210.33717346  269.64126587]
#  [  49.88881683  104.83740997  210.26977539  269.67956543]
#  [  49.84279251  104.87780762  210.23997498  269.65951538]
#  [  49.83046722  104.90775299  210.21266174  269.70593262]
#  [  49.78752136  104.93826294  210.19094849  269.76644897]
#  [  49.74105835  104.93510437  210.24830627  269.72012329]
#  [  49.72859955  104.96312714  210.26535034  269.78302002]
#  [  49.69008636  104.91980743  210.24862671  269.82003784]
#  [  49.70877838  104.88763428  210.30291748  269.87207031]
#  [  49.7228775   104.84786987  210.33892822  269.8416748 ]
#  [  49.66774368  104.87088013  210.38041687  269.77911377]
#  [  49.6448822   104.88683319  210.34161377  269.89544678]]
