# %% [markdown]
# # Fully Connected Network
#
# This is the second part of our whole deep learning planning structure.
#
# The Data in this experiments is generated from RDDL simulator [Github](https://github.com/ssanner/rddlsim), which is written by Prof.Scott Sanner at University of Toronto.
#
# In the section, we need a fully connected network to compute the reward of each (STATE,ACTION,STATE') tuple, that is (STATE,ACTION,STATE') -> Reward. Since this part is deterministic, fully connected network is capable to solve.
#
# Problem list:
# 1. Data normalization will highly impact the network performance, we need to normalize the input. However, the input of this section is an output of VAE, which is unnormalized. And since everything is working under tensorflow environment, we need to build normalizer inside tensorflow graph.
# 2. For reward function R(s,a), in nondeterministic domain, R(s,a) is stochastic. We need a deterministic function. Therefore, we rewrite the reward function as R(s,a,s'). This requires us to concate s,a,s' as single input matrix(also under tensorflow).

# %% [markdown]
# ### Import Packages
# We do note provide pip installation commands, please search this package and install it through pip install. Please upgrade your pip before installing, since old pip would cause errors.

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import tensorflow as tf
import numpy as np
from sklearn.metrics import confusion_matrix
import time
from datetime import timedelta
import math
import os
import pandas as pd
#Functional coding
import functools
from functools import partial
import re

# %% [markdown]
# ### Load Data
# We load data from csv files. The following code shows how to load data through pandas and numpy. Result of this progress can be feed into tensorflow with "feed_dict" argument.

# %%
#Data Path..
Datapath="DATA/Navigation/Navigation_Data.txt"
Labelpath="DATA/Navigation/Navigation_Label.txt"
Rewardpath="DATA/Navigation/Navigation_Reward.txt"

# %%
#Given local path, find full path
def PathFinder(path):
    #python 2
    #script_dir = os.path.dirname('__file__')
    #fullpath = os.path.join(script_dir,path)
    #python 3
    fullpath=os.path.abspath(path)
    print(fullpath)
    return fullpath

#Read Data for Deep Learning
def ReadData(path):
    fullpath=PathFinder(path)
    return pd.read_csv(fullpath, sep=',', header=0)

#Won't use this one to normalize
#Input Normalization
def Normalize(features, mean = [], std = []):
    if mean == []:
        mean = np.mean(features, axis = 0)
        std = np.std(features, axis = 0)
#     print std
#     print std[:,None]
    new_feature = (features.T - mean[:,None]).T
    new_feature = (new_feature.T / std[:,None]).T
    new_feature[np.isnan(new_feature)]=0
#     print new_feature
    return new_feature, mean, std

# %%
x_pd = ReadData(Datapath)
r_pd = ReadData(Rewardpath)
# Out:
# /home/wuga/Documents/Notebook/VAE-PLANNING/DATA/Navigation/Navigation_Data.txt
# /home/wuga/Documents/Notebook/VAE-PLANNING/DATA/Navigation/Navigation_Reward.txt

# %%
#Get Numpy Arrays
x_matrix=x_pd.as_matrix()
x_train = x_matrix[:100000]
x_valid = x_matrix[100000:]
r_matrix=r_pd.as_matrix()
r_train = r_matrix[:100000]
r_valid = r_matrix[100000:]

# %%
len(x_matrix)
# Out:
# 250000

# %%
data_size=len(x_matrix)
# Uppercase for constants
INPUT_S_A_SIZE = 4
OUTPUT_SIZE = 1

# %% [markdown]
# ### Support Functions
# The following functions allows us passthrough multiple functions without explicitly assign intermediate output variables.

# %%
def compose(f,g):
    return lambda x:g(f(x))
    
def composeAll(*args):
    """
    composeAll([f,g,h])(x): f(g(h(x)))
    """
    return partial(functools.reduce, compose)(*args)

# %% [markdown]
# ## Tensorflow
# ### Input tensor place holders

# %%
# Input features s,a
x = tf.placeholder(tf.float32,[None, INPUT_S_A_SIZE],name="Features_S_A")

# Input label
r = tf.placeholder(tf.float32, [None, OUTPUT_SIZE],name="Labels")

# %% [markdown]
# ### Variable Generating functions

# %%
#Weight constructing function
def weight_variable(shape):
    initial = tf.truncated_normal(shape,stddev=0.001)
    return tf.Variable(initial,name="Matrix")

#Bias constructing function
def bias_variable(shape):
    initial = tf.constant(0.,shape=shape)
    return tf.Variable(initial,name="Bias")

# %% [markdown]
# ### Fully Connected Layer Defination

# %%
class Dense():
    """Fully Connected Layer"""
    def __init__(self, scope="fully_connected_layer", output_dim =None, dropout=1.0, activation=tf.identity):
        assert output_dim, "Missing output dimension specification!"
        self.scope = scope
        self.output_dim = output_dim
        self.dropout = dropout
        self.activation = activation
        
    def __call__(self,x):
        with tf.name_scope(self.scope):
            while True:
                try:
                    return self.activation(tf.matmul(x,self.w)+self.b)
                except(AttributeError):
                    self.w = tf.nn.dropout(weight_variable([x.get_shape()[1].value, self.output_dim]),self.dropout)
                    self.b = bias_variable([self.output_dim])
    
    def set_parameters(self, weight, bias):
        self.w.assign(weight)
        self.b.assign(bias)
        
    def get_l2_loss(self):
        return tf.nn.l2_loss(self.w)

# %% [markdown]
# ### Full Deep Network Class
# The following class define a complete deep network, which include:
# 1. Network structure specification
# 2. Loss function specification
# 3. Prediction specification
# 4. Optimization method specification
# 5. Training function
# 6. Saving function(not tensorflow variable saving, but numpy weight dumping!)
# 7. Loading function(not tensorflow variable loading, but numpy weight assignment!)
# 8. Mini-Batch generation function

# %%
class DeepNet(object):
    
    def __init__(self, 
                 x, #Input Features for S,A
                 r, #Output Label for R
                 num_hidden_layers, #number of layers for both encoder and decoder
                 num_hidden_nodes, #number of nodes in each layer
                 activation, #nonlinear activation function
                 learning_rate=0.001, #Learning rate
                 dropout = 1,
                 batch_size=1000, 
                 l2_lambda = 1E-4): #Batch size        
#        self.mean = tf.Variable(tf.zeros([x.get_shape()[1]]),trainable=False,name="NORM_MEAN")
#        self.var = tf.Variable(tf.ones([x.get_shape()[1]]),trainable=False,name="NORM_VAR")
#        self.f = self._p_normalize(x)
        self.f = x
        self.r = r
        self.num_hidden_layers = num_hidden_layers
        self.num_hidden_nodes = num_hidden_nodes
        self.activation = activation
        self.learning_rate = learning_rate
        self.batch_size = batch_size
        self.l2_lambda = l2_lambda
        self.dropout = dropout
        self._p_create_dnn_graph()
        self._p_create_loss()
        self.sess = tf.InteractiveSession()
        self.sess.run(tf.global_variables_initializer())
        
    def _p_create_dnn_graph(self):

        layers = []
        for i in range(self.num_hidden_layers):
            layers.append(Dense("Layer"+str(i),self.num_hidden_nodes,self.dropout,self.activation))
        layers.append(Dense("Layer"+str(self.num_hidden_layers),self.r.get_shape()[1].value,self.dropout))
        self.r_pred = composeAll(layers)(self.f)
        self.layers = layers 
    
    def _p_normalize(self, unnormed):
        epsilon = 1e-3
        normed = tf.nn.batch_normalization(unnormed,self.mean,self.var,None,None,epsilon)
        return normed
        
    def _p_create_loss(self): #lambda for l2 regularization

        #L2 regularization loss
        l2_loss = tf.constant(0.0)
        for layer in self.layers:
            l2_loss += layer.get_l2_loss()

        #Mean Squared Error
        mse_r = tf.reduce_mean(tf.square(tf.sub(self.r,self.r_pred)), reduction_indices=1)

        #loss
        self.loss = tf.reduce_mean(mse_r)+self.l2_lambda*l2_loss
        self.optimizer = tf.train.RMSPropOptimizer(self.learning_rate).minimize(self.loss)   
        
    def update_normalization(self,x_matrix):
        tf_mean,tf_var = tf.nn.moments(x, axes = [0])
        feed_dict = {x:x_matrix}
        np_mean,np_var = self.sess.run([tf_mean,tf_var],feed_dict=feed_dict)
        print(np_mean)
        self.sess.run(self.mean.assign(np_mean))
        self.sess.run(self.var.assign(np_var))
        print(self.mean.eval())
        
    
    def train_model(self,train_s_a,train_r,test_s_a,test_r,epoch=100):
        
#        self.update_normalization(train_s_a)
        
        batches = self._p_get_batches(train_s_a,train_r,self.batch_size)
        
#        self.mean = tf.Variable(tf.zeros([x.get_shape()[1]]),trainable=False)
#        self.var = tf.Variable(tf.ones([x.get_shape()[1]]),trainable=False)
        
        summary_writer = tf.summary.FileWriter('experiment', graph=self.sess.graph)
        feed_test={x:test_s_a,r:test_r}
        feed_train={x:train_s_a, r:train_r}

        #Training
        for epoch in range(epoch):
            for step in range(len(batches)):
                feed_dict = {x: batches[step][0],r: batches[step][1]}
                training = self.sess.run([self.optimizer], feed_dict=feed_dict)
            train_loss = self.sess.run([self.loss],feed_dict=feed_dict)
            test_loss = self.sess.run([self.loss],feed_dict=feed_test)
            print('Train loss in epoch {0}: {1}, Test loss: {2}'.format(epoch, train_loss, test_loss)) 
            
    def predict_test(self, test_s_a):
        feed_dict={x:test_s_a}
        return self.sess.run([self.r_pred],feed_dict=feed_dict)
            
    def _p_get_batches(self,x_matrix,r_matrix,batch_size):
        remaining_size = len(x_matrix)
        batch_index=0
        batches = []
        while(remaining_size>0):
            batch = []
            if remaining_size<batch_size:
                batch.append(x_matrix[batch_index*batch_size:-1])
                batch.append(r_matrix[batch_index*batch_size:-1])
            else:
                batch.append(x_matrix[batch_index*batch_size:(batch_index+1)*batch_size]) 
                batch.append(r_matrix[batch_index*batch_size:(batch_index+1)*batch_size]) 
            batch_index+=1
            remaining_size-=batch_size
            batches.append(batch)
        return batches
    
    def _p_extract_weights(self):
        # a hashmap maps from layer name to weights and biases
        mp_layer_weights = {}

        #iteratively save values
        for dense in self.layers:
            values = {'weights':dense.w, 'biases':dense.b}
            mp_layer_weights[layer.scope] = values
        
        norms = {'mean':self.mean, 'var':self.var}
        mp_layer_weights['normalizations'] = norms

        return mp_layer_weights
    
    def save_weights(self,path):
        #extract weights from trained model
        layer_weights = self.sess.run(_p_extract_weights())
        print('Whole layer weights: {0}'.format(layer_weights))
        np.save(path,layer_weights)
    
    def load_weights(self,path):
        layer_weights = np.load(path)
        for dense in self.layers:
            print('Scope:{0}'.format(dense.scope))
            values = layer_weights.get(dense.scope)
            weights = values.get('weights')
            biases = values.get('biases')
            dense.set_parameters(weights,biases)
        print('Done!')
        
    def save_variables_for_rnn(self,path,prefix="RNN/FullNetworkCell/Reward/"):
        variables = tf.trainable_variables()
        var_dict = {}
        for v in variables:
            if "/read" in v.name:
                name = prefix+re.sub("/read", "", v.name)
                name = re.sub(":0", "", name)
                var_dict[name] = v
            else:
                name = prefix+v.name
                name = re.sub(":0", "", name)
                var_dict[name] = v
        for k,v in var_dict.items():
            print(k)
            print(v)
        saver = tf.train.Saver(var_dict)
        saver.save(self.sess, PathFinder(path))

# %%
#Instantiate a network
dnn_inst = DeepNet(x,r,2,32,tf.nn.sigmoid)

# %% [markdown]
# ### Tensorflow graph visualization function

# %%
from IPython.display import clear_output, Image, display, HTML

def strip_consts(graph_def, max_const_size=32):
    """Strip large constant values from graph_def."""
    strip_def = tf.GraphDef()
    for n0 in graph_def.node:
        n = strip_def.node.add() 
        n.MergeFrom(n0)
        if n.op == 'Const':
            tensor = n.attr['value'].tensor
            size = len(tensor.tensor_content)
            if size > max_const_size:
                tensor.tensor_content = "<stripped %d bytes>"%size
    return strip_def

def show_graph(graph_def, max_const_size=32):
    """Visualize TensorFlow graph."""
    if hasattr(graph_def, 'as_graph_def'):
        graph_def = graph_def.as_graph_def()
    strip_def = strip_consts(graph_def, max_const_size=max_const_size)
    code = """
        <script>
          function load() {{
            document.getElementById("{id}").pbtxt = {data};
          }}
        </script>
        <link rel="import" href="https://tensorboard.appspot.com/tf-graph-basic.build.html" onload=load()>
        <div style="height:600px">
          <tf-graph-basic id="{id}"></tf-graph-basic>
        </div>
    """.format(data=repr(str(strip_def)), id='graph'+str(np.random.rand()))

    iframe = """
        <iframe seamless style="width:960px;height:600px;border:0" srcdoc="{}"></iframe>
    """.format(code.replace('"', '&quot;'))
    display(HTML(iframe))

# %%
show_graph(tf.get_default_graph().as_graph_def())
# Out:
#         <iframe seamless style="width:960px;height:600px;border:0" srcdoc="
#         <script>
#           function load() {
#             document.getElementById(&quot;graph0.6224927980120325&quot;).pbtxt = 'node {\n  name: &quot;Features_S_A&quot;\n  op: &quot;Placeholder&quot;\n  attr {\n    key: &quot;dtype&quot;\n    value {\n      type: DT_FLOAT\n    }\n  }\n  attr {\n    key: &quot;shape&quot;\n    value {\n      shape {\n      }\n    }\n  }\n}\nnode {\n  name: &quot;Labels&quot;\n  op: &quot;Placeholder&quot;\n  attr {\n    key: &quot;dtype&quot;\n    value {\n      type: DT_FLOAT\n    }\n  }\n  attr {\n    key: &quot;shape&quot;\n    value {\n      shape {\n      }\n    }\n  }\n}\nnode {\n  name: &quot;Layer0/truncated_normal/shape&quot;\n  op: &quot;Const&quot;\n  attr {\n    key: &quot;dtype&quot;\n    value {\n      type: DT_INT32\n    }\n  }\n  attr {\n    key: &quot;value&quot;\n    value {\n      tensor {\n        dtype: DT_INT32\n        tensor_shape {\n          dim {\n            size: 2\n          }\n        }\n        tensor_content: &quot;\\004\\000\\000\\000 \\000\\000\\000&quot;\n      }\n    }\n  }\n}\nnode {\n  name: &quot;Layer0/truncated_normal/mean&quot;\n  op: &quot;Const&quot;\n  attr {\n    key: &quot;dtype&quot;\n    value {\n      type: DT_FLOAT\n    }\n  }\n  attr {\n    key: &quot;value&quot;\n    value {\n      tensor {\n        dtype: DT_FLOAT\n        tensor_shape {\n        }\n        float_val: 0.0\n      }\n    }\n  }\n}\nnode {\n  name: &quot;Layer0/truncated_normal/stddev&quot;\n  op: &quot;Const&quot;\n  attr {\n    key: &quot;dtype&quot;\n    value {\n      type: DT_FLOAT\n    }\n  }\n  attr {\n    key: &quot;value&quot;\n    value {\n      tensor {\n        dtype: DT_FLOAT\n        tensor_shape {\n        }\n        float_val: 0.0010000000474974513\n      }\n    }\n  }\n}\nnode {\n  name: &quot;Layer0/truncated_normal/TruncatedNormal&quot;\n  op: &quot;TruncatedNormal&quot;\n  input: &quot;Layer0/truncated_normal/shape&quot;\n  attr {\n    key: &quot;T&quot;\n    value {\n      type: DT_INT32\n    }\n  }\n  attr {\n    key: &quot;dtype&quot;\n    value {\n      type: DT_FLOAT\n    }\n  }\n  attr {\n    key: &quot;seed&quot;\n    value {\n      i: 0\n    }\n  }\n  attr {\n    key: &quot;seed2&quot;\n    value {\n      i: 0\n    }\n  }\n}\nnode {\n  name: &quot;Layer0/truncated_normal/mul&quot;\n  op: &quot;Mul&quot;\n  input: &quot;Layer0/truncated_normal/TruncatedNormal&quot;\n  input: &quot;Layer0/truncated_normal/stddev&quot;\n  attr {\n    key: &quot;T&quot;\n    value {\n      type: DT_FLOAT\n    }\n  }\n}\nnode {\n  name: &quot;Layer0/truncated_normal&quot;\n  op: &quot;Add&quot;\n  input: &quot;Layer0/truncated_normal/mul&quot;\n  input: &quot;Layer0/truncated_normal/mean&quot;\n  attr {\n    key: &quot;T&quot;\n    value {\n      type: DT_FLOAT\n    }\n  }\n}\nnode {\n  name: &quot;Layer0/Matrix&quot;\n  op: &quot;Variable&quot;\n  attr {\n    key: &quot;container&quot;\n    value {\n      s: &quot;&quot;\n    }\n  }\n  attr {\n    key: &quot;dtype&quot;\n    value {\n      type: DT_FLOAT\n    }\n  }\n  attr {\n    key: &quot;shape&quot;\n    value {\n      shape {\n        dim {\n          size: 4\n        }\n        dim {\n          size: 32\n        }\n      }\n    }\n  }\n  attr {\n    key: &quot;shared_name&quot;\n    value {\n      s: &quot;&quot;\n    }\n  }\n}\nnode {\n  name: &quot;Layer0/Matrix/Assign&quot;\n  op: &quot;Assign&quot;\n  input: &quot;Layer0/Matrix&quot;\n  input: &quot;Layer0/truncated_normal&quot;\n  attr {\n    key: &quot;T&quot;\n    value {\n      type: DT_FLOAT\n    }\n  }\n  attr {\n    key: &quot;_class&quot;\n    value {\n      list {\n        s: &quot;loc:@Layer0/Matrix&quot;\n      }\n    }\n  }\n  attr {\n    key: &quot;use_locking&quot;\n    value {\n      b: true\n    }\n  }\n  attr {\n    key: &quot;validate_shape&quot;\n    value {\n      b: true\n    }\n  }\n}\nnode {\n  name: &quot;Layer0/Matrix/read&quot;\n  op: &quot;Identity&quot;\n  input: &quot;Layer0/Matrix&quot;\n  attr {\n    key: &quot;T&quot;\n    value {\n      type: DT_FLOAT\n    }\n  }\n  attr { ...

# %% [markdown]
# ### Training

# %%
dnn_inst.train_model(x_train,r_train,x_valid,r_valid,1000)
# Out:
# Train loss in epoch 0: [43.309788], Test loss: [43.908665]
# Train loss in epoch 1: [32.520985], Test loss: [33.09491]
# Train loss in epoch 2: [23.168934], Test loss: [23.721668]
# Train loss in epoch 3: [18.434475], Test loss: [18.958078]
# Train loss in epoch 4: [17.049158], Test loss: [17.542454]
# Train loss in epoch 5: [16.715883], Test loss: [17.197832]
# Train loss in epoch 6: [16.547064], Test loss: [17.02577]
# Train loss in epoch 7: [16.468616], Test loss: [16.946672]
# Train loss in epoch 8: [16.433315], Test loss: [16.911661]
# Train loss in epoch 9: [16.417906], Test loss: [16.896872]
# Train loss in epoch 10: [16.411554], Test loss: [16.890984]
# Train loss in epoch 11: [16.409235], Test loss: [16.889029]
# Train loss in epoch 12: [16.408548], Test loss: [16.888611]
# Train loss in epoch 13: [16.408209], Test loss: [16.888363]
# Train loss in epoch 14: [16.407907], Test loss: [16.888119]
# Train loss in epoch 15: [16.407633], Test loss: [16.887888]
# Train loss in epoch 16: [16.407379], Test loss: [16.887672]
# Train loss in epoch 17: [16.407135], Test loss: [16.887466]
# Train loss in epoch 18: [16.406908], Test loss: [16.88727]
# Train loss in epoch 19: [16.406693], Test loss: [16.887085]
# Train loss in epoch 20: [16.406492], Test loss: [16.886904]
# Train loss in epoch 21: [16.406296], Test loss: [16.886726]
# Train loss in epoch 22: [16.406109], Test loss: [16.886559]
# Train loss in epoch 23: [16.405924], Test loss: [16.886398]
# Train loss in epoch 24: [16.405745], Test loss: [16.886242]
# Train loss in epoch 25: [16.405577], Test loss: [16.886093]
# Train loss in epoch 26: [16.405415], Test loss: [16.885948]
# Train loss in epoch 27: [16.405258], Test loss: [16.885803]
# Train loss in epoch 28: [16.405107], Test loss: [16.88566]
# Train loss in epoch 29: [16.404961], Test loss: [16.885523]
# Train loss in epoch 30: [16.404819], Test loss: [16.885389]
# Train loss in epoch 31: [16.40468], Test loss: [16.885258]
# Train loss in epoch 32: [16.404551], Test loss: [16.88513]
# Train loss in epoch 33: [16.404421], Test loss: [16.885006]
# Train loss in epoch 34: [16.404297], Test loss: [16.88489]
# Train loss in epoch 35: [16.404179], Test loss: [16.884775]
# Train loss in epoch 36: [16.404058], Test loss: [16.884659]
# Train loss in epoch 37: [16.403944], Test loss: [16.88455]
# Train loss in epoch 38: [16.403833], Test loss: [16.884447]
# Train loss in epoch 39: [16.403725], Test loss: [16.884344]
# Train loss in epoch 40: [16.403616], Test loss: [16.884243]
# Train loss in epoch 41: [16.403513], Test loss: [16.884146]
# Train loss in epoch 42: [16.403414], Test loss: [16.88405]
# Train loss in epoch 43: [16.403316], Test loss: [16.883959]
# Train loss in epoch 44: [16.403219], Test loss: [16.883871]
# Train loss in epoch 45: [16.40313], Test loss: [16.883783]
# Train loss in epoch 46: [16.403034], Test loss: [16.883696]
# Train loss in epoch 47: [16.402946], Test loss: [16.88361]
# Train loss in epoch 48: [16.402859], Test loss: [16.883526]
# Train loss in epoch 49: [16.402773], Test loss: [16.88344]
# Train loss in epoch 50: [16.402687], Test loss: [16.883356]
# Train loss in epoch 51: [16.402605], Test loss: [16.883276]
# Train loss in epoch 52: [16.402523], Test loss: [16.883196]
# Train loss in epoch 53: [16.402441], Test loss: [16.883116]
# Train loss in epoch 54: [16.402361], Test loss: [16.883041]
# Train loss in epoch 55: [16.402285], Test loss: [16.882967]
# Train loss in epoch 56: [16.402212], Test loss: [16.882896]
# Train loss in epoch 57: [16.402136], Test loss: [16.882826]
# Train loss in epoch 58: [16.402063], Test loss: [16.882755]
# Train loss in epoch 59: [16.401989], Test loss: [16.882689]
# Train loss in epoch 60: [16.40192], Test loss: [16.882622]
# Train loss in epoch 61: [16.401852], Test loss: [16.882555]
# Train loss in epoch 62: [16.401781], Test loss: [16.88249]
# Train loss in epoch 63: [16.401714], Test loss: [16.882427]
# Train loss in epoch 64: [16.401646], Test loss: [16.882362]
# Train loss in epoch 65: [16.401579], Test loss: [16.882299]
# Train loss in epoch 66: [16.401508], Test loss: [16.882236]
# Train loss in epoch 67: [16.401434], Test loss: [16.882164]
# Train loss in epoch 68: [16.40132], Test loss: [16.882065]
# Train loss in epoch 69: [16.401018], Test loss: [16.881788]
# Train loss in epoch 70: [16.39945], Test loss: [16.88035]
# Train loss in epoch 71: [16.373413], Test loss: [16.851643]
# Train loss in epoch 72: [16.187241], Test loss: [16.662533]
# Train loss in epoch 73: [15.923283], Test loss: [16.3909]
# Train loss in epoch 74: [15.640272], Test loss: [16.100498]
# Train loss in epoch 75: [15.355987], Test loss: [15.808701]
# Train loss in epoch 76: [15.100064], Test loss: [15.5455]
# Train loss in epoch 77: [14.880919], Test loss: [15.31982]
# Train loss in epoch 78: [14.696003], Test loss: [15.127843]
# Train loss in epoch 79: [14.538838], Test loss: [14.965409]
# Train loss in epoch 80: [14.401708], Test loss: [14.820985]
# Train loss in epoch 81: [14.277174], Test loss: [14.692156]
# Train loss in epoch 82: [14.159316], Test loss: [14.568571]
# Train loss in epoch 83: [14.044753], Test loss: [14.449438]
# Train loss in epoch 84: [13.930764], Test loss: [14.331404]
# Train loss in epoch 85: [13.814898], Test loss: [14.211169]
# Train loss in epoch 86: [13.696046], Test loss: [14.086784]
# Train loss in epoch 87: [13.573733], Test loss: [13.961606]
# Train loss in epoch 88: [13.447627], Test loss: [13.83004]
# Train loss in epoch 89: [13.317456], Test loss: [13.695437]
# Train loss in epoch 90: [13.182976], Test loss: [13.556875]
# Train loss in epoch 91: [13.043947], Test loss: [13.41191]
# Train loss in epoch 92: [12.900137], Test loss: [13.263844]
# Train loss in epoch 93: [12.751315], Test loss: [13.109127]
# Train loss in epoch 94: [12.597296], Test loss: [12.950432]
# Train loss in epoch 95: [12.437901], Test loss: [12.784846]
# Train loss in epoch 96: [12.272997], Test loss: [12.614442]
# Train loss in epoch 97: [12.102489], Test loss: [12.439]
# Train loss in epoch 98: [11.92628], Test loss: [12.255448]
# Train loss in epoch 99: [11.744308], Test loss: [12.068068]
# Train loss in epoch 100: [11.556528], Test loss: [11.873928]
# Train loss in epoch 101: [11.362896], Test loss: [11.674122]
# Train loss in epoch 102: [11.163397], Test loss: [11.467318]
# Train loss in epoch 103: [10.958028], Test loss: [11.254609]
# Train loss in epoch 104: [10.746804], Test loss: [11.036136]
# Train loss in epoch 105: [10.529758], Test loss: [10.813309]
# Train loss in epoch 106: [10.306959], Test loss: [10.583138]
# Train loss in epoch 107: [10.078484], Test loss: [10.345716]
# Train loss in epoch 108: [9.8444443], Test loss: [10.10396]
# Train loss in epoch 109: [9.6049862], Test loss: [9.8571491]
# Train loss in epoch 110: [9.3602695], Test loss: [9.6048784]
# Train loss in epoch 111: [9.1105051], Test loss: [9.3462734]
# Train loss in epoch 112: [8.8559256], Test loss: [9.082757]
# Train loss in epoch 113: [8.5968037], Test loss: [8.8157921]
# Train loss in epoch 114: [8.3334579], Test loss: [8.543745]
# Train loss in epoch 115: [8.0662365], Test loss: [8.26758]
# Train loss in epoch 116: [7.7955379], Test loss: [7.9880829]
# Train loss in epoch 117: [7.5217986], Test loss: [7.7056417]
# Train loss in epoch 118: [7.2455082], Test loss: [7.4209871]
# Train loss in epoch 119: [6.9671841], Test loss: [7.1336126]
# Train loss in epoch 120: [6.6874042], Test loss: [6.8441014]
# Train loss in epoch 121: [6.4067822], Test loss: [6.5552731]
# Train loss in epoch 122: [6.1259737], Test loss: [6.2651806]
# Train loss in epoch 123: [5.8456707], Test loss: [5.9765725]
# Train loss in epoch 124: [5.5665913], Test loss: [5.6887932]
# Train loss in epoch 125: [5.2894831], Test loss: [5.4032264]
# Train loss in epoch 126: [5.0150943], Test loss: [5.1205339]
# Train loss in epoch 127: [4.7441745], Test loss: [4.8417139]
# Train loss in epoch 128: [4.4774351], Test loss: [4.5670328]
# Train loss in epoch 129: [4.2155628], Test loss: [4.2975335]
# Train loss in epoch 130: [3.9591796], Test loss: [4.0343614]
# Train loss in epoch 131: [3.708853], Test loss: [3.7772079]
# Train loss in epoch 132: [3.4651132], Test loss: [3.5275249]
# Train loss in epoch 133: [3.2285466], Test loss: [3.285553]
# Train loss in epoch 134: [3.000011], Test loss: [3.0523512]
# Train loss in epoch 135: [2.7808652], Test loss: [2.8294494]
# Train loss in epoch 136: [2.5726533], Test loss: [2.6184804]
# Train loss in epoch 137: [2.3763435], Test loss: [2.4203999]
# Train loss in epoch 138: [2.1923025], Test loss: [2.234838]
# Train loss in epoch 139: [2.020746], Test loss: [2.0629396]
# Train loss in epoch 140: [1.8617642], Test loss: [1.9039847]
# Train loss in epoch 141: [1.7147506], Test loss: [1.7580949]
# Train loss in epoch 142: [1.5765687], Test loss: [1.6217989]
# Train loss in epoch 143: [1.4415259], Test loss: [1.489544]
# Train loss in epoch 144: [1.3082224], Test loss: [1.360052]
# Train loss in epoch 145: [1.1801049], Test loss: [1.2360358]
# Train loss in epoch 146: [1.0613388], Test loss: [1.1220599]
# Train loss in epoch 147: [0.95543832], Test loss: [1.0217173]
# Train loss in epoch 148: [0.86410904], Test loss: [0.93644464]
# Train loss in epoch 149: [0.78751624], Test loss: [0.86594033]
# Train loss in epoch 150: [0.72537231], Test loss: [0.8093968]
# Train loss in epoch 151: [0.6769101], Test loss: [0.76562679]
# Train loss in epoch 152: [0.6407268], Test loss: [0.73298365]
# Train loss in epoch 153: [0.6146099], Test loss: [0.70920628]
# Train loss in epoch 154: [0.59624785], Test loss: [0.69222522]
# Train loss in epoch 155: [0.58350003], Test loss: [0.6802637]
# Train loss in epoch 156: [0.57471287], Test loss: [0.67195511]
# Train loss in epoch 157: [0.56877929], Test loss: [0.66635424]
# Train loss in epoch 158: [0.56493253], Test loss: [0.66279095]
# Train loss in epoch 159: [0.56245548], Test loss: [0.66055548]
# Train loss in epoch 160: [0.56075853], Test loss: [0.65899581]
# Train loss in epoch 161: [0.55946851], Test loss: [0.65783709]
# Train loss in epoch 162: [0.55838954], Test loss: [0.65682757]
# Train loss in epoch 163: [0.55742061], Test loss: [0.65594983]
# Train loss in epoch 164: [0.55650735], Test loss: [0.65504879]
# Train loss in epoch 165: [0.55561572], Test loss: [0.65416819]
# Train loss in epoch 166: [0.55472279], Test loss: [0.65319884]
# Train loss in epoch 167: [0.55381489], Test loss: [0.65228367]
# Train loss in epoch 168: [0.55289209], Test loss: [0.65134239]
# Train loss in epoch 169: [0.55195576], Test loss: [0.65037113]
# Train loss in epoch 170: [0.55101049], Test loss: [0.649382]
# Train loss in epoch 171: [0.55006295], Test loss: [0.64831531]
# Train loss in epoch 172: [0.54912215], Test loss: [0.64731944]
# Train loss in epoch 173: [0.54819608], Test loss: [0.64631861]
# Train loss in epoch 174: [0.5472905], Test loss: [0.6453492]
# Train loss in epoch 175: [0.54640901], Test loss: [0.64438927]
# Train loss in epoch 176: [0.54555231], Test loss: [0.64342314]
# Train loss in epoch 177: [0.54471833], Test loss: [0.64244998]
# Train loss in epoch 178: [0.54390299], Test loss: [0.64141095]
# Train loss in epoch 179: [0.54310113], Test loss: [0.64042336]
# Train loss in epoch 180: [0.5423066], Test loss: [0.63942438]
# Train loss in epoch 181: [0.54151398], Test loss: [0.63830608]
# Train loss in epoch 182: [0.54071862], Test loss: [0.63716042]
# Train loss in epoch 183: [0.53991741], Test loss: [0.63600224]
# Train loss in epoch 184: [0.53910542], Test loss: [0.63467646]
# Train loss in epoch 185: [0.53827554], Test loss: [0.63332009]
# Train loss in epoch 186: [0.53742278], Test loss: [0.63188076]
# Train loss in epoch 187: [0.53654134], Test loss: [0.63026792]
# Train loss in epoch 188: [0.53562748], Test loss: [0.62853998]
# Train loss in epoch 189: [0.53467715], Test loss: [0.6267038]
# Train loss in epoch 190: [0.53368729], Test loss: [0.62472707]
# Train loss in epoch 191: [0.53265536], Test loss: [0.62259322]
# Train loss in epoch 192: [0.53158015], Test loss: [0.62030327]
# Train loss in epoch 193: [0.53046131], Test loss: [0.61787283]
# Train loss in epoch 194: [0.5292995], Test loss: [0.61533958]
# Train loss in epoch 195: [0.52809769], Test loss: [0.6126225]
# Train loss in epoch 196: [0.52686042], Test loss: [0.60983109]
# Train loss in epoch 197: [0.52559388], Test loss: [0.60690528]
# Train loss in epoch 198: [0.52430642], Test loss: [0.60393906]
# Train loss in epoch 199: [0.52300912], Test loss: [0.60092789]
# Train loss in epoch 200: [0.52171397], Test loss: [0.59789783]
# Train loss in epoch 201: [0.52043408], Test loss: [0.59488165]
# Train loss in epoch 202: [0.51918197], Test loss: [0.59191197]
# Train loss in epoch 203: [0.51796925], Test loss: [0.58902216]
# Train loss in epoch 204: [0.51680404], Test loss: [0.58623242]
# Train loss in epoch 205: [0.51569003], Test loss: [0.583556]
# Train loss in epoch 206: [0.5146243], Test loss: [0.58101541]
# Train loss in epoch 207: [0.51359218], Test loss: [0.57858092]
# Train loss in epoch 208: [0.51255625], Test loss: [0.57622147]
# Train loss in epoch 209: [0.51142073], Test loss: [0.57379758]
# Train loss in epoch 210: [0.50992686], Test loss: [0.57105029]
# Train loss in epoch 211: [0.50736314], Test loss: [0.56717157]
# Train loss in epoch 212: [0.50204521], Test loss: [0.56057435]
# Train loss in epoch 213: [0.49118409], Test loss: [0.54857862]
# Train loss in epoch 214: [0.4728106], Test loss: [0.52938426]
# Train loss in epoch 215: [0.44943279], Test loss: [0.50546747]
# Train loss in epoch 216: [0.42644635], Test loss: [0.48186788]
# Train loss in epoch 217: [0.40583578], Test loss: [0.46036154]
# Train loss in epoch 218: [0.38867816], Test loss: [0.44203031]
# Train loss in epoch 219: [0.37548986], Test loss: [0.42738667]
# Train loss in epoch 220: [0.36473459], Test loss: [0.41502357]
# Train loss in epoch 221: [0.35493743], Test loss: [0.40357479]
# Train loss in epoch 222: [0.34520349], Test loss: [0.39219153]
# Train loss in epoch 223: [0.33479646], Test loss: [0.38018033]
# Train loss in epoch 224: [0.32306278], Test loss: [0.36695847]
# Train loss in epoch 225: [0.30993837], Test loss: [0.35249788]
# Train loss in epoch 226: [0.29654235], Test loss: [0.33785835]
# Train loss in epoch 227: [0.28455821], Test loss: [0.32461753]
# Train loss in epoch 228: [0.27458307], Test loss: [0.3133384]
# Train loss in epoch 229: [0.2660369], Test loss: [0.30349532]
# Train loss in epoch 230: [0.25829184], Test loss: [0.29452267]
# Train loss in epoch 231: [0.25104046], Test loss: [0.28613871]
# Train loss in epoch 232: [0.24416448], Test loss: [0.27822852]
# Train loss in epoch 233: [0.23761605], Test loss: [0.2707414]
# Train loss in epoch 234: [0.23136961], Test loss: [0.2636461]
# Train loss in epoch 235: [0.22540511], Test loss: [0.25691158]
# Train loss in epoch 236: [0.21970426], Test loss: [0.25051045]
# Train loss in epoch 237: [0.21424864], Test loss: [0.24441409]
# Train loss in epoch 238: [0.20902112], Test loss: [0.23859937]
# Train loss in epoch 239: [0.20400527], Test loss: [0.23304094]
# Train loss in epoch 240: [0.19918607], Test loss: [0.22771703]
# Train loss in epoch 241: [0.19455007], Test loss: [0.22260918]
# Train loss in epoch 242: [0.19008492], Test loss: [0.21770525]
# Train loss in epoch 243: [0.18577985], Test loss: [0.21298811]
# Train loss in epoch 244: [0.18162513], Test loss: [0.20844416]
# Train loss in epoch 245: [0.17761213], Test loss: [0.20406592]
# Train loss in epoch 246: [0.17373325], Test loss: [0.19984117]
# Train loss in epoch 247: [0.16998149], Test loss: [0.19576199]
# Train loss in epoch 248: [0.16635062], Test loss: [0.19182044]
# Train loss in epoch 249: [0.16283502], Test loss: [0.18801016]
# Train loss in epoch 250: [0.15942983], Test loss: [0.18432443]
# Train loss in epoch 251: [0.15613019], Test loss: [0.18075708]
# Train loss in epoch 252: [0.15293221], Test loss: [0.1773047]
# Train loss in epoch 253: [0.1498318], Test loss: [0.17396076]
# Train loss in epoch 254: [0.14682563], Test loss: [0.17072228]
# Train loss in epoch 255: [0.14391054], Test loss: [0.1675857]
# Train loss in epoch 256: [0.14108366], Test loss: [0.16454646]
# Train loss in epoch 257: [0.1383424], Test loss: [0.16160133]
# Train loss in epoch 258: [0.13568415], Test loss: [0.15874824]
# Train loss in epoch 259: [0.13310689], Test loss: [0.1559848]
# Train loss in epoch 260: [0.13060853], Test loss: [0.15330815]
# Train loss in epoch 261: [0.12818731], Test loss: [0.1507155]
# Train loss in epoch 262: [0.12584142], Test loss: [0.1482053]
# Train loss in epoch 263: [0.12356947], Test loss: [0.14577787]
# Train loss in epoch 264: [0.12136994], Test loss: [0.14342879]
# Train loss in epoch 265: [0.11924171], Test loss: [0.14115794]
# Train loss in epoch 266: [0.11718345], Test loss: [0.13896281]
# Train loss in epoch 267: [0.11519407], Test loss: [0.13684185]
# Train loss in epoch 268: [0.11327271], Test loss: [0.13479529]
# Train loss in epoch 269: [0.11141841], Test loss: [0.13282187]
# Train loss in epoch 270: [0.10963009], Test loss: [0.13091968]
# Train loss in epoch 271: [0.107907], Test loss: [0.12908761]
# Train loss in epoch 272: [0.10624816], Test loss: [0.12732546]
# Train loss in epoch 273: [0.10465278], Test loss: [0.12563078]
# Train loss in epoch 274: [0.10311978], Test loss: [0.12400349]
# Train loss in epoch 275: [0.10164808], Test loss: [0.12244076]
# Train loss in epoch 276: [0.10023658], Test loss: [0.12094238]
# Train loss in epoch 277: [0.098883942], Test loss: [0.11950546]
# Train loss in epoch 278: [0.097588353], Test loss: [0.11812858]
# Train loss in epoch 279: [0.09634804], Test loss: [0.11681006]
# Train loss in epoch 280: [0.095160797], Test loss: [0.11554577]
# Train loss in epoch 281: [0.09402357], Test loss: [0.11433301]
# Train loss in epoch 282: [0.092933431], Test loss: [0.1131685]
# Train loss in epoch 283: [0.091886513], Test loss: [0.11204604]
# Train loss in epoch 284: [0.090878233], Test loss: [0.11096198]
# Train loss in epoch 285: [0.089904524], Test loss: [0.10991154]
# Train loss in epoch 286: [0.088959605], Test loss: [0.10888743]
# Train loss in epoch 287: [0.088038303], Test loss: [0.10788449]
# Train loss in epoch 288: [0.087135173], Test loss: [0.10689608]
# Train loss in epoch 289: [0.086245142], Test loss: [0.10591703]
# Train loss in epoch 290: [0.085363604], Test loss: [0.10494174]
# Train loss in epoch 291: [0.084486559], Test loss: [0.10396568]
# Train loss in epoch 292: [0.083610967], Test loss: [0.1029871]
# Train loss in epoch 293: [0.082734384], Test loss: [0.10200085]
# Train loss in epoch 294: [0.081855737], Test loss: [0.10100809]
# Train loss in epoch 295: [0.080974296], Test loss: [0.10000639]
# Train loss in epoch 296: [0.080090739], Test loss: [0.098996252]
# Train loss in epoch 297: [0.079206288], Test loss: [0.097980209]
# Train loss in epoch 298: [0.078322276], Test loss: [0.096958593]
# Train loss in epoch 299: [0.077440888], Test loss: [0.095933147]
# Train loss in epoch 300: [0.076565057], Test loss: [0.094907224]
# Train loss in epoch 301: [0.075697824], Test loss: [0.09388379]
# Train loss in epoch 302: [0.074842744], Test loss: [0.092864253]
# Train loss in epoch 303: [0.07400468], Test loss: [0.09185449]
# Train loss in epoch 304: [0.073188305], Test loss: [0.090859115]
# Train loss in epoch 305: [0.072391368], Test loss: [0.089876987]
# Train loss in epoch 306: [0.071628295], Test loss: [0.088911489]
# Train loss in epoch 307: [0.071122475], Test loss: [0.08819598]
# Train loss in epoch 308: [0.070573226], Test loss: [0.087438993]
# Train loss in epoch 309: [0.069769271], Test loss: [0.086404718]
# Train loss in epoch 310: [0.068939358], Test loss: [0.085351095]
# Train loss in epoch 311: [0.068242691], Test loss: [0.084444828]
# Train loss in epoch 312: [0.067565322], Test loss: [0.083558679]
# Train loss in epoch 313: [0.066846952], Test loss: [0.08262828]
# Train loss in epoch 314: [0.066117018], Test loss: [0.081686683]
# Train loss in epoch 315: [0.065405823], Test loss: [0.080767497]
# Train loss in epoch 316: [0.064727068], Test loss: [0.079887114]
# Train loss in epoch 317: [0.064081877], Test loss: [0.079046249]
# Train loss in epoch 318: [0.063467249], Test loss: [0.078242175]
# Train loss in epoch 319: [0.062879056], Test loss: [0.077470563]
# Train loss in epoch 320: [0.06231413], Test loss: [0.076728225]
# Train loss in epoch 321: [0.061769702], Test loss: [0.076011904]
# Train loss in epoch 322: [0.061243527], Test loss: [0.075319864]
# Train loss in epoch 323: [0.06073397], Test loss: [0.074649386]
# Train loss in epoch 324: [0.060239509], Test loss: [0.07399936]
# Train loss in epoch 325: [0.059759066], Test loss: [0.073368534]
# Train loss in epoch 326: [0.059291698], Test loss: [0.072755739]
# Train loss in epoch 327: [0.058836412], Test loss: [0.072159834]
# Train loss in epoch 328: [0.058392514], Test loss: [0.071579799]
# Train loss in epoch 329: [0.057959266], Test loss: [0.071014874]
# Train loss in epoch 330: [0.057536133], Test loss: [0.070464149]
# Train loss in epoch 331: [0.057122696], Test loss: [0.069926985]
# Train loss in epoch 332: [0.056718256], Test loss: [0.069402851]
# Train loss in epoch 333: [0.056322545], Test loss: [0.068890698]
# Train loss in epoch 334: [0.055935241], Test loss: [0.068390727]
# Train loss in epoch 335: [0.055556055], Test loss: [0.067901835]
# Train loss in epoch 336: [0.055184424], Test loss: [0.067423403]
# Train loss in epoch 337: [0.054820199], Test loss: [0.066955127]
# Train loss in epoch 338: [0.054463357], Test loss: [0.066496849]
# Train loss in epoch 339: [0.054113161], Test loss: [0.066047713]
# Train loss in epoch 340: [0.053769987], Test loss: [0.065607697]
# Train loss in epoch 341: [0.053433303], Test loss: [0.065176584]
# Train loss in epoch 342: [0.053102959], Test loss: [0.064753473]
# Train loss in epoch 343: [0.052778777], Test loss: [0.064338647]
# Train loss in epoch 344: [0.052460685], Test loss: [0.063931584]
# Train loss in epoch 345: [0.052148297], Test loss: [0.063531697]
# Train loss in epoch 346: [0.051841818], Test loss: [0.063139245]
# Train loss in epoch 347: [0.051540952], Test loss: [0.06275396]
# Train loss in epoch 348: [0.051245376], Test loss: [0.062375382]
# Train loss in epoch 349: [0.050955251], Test loss: [0.062003307]
# Train loss in epoch 350: [0.050670296], Test loss: [0.061637476]
# Train loss in epoch 351: [0.050390329], Test loss: [0.061277758]
# Train loss in epoch 352: [0.050115436], Test loss: [0.060924195]
# Train loss in epoch 353: [0.049845383], Test loss: [0.060576178]
# Train loss in epoch 354: [0.049579978], Test loss: [0.060233902]
# Train loss in epoch 355: [0.0493192], Test loss: [0.059897073]
# Train loss in epoch 356: [0.049062986], Test loss: [0.059565749]
# Train loss in epoch 357: [0.048811149], Test loss: [0.059239458]
# Train loss in epoch 358: [0.048563577], Test loss: [0.058918051]
# Train loss in epoch 359: [0.048320144], Test loss: [0.058601551]
# Train loss in epoch 360: [0.048080817], Test loss: [0.058289833]
# Train loss in epoch 361: [0.04784549], Test loss: [0.057982869]
# Train loss in epoch 362: [0.047614109], Test loss: [0.057680499]
# Train loss in epoch 363: [0.047386337], Test loss: [0.057382144]
# Train loss in epoch 364: [0.047162428], Test loss: [0.057088442]
# Train loss in epoch 365: [0.046941921], Test loss: [0.056798793]
# Train loss in epoch 366: [0.046725057], Test loss: [0.056513302]
# Train loss in epoch 367: [0.046511535], Test loss: [0.056231622]
# Train loss in epoch 368: [0.046301279], Test loss: [0.055953845]
# Train loss in epoch 369: [0.046094321], Test loss: [0.055679999]
# Train loss in epoch 370: [0.045890585], Test loss: [0.055409968]
# Train loss in epoch 371: [0.045689892], Test loss: [0.055143394]
# Train loss in epoch 372: [0.045492161], Test loss: [0.054880481]
# Train loss in epoch 373: [0.045297332], Test loss: [0.054620899]
# Train loss in epoch 374: [0.045105234], Test loss: [0.054364584]
# Train loss in epoch 375: [0.044916019], Test loss: [0.054111868]
# Train loss in epoch 376: [0.044729538], Test loss: [0.053862631]
# Train loss in epoch 377: [0.04454558], Test loss: [0.0536162]
# Train loss in epoch 378: [0.044364281], Test loss: [0.05337311]
# Train loss in epoch 379: [0.04418524], Test loss: [0.053132832]
# Train loss in epoch 380: [0.044008952], Test loss: [0.05289593]
# Train loss in epoch 381: [0.043834887], Test loss: [0.052661739]
# Train loss in epoch 382: [0.043663286], Test loss: [0.052430768]
# Train loss in epoch 383: [0.043493882], Test loss: [0.052202456]
# Train loss in epoch 384: [0.043326624], Test loss: [0.05197693]
# Train loss in epoch 385: [0.043161605], Test loss: [0.051754281]
# Train loss in epoch 386: [0.042998724], Test loss: [0.051534407]
# Train loss in epoch 387: [0.042837892], Test loss: [0.051317055]
# Train loss in epoch 388: [0.042679261], Test loss: [0.051102556]
# Train loss in epoch 389: [0.042522401], Test loss: [0.050890401]
# Train loss in epoch 390: [0.042367555], Test loss: [0.050680853]
# Train loss in epoch 391: [0.042214751], Test loss: [0.050473984]
# Train loss in epoch 392: [0.042063609], Test loss: [0.050269309]
# Train loss in epoch 393: [0.041914407], Test loss: [0.050067313]
# Train loss in epoch 394: [0.041767068], Test loss: [0.049867541]
# Train loss in epoch 395: [0.041621201], Test loss: [0.049670041]
# Train loss in epoch 396: [0.04147727], Test loss: [0.049475051]
# Train loss in epoch 397: [0.041334987], Test loss: [0.049282238]
# Train loss in epoch 398: [0.041194178], Test loss: [0.049091373]
# Train loss in epoch 399: [0.041055128], Test loss: [0.048902966]
# Train loss in epoch 400: [0.040917479], Test loss: [0.048716441]
# Train loss in epoch 401: [0.04078126], Test loss: [0.048531938]
# Train loss in epoch 402: [0.040646669], Test loss: [0.048349701]
# Train loss in epoch 403: [0.040513247], Test loss: [0.048169229]
# Train loss in epoch 404: [0.040381093], Test loss: [0.047990594]
# Train loss in epoch 405: [0.040250294], Test loss: [0.047813617]
# Train loss in epoch 406: [0.04012059], Test loss: [0.047638468]
# Train loss in epoch 407: [0.039991945], Test loss: [0.047464997]
# Train loss in epoch 408: [0.03986425], Test loss: [0.047292899]
# Train loss in epoch 409: [0.039737381], Test loss: [0.047122065]
# Train loss in epoch 410: [0.039611191], Test loss: [0.046952486]
# Train loss in epoch 411: [0.039485842], Test loss: [0.046784416]
# Train loss in epoch 412: [0.039360929], Test loss: [0.046617083]
# Train loss in epoch 413: [0.039236292], Test loss: [0.046450607]
# Train loss in epoch 414: [0.039111655], Test loss: [0.046284668]
# Train loss in epoch 415: [0.038987108], Test loss: [0.046119262]
# Train loss in epoch 416: [0.038862161], Test loss: [0.045953959]
# Train loss in epoch 417: [0.038736831], Test loss: [0.045788638]
# Train loss in epoch 418: [0.038610432], Test loss: [0.045622721]
# Train loss in epoch 419: [0.038482822], Test loss: [0.045455955]
# Train loss in epoch 420: [0.038353533], Test loss: [0.045288149]
# Train loss in epoch 421: [0.038221903], Test loss: [0.045118146]
# Train loss in epoch 422: [0.038087085], Test loss: [0.044945359]
# Train loss in epoch 423: [0.037948228], Test loss: [0.044768892]
# Train loss in epoch 424: [0.037803017], Test loss: [0.044586159]
# Train loss in epoch 425: [0.037648138], Test loss: [0.044393886]
# Train loss in epoch 426: [0.037477106], Test loss: [0.044185333]
# Train loss in epoch 427: [0.037274364], Test loss: [0.043944381]
# Train loss in epoch 428: [0.036991157], Test loss: [0.043620568]
# Train loss in epoch 429: [0.03639948], Test loss: [0.042971067]
# Train loss in epoch 430: [0.034551904], Test loss: [0.040821761]
# Train loss in epoch 431: [0.036809314], Test loss: [0.043311954]
# Train loss in epoch 432: [0.037304968], Test loss: [0.04381112]
# Train loss in epoch 433: [0.036864407], Test loss: [0.043324333]
# Train loss in epoch 434: [0.036208156], Test loss: [0.042617671]
# Train loss in epoch 435: [0.034082178], Test loss: [0.04025276]
# Train loss in epoch 436: [0.036143217], Test loss: [0.042465504]
# Train loss in epoch 437: [0.036722891], Test loss: [0.043057669]
# Train loss in epoch 438: [0.035986166], Test loss: [0.04226758]
# Train loss in epoch 439: [0.035554748], Test loss: [0.041429803]
# Train loss in epoch 440: [0.033800825], Test loss: [0.039859273]
# Train loss in epoch 441: [0.035565861], Test loss: [0.041713096]
# Train loss in epoch 442: [0.036154453], Test loss: [0.042323425]
# Train loss in epoch 443: [0.033902347], Test loss: [0.039842941]
# Train loss in epoch 444: [0.035688803], Test loss: [0.041757971]
# Train loss in epoch 445: [0.035856713], Test loss: [0.041924082]
# Train loss in epoch 446: [0.033374049], Test loss: [0.03923367]
# Train loss in epoch 447: [0.035320438], Test loss: [0.041292988]
# Train loss in epoch 448: [0.0354148], Test loss: [0.041386809]
# Train loss in epoch 449: [0.034556102], Test loss: [0.040446747]
# Train loss in epoch 450: [0.035746045], Test loss: [0.041702222]
# Train loss in epoch 451: [0.033335447], Test loss: [0.039082967]
# Train loss in epoch 452: [0.035067298], Test loss: [0.040906817]
# Train loss in epoch 453: [0.034821741], Test loss: [0.040646091]
# Train loss in epoch 454: [0.034734417], Test loss: [0.040517889]
# Train loss in epoch 455: [0.033019677], Test loss: [0.038619183]
# Train loss in epoch 456: [0.034819327], Test loss: [0.040545721]
# Train loss in epoch 457: [0.0344541], Test loss: [0.040163122]
# Train loss in epoch 458: [0.03462711], Test loss: [0.040309556]
# Train loss in epoch 459: [0.032604076], Test loss: [0.038113743]
# Train loss in epoch 460: [0.034476597], Test loss: [0.040092982]
# Train loss in epoch 461: [0.033459961], Test loss: [0.038991421]
# Train loss in epoch 462: [0.033798136], Test loss: [0.039033629]
# Train loss in epoch 463: [0.033188961], Test loss: [0.038473777]
# Train loss in epoch 464: [0.03640664], Test loss: [0.041551448]
# Train loss in epoch 465: [0.032335997], Test loss: [0.037738379]
# Train loss in epoch 466: [0.033887416], Test loss: [0.039352849]
# Train loss in epoch 467: [0.032074586], Test loss: [0.03737535]
# Train loss in epoch 468: [0.033992521], Test loss: [0.039410841]
# Train loss in epoch 469: [0.032079048], Test loss: [0.037332378]
# Train loss in epoch 470: [0.0339185], Test loss: [0.039281063]
# Train loss in epoch 471: [0.031838275], Test loss: [0.037025776]
# Train loss in epoch 472: [0.033756085], Test loss: [0.039064832]
# Train loss in epoch 473: [0.03162016], Test loss: [0.036720369]
# Train loss in epoch 474: [0.033537921], Test loss: [0.038797699]
# Train loss in epoch 475: [0.031706281], Test loss: [0.036804862]
# Train loss in epoch 476: [0.033582695], Test loss: [0.03879464]
# Train loss in epoch 477: [0.033165671], Test loss: [0.038006999]
# Train loss in epoch 478: [0.032638572], Test loss: [0.037541073]
# Train loss in epoch 479: [0.035383217], Test loss: [0.040164385]
# Train loss in epoch 480: [0.031289373], Test loss: [0.036251612]
# Train loss in epoch 481: [0.0330793], Test loss: [0.038185161]
# Train loss in epoch 482: [0.032979943], Test loss: [0.037683949]
# Train loss in epoch 483: [0.031134952], Test loss: [0.036038168]
# Train loss in epoch 484: [0.032920785], Test loss: [0.037951712]
# Train loss in epoch 485: [0.032618597], Test loss: [0.03761195]
# Train loss in epoch 486: [0.032877736], Test loss: [0.037869655]
# Train loss in epoch 487: [0.033254966], Test loss: [0.038241044]
# Train loss in epoch 488: [0.033099677], Test loss: [0.038052917]
# Train loss in epoch 489: [0.033140168], Test loss: [0.03807259]
# Train loss in epoch 490: [0.033072062], Test loss: [0.037979122]
# Train loss in epoch 491: [0.033062577], Test loss: [0.037947886]
# Train loss in epoch 492: [0.033020698], Test loss: [0.037883058]
# Train loss in epoch 493: [0.032996714], Test loss: [0.037837375]
# Train loss in epoch 494: [0.032963272], Test loss: [0.037781887]
# Train loss in epoch 495: [0.032935575], Test loss: [0.037732638]
# Train loss in epoch 496: [0.0329048], Test loss: [0.037680238]
# Train loss in epoch 497: [0.032876331], Test loss: [0.037630469]
# Train loss in epoch 498: [0.032846853], Test loss: [0.037579533]
# Train loss in epoch 499: [0.032817978], Test loss: [0.037529409]
# Train loss in epoch 500: [0.032789394], Test loss: [0.037479747]
# Train loss in epoch 501: [0.032760747], Test loss: [0.037429862]
# Train loss in epoch 502: [0.032732423], Test loss: [0.037380353]
# Train loss in epoch 503: [0.03270442], Test loss: [0.03733132]
# Train loss in epoch 504: [0.03267625], Test loss: [0.03728202]
# Train loss in epoch 505: [0.032648407], Test loss: [0.03723307]
# Train loss in epoch 506: [0.032620806], Test loss: [0.037184432]
# Train loss in epoch 507: [0.032593317], Test loss: [0.037135892]
# Train loss in epoch 508: [0.032565854], Test loss: [0.037087403]
# Train loss in epoch 509: [0.032538496], Test loss: [0.037038974]
# Train loss in epoch 510: [0.032511503], Test loss: [0.036990978]
# Train loss in epoch 511: [0.032484457], Test loss: [0.036942899]
# Train loss in epoch 512: [0.032457553], Test loss: [0.036894925]
# Train loss in epoch 513: [0.032430768], Test loss: [0.036847107]
# Train loss in epoch 514: [0.032404132], Test loss: [0.036799483]
# Train loss in epoch 515: [0.032377679], Test loss: [0.036752023]
# Train loss in epoch 516: [0.032351092], Test loss: [0.036704436]
# Train loss in epoch 517: [0.032324869], Test loss: [0.036657251]
# Train loss in epoch 518: [0.032298543], Test loss: [0.036609977]
# Train loss in epoch 519: [0.032272309], Test loss: [0.036562752]
# Train loss in epoch 520: [0.032246076], Test loss: [0.036515605]
# Train loss in epoch 521: [0.032220077], Test loss: [0.036468737]
# Train loss in epoch 522: [0.032194078], Test loss: [0.036421869]
# Train loss in epoch 523: [0.032168113], Test loss: [0.036375046]
# Train loss in epoch 524: [0.032142416], Test loss: [0.036328614]
# Train loss in epoch 525: [0.032116488], Test loss: [0.036281973]
# Train loss in epoch 526: [0.032090761], Test loss: [0.036235549]
# Train loss in epoch 527: [0.032065175], Test loss: [0.03618934]
# Train loss in epoch 528: [0.03203946], Test loss: [0.036143079]
# Train loss in epoch 529: [0.032013871], Test loss: [0.036097057]
# Train loss in epoch 530: [0.031988196], Test loss: [0.036050998]
# Train loss in epoch 531: [0.031962812], Test loss: [0.0360053]
# Train loss in epoch 532: [0.031937469], Test loss: [0.03595978]
# Train loss in epoch 533: [0.031912073], Test loss: [0.035914294]
# Train loss in epoch 534: [0.031886622], Test loss: [0.035868913]
# Train loss in epoch 535: [0.031861451], Test loss: [0.03582377]
# Train loss in epoch 536: [0.031835981], Test loss: [0.035778567]
# Train loss in epoch 537: [0.031810898], Test loss: [0.035733804]
# Train loss in epoch 538: [0.031785823], Test loss: [0.035689209]
# Train loss in epoch 539: [0.031760771], Test loss: [0.03564477]
# Train loss in epoch 540: [0.031735834], Test loss: [0.03560061]
# Train loss in epoch 541: [0.031710714], Test loss: [0.035556369]
# Train loss in epoch 542: [0.031685822], Test loss: [0.035512567]
# Train loss in epoch 543: [0.031661123], Test loss: [0.035469003]
# Train loss in epoch 544: [0.031636279], Test loss: [0.035425477]
# Train loss in epoch 545: [0.031611703], Test loss: [0.035382476]
# Train loss in epoch 546: [0.031586997], Test loss: [0.035339437]
# Train loss in epoch 547: [0.03156241], Test loss: [0.035296679]
# Train loss in epoch 548: [0.031537734], Test loss: [0.035254017]
# Train loss in epoch 549: [0.031513523], Test loss: [0.03521198]
# Train loss in epoch 550: [0.031489126], Test loss: [0.035169978]
# Train loss in epoch 551: [0.031464972], Test loss: [0.035128415]
# Train loss in epoch 552: [0.03144075], Test loss: [0.035086837]
# Train loss in epoch 553: [0.031416621], Test loss: [0.035045557]
# Train loss in epoch 554: [0.03139253], Test loss: [0.035004489]
# Train loss in epoch 555: [0.031368691], Test loss: [0.034963958]
# Train loss in epoch 556: [0.031344809], Test loss: [0.034923501]
# Train loss in epoch 557: [0.031321049], Test loss: [0.034883291]
# Train loss in epoch 558: [0.031297419], Test loss: [0.034843381]
# Train loss in epoch 559: [0.031273868], Test loss: [0.034803793]
# Train loss in epoch 560: [0.031250395], Test loss: [0.034764484]
# Train loss in epoch 561: [0.031227022], Test loss: [0.03472539]
# Train loss in epoch 562: [0.031203646], Test loss: [0.034686387]
# Train loss in epoch 563: [0.031180453], Test loss: [0.03464783]
# Train loss in epoch 564: [0.031157382], Test loss: [0.034609534]
# Train loss in epoch 565: [0.031134304], Test loss: [0.034571469]
# Train loss in epoch 566: [0.031111255], Test loss: [0.034533516]
# Train loss in epoch 567: [0.031088402], Test loss: [0.034495961]
# Train loss in epoch 568: [0.031065803], Test loss: [0.034458838]
# Train loss in epoch 569: [0.031043112], Test loss: [0.034421749]
# Train loss in epoch 570: [0.031020505], Test loss: [0.034384869]
# Train loss in epoch 571: [0.030998074], Test loss: [0.034348398]
# Train loss in epoch 572: [0.0309755], Test loss: [0.034311913]
# Train loss in epoch 573: [0.030953269], Test loss: [0.034275807]
# Train loss in epoch 574: [0.030930985], Test loss: [0.034239929]
# Train loss in epoch 575: [0.030908834], Test loss: [0.034204207]
# Train loss in epoch 576: [0.030886907], Test loss: [0.034168929]
# Train loss in epoch 577: [0.030864749], Test loss: [0.034133576]
# Train loss in epoch 578: [0.030842997], Test loss: [0.034098715]
# Train loss in epoch 579: [0.030821035], Test loss: [0.034063794]
# Train loss in epoch 580: [0.030799415], Test loss: [0.034029365]
# Train loss in epoch 581: [0.030777823], Test loss: [0.033995103]
# Train loss in epoch 582: [0.03075622], Test loss: [0.03396095]
# Train loss in epoch 583: [0.030734802], Test loss: [0.033927098]
# Train loss in epoch 584: [0.030713614], Test loss: [0.033893563]
# Train loss in epoch 585: [0.030692149], Test loss: [0.033859886]
# Train loss in epoch 586: [0.030670997], Test loss: [0.033826597]
# Train loss in epoch 587: [0.0306498], Test loss: [0.033793487]
# Train loss in epoch 588: [0.03062883], Test loss: [0.03376063]
# Train loss in epoch 589: [0.030607861], Test loss: [0.033727936]
# Train loss in epoch 590: [0.030586975], Test loss: [0.033695467]
# Train loss in epoch 591: [0.030566104], Test loss: [0.033663072]
# Train loss in epoch 592: [0.03054541], Test loss: [0.03363096]
# Train loss in epoch 593: [0.030524578], Test loss: [0.03359887]
# Train loss in epoch 594: [0.030504022], Test loss: [0.033567093]
# Train loss in epoch 595: [0.030483687], Test loss: [0.033535648]
# Train loss in epoch 596: [0.030463044], Test loss: [0.033504024]
# Train loss in epoch 597: [0.030442692], Test loss: [0.033472821]
# Train loss in epoch 598: [0.030422457], Test loss: [0.033441775]
# Train loss in epoch 599: [0.030402351], Test loss: [0.033410989]
# Train loss in epoch 600: [0.030382199], Test loss: [0.033380266]
# Train loss in epoch 601: [0.030361939], Test loss: [0.033349466]
# Train loss in epoch 602: [0.030342039], Test loss: [0.033319179]
# Train loss in epoch 603: [0.030322168], Test loss: [0.033289023]
# Train loss in epoch 604: [0.030302159], Test loss: [0.033258777]
# Train loss in epoch 605: [0.030282453], Test loss: [0.0332289]
# Train loss in epoch 606: [0.030262835], Test loss: [0.033199247]
# Train loss in epoch 607: [0.030242953], Test loss: [0.033169456]
# Train loss in epoch 608: [0.030223502], Test loss: [0.033140164]
# Train loss in epoch 609: [0.030203894], Test loss: [0.033110712]
# Train loss in epoch 610: [0.030184494], Test loss: [0.033081692]
# Train loss in epoch 611: [0.030165225], Test loss: [0.033052862]
# Train loss in epoch 612: [0.030145798], Test loss: [0.03302373]
# Train loss in epoch 613: [0.030126464], Test loss: [0.032994978]
# Train loss in epoch 614: [0.030107308], Test loss: [0.032966491]
# Train loss in epoch 615: [0.030088235], Test loss: [0.032938156]
# Train loss in epoch 616: [0.030069143], Test loss: [0.032909863]
# Train loss in epoch 617: [0.03005011], Test loss: [0.0328817]
# Train loss in epoch 618: [0.030031346], Test loss: [0.032853846]
# Train loss in epoch 619: [0.030012151], Test loss: [0.032825738]
# Train loss in epoch 620: [0.029993331], Test loss: [0.032798003]
# Train loss in epoch 621: [0.029974483], Test loss: [0.032770298]
# Train loss in epoch 622: [0.029955879], Test loss: [0.03274297]
# Train loss in epoch 623: [0.029937126], Test loss: [0.032715477]
# Train loss in epoch 624: [0.029918576], Test loss: [0.032688342]
# Train loss in epoch 625: [0.029899906], Test loss: [0.032661125]
# Train loss in epoch 626: [0.02988153], Test loss: [0.032634314]
# Train loss in epoch 627: [0.029862897], Test loss: [0.032607246]
# Train loss in epoch 628: [0.029844621], Test loss: [0.032580622]
# Train loss in epoch 629: [0.029826161], Test loss: [0.032553889]
# Train loss in epoch 630: [0.029808048], Test loss: [0.032527588]
# Train loss in epoch 631: [0.029789727], Test loss: [0.03250115]
# Train loss in epoch 632: [0.029771475], Test loss: [0.032474853]
# Train loss in epoch 633: [0.029753178], Test loss: [0.032448553]
# Train loss in epoch 634: [0.029735114], Test loss: [0.032422557]
# Train loss in epoch 635: [0.029717222], Test loss: [0.032396842]
# Train loss in epoch 636: [0.029699091], Test loss: [0.032370888]
# Train loss in epoch 637: [0.029681232], Test loss: [0.03234528]
# Train loss in epoch 638: [0.029663164], Test loss: [0.032319486]
# Train loss in epoch 639: [0.029645272], Test loss: [0.032293946]
# Train loss in epoch 640: [0.029627452], Test loss: [0.032268547]
# Train loss in epoch 641: [0.029609747], Test loss: [0.032243282]
# Train loss in epoch 642: [0.029592037], Test loss: [0.032218132]
# Train loss in epoch 643: [0.029574201], Test loss: [0.03219289]
# Train loss in epoch 644: [0.029556643], Test loss: [0.032168023]
# Train loss in epoch 645: [0.029538989], Test loss: [0.032143045]
# Train loss in epoch 646: [0.02952129], Test loss: [0.032118134]
# Train loss in epoch 647: [0.029503873], Test loss: [0.032093525]
# Train loss in epoch 648: [0.029486347], Test loss: [0.032068867]
# Train loss in epoch 649: [0.029469019], Test loss: [0.032044537]
# Train loss in epoch 650: [0.029451571], Test loss: [0.03202001]
# Train loss in epoch 651: [0.029433995], Test loss: [0.03199546]
# Train loss in epoch 652: [0.029416701], Test loss: [0.031971276]
# Train loss in epoch 653: [0.029399602], Test loss: [0.03194733]
# Train loss in epoch 654: [0.029381908], Test loss: [0.031922795]
# Train loss in epoch 655: [0.029364824], Test loss: [0.031898893]
# Train loss in epoch 656: [0.029347751], Test loss: [0.031875059]
# Train loss in epoch 657: [0.029330544], Test loss: [0.031851139]
# Train loss in epoch 658: [0.029313305], Test loss: [0.031827275]
# Train loss in epoch 659: [0.029296264], Test loss: [0.031803675]
# Train loss in epoch 660: [0.029279077], Test loss: [0.0317799]
# Train loss in epoch 661: [0.029262114], Test loss: [0.031756431]
# Train loss in epoch 662: [0.029245112], Test loss: [0.031732969]
# Train loss in epoch 663: [0.02922827], Test loss: [0.031709772]
# Train loss in epoch 664: [0.029211335], Test loss: [0.031686455]
# Train loss in epoch 665: [0.029194281], Test loss: [0.03166306]
# Train loss in epoch 666: [0.029177457], Test loss: [0.031640034]
# Train loss in epoch 667: [0.029160578], Test loss: [0.031616934]
# Train loss in epoch 668: [0.029143903], Test loss: [0.031594027]
# Train loss in epoch 669: [0.029126994], Test loss: [0.031570956]
# Train loss in epoch 670: [0.02911016], Test loss: [0.031548105]
# Train loss in epoch 671: [0.029093612], Test loss: [0.031525478]
# Train loss in epoch 672: [0.029076856], Test loss: [0.031502649]
# Train loss in epoch 673: [0.029060278], Test loss: [0.031480063]
# Train loss in epoch 674: [0.029043652], Test loss: [0.031457495]
# Train loss in epoch 675: [0.029026922], Test loss: [0.031434827]
# Train loss in epoch 676: [0.029010333], Test loss: [0.031412438]
# Train loss in epoch 677: [0.028993756], Test loss: [0.031389985]
# Train loss in epoch 678: [0.028977295], Test loss: [0.031367693]
# Train loss in epoch 679: [0.028960798], Test loss: [0.03134542]
# Train loss in epoch 680: [0.028944485], Test loss: [0.031323373]
# Train loss in epoch 681: [0.02892801], Test loss: [0.03130123]
# Train loss in epoch 682: [0.028911557], Test loss: [0.031279121]
# Train loss in epoch 683: [0.028895009], Test loss: [0.031256992]
# Train loss in epoch 684: [0.028878774], Test loss: [0.031235157]
# Train loss in epoch 685: [0.02886243], Test loss: [0.031213257]
# Train loss in epoch 686: [0.028846191], Test loss: [0.031191472]
# Train loss in epoch 687: [0.028829809], Test loss: [0.031169647]
# Train loss in epoch 688: [0.028813543], Test loss: [0.031147931]
# Train loss in epoch 689: [0.028797325], Test loss: [0.031126305]
# Train loss in epoch 690: [0.028781101], Test loss: [0.031104725]
# Train loss in epoch 691: [0.028764885], Test loss: [0.03108317]
# Train loss in epoch 692: [0.028748807], Test loss: [0.031061774]
# Train loss in epoch 693: [0.028732639], Test loss: [0.031040316]
# Train loss in epoch 694: [0.028716534], Test loss: [0.031018984]
# Train loss in epoch 695: [0.02870032], Test loss: [0.030997559]
# Train loss in epoch 696: [0.028684203], Test loss: [0.030976247]
# Train loss in epoch 697: [0.028668256], Test loss: [0.030955117]
# Train loss in epoch 698: [0.028652156], Test loss: [0.030933926]
# Train loss in epoch 699: [0.028636198], Test loss: [0.030912865]
# Train loss in epoch 700: [0.028620273], Test loss: [0.030891839]
# Train loss in epoch 701: [0.028604232], Test loss: [0.030870771]
# Train loss in epoch 702: [0.028588399], Test loss: [0.030849965]
# Train loss in epoch 703: [0.028572403], Test loss: [0.030828958]
# Train loss in epoch 704: [0.028556684], Test loss: [0.030808281]
# Train loss in epoch 705: [0.028540682], Test loss: [0.030787393]
# Train loss in epoch 706: [0.028524991], Test loss: [0.030766783]
# Train loss in epoch 707: [0.028509099], Test loss: [0.030746013]
# Train loss in epoch 708: [0.028493306], Test loss: [0.030725434]
# Train loss in epoch 709: [0.028477445], Test loss: [0.030704752]
# Train loss in epoch 710: [0.028461695], Test loss: [0.03068424]
# Train loss in epoch 711: [0.028445926], Test loss: [0.030663697]
# Train loss in epoch 712: [0.028430134], Test loss: [0.030643154]
# Train loss in epoch 713: [0.028414585], Test loss: [0.030622918]
# Train loss in epoch 714: [0.028398849], Test loss: [0.030602477]
# Train loss in epoch 715: [0.028383123], Test loss: [0.030582111]
# Train loss in epoch 716: [0.028367504], Test loss: [0.030561883]
# Train loss in epoch 717: [0.028351888], Test loss: [0.030541725]
# Train loss in epoch 718: [0.028336307], Test loss: [0.030521546]
# Train loss in epoch 719: [0.028320879], Test loss: [0.030501574]
# Train loss in epoch 720: [0.028305195], Test loss: [0.030481376]
# Train loss in epoch 721: [0.02828975], Test loss: [0.030461494]
# Train loss in epoch 722: [0.028274225], Test loss: [0.030441446]
# Train loss in epoch 723: [0.028258856], Test loss: [0.030421667]
# Train loss in epoch 724: [0.028243344], Test loss: [0.030401733]
# Train loss in epoch 725: [0.028227877], Test loss: [0.030381925]
# Train loss in epoch 726: [0.028212432], Test loss: [0.030362075]
# Train loss in epoch 727: [0.028196959], Test loss: [0.030342311]
# Train loss in epoch 728: [0.028181616], Test loss: [0.03032269]
# Train loss in epoch 729: [0.028166369], Test loss: [0.030303176]
# Train loss in epoch 730: [0.028151004], Test loss: [0.030283486]
# Train loss in epoch 731: [0.028135762], Test loss: [0.030264031]
# Train loss in epoch 732: [0.028120417], Test loss: [0.030244492]
# Train loss in epoch 733: [0.028105095], Test loss: [0.030224977]
# Train loss in epoch 734: [0.028089885], Test loss: [0.030205578]
# Train loss in epoch 735: [0.028074736], Test loss: [0.030186277]
# Train loss in epoch 736: [0.028059591], Test loss: [0.030167039]
# Train loss in epoch 737: [0.02804435], Test loss: [0.03014769]
# Train loss in epoch 738: [0.028029243], Test loss: [0.030128498]
# Train loss in epoch 739: [0.028014015], Test loss: [0.030109216]
# Train loss in epoch 740: [0.027998907], Test loss: [0.030090103]
# Train loss in epoch 741: [0.027983908], Test loss: [0.030071104]
# Train loss in epoch 742: [0.027968761], Test loss: [0.030051928]
# Train loss in epoch 743: [0.027953662], Test loss: [0.030032914]
# Train loss in epoch 744: [0.027938608], Test loss: [0.030013923]
# Train loss in epoch 745: [0.02792369], Test loss: [0.02999506]
# Train loss in epoch 746: [0.027908709], Test loss: [0.029976204]
# Train loss in epoch 747: [0.027893543], Test loss: [0.029957188]
# Train loss in epoch 748: [0.027878631], Test loss: [0.029938448]
# Train loss in epoch 749: [0.027863652], Test loss: [0.02991965]
# Train loss in epoch 750: [0.027848903], Test loss: [0.029901098]
# Train loss in epoch 751: [0.027834088], Test loss: [0.029882474]
# Train loss in epoch 752: [0.027819144], Test loss: [0.029863801]
# Train loss in epoch 753: [0.027804397], Test loss: [0.029845282]
# Train loss in epoch 754: [0.027789393], Test loss: [0.029826589]
# Train loss in epoch 755: [0.027774666], Test loss: [0.02980816]
# Train loss in epoch 756: [0.027759943], Test loss: [0.029789776]
# Train loss in epoch 757: [0.02774518], Test loss: [0.02977138]
# Train loss in epoch 758: [0.027730379], Test loss: [0.029752962]
# Train loss in epoch 759: [0.027715618], Test loss: [0.029734565]
# Train loss in epoch 760: [0.027700998], Test loss: [0.029716294]
# Train loss in epoch 761: [0.027686428], Test loss: [0.029698154]
# Train loss in epoch 762: [0.027671827], Test loss: [0.029680029]
# Train loss in epoch 763: [0.027657129], Test loss: [0.029661782]
# Train loss in epoch 764: [0.027642412], Test loss: [0.029643569]
# Train loss in epoch 765: [0.027627844], Test loss: [0.029625501]
# Train loss in epoch 766: [0.02761331], Test loss: [0.029607497]
# Train loss in epoch 767: [0.027598903], Test loss: [0.029589633]
# Train loss in epoch 768: [0.027584398], Test loss: [0.02957169]
# Train loss in epoch 769: [0.027569909], Test loss: [0.029553778]
# Train loss in epoch 770: [0.027555304], Test loss: [0.029535796]
# Train loss in epoch 771: [0.027540809], Test loss: [0.029517911]
# Train loss in epoch 772: [0.027526367], Test loss: [0.029500159]
# Train loss in epoch 773: [0.027512003], Test loss: [0.029482456]
# Train loss in epoch 774: [0.02749758], Test loss: [0.029464729]
# Train loss in epoch 775: [0.027483281], Test loss: [0.02944709]
# Train loss in epoch 776: [0.027468959], Test loss: [0.029429451]
# Train loss in epoch 777: [0.027454618], Test loss: [0.029411823]
# Train loss in epoch 778: [0.027440324], Test loss: [0.029394314]
# Train loss in epoch 779: [0.02742606], Test loss: [0.029376816]
# Train loss in epoch 780: [0.027411815], Test loss: [0.029359402]
# Train loss in epoch 781: [0.027397523], Test loss: [0.029341906]
# Train loss in epoch 782: [0.027383365], Test loss: [0.029324578]
# Train loss in epoch 783: [0.027369162], Test loss: [0.029307261]
# Train loss in epoch 784: [0.027355], Test loss: [0.029289957]
# Train loss in epoch 785: [0.027340923], Test loss: [0.02927275]
# Train loss in epoch 786: [0.027326833], Test loss: [0.02925556]
# Train loss in epoch 787: [0.027312677], Test loss: [0.029238353]
# Train loss in epoch 788: [0.027298432], Test loss: [0.029221002]
# Train loss in epoch 789: [0.02728444], Test loss: [0.029203925]
# Train loss in epoch 790: [0.02727036], Test loss: [0.029186839]
# Train loss in epoch 791: [0.027256317], Test loss: [0.029169794]
# Train loss in epoch 792: [0.027242426], Test loss: [0.029152883]
# Train loss in epoch 793: [0.027228385], Test loss: [0.029135868]
# Train loss in epoch 794: [0.027214449], Test loss: [0.029118977]
# Train loss in epoch 795: [0.02720058], Test loss: [0.029102165]
# Train loss in epoch 796: [0.027186688], Test loss: [0.029085364]
# Train loss in epoch 797: [0.027172631], Test loss: [0.029068384]
# Train loss in epoch 798: [0.027158834], Test loss: [0.029051708]
# Train loss in epoch 799: [0.027145039], Test loss: [0.029034967]
# Train loss in epoch 800: [0.027131176], Test loss: [0.029018261]
# Train loss in epoch 801: [0.027117345], Test loss: [0.02900156]
# Train loss in epoch 802: [0.027103677], Test loss: [0.02898507]
# Train loss in epoch 803: [0.02708978], Test loss: [0.028968351]
# Train loss in epoch 804: [0.027076058], Test loss: [0.028951826]
# Train loss in epoch 805: [0.027062288], Test loss: [0.028935283]
# Train loss in epoch 806: [0.027048651], Test loss: [0.028918825]
# Train loss in epoch 807: [0.02703508], Test loss: [0.028902497]
# Train loss in epoch 808: [0.027021382], Test loss: [0.028886041]
# Train loss in epoch 809: [0.027007617], Test loss: [0.028869499]
# Train loss in epoch 810: [0.026994059], Test loss: [0.028853221]
# Train loss in epoch 811: [0.026980463], Test loss: [0.028836917]
# Train loss in epoch 812: [0.026966844], Test loss: [0.028820626]
# Train loss in epoch 813: [0.026953295], Test loss: [0.028804392]
# Train loss in epoch 814: [0.026939869], Test loss: [0.02878825]
# Train loss in epoch 815: [0.026926149], Test loss: [0.028771827]
# Train loss in epoch 816: [0.026912741], Test loss: [0.028755838]
# Train loss in epoch 817: [0.026899435], Test loss: [0.028739896]
# Train loss in epoch 818: [0.026885903], Test loss: [0.028723776]
# Train loss in epoch 819: [0.026872413], Test loss: [0.028707709]
# Train loss in epoch 820: [0.026859019], Test loss: [0.028691674]
# Train loss in epoch 821: [0.026845548], Test loss: [0.028675638]
# Train loss in epoch 822: [0.026832238], Test loss: [0.02865977]
# Train loss in epoch 823: [0.026818942], Test loss: [0.028643906]
# Train loss in epoch 824: [0.026805513], Test loss: [0.028627943]
# Train loss in epoch 825: [0.026792189], Test loss: [0.028612081]
# Train loss in epoch 826: [0.026778858], Test loss: [0.02859623]
# Train loss in epoch 827: [0.02676576], Test loss: [0.028580599]
# Train loss in epoch 828: [0.026752396], Test loss: [0.028564768]
# Train loss in epoch 829: [0.026739225], Test loss: [0.028549083]
# Train loss in epoch 830: [0.026726035], Test loss: [0.02853344]
# Train loss in epoch 831: [0.026712764], Test loss: [0.028517669]
# Train loss in epoch 832: [0.026699521], Test loss: [0.02850196]
# Train loss in epoch 833: [0.026686307], Test loss: [0.028486315]
# Train loss in epoch 834: [0.02667328], Test loss: [0.028470827]
# Train loss in epoch 835: [0.026660144], Test loss: [0.028455287]
# Train loss in epoch 836: [0.026647169], Test loss: [0.028439868]
# Train loss in epoch 837: [0.026634006], Test loss: [0.02842433]
# Train loss in epoch 838: [0.026620787], Test loss: [0.028408755]
# Train loss in epoch 839: [0.026607845], Test loss: [0.028393384]
# Train loss in epoch 840: [0.026594859], Test loss: [0.028378025]
# Train loss in epoch 841: [0.02658188], Test loss: [0.028362721]
# Train loss in epoch 842: [0.026568931], Test loss: [0.028347403]
# Train loss in epoch 843: [0.026555989], Test loss: [0.028332144]
# Train loss in epoch 844: [0.026542868], Test loss: [0.028316703]
# Train loss in epoch 845: [0.026530096], Test loss: [0.028301612]
# Train loss in epoch 846: [0.026517093], Test loss: [0.028286312]
# Train loss in epoch 847: [0.026504129], Test loss: [0.028271077]
# Train loss in epoch 848: [0.026491161], Test loss: [0.028255749]
# Train loss in epoch 849: [0.026478477], Test loss: [0.028240804]
# Train loss in epoch 850: [0.026465673], Test loss: [0.028225733]
# Train loss in epoch 851: [0.026452841], Test loss: [0.028210612]
# Train loss in epoch 852: [0.026439991], Test loss: [0.02819551]
# Train loss in epoch 853: [0.026427157], Test loss: [0.028180465]
# Train loss in epoch 854: [0.026414424], Test loss: [0.028165512]
# Train loss in epoch 855: [0.026401548], Test loss: [0.028150409]
# Train loss in epoch 856: [0.026388887], Test loss: [0.028135534]
# Train loss in epoch 857: [0.026376229], Test loss: [0.02812068]
# Train loss in epoch 858: [0.026363485], Test loss: [0.028105751]
# Train loss in epoch 859: [0.026350804], Test loss: [0.028090887]
# Train loss in epoch 860: [0.02633816], Test loss: [0.028076027]
# Train loss in epoch 861: [0.026325541], Test loss: [0.028061243]
# Train loss in epoch 862: [0.026312949], Test loss: [0.028046478]
# Train loss in epoch 863: [0.026300229], Test loss: [0.028031629]
# Train loss in epoch 864: [0.026287746], Test loss: [0.028017003]
# Train loss in epoch 865: [0.026275251], Test loss: [0.028002325]
# Train loss in epoch 866: [0.026262525], Test loss: [0.027987473]
# Train loss in epoch 867: [0.026249945], Test loss: [0.027972791]
# Train loss in epoch 868: [0.026237415], Test loss: [0.027958151]
# Train loss in epoch 869: [0.026225058], Test loss: [0.027943656]
# Train loss in epoch 870: [0.026212523], Test loss: [0.027929002]
# Train loss in epoch 871: [0.026199937], Test loss: [0.027914319]
# Train loss in epoch 872: [0.026187455], Test loss: [0.027899802]
# Train loss in epoch 873: [0.026175007], Test loss: [0.027885258]
# Train loss in epoch 874: [0.02616268], Test loss: [0.027870819]
# Train loss in epoch 875: [0.02615032], Test loss: [0.027856374]
# Train loss in epoch 876: [0.026137982], Test loss: [0.02784203]
# Train loss in epoch 877: [0.026125574], Test loss: [0.027827557]
# Train loss in epoch 878: [0.026113201], Test loss: [0.027813133]
# Train loss in epoch 879: [0.026100904], Test loss: [0.027798798]
# Train loss in epoch 880: [0.026088508], Test loss: [0.027784385]
# Train loss in epoch 881: [0.026076213], Test loss: [0.027770087]
# Train loss in epoch 882: [0.026063917], Test loss: [0.027755756]
# Train loss in epoch 883: [0.026051741], Test loss: [0.027741559]
# Train loss in epoch 884: [0.026039246], Test loss: [0.027727099]
# Train loss in epoch 885: [0.026027249], Test loss: [0.027713098]
# Train loss in epoch 886: [0.026014864], Test loss: [0.02769874]
# Train loss in epoch 887: [0.026002826], Test loss: [0.027684722]
# Train loss in epoch 888: [0.025990473], Test loss: [0.02767041]
# Train loss in epoch 889: [0.025978386], Test loss: [0.027656339]
# Train loss in epoch 890: [0.025966171], Test loss: [0.027642159]
# Train loss in epoch 891: [0.025954109], Test loss: [0.02762815]
# Train loss in epoch 892: [0.02594197], Test loss: [0.027614042]
# Train loss in epoch 893: [0.025929838], Test loss: [0.02759999]
# Train loss in epoch 894: [0.025917685], Test loss: [0.027585911]
# Train loss in epoch 895: [0.025905643], Test loss: [0.027571946]
# Train loss in epoch 896: [0.025893532], Test loss: [0.027557917]
# Train loss in epoch 897: [0.025881577], Test loss: [0.027544044]
# Train loss in epoch 898: [0.025869366], Test loss: [0.027529936]
# Train loss in epoch 899: [0.025857441], Test loss: [0.027516074]
# Train loss in epoch 900: [0.025845485], Test loss: [0.027502233]
# Train loss in epoch 901: [0.025833489], Test loss: [0.027488332]
# Train loss in epoch 902: [0.025821455], Test loss: [0.027474459]
# Train loss in epoch 903: [0.025809448], Test loss: [0.027460584]
# Train loss in epoch 904: [0.02579757], Test loss: [0.027446819]
# Train loss in epoch 905: [0.025785726], Test loss: [0.027433099]
# Train loss in epoch 906: [0.025773793], Test loss: [0.027419288]
# Train loss in epoch 907: [0.02576182], Test loss: [0.027405487]
# Train loss in epoch 908: [0.025749881], Test loss: [0.027391702]
# Train loss in epoch 909: [0.025737986], Test loss: [0.027377952]
# Train loss in epoch 910: [0.025726259], Test loss: [0.027364392]
# Train loss in epoch 911: [0.025714368], Test loss: [0.027350685]
# Train loss in epoch 912: [0.025702622], Test loss: [0.027337115]
# Train loss in epoch 913: [0.025690913], Test loss: [0.027323589]
# Train loss in epoch 914: [0.025679035], Test loss: [0.027309921]
# Train loss in epoch 915: [0.025667179], Test loss: [0.02729626]
# Train loss in epoch 916: [0.025655529], Test loss: [0.027282838]
# Train loss in epoch 917: [0.025643684], Test loss: [0.027269177]
# Train loss in epoch 918: [0.025632022], Test loss: [0.027255731]
# Train loss in epoch 919: [0.02562025], Test loss: [0.027242191]
# Train loss in epoch 920: [0.02560861], Test loss: [0.027228741]
# Train loss in epoch 921: [0.025596891], Test loss: [0.027215265]
# Train loss in epoch 922: [0.025585257], Test loss: [0.027201857]
# Train loss in epoch 923: [0.025573451], Test loss: [0.027188294]
# Train loss in epoch 924: [0.025561832], Test loss: [0.027174916]
# Train loss in epoch 925: [0.0255503], Test loss: [0.027161634]
# Train loss in epoch 926: [0.025538778], Test loss: [0.027148392]
# Train loss in epoch 927: [0.025527012], Test loss: [0.027134884]
# Train loss in epoch 928: [0.025515569], Test loss: [0.027121743]
# Train loss in epoch 929: [0.025503939], Test loss: [0.027108345]
# Train loss in epoch 930: [0.025492284], Test loss: [0.027094983]
# Train loss in epoch 931: [0.025480762], Test loss: [0.027081747]
# Train loss in epoch 932: [0.025469411], Test loss: [0.027068686]
# Train loss in epoch 933: [0.0254579], Test loss: [0.027055446]
# Train loss in epoch 934: [0.025446407], Test loss: [0.027042257]
# Train loss in epoch 935: [0.025434889], Test loss: [0.027029052]
# Train loss in epoch 936: [0.025423404], Test loss: [0.02701587]
# Train loss in epoch 937: [0.025411937], Test loss: [0.027002737]
# Train loss in epoch 938: [0.025400549], Test loss: [0.026989665]
# Train loss in epoch 939: [0.025389176], Test loss: [0.02697658]
# Train loss in epoch 940: [0.025377726], Test loss: [0.02696348]
# Train loss in epoch 941: [0.025366373], Test loss: [0.026950458]
# Train loss in epoch 942: [0.025355063], Test loss: [0.026937511]
# Train loss in epoch 943: [0.025343735], Test loss: [0.026924532]
# Train loss in epoch 944: [0.025332287], Test loss: [0.026911428]
# Train loss in epoch 945: [0.02532096], Test loss: [0.026898451]
# Train loss in epoch 946: [0.025309589], Test loss: [0.026885465]
# Train loss in epoch 947: [0.025298309], Test loss: [0.026872503]
# Train loss in epoch 948: [0.025286976], Test loss: [0.026859544]
# Train loss in epoch 949: [0.025275668], Test loss: [0.026846647]
# Train loss in epoch 950: [0.025264353], Test loss: [0.026833706]
# Train loss in epoch 951: [0.025253257], Test loss: [0.026821012]
# Train loss in epoch 952: [0.025242127], Test loss: [0.026808271]
# Train loss in epoch 953: [0.025230791], Test loss: [0.026795326]
# Train loss in epoch 954: [0.025219515], Test loss: [0.02678242]
# Train loss in epoch 955: [0.025208477], Test loss: [0.026769789]
# Train loss in epoch 956: [0.025197331], Test loss: [0.026757065]
# Train loss in epoch 957: [0.02518601], Test loss: [0.026744165]
# Train loss in epoch 958: [0.025174864], Test loss: [0.026731435]
# Train loss in epoch 959: [0.025163809], Test loss: [0.026718806]
# Train loss in epoch 960: [0.02515268], Test loss: [0.026706096]
# Train loss in epoch 961: [0.02514153], Test loss: [0.026693404]
# Train loss in epoch 962: [0.025130454], Test loss: [0.026680728]
# Train loss in epoch 963: [0.025119536], Test loss: [0.026668234]
# Train loss in epoch 964: [0.025108289], Test loss: [0.026655458]
# Train loss in epoch 965: [0.025097311], Test loss: [0.02664293]
# Train loss in epoch 966: [0.025086239], Test loss: [0.02663031]
# Train loss in epoch 967: [0.025075231], Test loss: [0.026617792]
# Train loss in epoch 968: [0.025064223], Test loss: [0.026605248]
# Train loss in epoch 969: [0.025053244], Test loss: [0.026592724]
# Train loss in epoch 970: [0.025042363], Test loss: [0.0265803]
# Train loss in epoch 971: [0.025031436], Test loss: [0.026567865]
# Train loss in epoch 972: [0.025020445], Test loss: [0.026555393]
# Train loss in epoch 973: [0.025009507], Test loss: [0.026542898]
# Train loss in epoch 974: [0.024998464], Test loss: [0.026530359]
# Train loss in epoch 975: [0.024987668], Test loss: [0.026518073]
# Train loss in epoch 976: [0.024976753], Test loss: [0.02650566]
# Train loss in epoch 977: [0.024965934], Test loss: [0.026493324]
# Train loss in epoch 978: [0.024955042], Test loss: [0.026480956]
# Train loss in epoch 979: [0.024944274], Test loss: [0.026468698]
# Train loss in epoch 980: [0.024933446], Test loss: [0.026456363]
# Train loss in epoch 981: [0.024922673], Test loss: [0.026444113]
# Train loss in epoch 982: [0.024911819], Test loss: [0.026431791]
# Train loss in epoch 983: [0.024900999], Test loss: [0.026419524]
# Train loss in epoch 984: [0.02489021], Test loss: [0.026407283]
# Train loss in epoch 985: [0.024879508], Test loss: [0.026395109]
# Train loss in epoch 986: [0.024868645], Test loss: [0.026382815]
# Train loss in epoch 987: [0.024858052], Test loss: [0.026370715]
# Train loss in epoch 988: [0.02484725], Test loss: [0.026358496]
# Train loss in epoch 989: [0.024836699], Test loss: [0.026346486]
# Train loss in epoch 990: [0.024825951], Test loss: [0.026334273]
# Train loss in epoch 991: [0.024815224], Test loss: [0.026322136]
# Train loss in epoch 992: [0.024804566], Test loss: [0.026310053]
# Train loss in epoch 993: [0.024794064], Test loss: [0.026298121]
# Train loss in epoch 994: [0.024783377], Test loss: [0.026286019]
# Train loss in epoch 995: [0.02477262], Test loss: [0.026273856]
# Train loss in epoch 996: [0.024762012], Test loss: [0.026261823]
# Train loss in epoch 997: [0.024751455], Test loss: [0.026249833]
# Train loss in epoch 998: [0.024740979], Test loss: [0.026237946]
# Train loss in epoch 999: [0.024730381], Test loss: [0.026225939]

# %%
#Saving function checking..
dnn_inst.layers[0].w.name
# Out:
# 'Layer0/Matrix/read:0'

# %%
tf.trainable_variables()
# Out:
# [<tensorflow.python.ops.variables.Variable at 0x7fe2bcd663c8>,
#  <tensorflow.python.ops.variables.Variable at 0x7fe2bd3d3a58>,
#  <tensorflow.python.ops.variables.Variable at 0x7fe2bcd660b8>,
#  <tensorflow.python.ops.variables.Variable at 0x7fe2bcd66240>,
#  <tensorflow.python.ops.variables.Variable at 0x7fe2bcd661d0>,
#  <tensorflow.python.ops.variables.Variable at 0x7fe2bc91a390>]

# %%
dnn_inst.save_variables_for_rnn("WEIGHTS_FOLDER/REWARD_NET.chkp")
# Out:
# RNN/FullNetworkCell/Reward/Layer0/Bias
# Tensor("Layer0/Bias/read:0", shape=(32,), dtype=float32)
# RNN/FullNetworkCell/Reward/Layer1/Bias
# Tensor("Layer1/Bias/read:0", shape=(32,), dtype=float32)
# RNN/FullNetworkCell/Reward/Layer1/Matrix
# Tensor("Layer1/Matrix/read:0", shape=(32, 32), dtype=float32)
# RNN/FullNetworkCell/Reward/Layer0/Matrix
# Tensor("Layer0/Matrix/read:0", shape=(4, 32), dtype=float32)
# RNN/FullNetworkCell/Reward/Layer2/Bias
# Tensor("Layer2/Bias/read:0", shape=(1,), dtype=float32)
# RNN/FullNetworkCell/Reward/Layer2/Matrix
# Tensor("Layer2/Matrix/read:0", shape=(32, 1), dtype=float32)
# /home/wuga/Documents/Notebook/VAE-PLANNING/WEIGHTS_FOLDER/REWARD_NET.chkp

# %%
#dnn_inst.predict_test([[1,1,6,6]])
