# %% [markdown]
# # Fully Connected Network
#
# This is the second part of our whole deep learning planning structure.
#
# The Data in this experiments is generated from RDDL simulator [Github](https://github.com/ssanner/rddlsim), which is written by Prof.Scott Sanner at University of Toronto.
#
# In the section, we need a fully connected network to compute the reward of each (STATE,ACTION,STATE') tuple, that is (STATE,ACTION,STATE') -> Reward. Since this part is deterministic, fully connected network is capable to solve.
#
# Problem list:
# 1. Data normalization will highly impact the network performance, we need to normalize the input. However, the input of this section is an output of VAE, which is unnormalized. And since everything is working under tensorflow environment, we need to build normalizer inside tensorflow graph.
# 2. For reward function R(s,a), in nondeterministic domain, R(s,a) is stochastic. We need a deterministic function. Therefore, we rewrite the reward function as R(s,a,s'). This requires us to concate s,a,s' as single input matrix(also under tensorflow).

# %% [markdown]
# ### Import Packages
# We do note provide pip installation commands, please search this package and install it through pip install. Please upgrade your pip before installing, since old pip would cause errors.

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import tensorflow as tf
import numpy as np
from sklearn.metrics import confusion_matrix
import time
from datetime import timedelta
import math
import os
import pandas as pd
#Functional coding
import functools
from functools import partial
import re

# %% [markdown]
# ### Load Data
# We load data from csv files. The following code shows how to load data through pandas and numpy. Result of this progress can be feed into tensorflow with "feed_dict" argument.

# %%
#Data Path..
Datapath="DATA/Navigation/Nav_RDDL_Data.txt"
Labelpath="DATA/Navigation/Nav_RDDL_Label.txt"
Rewardpath="DATA/Navigation/Nav_RDDL_Reward.txt"

# %%
#Given local path, find full path
def PathFinder(path):
    #python 2
    #script_dir = os.path.dirname('__file__')
    #fullpath = os.path.join(script_dir,path)
    #python 3
    fullpath=os.path.abspath(path)
    print(fullpath)
    return fullpath

#Read Data for Deep Learning
def ReadData(path):
    fullpath=PathFinder(path)
    return pd.read_csv(fullpath, sep=',', header=0)

#Won't use this one to normalize
#Input Normalization
def Normalize(features, mean = [], std = []):
    if mean == []:
        mean = np.mean(features, axis = 0)
        std = np.std(features, axis = 0)
#     print std
#     print std[:,None]
    new_feature = (features.T - mean[:,None]).T
    new_feature = (new_feature.T / std[:,None]).T
    new_feature[np.isnan(new_feature)]=0
#     print new_feature
    return new_feature, mean, std

# %%
x_pd = ReadData(Datapath)
r_pd = ReadData(Rewardpath)
# Out:
# /home/wuga/Documents/Notebook/VAE-PLANNING/DATA/Navigation/Nav_RDDL_Data.txt
# /home/wuga/Documents/Notebook/VAE-PLANNING/DATA/Navigation/Nav_RDDL_Reward.txt

# %%
#Get Numpy Arrays
x_matrix=x_pd.as_matrix()
x_train = x_matrix[:100000]
x_valid = x_matrix[100000:]
r_matrix=r_pd.as_matrix()
r_train = r_matrix[:100000]
r_valid = r_matrix[100000:]

# %%
len(x_matrix)
# Out:
# 150000

# %%
data_size=len(x_matrix)
# Uppercase for constants
INPUT_S_A_SIZE = 4
OUTPUT_SIZE = 1

# %% [markdown]
# ### Support Functions
# The following functions allows us passthrough multiple functions without explicitly assign intermediate output variables.

# %%
def compose(f,g):
    return lambda x:g(f(x))
    
def composeAll(*args):
    """
    composeAll([f,g,h])(x): f(g(h(x)))
    """
    return partial(functools.reduce, compose)(*args)

# %% [markdown]
# ## Tensorflow
# ### Input tensor place holders

# %%
# Input features s,a
x = tf.placeholder(tf.float32,[None, INPUT_S_A_SIZE],name="Features_S_A")

# Input label
r = tf.placeholder(tf.float32, [None, OUTPUT_SIZE],name="Labels")

# %% [markdown]
# ### Variable Generating functions

# %%
#Weight constructing function
def weight_variable(shape):
    initial = tf.truncated_normal(shape,stddev=0.001)
    return tf.Variable(initial,name="Matrix")

#Bias constructing function
def bias_variable(shape):
    initial = tf.constant(0.,shape=shape)
    return tf.Variable(initial,name="Bias")

# %% [markdown]
# ### Fully Connected Layer Defination

# %%
class Dense():
    """Fully Connected Layer"""
    def __init__(self, scope="fully_connected_layer", output_dim =None, dropout=1.0, activation=tf.identity):
        assert output_dim, "Missing output dimension specification!"
        self.scope = scope
        self.output_dim = output_dim
        self.dropout = dropout
        self.activation = activation
        
    def __call__(self,x):
        with tf.name_scope(self.scope):
            while True:
                try:
                    return self.activation(tf.matmul(x,self.w)+self.b)
                except(AttributeError):
                    self.w = tf.nn.dropout(weight_variable([x.get_shape()[1].value, self.output_dim]),self.dropout)
                    self.b = bias_variable([self.output_dim])
    
    def set_parameters(self, weight, bias):
        self.w.assign(weight)
        self.b.assign(bias)
        
    def get_l2_loss(self):
        return tf.nn.l2_loss(self.w)

# %% [markdown]
# ### Full Deep Network Class
# The following class define a complete deep network, which include:
# 1. Network structure specification
# 2. Loss function specification
# 3. Prediction specification
# 4. Optimization method specification
# 5. Training function
# 6. Saving function(not tensorflow variable saving, but numpy weight dumping!)
# 7. Loading function(not tensorflow variable loading, but numpy weight assignment!)
# 8. Mini-Batch generation function

# %%
class DeepNet(object):
    
    def __init__(self, 
                 x, #Input Features for S,A
                 r, #Output Label for R
                 num_hidden_layers, #number of layers for both encoder and decoder
                 num_hidden_nodes, #number of nodes in each layer
                 activation, #nonlinear activation function
                 learning_rate=0.001, #Learning rate
                 dropout = 1,
                 batch_size=1000, 
                 l2_lambda = 1E-4): #Batch size        
#        self.mean = tf.Variable(tf.zeros([x.get_shape()[1]]),trainable=False,name="NORM_MEAN")
#        self.var = tf.Variable(tf.ones([x.get_shape()[1]]),trainable=False,name="NORM_VAR")
#        self.f = self._p_normalize(x)
        self.f = x
        self.r = r
        self.num_hidden_layers = num_hidden_layers
        self.num_hidden_nodes = num_hidden_nodes
        self.activation = activation
        self.learning_rate = learning_rate
        self.batch_size = batch_size
        self.l2_lambda = l2_lambda
        self.dropout = dropout
        self._p_create_dnn_graph()
        self._p_create_loss()
        self.sess = tf.InteractiveSession()
        self.sess.run(tf.global_variables_initializer())
        
    def _p_create_dnn_graph(self):

        layers = []
        for i in range(self.num_hidden_layers):
            layers.append(Dense("Layer"+str(i),self.num_hidden_nodes,self.dropout,self.activation))
        layers.append(Dense("Layer"+str(self.num_hidden_layers),self.r.get_shape()[1].value,self.dropout))
        self.r_pred = composeAll(layers)(self.f)
        self.layers = layers 
    
    def _p_normalize(self, unnormed):
        epsilon = 1e-3
        normed = tf.nn.batch_normalization(unnormed,self.mean,self.var,None,None,epsilon)
        return normed
        
    def _p_create_loss(self): #lambda for l2 regularization

        #L2 regularization loss
        l2_loss = tf.constant(0.0)
        for layer in self.layers:
            l2_loss += layer.get_l2_loss()

        #Mean Squared Error
        mse_r = tf.reduce_mean(tf.square(tf.sub(self.r,self.r_pred)), reduction_indices=1)

        #loss
        self.loss = tf.reduce_mean(mse_r)+self.l2_lambda*l2_loss
        self.optimizer = tf.train.RMSPropOptimizer(self.learning_rate).minimize(self.loss)   
        
    def update_normalization(self,x_matrix):
        tf_mean,tf_var = tf.nn.moments(x, axes = [0])
        feed_dict = {x:x_matrix}
        np_mean,np_var = self.sess.run([tf_mean,tf_var],feed_dict=feed_dict)
        print(np_mean)
        self.sess.run(self.mean.assign(np_mean))
        self.sess.run(self.var.assign(np_var))
        print(self.mean.eval())
        
    
    def train_model(self,train_s_a,train_r,test_s_a,test_r,epoch=100):
        
#        self.update_normalization(train_s_a)
        
        batches = self._p_get_batches(train_s_a,train_r,self.batch_size)
        
#        self.mean = tf.Variable(tf.zeros([x.get_shape()[1]]),trainable=False)
#        self.var = tf.Variable(tf.ones([x.get_shape()[1]]),trainable=False)
        
        summary_writer = tf.summary.FileWriter('experiment', graph=self.sess.graph)
        feed_test={x:test_s_a,r:test_r}
        feed_train={x:train_s_a, r:train_r}

        #Training
        for epoch in range(epoch):
            for step in range(len(batches)):
                feed_dict = {x: batches[step][0],r: batches[step][1]}
                training = self.sess.run([self.optimizer], feed_dict=feed_dict)
            train_loss = self.sess.run([self.loss],feed_dict=feed_dict)
            test_loss = self.sess.run([self.loss],feed_dict=feed_test)
            print('Train loss in epoch {0}: {1}, Test loss: {2}'.format(epoch, train_loss, test_loss)) 
            
    def predict_test(self, test_s_a):
        feed_dict={x:test_s_a}
        return self.sess.run([self.r_pred],feed_dict=feed_dict)
            
    def _p_get_batches(self,x_matrix,r_matrix,batch_size):
        remaining_size = len(x_matrix)
        batch_index=0
        batches = []
        while(remaining_size>0):
            batch = []
            if remaining_size<batch_size:
                batch.append(x_matrix[batch_index*batch_size:-1])
                batch.append(r_matrix[batch_index*batch_size:-1])
            else:
                batch.append(x_matrix[batch_index*batch_size:(batch_index+1)*batch_size]) 
                batch.append(r_matrix[batch_index*batch_size:(batch_index+1)*batch_size]) 
            batch_index+=1
            remaining_size-=batch_size
            batches.append(batch)
        return batches
    
    def _p_extract_weights(self):
        # a hashmap maps from layer name to weights and biases
        mp_layer_weights = {}

        #iteratively save values
        for dense in self.layers:
            values = {'weights':dense.w, 'biases':dense.b}
            mp_layer_weights[layer.scope] = values
        
        norms = {'mean':self.mean, 'var':self.var}
        mp_layer_weights['normalizations'] = norms

        return mp_layer_weights
    
    def save_weights(self,path):
        #extract weights from trained model
        layer_weights = self.sess.run(_p_extract_weights())
        print('Whole layer weights: {0}'.format(layer_weights))
        np.save(path,layer_weights)
    
    def load_weights(self,path):
        layer_weights = np.load(path)
        for dense in self.layers:
            print('Scope:{0}'.format(dense.scope))
            values = layer_weights.get(dense.scope)
            weights = values.get('weights')
            biases = values.get('biases')
            dense.set_parameters(weights,biases)
        print('Done!')
        
    def save_variables_for_rnn(self,path,prefix="RNN/FullNetworkCell/Reward/"):
        variables = tf.trainable_variables()
        var_dict = {}
        for v in variables:
            if "/read" in v.name:
                name = prefix+re.sub("/read", "", v.name)
                name = re.sub(":0", "", name)
                var_dict[name] = v
            else:
                name = prefix+v.name
                name = re.sub(":0", "", name)
                var_dict[name] = v
        for k,v in var_dict.items():
            print(k)
            print(v)
        saver = tf.train.Saver(var_dict)
        saver.save(self.sess, PathFinder(path))

# %%
#Instantiate a network
dnn_inst = DeepNet(x,r,2,32,tf.nn.sigmoid)

# %% [markdown]
# ### Tensorflow graph visualization function

# %%
from IPython.display import clear_output, Image, display, HTML

def strip_consts(graph_def, max_const_size=32):
    """Strip large constant values from graph_def."""
    strip_def = tf.GraphDef()
    for n0 in graph_def.node:
        n = strip_def.node.add() 
        n.MergeFrom(n0)
        if n.op == 'Const':
            tensor = n.attr['value'].tensor
            size = len(tensor.tensor_content)
            if size > max_const_size:
                tensor.tensor_content = "<stripped %d bytes>"%size
    return strip_def

def show_graph(graph_def, max_const_size=32):
    """Visualize TensorFlow graph."""
    if hasattr(graph_def, 'as_graph_def'):
        graph_def = graph_def.as_graph_def()
    strip_def = strip_consts(graph_def, max_const_size=max_const_size)
    code = """
        <script>
          function load() {{
            document.getElementById("{id}").pbtxt = {data};
          }}
        </script>
        <link rel="import" href="https://tensorboard.appspot.com/tf-graph-basic.build.html" onload=load()>
        <div style="height:600px">
          <tf-graph-basic id="{id}"></tf-graph-basic>
        </div>
    """.format(data=repr(str(strip_def)), id='graph'+str(np.random.rand()))

    iframe = """
        <iframe seamless style="width:960px;height:600px;border:0" srcdoc="{}"></iframe>
    """.format(code.replace('"', '&quot;'))
    display(HTML(iframe))

# %%
show_graph(tf.get_default_graph().as_graph_def())
# Out:
#         <iframe seamless style="width:960px;height:600px;border:0" srcdoc="
#         <script>
#           function load() {
#             document.getElementById(&quot;graph0.3076271854436664&quot;).pbtxt = 'node {\n  name: &quot;Features_S_A&quot;\n  op: &quot;Placeholder&quot;\n  attr {\n    key: &quot;dtype&quot;\n    value {\n      type: DT_FLOAT\n    }\n  }\n  attr {\n    key: &quot;shape&quot;\n    value {\n      shape {\n      }\n    }\n  }\n}\nnode {\n  name: &quot;Labels&quot;\n  op: &quot;Placeholder&quot;\n  attr {\n    key: &quot;dtype&quot;\n    value {\n      type: DT_FLOAT\n    }\n  }\n  attr {\n    key: &quot;shape&quot;\n    value {\n      shape {\n      }\n    }\n  }\n}\nnode {\n  name: &quot;Layer0/truncated_normal/shape&quot;\n  op: &quot;Const&quot;\n  attr {\n    key: &quot;dtype&quot;\n    value {\n      type: DT_INT32\n    }\n  }\n  attr {\n    key: &quot;value&quot;\n    value {\n      tensor {\n        dtype: DT_INT32\n        tensor_shape {\n          dim {\n            size: 2\n          }\n        }\n        tensor_content: &quot;\\004\\000\\000\\000\\024\\000\\000\\000&quot;\n      }\n    }\n  }\n}\nnode {\n  name: &quot;Layer0/truncated_normal/mean&quot;\n  op: &quot;Const&quot;\n  attr {\n    key: &quot;dtype&quot;\n    value {\n      type: DT_FLOAT\n    }\n  }\n  attr {\n    key: &quot;value&quot;\n    value {\n      tensor {\n        dtype: DT_FLOAT\n        tensor_shape {\n        }\n        float_val: 0.0\n      }\n    }\n  }\n}\nnode {\n  name: &quot;Layer0/truncated_normal/stddev&quot;\n  op: &quot;Const&quot;\n  attr {\n    key: &quot;dtype&quot;\n    value {\n      type: DT_FLOAT\n    }\n  }\n  attr {\n    key: &quot;value&quot;\n    value {\n      tensor {\n        dtype: DT_FLOAT\n        tensor_shape {\n        }\n        float_val: 0.0010000000474974513\n      }\n    }\n  }\n}\nnode {\n  name: &quot;Layer0/truncated_normal/TruncatedNormal&quot;\n  op: &quot;TruncatedNormal&quot;\n  input: &quot;Layer0/truncated_normal/shape&quot;\n  attr {\n    key: &quot;T&quot;\n    value {\n      type: DT_INT32\n    }\n  }\n  attr {\n    key: &quot;dtype&quot;\n    value {\n      type: DT_FLOAT\n    }\n  }\n  attr {\n    key: &quot;seed&quot;\n    value {\n      i: 0\n    }\n  }\n  attr {\n    key: &quot;seed2&quot;\n    value {\n      i: 0\n    }\n  }\n}\nnode {\n  name: &quot;Layer0/truncated_normal/mul&quot;\n  op: &quot;Mul&quot;\n  input: &quot;Layer0/truncated_normal/TruncatedNormal&quot;\n  input: &quot;Layer0/truncated_normal/stddev&quot;\n  attr {\n    key: &quot;T&quot;\n    value {\n      type: DT_FLOAT\n    }\n  }\n}\nnode {\n  name: &quot;Layer0/truncated_normal&quot;\n  op: &quot;Add&quot;\n  input: &quot;Layer0/truncated_normal/mul&quot;\n  input: &quot;Layer0/truncated_normal/mean&quot;\n  attr {\n    key: &quot;T&quot;\n    value {\n      type: DT_FLOAT\n    }\n  }\n}\nnode {\n  name: &quot;Layer0/Matrix&quot;\n  op: &quot;Variable&quot;\n  attr {\n    key: &quot;container&quot;\n    value {\n      s: &quot;&quot;\n    }\n  }\n  attr {\n    key: &quot;dtype&quot;\n    value {\n      type: DT_FLOAT\n    }\n  }\n  attr {\n    key: &quot;shape&quot;\n    value {\n      shape {\n        dim {\n          size: 4\n        }\n        dim {\n          size: 20\n        }\n      }\n    }\n  }\n  attr {\n    key: &quot;shared_name&quot;\n    value {\n      s: &quot;&quot;\n    }\n  }\n}\nnode {\n  name: &quot;Layer0/Matrix/Assign&quot;\n  op: &quot;Assign&quot;\n  input: &quot;Layer0/Matrix&quot;\n  input: &quot;Layer0/truncated_normal&quot;\n  attr {\n    key: &quot;T&quot;\n    value {\n      type: DT_FLOAT\n    }\n  }\n  attr {\n    key: &quot;_class&quot;\n    value {\n      list {\n        s: &quot;loc:@Layer0/Matrix&quot;\n      }\n    }\n  }\n  attr {\n    key: &quot;use_locking&quot;\n    value {\n      b: true\n    }\n  }\n  attr {\n    key: &quot;validate_shape&quot;\n    value {\n      b: true\n    }\n  }\n}\nnode {\n  name: &quot;Layer0/Matrix/read&quot;\n  op: &quot;Identity&quot;\n  input: &quot;Layer0/Matrix&quot;\n  attr {\n    key: &quot;T&quot;\n    value {\n      type: DT_FLOAT\n    }\n  }\n  at ...

# %% [markdown]
# ### Training

# %%
dnn_inst.train_model(x_train,r_train,x_valid,r_valid,1000)
# Out:
# Train loss in epoch 0: [42.64896], Test loss: [40.65247]
# Train loss in epoch 1: [25.22147], Test loss: [23.607525]
# Train loss in epoch 2: [18.165392], Test loss: [16.785326]
# Train loss in epoch 3: [6.9075918], Test loss: [5.8977599]
# Train loss in epoch 4: [2.05533], Test loss: [1.7484403]
# Train loss in epoch 5: [1.1380668], Test loss: [1.1107287]
# Train loss in epoch 6: [0.8559435], Test loss: [0.90043038]
# Train loss in epoch 7: [0.77973503], Test loss: [0.84214377]
# Train loss in epoch 8: [0.77093703], Test loss: [0.83556724]
# Train loss in epoch 9: [0.76652926], Test loss: [0.83192736]
# Train loss in epoch 10: [0.76315641], Test loss: [0.82895041]
# Train loss in epoch 11: [0.76018357], Test loss: [0.82623601]
# Train loss in epoch 12: [0.75738239], Test loss: [0.82364577]
# Train loss in epoch 13: [0.75467122], Test loss: [0.82112879]
# Train loss in epoch 14: [0.75201499], Test loss: [0.81866312]
# Train loss in epoch 15: [0.74939787], Test loss: [0.81623185]
# Train loss in epoch 16: [0.74680883], Test loss: [0.81382376]
# Train loss in epoch 17: [0.7442407], Test loss: [0.81143606]
# Train loss in epoch 18: [0.74168611], Test loss: [0.80905747]
# Train loss in epoch 19: [0.73913991], Test loss: [0.80668294]
# Train loss in epoch 20: [0.73659724], Test loss: [0.80431074]
# Train loss in epoch 21: [0.73405415], Test loss: [0.80192971]
# Train loss in epoch 22: [0.73150855], Test loss: [0.79954511]
# Train loss in epoch 23: [0.72895795], Test loss: [0.79715073]
# Train loss in epoch 24: [0.72640264], Test loss: [0.79474467]
# Train loss in epoch 25: [0.72384179], Test loss: [0.792328]
# Train loss in epoch 26: [0.72127646], Test loss: [0.78990155]
# Train loss in epoch 27: [0.71870828], Test loss: [0.78746355]
# Train loss in epoch 28: [0.71613878], Test loss: [0.78501654]
# Train loss in epoch 29: [0.71357054], Test loss: [0.78256136]
# Train loss in epoch 30: [0.7110073], Test loss: [0.78009742]
# Train loss in epoch 31: [0.70845193], Test loss: [0.77762455]
# Train loss in epoch 32: [0.70590806], Test loss: [0.77514565]
# Train loss in epoch 33: [0.70337933], Test loss: [0.77265555]
# Train loss in epoch 34: [0.70086956], Test loss: [0.77015328]
# Train loss in epoch 35: [0.6983816], Test loss: [0.76763183]
# Train loss in epoch 36: [0.69591886], Test loss: [0.76508552]
# Train loss in epoch 37: [0.69348347], Test loss: [0.76250178]
# Train loss in epoch 38: [0.69107729], Test loss: [0.75986832]
# Train loss in epoch 39: [0.68870193], Test loss: [0.75716972]
# Train loss in epoch 40: [0.68635821], Test loss: [0.75438768]
# Train loss in epoch 41: [0.68404716], Test loss: [0.75150353]
# Train loss in epoch 42: [0.68177104], Test loss: [0.74849683]
# Train loss in epoch 43: [0.67953295], Test loss: [0.74535465]
# Train loss in epoch 44: [0.67733872], Test loss: [0.74206907]
# Train loss in epoch 45: [0.67519653], Test loss: [0.73864472]
# Train loss in epoch 46: [0.67311782], Test loss: [0.73510426]
# Train loss in epoch 47: [0.67111641], Test loss: [0.73148757]
# Train loss in epoch 48: [0.66920471], Test loss: [0.72785503]
# Train loss in epoch 49: [0.66739011], Test loss: [0.72428018]
# Train loss in epoch 50: [0.6656726], Test loss: [0.72077191]
# Train loss in epoch 51: [0.66408902], Test loss: [0.7173968]
# Train loss in epoch 52: [0.66263992], Test loss: [0.71432823]
# Train loss in epoch 53: [0.66125596], Test loss: [0.71150398]
# Train loss in epoch 54: [0.65990978], Test loss: [0.70890135]
# Train loss in epoch 55: [0.65858561], Test loss: [0.70648396]
# Train loss in epoch 56: [0.65727067], Test loss: [0.70421058]
# Train loss in epoch 57: [0.65595841], Test loss: [0.70204955]
# Train loss in epoch 58: [0.65463287], Test loss: [0.69997054]
# Train loss in epoch 59: [0.65328455], Test loss: [0.69794738]
# Train loss in epoch 60: [0.65190983], Test loss: [0.69596332]
# Train loss in epoch 61: [0.65051019], Test loss: [0.69400609]
# Train loss in epoch 62: [0.6490925], Test loss: [0.69206679]
# Train loss in epoch 63: [0.64766234], Test loss: [0.69014245]
# Train loss in epoch 64: [0.64621747], Test loss: [0.68822777]
# Train loss in epoch 65: [0.6447525], Test loss: [0.68631428]
# Train loss in epoch 66: [0.64324951], Test loss: [0.6843732]
# Train loss in epoch 67: [0.64163476], Test loss: [0.6823259]
# Train loss in epoch 68: [0.63966793], Test loss: [0.67993414]
# Train loss in epoch 69: [0.63681561], Test loss: [0.67667067]
# Train loss in epoch 70: [0.63259578], Test loss: [0.67207682]
# Train loss in epoch 71: [0.62743449], Test loss: [0.66654462]
# Train loss in epoch 72: [0.62189627], Test loss: [0.66058379]
# Train loss in epoch 73: [0.61582464], Test loss: [0.65405309]
# Train loss in epoch 74: [0.60969096], Test loss: [0.64744425]
# Train loss in epoch 75: [0.60468054], Test loss: [0.6419028]
# Train loss in epoch 76: [0.60089666], Test loss: [0.63753682]
# Train loss in epoch 77: [0.59765565], Test loss: [0.63371015]
# Train loss in epoch 78: [0.59439278], Test loss: [0.62989759]
# Train loss in epoch 79: [0.59086102], Test loss: [0.62588358]
# Train loss in epoch 80: [0.58735043], Test loss: [0.62195772]
# Train loss in epoch 81: [0.58423692], Test loss: [0.61846483]
# Train loss in epoch 82: [0.58145028], Test loss: [0.61531293]
# Train loss in epoch 83: [0.57880104], Test loss: [0.61231315]
# Train loss in epoch 84: [0.57618934], Test loss: [0.60936934]
# Train loss in epoch 85: [0.57357746], Test loss: [0.60644215]
# Train loss in epoch 86: [0.57094896], Test loss: [0.6035133]
# Train loss in epoch 87: [0.56829309], Test loss: [0.60056984]
# Train loss in epoch 88: [0.56559962], Test loss: [0.59760123]
# Train loss in epoch 89: [0.56285805], Test loss: [0.59459877]
# Train loss in epoch 90: [0.56006449], Test loss: [0.59155214]
# Train loss in epoch 91: [0.55721098], Test loss: [0.58845216]
# Train loss in epoch 92: [0.55429], Test loss: [0.58529139]
# Train loss in epoch 93: [0.5512954], Test loss: [0.58206111]
# Train loss in epoch 94: [0.54822427], Test loss: [0.57875574]
# Train loss in epoch 95: [0.5450691], Test loss: [0.57537186]
# Train loss in epoch 96: [0.54182881], Test loss: [0.57190317]
# Train loss in epoch 97: [0.53850484], Test loss: [0.56834894]
# Train loss in epoch 98: [0.53509766], Test loss: [0.56470919]
# Train loss in epoch 99: [0.53160769], Test loss: [0.56098074]
# Train loss in epoch 100: [0.52803499], Test loss: [0.55716598]
# Train loss in epoch 101: [0.52437788], Test loss: [0.55326611]
# Train loss in epoch 102: [0.52063984], Test loss: [0.54928261]
# Train loss in epoch 103: [0.51682132], Test loss: [0.54521334]
# Train loss in epoch 104: [0.51292086], Test loss: [0.5410611]
# Train loss in epoch 105: [0.50893945], Test loss: [0.53682619]
# Train loss in epoch 106: [0.50487447], Test loss: [0.53251016]
# Train loss in epoch 107: [0.500723], Test loss: [0.52811283]
# Train loss in epoch 108: [0.49647892], Test loss: [0.52363193]
# Train loss in epoch 109: [0.49213877], Test loss: [0.51906395]
# Train loss in epoch 110: [0.48769969], Test loss: [0.5144099]
# Train loss in epoch 111: [0.48315695], Test loss: [0.50966841]
# Train loss in epoch 112: [0.478506], Test loss: [0.50484067]
# Train loss in epoch 113: [0.47374746], Test loss: [0.49993196]
# Train loss in epoch 114: [0.46888024], Test loss: [0.49493635]
# Train loss in epoch 115: [0.46390289], Test loss: [0.48985445]
# Train loss in epoch 116: [0.45881373], Test loss: [0.48468375]
# Train loss in epoch 117: [0.45361716], Test loss: [0.47943085]
# Train loss in epoch 118: [0.44832107], Test loss: [0.47410172]
# Train loss in epoch 119: [0.44292831], Test loss: [0.46869662]
# Train loss in epoch 120: [0.43744564], Test loss: [0.46322268]
# Train loss in epoch 121: [0.43187892], Test loss: [0.45768249]
# Train loss in epoch 122: [0.4262391], Test loss: [0.45208484]
# Train loss in epoch 123: [0.42053598], Test loss: [0.44643453]
# Train loss in epoch 124: [0.41478091], Test loss: [0.44073957]
# Train loss in epoch 125: [0.40898308], Test loss: [0.43500286]
# Train loss in epoch 126: [0.40315101], Test loss: [0.4292351]
# Train loss in epoch 127: [0.39729735], Test loss: [0.42344084]
# Train loss in epoch 128: [0.39143389], Test loss: [0.41763017]
# Train loss in epoch 129: [0.38557872], Test loss: [0.41182062]
# Train loss in epoch 130: [0.37974599], Test loss: [0.4060266]
# Train loss in epoch 131: [0.37394723], Test loss: [0.40025556]
# Train loss in epoch 132: [0.36818811], Test loss: [0.39451584]
# Train loss in epoch 133: [0.36245507], Test loss: [0.38879621]
# Train loss in epoch 134: [0.35673192], Test loss: [0.38308319]
# Train loss in epoch 135: [0.35109776], Test loss: [0.3774395]
# Train loss in epoch 136: [0.34558773], Test loss: [0.37188166]
# Train loss in epoch 137: [0.34012958], Test loss: [0.36634761]
# Train loss in epoch 138: [0.3346971], Test loss: [0.36081856]
# Train loss in epoch 139: [0.32929075], Test loss: [0.35529846]
# Train loss in epoch 140: [0.32391882], Test loss: [0.34980005]
# Train loss in epoch 141: [0.31859958], Test loss: [0.34434935]
# Train loss in epoch 142: [0.31338573], Test loss: [0.33899999]
# Train loss in epoch 143: [0.30835935], Test loss: [0.33382601]
# Train loss in epoch 144: [0.30360547], Test loss: [0.32891142]
# Train loss in epoch 145: [0.29921138], Test loss: [0.32434565]
# Train loss in epoch 146: [0.29522958], Test loss: [0.32018346]
# Train loss in epoch 147: [0.29163259], Test loss: [0.31639469]
# Train loss in epoch 148: [0.28811154], Test loss: [0.31266096]
# Train loss in epoch 149: [0.28501329], Test loss: [0.30942044]
# Train loss in epoch 150: [0.28210771], Test loss: [0.30630895]
# Train loss in epoch 151: [0.27540523], Test loss: [0.29920414]
# Train loss in epoch 152: [0.26918408], Test loss: [0.29291508]
# Train loss in epoch 153: [0.2666651], Test loss: [0.29027179]
# Train loss in epoch 154: [0.26508018], Test loss: [0.28857443]
# Train loss in epoch 155: [0.26264605], Test loss: [0.28601593]
# Train loss in epoch 156: [0.26004887], Test loss: [0.28330427]
# Train loss in epoch 157: [0.25742292], Test loss: [0.28058141]
# Train loss in epoch 158: [0.25468659], Test loss: [0.27776867]
# Train loss in epoch 159: [0.25157151], Test loss: [0.27457759]
# Train loss in epoch 160: [0.24590722], Test loss: [0.26867816]
# Train loss in epoch 161: [0.23940589], Test loss: [0.26209503]
# Train loss in epoch 162: [0.24063006], Test loss: [0.26321095]
# Train loss in epoch 163: [0.25587431], Test loss: [0.27880007]
# Train loss in epoch 164: [0.25297159], Test loss: [0.275769]
# Train loss in epoch 165: [0.25171453], Test loss: [0.27448189]
# Train loss in epoch 166: [0.23477343], Test loss: [0.25724816]
# Train loss in epoch 167: [0.24051556], Test loss: [0.26279142]
# Train loss in epoch 168: [0.24550246], Test loss: [0.26788929]
# Train loss in epoch 169: [0.22372833], Test loss: [0.24559589]
# Train loss in epoch 170: [0.23563281], Test loss: [0.25757152]
# Train loss in epoch 171: [0.2259043], Test loss: [0.2477081]
# Train loss in epoch 172: [0.2376238], Test loss: [0.2594949]
# Train loss in epoch 173: [0.21732549], Test loss: [0.23879357]
# Train loss in epoch 174: [0.23096015], Test loss: [0.2525062]
# Train loss in epoch 175: [0.21405709], Test loss: [0.23533106]
# Train loss in epoch 176: [0.23551059], Test loss: [0.25712603]
# Train loss in epoch 177: [0.21127698], Test loss: [0.2322873]
# Train loss in epoch 178: [0.21386103], Test loss: [0.23491423]
# Train loss in epoch 179: [0.20946661], Test loss: [0.23036391]
# Train loss in epoch 180: [0.20913818], Test loss: [0.22996736]
# Train loss in epoch 181: [0.20621434], Test loss: [0.22691728]
# Train loss in epoch 182: [0.20507804], Test loss: [0.22569278]
# Train loss in epoch 183: [0.20333277], Test loss: [0.22383961]
# Train loss in epoch 184: [0.20193887], Test loss: [0.22234523]
# Train loss in epoch 185: [0.2005251], Test loss: [0.22082844]
# Train loss in epoch 186: [0.19921562], Test loss: [0.21941823]
# Train loss in epoch 187: [0.19799426], Test loss: [0.21809745]
# Train loss in epoch 188: [0.1968677], Test loss: [0.21687473]
# Train loss in epoch 189: [0.19581527], Test loss: [0.21572949]
# Train loss in epoch 190: [0.19481705], Test loss: [0.21464144]
# Train loss in epoch 191: [0.19385132], Test loss: [0.21358903]
# Train loss in epoch 192: [0.19290054], Test loss: [0.2125562]
# Train loss in epoch 193: [0.1919543], Test loss: [0.2115331]
# Train loss in epoch 194: [0.19100924], Test loss: [0.21051647]
# Train loss in epoch 195: [0.190064], Test loss: [0.20950462]
# Train loss in epoch 196: [0.18912338], Test loss: [0.20850228]
# Train loss in epoch 197: [0.18818808], Test loss: [0.20751026]
# Train loss in epoch 198: [0.18726109], Test loss: [0.20653038]
# Train loss in epoch 199: [0.18634248], Test loss: [0.20556225]
# Train loss in epoch 200: [0.18543297], Test loss: [0.20460671]
# Train loss in epoch 201: [0.18453407], Test loss: [0.20366102]
# Train loss in epoch 202: [0.18364792], Test loss: [0.20272702]
# Train loss in epoch 203: [0.18277311], Test loss: [0.20180441]
# Train loss in epoch 204: [0.18190949], Test loss: [0.20089409]
# Train loss in epoch 205: [0.18105777], Test loss: [0.19999464]
# Train loss in epoch 206: [0.18021673], Test loss: [0.19910772]
# Train loss in epoch 207: [0.17938462], Test loss: [0.19823059]
# Train loss in epoch 208: [0.17856078], Test loss: [0.19736317]
# Train loss in epoch 209: [0.17774558], Test loss: [0.19650654]
# Train loss in epoch 210: [0.17693743], Test loss: [0.19565894]
# Train loss in epoch 211: [0.17613742], Test loss: [0.19482285]
# Train loss in epoch 212: [0.17534739], Test loss: [0.1939998]
# Train loss in epoch 213: [0.17456569], Test loss: [0.19318846]
# Train loss in epoch 214: [0.17379566], Test loss: [0.19239135]
# Train loss in epoch 215: [0.17303944], Test loss: [0.19161113]
# Train loss in epoch 216: [0.17229648], Test loss: [0.19084603]
# Train loss in epoch 217: [0.17156762], Test loss: [0.19009712]
# Train loss in epoch 218: [0.17085032], Test loss: [0.18936257]
# Train loss in epoch 219: [0.17014503], Test loss: [0.18864246]
# Train loss in epoch 220: [0.16945346], Test loss: [0.18793738]
# Train loss in epoch 221: [0.16877459], Test loss: [0.18724494]
# Train loss in epoch 222: [0.16810863], Test loss: [0.1865664]
# Train loss in epoch 223: [0.16745748], Test loss: [0.18590303]
# Train loss in epoch 224: [0.16681929], Test loss: [0.18525317]
# Train loss in epoch 225: [0.16619344], Test loss: [0.18461636]
# Train loss in epoch 226: [0.16558228], Test loss: [0.18399441]
# Train loss in epoch 227: [0.16498555], Test loss: [0.18338756]
# Train loss in epoch 228: [0.16439976], Test loss: [0.18279289]
# Train loss in epoch 229: [0.16382682], Test loss: [0.18221074]
# Train loss in epoch 230: [0.16326673], Test loss: [0.18164173]
# Train loss in epoch 231: [0.16271915], Test loss: [0.18108284]
# Train loss in epoch 232: [0.16218457], Test loss: [0.18053557]
# Train loss in epoch 233: [0.16166231], Test loss: [0.18000011]
# Train loss in epoch 234: [0.16115071], Test loss: [0.17947415]
# Train loss in epoch 235: [0.16065055], Test loss: [0.17895886]
# Train loss in epoch 236: [0.16016266], Test loss: [0.17845529]
# Train loss in epoch 237: [0.1596846], Test loss: [0.17796013]
# Train loss in epoch 238: [0.15921736], Test loss: [0.17747581]
# Train loss in epoch 239: [0.15876016], Test loss: [0.17700079]
# Train loss in epoch 240: [0.15831238], Test loss: [0.17653528]
# Train loss in epoch 241: [0.15787478], Test loss: [0.17607901]
# Train loss in epoch 242: [0.15744473], Test loss: [0.17563009]
# Train loss in epoch 243: [0.15702423], Test loss: [0.17519045]
# Train loss in epoch 244: [0.15661138], Test loss: [0.17475794]
# Train loss in epoch 245: [0.15620542], Test loss: [0.17433174]
# Train loss in epoch 246: [0.15580925], Test loss: [0.17391486]
# Train loss in epoch 247: [0.15542048], Test loss: [0.17350499]
# Train loss in epoch 248: [0.15503901], Test loss: [0.17310241]
# Train loss in epoch 249: [0.15466425], Test loss: [0.17270575]
# Train loss in epoch 250: [0.15429735], Test loss: [0.17231682]
# Train loss in epoch 251: [0.15393619], Test loss: [0.17193323]
# Train loss in epoch 252: [0.15358159], Test loss: [0.17155603]
# Train loss in epoch 253: [0.15323263], Test loss: [0.17118353]
# Train loss in epoch 254: [0.15288833], Test loss: [0.17081581]
# Train loss in epoch 255: [0.15255082], Test loss: [0.17045456]
# Train loss in epoch 256: [0.15221702], Test loss: [0.17009678]
# Train loss in epoch 257: [0.15188922], Test loss: [0.16974418]
# Train loss in epoch 258: [0.15156673], Test loss: [0.1693971]
# Train loss in epoch 259: [0.15124881], Test loss: [0.16905394]
# Train loss in epoch 260: [0.15093522], Test loss: [0.16871476]
# Train loss in epoch 261: [0.15062679], Test loss: [0.16838028]
# Train loss in epoch 262: [0.15032293], Test loss: [0.16805027]
# Train loss in epoch 263: [0.15002282], Test loss: [0.16772345]
# Train loss in epoch 264: [0.14972819], Test loss: [0.16740154]
# Train loss in epoch 265: [0.1494374], Test loss: [0.16708334]
# Train loss in epoch 266: [0.14914998], Test loss: [0.16676807]
# Train loss in epoch 267: [0.14886697], Test loss: [0.16645662]
# Train loss in epoch 268: [0.14858642], Test loss: [0.16614707]
# Train loss in epoch 269: [0.1483098], Test loss: [0.16584097]
# Train loss in epoch 270: [0.14803772], Test loss: [0.16553882]
# Train loss in epoch 271: [0.14776783], Test loss: [0.1652382]
# Train loss in epoch 272: [0.14750117], Test loss: [0.16494055]
# Train loss in epoch 273: [0.14723684], Test loss: [0.16464429]
# Train loss in epoch 274: [0.14697549], Test loss: [0.16435076]
# Train loss in epoch 275: [0.14671658], Test loss: [0.1640587]
# Train loss in epoch 276: [0.14646094], Test loss: [0.16376939]
# Train loss in epoch 277: [0.14620791], Test loss: [0.16348185]
# Train loss in epoch 278: [0.14595754], Test loss: [0.16319655]
# Train loss in epoch 279: [0.14570996], Test loss: [0.16291316]
# Train loss in epoch 280: [0.14546505], Test loss: [0.16263179]
# Train loss in epoch 281: [0.14522141], Test loss: [0.16235077]
# Train loss in epoch 282: [0.1449821], Test loss: [0.16207357]
# Train loss in epoch 283: [0.14474405], Test loss: [0.16179661]
# Train loss in epoch 284: [0.14450799], Test loss: [0.1615209]
# Train loss in epoch 285: [0.14427359], Test loss: [0.16124631]
# Train loss in epoch 286: [0.14404082], Test loss: [0.16097216]
# Train loss in epoch 287: [0.14381021], Test loss: [0.1606992]
# Train loss in epoch 288: [0.14358115], Test loss: [0.16042663]
# Train loss in epoch 289: [0.14335418], Test loss: [0.160155]
# Train loss in epoch 290: [0.14312907], Test loss: [0.15988442]
# Train loss in epoch 291: [0.14290552], Test loss: [0.15961406]
# Train loss in epoch 292: [0.14268363], Test loss: [0.15934408]
# Train loss in epoch 293: [0.14246303], Test loss: [0.15907432]
# Train loss in epoch 294: [0.14224398], Test loss: [0.15880468]
# Train loss in epoch 295: [0.1420268], Test loss: [0.15853563]
# Train loss in epoch 296: [0.14181134], Test loss: [0.15826729]
# Train loss in epoch 297: [0.14159574], Test loss: [0.1579978]
# Train loss in epoch 298: [0.14138356], Test loss: [0.15772969]
# Train loss in epoch 299: [0.14117275], Test loss: [0.15746188]
# Train loss in epoch 300: [0.14096338], Test loss: [0.15719402]
# Train loss in epoch 301: [0.14075671], Test loss: [0.15692735]
# Train loss in epoch 302: [0.14055093], Test loss: [0.15666057]
# Train loss in epoch 303: [0.14034817], Test loss: [0.15639485]
# Train loss in epoch 304: [0.1401476], Test loss: [0.15612996]
# Train loss in epoch 305: [0.13994783], Test loss: [0.15586521]
# Train loss in epoch 306: [0.13975042], Test loss: [0.15560117]
# Train loss in epoch 307: [0.13955544], Test loss: [0.15533817]
# Train loss in epoch 308: [0.13936287], Test loss: [0.15507683]
# Train loss in epoch 309: [0.13917224], Test loss: [0.1548163]
# Train loss in epoch 310: [0.13898413], Test loss: [0.15455727]
# Train loss in epoch 311: [0.1387976], Test loss: [0.15429886]
# Train loss in epoch 312: [0.13861239], Test loss: [0.15404128]
# Train loss in epoch 313: [0.13842969], Test loss: [0.15378539]
# Train loss in epoch 314: [0.13824743], Test loss: [0.15352909]
# Train loss in epoch 315: [0.138069], Test loss: [0.15327626]
# Train loss in epoch 316: [0.13789228], Test loss: [0.15302457]
# Train loss in epoch 317: [0.13771753], Test loss: [0.15277429]
# Train loss in epoch 318: [0.13754381], Test loss: [0.15252504]
# Train loss in epoch 319: [0.13737108], Test loss: [0.15227622]
# Train loss in epoch 320: [0.13720027], Test loss: [0.15202954]
# Train loss in epoch 321: [0.13703097], Test loss: [0.15178441]
# Train loss in epoch 322: [0.13686267], Test loss: [0.15154052]
# Train loss in epoch 323: [0.13669619], Test loss: [0.15129863]
# Train loss in epoch 324: [0.13653189], Test loss: [0.15105885]
# Train loss in epoch 325: [0.13636886], Test loss: [0.15082103]
# Train loss in epoch 326: [0.13620606], Test loss: [0.15058361]
# Train loss in epoch 327: [0.1360456], Test loss: [0.15034978]
# Train loss in epoch 328: [0.13588683], Test loss: [0.15011744]
# Train loss in epoch 329: [0.1357291], Test loss: [0.14988708]
# Train loss in epoch 330: [0.13557363], Test loss: [0.14965954]
# Train loss in epoch 331: [0.13541982], Test loss: [0.14943413]
# Train loss in epoch 332: [0.13526689], Test loss: [0.14921099]
# Train loss in epoch 333: [0.13511552], Test loss: [0.1489895]
# Train loss in epoch 334: [0.13496581], Test loss: [0.148771]
# Train loss in epoch 335: [0.13481787], Test loss: [0.14855513]
# Train loss in epoch 336: [0.13467079], Test loss: [0.14834049]
# Train loss in epoch 337: [0.13452399], Test loss: [0.14812729]
# Train loss in epoch 338: [0.13437894], Test loss: [0.14791641]
# Train loss in epoch 339: [0.13423517], Test loss: [0.14770754]
# Train loss in epoch 340: [0.13409187], Test loss: [0.14749995]
# Train loss in epoch 341: [0.13395071], Test loss: [0.14729504]
# Train loss in epoch 342: [0.13381031], Test loss: [0.14709176]
# Train loss in epoch 343: [0.13366996], Test loss: [0.14688897]
# Train loss in epoch 344: [0.13353111], Test loss: [0.14668874]
# Train loss in epoch 345: [0.13339286], Test loss: [0.1464898]
# Train loss in epoch 346: [0.13325591], Test loss: [0.14629261]
# Train loss in epoch 347: [0.13311827], Test loss: [0.14609557]
# Train loss in epoch 348: [0.13298154], Test loss: [0.14590031]
# Train loss in epoch 349: [0.13284636], Test loss: [0.1457072]
# Train loss in epoch 350: [0.13271178], Test loss: [0.14551514]
# Train loss in epoch 351: [0.13257846], Test loss: [0.14532545]
# Train loss in epoch 352: [0.13244548], Test loss: [0.1451363]
# Train loss in epoch 353: [0.13231236], Test loss: [0.14494763]
# Train loss in epoch 354: [0.1321795], Test loss: [0.14475995]
# Train loss in epoch 355: [0.1320457], Test loss: [0.14457184]
# Train loss in epoch 356: [0.13191184], Test loss: [0.14438435]
# Train loss in epoch 357: [0.131778], Test loss: [0.14419705]
# Train loss in epoch 358: [0.13164361], Test loss: [0.14400993]
# Train loss in epoch 359: [0.13150963], Test loss: [0.14382325]
# Train loss in epoch 360: [0.13137457], Test loss: [0.14363605]
# Train loss in epoch 361: [0.13123979], Test loss: [0.1434491]
# Train loss in epoch 362: [0.13110392], Test loss: [0.14326215]
# Train loss in epoch 363: [0.13096794], Test loss: [0.14307497]
# Train loss in epoch 364: [0.13083223], Test loss: [0.1428881]
# Train loss in epoch 365: [0.13069598], Test loss: [0.14270136]
# Train loss in epoch 366: [0.13056159], Test loss: [0.14251626]
# Train loss in epoch 367: [0.13042562], Test loss: [0.14232937]
# Train loss in epoch 368: [0.13029122], Test loss: [0.14214428]
# Train loss in epoch 369: [0.13015519], Test loss: [0.14195763]
# Train loss in epoch 370: [0.13002023], Test loss: [0.14177173]
# Train loss in epoch 371: [0.12988441], Test loss: [0.14158486]
# Train loss in epoch 372: [0.12974826], Test loss: [0.14139776]
# Train loss in epoch 373: [0.12961151], Test loss: [0.14121011]
# Train loss in epoch 374: [0.12947461], Test loss: [0.1410218]
# Train loss in epoch 375: [0.12933704], Test loss: [0.14083309]
# Train loss in epoch 376: [0.12920064], Test loss: [0.14064485]
# Train loss in epoch 377: [0.12906474], Test loss: [0.14045763]
# Train loss in epoch 378: [0.12892775], Test loss: [0.14026903]
# Train loss in epoch 379: [0.1287916], Test loss: [0.14008133]
# Train loss in epoch 380: [0.12865619], Test loss: [0.13989413]
# Train loss in epoch 381: [0.12852007], Test loss: [0.1397064]
# Train loss in epoch 382: [0.12838534], Test loss: [0.13952009]
# Train loss in epoch 383: [0.12825017], Test loss: [0.13933313]
# Train loss in epoch 384: [0.12811497], Test loss: [0.13914663]
# Train loss in epoch 385: [0.12798049], Test loss: [0.13896054]
# Train loss in epoch 386: [0.12784611], Test loss: [0.13877469]
# Train loss in epoch 387: [0.12771334], Test loss: [0.13859068]
# Train loss in epoch 388: [0.12758024], Test loss: [0.13840643]
# Train loss in epoch 389: [0.12744929], Test loss: [0.13822475]
# Train loss in epoch 390: [0.12731619], Test loss: [0.13804144]
# Train loss in epoch 391: [0.12718461], Test loss: [0.13785982]
# Train loss in epoch 392: [0.12705268], Test loss: [0.13767825]
# Train loss in epoch 393: [0.12692052], Test loss: [0.13749769]
# Train loss in epoch 394: [0.12678789], Test loss: [0.13731696]
# Train loss in epoch 395: [0.12665598], Test loss: [0.13713771]
# Train loss in epoch 396: [0.12652339], Test loss: [0.13695872]
# Train loss in epoch 397: [0.12638976], Test loss: [0.13677931]
# Train loss in epoch 398: [0.12625565], Test loss: [0.1366007]
# Train loss in epoch 399: [0.12612046], Test loss: [0.13642181]
# Train loss in epoch 400: [0.12598445], Test loss: [0.1362433]
# Train loss in epoch 401: [0.1258464], Test loss: [0.13606374]
# Train loss in epoch 402: [0.12570839], Test loss: [0.1358856]
# Train loss in epoch 403: [0.12556767], Test loss: [0.13570596]
# Train loss in epoch 404: [0.12542702], Test loss: [0.13552806]
# Train loss in epoch 405: [0.12528528], Test loss: [0.13535064]
# Train loss in epoch 406: [0.12514235], Test loss: [0.13517383]
# Train loss in epoch 407: [0.12500092], Test loss: [0.13500039]
# Train loss in epoch 408: [0.12485681], Test loss: [0.13482663]
# Train loss in epoch 409: [0.12470935], Test loss: [0.13465072]
# Train loss in epoch 410: [0.12455643], Test loss: [0.13447037]
# Train loss in epoch 411: [0.12439576], Test loss: [0.13428299]
# Train loss in epoch 412: [0.12422691], Test loss: [0.13408883]
# Train loss in epoch 413: [0.12405279], Test loss: [0.13389061]
# Train loss in epoch 414: [0.12387221], Test loss: [0.133687]
# Train loss in epoch 415: [0.12368679], Test loss: [0.13347867]
# Train loss in epoch 416: [0.12349597], Test loss: [0.13326606]
# Train loss in epoch 417: [0.1233005], Test loss: [0.13305008]
# Train loss in epoch 418: [0.12310096], Test loss: [0.13283068]
# Train loss in epoch 419: [0.12289789], Test loss: [0.13260786]
# Train loss in epoch 420: [0.12269382], Test loss: [0.13238357]
# Train loss in epoch 421: [0.12248723], Test loss: [0.13215609]
# Train loss in epoch 422: [0.12227999], Test loss: [0.13192785]
# Train loss in epoch 423: [0.12207141], Test loss: [0.13169883]
# Train loss in epoch 424: [0.12186591], Test loss: [0.1314736]
# Train loss in epoch 425: [0.121663], Test loss: [0.13125183]
# Train loss in epoch 426: [0.1214659], Test loss: [0.13103624]
# Train loss in epoch 427: [0.12127569], Test loss: [0.13082722]
# Train loss in epoch 428: [0.12108919], Test loss: [0.13061987]
# Train loss in epoch 429: [0.12090985], Test loss: [0.13041757]
# Train loss in epoch 430: [0.12073161], Test loss: [0.1302146]
# Train loss in epoch 431: [0.12056204], Test loss: [0.13001896]
# Train loss in epoch 432: [0.12040855], Test loss: [0.12983848]
# Train loss in epoch 433: [0.12027497], Test loss: [0.12967765]
# Train loss in epoch 434: [0.12016955], Test loss: [0.12954576]
# Train loss in epoch 435: [0.12006587], Test loss: [0.12941636]
# Train loss in epoch 436: [0.11996137], Test loss: [0.12928392]
# Train loss in epoch 437: [0.11986314], Test loss: [0.12915552]
# Train loss in epoch 438: [0.11976928], Test loss: [0.12903021]
# Train loss in epoch 439: [0.11967928], Test loss: [0.12890743]
# Train loss in epoch 440: [0.11959302], Test loss: [0.12878738]
# Train loss in epoch 441: [0.11950773], Test loss: [0.12866746]
# Train loss in epoch 442: [0.11942557], Test loss: [0.12855005]
# Train loss in epoch 443: [0.11934306], Test loss: [0.1284315]
# Train loss in epoch 444: [0.1192679], Test loss: [0.12831967]
# Train loss in epoch 445: [0.11919756], Test loss: [0.12821205]
# Train loss in epoch 446: [0.11912877], Test loss: [0.1281051]
# Train loss in epoch 447: [0.11905769], Test loss: [0.12799525]
# Train loss in epoch 448: [0.1189872], Test loss: [0.12788509]
# Train loss in epoch 449: [0.11891489], Test loss: [0.12777257]
# Train loss in epoch 450: [0.11884305], Test loss: [0.1276602]
# Train loss in epoch 451: [0.1187682], Test loss: [0.12754424]
# Train loss in epoch 452: [0.11869211], Test loss: [0.12742707]
# Train loss in epoch 453: [0.11861558], Test loss: [0.1273088]
# Train loss in epoch 454: [0.11853832], Test loss: [0.12718996]
# Train loss in epoch 455: [0.11846246], Test loss: [0.12707242]
# Train loss in epoch 456: [0.11838637], Test loss: [0.1269543]
# Train loss in epoch 457: [0.11831061], Test loss: [0.12683684]
# Train loss in epoch 458: [0.11823244], Test loss: [0.12671706]
# Train loss in epoch 459: [0.11815026], Test loss: [0.12659356]
# Train loss in epoch 460: [0.11806798], Test loss: [0.12647036]
# Train loss in epoch 461: [0.11798602], Test loss: [0.12634766]
# Train loss in epoch 462: [0.11790246], Test loss: [0.12622352]
# Train loss in epoch 463: [0.11781818], Test loss: [0.12609915]
# Train loss in epoch 464: [0.11773218], Test loss: [0.12597346]
# Train loss in epoch 465: [0.11764512], Test loss: [0.12584721]
# Train loss in epoch 466: [0.11755495], Test loss: [0.1257187]
# Train loss in epoch 467: [0.11746202], Test loss: [0.12558809]
# Train loss in epoch 468: [0.11736968], Test loss: [0.12545867]
# Train loss in epoch 469: [0.11727685], Test loss: [0.12532987]
# Train loss in epoch 470: [0.11718284], Test loss: [0.12520115]
# Train loss in epoch 471: [0.11708897], Test loss: [0.12507427]
# Train loss in epoch 472: [0.11699495], Test loss: [0.1249487]
# Train loss in epoch 473: [0.11689994], Test loss: [0.12482397]
# Train loss in epoch 474: [0.1168044], Test loss: [0.12469991]
# Train loss in epoch 475: [0.11670917], Test loss: [0.12457553]
# Train loss in epoch 476: [0.11660957], Test loss: [0.12444503]
# Train loss in epoch 477: [0.11650555], Test loss: [0.12430856]
# Train loss in epoch 478: [0.11639707], Test loss: [0.12416576]
# Train loss in epoch 479: [0.11628375], Test loss: [0.12401723]
# Train loss in epoch 480: [0.11616777], Test loss: [0.12386502]
# Train loss in epoch 481: [0.11605419], Test loss: [0.12371457]
# Train loss in epoch 482: [0.11594138], Test loss: [0.12356412]
# Train loss in epoch 483: [0.11583448], Test loss: [0.12341908]
# Train loss in epoch 484: [0.11573236], Test loss: [0.12327823]
# Train loss in epoch 485: [0.11563385], Test loss: [0.12314084]
# Train loss in epoch 486: [0.11553838], Test loss: [0.12300541]
# Train loss in epoch 487: [0.1154475], Test loss: [0.12287385]
# Train loss in epoch 488: [0.11535881], Test loss: [0.12274364]
# Train loss in epoch 489: [0.11527389], Test loss: [0.12261697]
# Train loss in epoch 490: [0.11519017], Test loss: [0.12249099]
# Train loss in epoch 491: [0.11510825], Test loss: [0.12236606]
# Train loss in epoch 492: [0.11502819], Test loss: [0.12224287]
# Train loss in epoch 493: [0.11495024], Test loss: [0.12212115]
# Train loss in epoch 494: [0.1148725], Test loss: [0.12199958]
# Train loss in epoch 495: [0.11479607], Test loss: [0.12187918]
# Train loss in epoch 496: [0.1147197], Test loss: [0.12175867]
# Train loss in epoch 497: [0.11464541], Test loss: [0.12164003]
# Train loss in epoch 498: [0.11457133], Test loss: [0.12152144]
# Train loss in epoch 499: [0.11449855], Test loss: [0.12140422]

# %%
#Saving function checking..
dnn_inst.layers[0].w.name
# Out:
# 'Layer0/Matrix/read:0'

# %%
tf.trainable_variables()
# Out:
# [<tensorflow.python.ops.variables.Variable at 0x7f17cdcc6128>,
#  <tensorflow.python.ops.variables.Variable at 0x7f17cdcc65f8>,
#  <tensorflow.python.ops.variables.Variable at 0x7f17cdcc6630>,
#  <tensorflow.python.ops.variables.Variable at 0x7f17cdcc6c18>,
#  <tensorflow.python.ops.variables.Variable at 0x7f17cdcc6470>,
#  <tensorflow.python.ops.variables.Variable at 0x7f17cdc821d0>]

# %%
dnn_inst.save_variables_for_rnn("WEIGHTS_FOLDER/REWARD_NET.chkp")
# Out:
# RNN/FullNetworkCell/Reward/Layer2/Matrix
# Tensor("Layer2/Matrix/read:0", shape=(20, 1), dtype=float32)
# RNN/FullNetworkCell/Reward/Layer0/Bias
# Tensor("Layer0/Bias/read:0", shape=(20,), dtype=float32)
# RNN/FullNetworkCell/Reward/Layer1/Matrix
# Tensor("Layer1/Matrix/read:0", shape=(20, 20), dtype=float32)
# RNN/FullNetworkCell/Reward/Layer0/Matrix
# Tensor("Layer0/Matrix/read:0", shape=(4, 20), dtype=float32)
# RNN/FullNetworkCell/Reward/Layer2/Bias
# Tensor("Layer2/Bias/read:0", shape=(1,), dtype=float32)
# RNN/FullNetworkCell/Reward/Layer1/Bias
# Tensor("Layer1/Bias/read:0", shape=(20,), dtype=float32)
# /home/wuga/Documents/Notebook/VAE-PLANNING/WEIGHTS_FOLDER/REWARD_NET.chkp

# %%
dnn_inst.predict_test([[1,1,6,6]])
# Out:
# [array([[-1.97787595]], dtype=float32)]
