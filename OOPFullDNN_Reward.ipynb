# %% [markdown]
# # Fully Connected Network
#
# This is the second part of our whole deep learning planning structure.
#
# The Data in this experiments is generated from RDDL simulator [Github](https://github.com/ssanner/rddlsim), which is written by Prof.Scott Sanner at University of Toronto.
#
# In the section, we need a fully connected network to compute the reward of each (STATE,ACTION,STATE') tuple, that is (STATE,ACTION,STATE') -> Reward. Since this part is deterministic, fully connected network is capable to solve.
#
# Problem list:
# 1. Data normalization will highly impact the network performance, we need to normalize the input. However, the input of this section is an output of VAE, which is unnormalized. And since everything is working under tensorflow environment, we need to build normalizer inside tensorflow graph.
# 2. For reward function R(s,a), in nondeterministic domain, R(s,a) is stochastic. We need a deterministic function. Therefore, we rewrite the reward function as R(s,a,s'). This requires us to concate s,a,s' as single input matrix(also under tensorflow).

# %% [markdown]
# ### Import Packages
# We do note provide pip installation commands, please search this package and install it through pip install. Please upgrade your pip before installing, since old pip would cause errors.

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import tensorflow as tf
import numpy as np
from sklearn.metrics import confusion_matrix
import time
from datetime import timedelta
import math
import os
import pandas as pd
#Functional coding
import functools
from functools import partial
import re

# %% [markdown]
# ### Load Data
# We load data from csv files. The following code shows how to load data through pandas and numpy. Result of this progress can be feed into tensorflow with "feed_dict" argument.

# %%
#Data Path..
Datapath="DATA/Navigation/Nav_RDDL_Data.txt"
Labelpath="DATA/Navigation/Nav_RDDL_Label.txt"
Rewardpath="DATA/Navigation/Nav_RDDL_Reward.txt"

# %%
#Given local path, find full path
def PathFinder(path):
    #python 2
    #script_dir = os.path.dirname('__file__')
    #fullpath = os.path.join(script_dir,path)
    #python 3
    fullpath=os.path.abspath(path)
    print(fullpath)
    return fullpath

#Read Data for Deep Learning
def ReadData(path):
    fullpath=PathFinder(path)
    return pd.read_csv(fullpath, sep=',', header=0)

#Won't use this one to normalize
#Input Normalization
def Normalize(features, mean = [], std = []):
    if mean == []:
        mean = np.mean(features, axis = 0)
        std = np.std(features, axis = 0)
#     print std
#     print std[:,None]
    new_feature = (features.T - mean[:,None]).T
    new_feature = (new_feature.T / std[:,None]).T
    new_feature[np.isnan(new_feature)]=0
#     print new_feature
    return new_feature, mean, std

# %%
x_pd = ReadData(Datapath)
r_pd = ReadData(Rewardpath)
# Out:
# /home/wuga/Documents/Notebook/VAE-PLANNING/DATA/Navigation/Nav_RDDL_Data.txt
# /home/wuga/Documents/Notebook/VAE-PLANNING/DATA/Navigation/Nav_RDDL_Reward.txt

# %%
#Get Numpy Arrays
x_matrix=x_pd.as_matrix()
x_train = x_matrix[:100000]
x_valid = x_matrix[100000:]
r_matrix=r_pd.as_matrix()
r_train = r_matrix[:100000]
r_valid = r_matrix[100000:]

# %%
len(x_matrix)
# Out:
# 150000

# %%
data_size=len(x_matrix)
# Uppercase for constants
INPUT_S_A_SIZE = 4
OUTPUT_SIZE = 1

# %% [markdown]
# ### Support Functions
# The following functions allows us passthrough multiple functions without explicitly assign intermediate output variables.

# %%
def compose(f,g):
    return lambda x:g(f(x))
    
def composeAll(*args):
    """
    composeAll([f,g,h])(x): f(g(h(x)))
    """
    return partial(functools.reduce, compose)(*args)

# %% [markdown]
# ## Tensorflow
# ### Input tensor place holders

# %%
# Input features s,a
x = tf.placeholder(tf.float32,[None, INPUT_S_A_SIZE],name="Features_S_A")

# Input label
r = tf.placeholder(tf.float32, [None, OUTPUT_SIZE],name="Labels")

# %% [markdown]
# ### Variable Generating functions

# %%
#Weight constructing function
def weight_variable(shape):
    initial = tf.truncated_normal(shape,stddev=0.001)
    return tf.Variable(initial,name="Matrix")

#Bias constructing function
def bias_variable(shape):
    initial = tf.constant(0.,shape=shape)
    return tf.Variable(initial,name="Bias")

# %% [markdown]
# ### Fully Connected Layer Defination

# %%
class Dense():
    """Fully Connected Layer"""
    def __init__(self, scope="fully_connected_layer", output_dim =None, dropout=1.0, activation=tf.identity):
        assert output_dim, "Missing output dimension specification!"
        self.scope = scope
        self.output_dim = output_dim
        self.dropout = dropout
        self.activation = activation
        
    def __call__(self,x):
        with tf.name_scope(self.scope):
            while True:
                try:
                    return self.activation(tf.matmul(x,self.w)+self.b)
                except(AttributeError):
                    self.w = tf.nn.dropout(weight_variable([x.get_shape()[1].value, self.output_dim]),self.dropout)
                    self.b = bias_variable([self.output_dim])
    
    def set_parameters(self, weight, bias):
        self.w.assign(weight)
        self.b.assign(bias)
        
    def get_l2_loss(self):
        return tf.nn.l2_loss(self.w)

# %% [markdown]
# ### Full Deep Network Class
# The following class define a complete deep network, which include:
# 1. Network structure specification
# 2. Loss function specification
# 3. Prediction specification
# 4. Optimization method specification
# 5. Training function
# 6. Saving function(not tensorflow variable saving, but numpy weight dumping!)
# 7. Loading function(not tensorflow variable loading, but numpy weight assignment!)
# 8. Mini-Batch generation function

# %%
class DeepNet(object):
    
    def __init__(self, 
                 x, #Input Features for S,A
                 r, #Output Label for R
                 num_hidden_layers, #number of layers for both encoder and decoder
                 num_hidden_nodes, #number of nodes in each layer
                 activation, #nonlinear activation function
                 learning_rate=0.001, #Learning rate
                 dropout = 1,
                 batch_size=1000, 
                 l2_lambda = 1E-4): #Batch size        
#        self.mean = tf.Variable(tf.zeros([x.get_shape()[1]]),trainable=False,name="NORM_MEAN")
#        self.var = tf.Variable(tf.ones([x.get_shape()[1]]),trainable=False,name="NORM_VAR")
#        self.f = self._p_normalize(x)
        self.f = x
        self.r = r
        self.num_hidden_layers = num_hidden_layers
        self.num_hidden_nodes = num_hidden_nodes
        self.activation = activation
        self.learning_rate = learning_rate
        self.batch_size = batch_size
        self.l2_lambda = l2_lambda
        self.dropout = dropout
        self._p_create_dnn_graph()
        self._p_create_loss()
        self.sess = tf.InteractiveSession()
        self.sess.run(tf.global_variables_initializer())
        
    def _p_create_dnn_graph(self):

        layers = []
        for i in range(self.num_hidden_layers):
            layers.append(Dense("Layer"+str(i),self.num_hidden_nodes,self.dropout,self.activation))
        layers.append(Dense("Layer"+str(self.num_hidden_layers),self.r.get_shape()[1].value,self.dropout))
        self.r_pred = composeAll(layers)(self.f)
        self.layers = layers 
    
    def _p_normalize(self, unnormed):
        epsilon = 1e-3
        normed = tf.nn.batch_normalization(unnormed,self.mean,self.var,None,None,epsilon)
        return normed
        
    def _p_create_loss(self): #lambda for l2 regularization

        #L2 regularization loss
        l2_loss = tf.constant(0.0)
        for layer in self.layers:
            l2_loss += layer.get_l2_loss()

        #Mean Squared Error
        mse_r = tf.reduce_mean(tf.square(tf.sub(self.r,self.r_pred)), reduction_indices=1)

        #loss
        self.loss = tf.reduce_mean(mse_r)+self.l2_lambda*l2_loss
        self.optimizer = tf.train.RMSPropOptimizer(self.learning_rate).minimize(self.loss)   
        
    def update_normalization(self,x_matrix):
        tf_mean,tf_var = tf.nn.moments(x, axes = [0])
        feed_dict = {x:x_matrix}
        np_mean,np_var = self.sess.run([tf_mean,tf_var],feed_dict=feed_dict)
        print(np_mean)
        self.sess.run(self.mean.assign(np_mean))
        self.sess.run(self.var.assign(np_var))
        print(self.mean.eval())
        
    
    def train_model(self,train_s_a,train_r,test_s_a,test_r,epoch=100):
        
#        self.update_normalization(train_s_a)
        
        batches = self._p_get_batches(train_s_a,train_r,self.batch_size)
        
#        self.mean = tf.Variable(tf.zeros([x.get_shape()[1]]),trainable=False)
#        self.var = tf.Variable(tf.ones([x.get_shape()[1]]),trainable=False)
        
        summary_writer = tf.summary.FileWriter('experiment', graph=self.sess.graph)
        feed_test={x:test_s_a,r:test_r}
        feed_train={x:train_s_a, r:train_r}

        #Training
        for epoch in range(epoch):
            for step in range(len(batches)):
                feed_dict = {x: batches[step][0],r: batches[step][1]}
                training = self.sess.run([self.optimizer], feed_dict=feed_dict)
            train_loss = self.sess.run([self.loss],feed_dict=feed_dict)
            test_loss = self.sess.run([self.loss],feed_dict=feed_test)
            print('Train loss in epoch {0}: {1}, Test loss: {2}'.format(epoch, train_loss, test_loss)) 
            
    def predict_test(self, test_s_a):
        feed_dict={x:test_s_a}
        return self.sess.run([self.r_pred],feed_dict=feed_dict)
            
    def _p_get_batches(self,x_matrix,r_matrix,batch_size):
        remaining_size = len(x_matrix)
        batch_index=0
        batches = []
        while(remaining_size>0):
            batch = []
            if remaining_size<batch_size:
                batch.append(x_matrix[batch_index*batch_size:-1])
                batch.append(r_matrix[batch_index*batch_size:-1])
            else:
                batch.append(x_matrix[batch_index*batch_size:(batch_index+1)*batch_size]) 
                batch.append(r_matrix[batch_index*batch_size:(batch_index+1)*batch_size]) 
            batch_index+=1
            remaining_size-=batch_size
            batches.append(batch)
        return batches
    
    def _p_extract_weights(self):
        # a hashmap maps from layer name to weights and biases
        mp_layer_weights = {}

        #iteratively save values
        for dense in self.layers:
            values = {'weights':dense.w, 'biases':dense.b}
            mp_layer_weights[layer.scope] = values
        
        norms = {'mean':self.mean, 'var':self.var}
        mp_layer_weights['normalizations'] = norms

        return mp_layer_weights
    
    def save_weights(self,path):
        #extract weights from trained model
        layer_weights = self.sess.run(_p_extract_weights())
        print('Whole layer weights: {0}'.format(layer_weights))
        np.save(path,layer_weights)
    
    def load_weights(self,path):
        layer_weights = np.load(path)
        for dense in self.layers:
            print('Scope:{0}'.format(dense.scope))
            values = layer_weights.get(dense.scope)
            weights = values.get('weights')
            biases = values.get('biases')
            dense.set_parameters(weights,biases)
        print('Done!')
        
    def save_variables_for_rnn(self,path,prefix="RNN/FullNetworkCell/Reward/"):
        variables = tf.trainable_variables()
        var_dict = {}
        for v in variables:
            if "/read" in v.name:
                name = prefix+re.sub("/read", "", v.name)
                name = re.sub(":0", "", name)
                var_dict[name] = v
            else:
                name = prefix+v.name
                name = re.sub(":0", "", name)
                var_dict[name] = v
        for k,v in var_dict.items():
            print(k)
            print(v)
        saver = tf.train.Saver(var_dict)
        saver.save(self.sess, PathFinder(path))

# %%
#Instantiate a network
dnn_inst = DeepNet(x,r,2,32,tf.nn.sigmoid)

# %% [markdown]
# ### Tensorflow graph visualization function

# %%
from IPython.display import clear_output, Image, display, HTML

def strip_consts(graph_def, max_const_size=32):
    """Strip large constant values from graph_def."""
    strip_def = tf.GraphDef()
    for n0 in graph_def.node:
        n = strip_def.node.add() 
        n.MergeFrom(n0)
        if n.op == 'Const':
            tensor = n.attr['value'].tensor
            size = len(tensor.tensor_content)
            if size > max_const_size:
                tensor.tensor_content = "<stripped %d bytes>"%size
    return strip_def

def show_graph(graph_def, max_const_size=32):
    """Visualize TensorFlow graph."""
    if hasattr(graph_def, 'as_graph_def'):
        graph_def = graph_def.as_graph_def()
    strip_def = strip_consts(graph_def, max_const_size=max_const_size)
    code = """
        <script>
          function load() {{
            document.getElementById("{id}").pbtxt = {data};
          }}
        </script>
        <link rel="import" href="https://tensorboard.appspot.com/tf-graph-basic.build.html" onload=load()>
        <div style="height:600px">
          <tf-graph-basic id="{id}"></tf-graph-basic>
        </div>
    """.format(data=repr(str(strip_def)), id='graph'+str(np.random.rand()))

    iframe = """
        <iframe seamless style="width:960px;height:600px;border:0" srcdoc="{}"></iframe>
    """.format(code.replace('"', '&quot;'))
    display(HTML(iframe))

# %%
show_graph(tf.get_default_graph().as_graph_def())
# Out:
#         <iframe seamless style="width:960px;height:600px;border:0" srcdoc="
#         <script>
#           function load() {
#             document.getElementById(&quot;graph0.1263293840240418&quot;).pbtxt = 'node {\n  name: &quot;Features_S_A&quot;\n  op: &quot;Placeholder&quot;\n  attr {\n    key: &quot;dtype&quot;\n    value {\n      type: DT_FLOAT\n    }\n  }\n  attr {\n    key: &quot;shape&quot;\n    value {\n      shape {\n      }\n    }\n  }\n}\nnode {\n  name: &quot;Labels&quot;\n  op: &quot;Placeholder&quot;\n  attr {\n    key: &quot;dtype&quot;\n    value {\n      type: DT_FLOAT\n    }\n  }\n  attr {\n    key: &quot;shape&quot;\n    value {\n      shape {\n      }\n    }\n  }\n}\nnode {\n  name: &quot;Layer0/truncated_normal/shape&quot;\n  op: &quot;Const&quot;\n  attr {\n    key: &quot;dtype&quot;\n    value {\n      type: DT_INT32\n    }\n  }\n  attr {\n    key: &quot;value&quot;\n    value {\n      tensor {\n        dtype: DT_INT32\n        tensor_shape {\n          dim {\n            size: 2\n          }\n        }\n        tensor_content: &quot;\\004\\000\\000\\000 \\000\\000\\000&quot;\n      }\n    }\n  }\n}\nnode {\n  name: &quot;Layer0/truncated_normal/mean&quot;\n  op: &quot;Const&quot;\n  attr {\n    key: &quot;dtype&quot;\n    value {\n      type: DT_FLOAT\n    }\n  }\n  attr {\n    key: &quot;value&quot;\n    value {\n      tensor {\n        dtype: DT_FLOAT\n        tensor_shape {\n        }\n        float_val: 0.0\n      }\n    }\n  }\n}\nnode {\n  name: &quot;Layer0/truncated_normal/stddev&quot;\n  op: &quot;Const&quot;\n  attr {\n    key: &quot;dtype&quot;\n    value {\n      type: DT_FLOAT\n    }\n  }\n  attr {\n    key: &quot;value&quot;\n    value {\n      tensor {\n        dtype: DT_FLOAT\n        tensor_shape {\n        }\n        float_val: 0.0010000000474974513\n      }\n    }\n  }\n}\nnode {\n  name: &quot;Layer0/truncated_normal/TruncatedNormal&quot;\n  op: &quot;TruncatedNormal&quot;\n  input: &quot;Layer0/truncated_normal/shape&quot;\n  attr {\n    key: &quot;T&quot;\n    value {\n      type: DT_INT32\n    }\n  }\n  attr {\n    key: &quot;dtype&quot;\n    value {\n      type: DT_FLOAT\n    }\n  }\n  attr {\n    key: &quot;seed&quot;\n    value {\n      i: 0\n    }\n  }\n  attr {\n    key: &quot;seed2&quot;\n    value {\n      i: 0\n    }\n  }\n}\nnode {\n  name: &quot;Layer0/truncated_normal/mul&quot;\n  op: &quot;Mul&quot;\n  input: &quot;Layer0/truncated_normal/TruncatedNormal&quot;\n  input: &quot;Layer0/truncated_normal/stddev&quot;\n  attr {\n    key: &quot;T&quot;\n    value {\n      type: DT_FLOAT\n    }\n  }\n}\nnode {\n  name: &quot;Layer0/truncated_normal&quot;\n  op: &quot;Add&quot;\n  input: &quot;Layer0/truncated_normal/mul&quot;\n  input: &quot;Layer0/truncated_normal/mean&quot;\n  attr {\n    key: &quot;T&quot;\n    value {\n      type: DT_FLOAT\n    }\n  }\n}\nnode {\n  name: &quot;Layer0/Matrix&quot;\n  op: &quot;Variable&quot;\n  attr {\n    key: &quot;container&quot;\n    value {\n      s: &quot;&quot;\n    }\n  }\n  attr {\n    key: &quot;dtype&quot;\n    value {\n      type: DT_FLOAT\n    }\n  }\n  attr {\n    key: &quot;shape&quot;\n    value {\n      shape {\n        dim {\n          size: 4\n        }\n        dim {\n          size: 32\n        }\n      }\n    }\n  }\n  attr {\n    key: &quot;shared_name&quot;\n    value {\n      s: &quot;&quot;\n    }\n  }\n}\nnode {\n  name: &quot;Layer0/Matrix/Assign&quot;\n  op: &quot;Assign&quot;\n  input: &quot;Layer0/Matrix&quot;\n  input: &quot;Layer0/truncated_normal&quot;\n  attr {\n    key: &quot;T&quot;\n    value {\n      type: DT_FLOAT\n    }\n  }\n  attr {\n    key: &quot;_class&quot;\n    value {\n      list {\n        s: &quot;loc:@Layer0/Matrix&quot;\n      }\n    }\n  }\n  attr {\n    key: &quot;use_locking&quot;\n    value {\n      b: true\n    }\n  }\n  attr {\n    key: &quot;validate_shape&quot;\n    value {\n      b: true\n    }\n  }\n}\nnode {\n  name: &quot;Layer0/Matrix/read&quot;\n  op: &quot;Identity&quot;\n  input: &quot;Layer0/Matrix&quot;\n  attr {\n    key: &quot;T&quot;\n    value {\n      type: DT_FLOAT\n    }\n  }\n  attr { ...

# %% [markdown]
# ### Training

# %%
dnn_inst.train_model(x_train,r_train,x_valid,r_valid,1000)
# Out:
# Train loss in epoch 0: [25.73196], Test loss: [24.356087]
# Train loss in epoch 1: [16.190565], Test loss: [15.553084]
# Train loss in epoch 2: [15.616026], Test loss: [15.031964]
# Train loss in epoch 3: [15.524913], Test loss: [14.953809]
# Train loss in epoch 4: [15.513767], Test loss: [14.946056]
# Train loss in epoch 5: [15.512682], Test loss: [14.945406]
# Train loss in epoch 6: [15.511963], Test loss: [14.944837]
# Train loss in epoch 7: [15.511357], Test loss: [14.944332]
# Train loss in epoch 8: [15.510823], Test loss: [14.94387]
# Train loss in epoch 9: [15.510344], Test loss: [14.943454]
# Train loss in epoch 10: [15.509911], Test loss: [14.943074]
# Train loss in epoch 11: [15.509517], Test loss: [14.942718]
# Train loss in epoch 12: [15.509171], Test loss: [14.942393]
# Train loss in epoch 13: [15.508841], Test loss: [14.942087]
# Train loss in epoch 14: [15.508533], Test loss: [14.941803]
# Train loss in epoch 15: [15.508247], Test loss: [14.941532]
# Train loss in epoch 16: [15.507977], Test loss: [14.941275]
# Train loss in epoch 17: [15.507727], Test loss: [14.941042]
# Train loss in epoch 18: [15.507488], Test loss: [14.940814]
# Train loss in epoch 19: [15.507267], Test loss: [14.940605]
# Train loss in epoch 20: [15.50705], Test loss: [14.940399]
# Train loss in epoch 21: [15.506851], Test loss: [14.940205]
# Train loss in epoch 22: [15.506655], Test loss: [14.940018]
# Train loss in epoch 23: [15.506469], Test loss: [14.939836]
# Train loss in epoch 24: [15.506287], Test loss: [14.939663]
# Train loss in epoch 25: [15.506098], Test loss: [14.939483]
# Train loss in epoch 26: [15.505602], Test loss: [14.939004]
# Train loss in epoch 27: [15.393684], Test loss: [14.830704]
# Train loss in epoch 28: [14.66129], Test loss: [14.139904]
# Train loss in epoch 29: [13.993327], Test loss: [13.499943]
# Train loss in epoch 30: [13.532576], Test loss: [13.055637]
# Train loss in epoch 31: [13.199657], Test loss: [12.734915]
# Train loss in epoch 32: [12.902527], Test loss: [12.448939]
# Train loss in epoch 33: [12.596963], Test loss: [12.155534]
# Train loss in epoch 34: [12.267738], Test loss: [11.839613]
# Train loss in epoch 35: [11.910362], Test loss: [11.496596]
# Train loss in epoch 36: [11.521988], Test loss: [11.123036]
# Train loss in epoch 37: [11.100432], Test loss: [10.717545]
# Train loss in epoch 38: [10.644462], Test loss: [10.277806]
# Train loss in epoch 39: [10.153649], Test loss: [9.8043785]
# Train loss in epoch 40: [9.6283541], Test loss: [9.2969952]
# Train loss in epoch 41: [9.0698128], Test loss: [8.7568245]
# Train loss in epoch 42: [8.4803019], Test loss: [8.1860609]
# Train loss in epoch 43: [7.8633413], Test loss: [7.5880322]
# Train loss in epoch 44: [7.2238503], Test loss: [6.9674377]
# Train loss in epoch 45: [6.5683022], Test loss: [6.3302064]
# Train loss in epoch 46: [5.9047728], Test loss: [5.6847334]
# Train loss in epoch 47: [5.2428665], Test loss: [5.0401278]
# Train loss in epoch 48: [4.5933609], Test loss: [4.4077048]
# Train loss in epoch 49: [3.9673584], Test loss: [3.7988415]
# Train loss in epoch 50: [3.3750026], Test loss: [3.2248006]
# Train loss in epoch 51: [2.8245308], Test loss: [2.6956513]
# Train loss in epoch 52: [2.326267], Test loss: [2.2223291]
# Train loss in epoch 53: [1.8997686], Test loss: [1.8217579]
# Train loss in epoch 54: [1.5530733], Test loss: [1.501305]
# Train loss in epoch 55: [1.2860236], Test loss: [1.2602987]
# Train loss in epoch 56: [1.0911918], Test loss: [1.0894846]
# Train loss in epoch 57: [0.93383324], Test loss: [0.95359695]
# Train loss in epoch 58: [0.79335743], Test loss: [0.83358496]
# Train loss in epoch 59: [0.70625782], Test loss: [0.75971878]
# Train loss in epoch 60: [0.66062123], Test loss: [0.72251707]
# Train loss in epoch 61: [0.63311642], Test loss: [0.70154661]
# Train loss in epoch 62: [0.61570334], Test loss: [0.68903202]
# Train loss in epoch 63: [0.60695082], Test loss: [0.68328887]
# Train loss in epoch 64: [0.60337114], Test loss: [0.68113124]
# Train loss in epoch 65: [0.60152692], Test loss: [0.67989969]
# Train loss in epoch 66: [0.60012841], Test loss: [0.67879421]
# Train loss in epoch 67: [0.59887397], Test loss: [0.67770541]
# Train loss in epoch 68: [0.59769243], Test loss: [0.67663544]
# Train loss in epoch 69: [0.59656048], Test loss: [0.67559314]
# Train loss in epoch 70: [0.595465], Test loss: [0.67457992]
# Train loss in epoch 71: [0.59439653], Test loss: [0.67359376]
# Train loss in epoch 72: [0.59334797], Test loss: [0.67263043]
# Train loss in epoch 73: [0.59231257], Test loss: [0.67168987]
# Train loss in epoch 74: [0.59128582], Test loss: [0.67076749]
# Train loss in epoch 75: [0.59026301], Test loss: [0.66986293]
# Train loss in epoch 76: [0.58923841], Test loss: [0.66897041]
# Train loss in epoch 77: [0.58819991], Test loss: [0.66808015]
# Train loss in epoch 78: [0.58711874], Test loss: [0.66716468]
# Train loss in epoch 79: [0.58592999], Test loss: [0.66616279]
# Train loss in epoch 80: [0.5845229], Test loss: [0.66496617]
# Train loss in epoch 81: [0.5828346], Test loss: [0.66349405]
# Train loss in epoch 82: [0.58100241], Test loss: [0.66185695]
# Train loss in epoch 83: [0.57920003], Test loss: [0.66022569]
# Train loss in epoch 84: [0.57742125], Test loss: [0.65861189]
# Train loss in epoch 85: [0.57551748], Test loss: [0.65688413]
# Train loss in epoch 86: [0.57334489], Test loss: [0.65489465]
# Train loss in epoch 87: [0.57089579], Test loss: [0.65261209]
# Train loss in epoch 88: [0.56826532], Test loss: [0.65010154]
# Train loss in epoch 89: [0.56558734], Test loss: [0.64745879]
# Train loss in epoch 90: [0.56300133], Test loss: [0.64478594]
# Train loss in epoch 91: [0.56059766], Test loss: [0.64214045]
# Train loss in epoch 92: [0.55839914], Test loss: [0.63950759]
# Train loss in epoch 93: [0.55638814], Test loss: [0.63683057]
# Train loss in epoch 94: [0.55453813], Test loss: [0.63402736]
# Train loss in epoch 95: [0.55282789], Test loss: [0.63101739]
# Train loss in epoch 96: [0.55123931], Test loss: [0.62772578]
# Train loss in epoch 97: [0.54973578], Test loss: [0.62407577]
# Train loss in epoch 98: [0.54819685], Test loss: [0.61993688]
# Train loss in epoch 99: [0.54608274], Test loss: [0.61482078]
# Train loss in epoch 100: [0.53976071], Test loss: [0.60550982]
# Train loss in epoch 101: [0.51428086], Test loss: [0.57830024]
# Train loss in epoch 102: [0.48329183], Test loss: [0.54449916]
# Train loss in epoch 103: [0.4659487], Test loss: [0.52264535]
# Train loss in epoch 104: [0.44962859], Test loss: [0.50146961]
# Train loss in epoch 105: [0.43217209], Test loss: [0.47909981]
# Train loss in epoch 106: [0.41302124], Test loss: [0.45517501]
# Train loss in epoch 107: [0.3912245], Test loss: [0.42885852]
# Train loss in epoch 108: [0.36391345], Test loss: [0.39732262]
# Train loss in epoch 109: [0.33311084], Test loss: [0.36265323]
# Train loss in epoch 110: [0.30619675], Test loss: [0.33259514]
# Train loss in epoch 111: [0.28184786], Test loss: [0.3059662]
# Train loss in epoch 112: [0.25974908], Test loss: [0.28220594]
# Train loss in epoch 113: [0.24003063], Test loss: [0.26138392]
# Train loss in epoch 114: [0.22073798], Test loss: [0.24191296]
# Train loss in epoch 115: [0.20278463], Test loss: [0.22473682]
# Train loss in epoch 116: [0.18973921], Test loss: [0.21107212]
# Train loss in epoch 117: [0.18080588], Test loss: [0.20060316]
# Train loss in epoch 118: [0.17329128], Test loss: [0.19190502]
# Train loss in epoch 119: [0.16230997], Test loss: [0.18113294]
# Train loss in epoch 120: [0.15300602], Test loss: [0.17201485]
# Train loss in epoch 121: [0.1451429], Test loss: [0.16425535]
# Train loss in epoch 122: [0.13827448], Test loss: [0.15746282]
# Train loss in epoch 123: [0.13222496], Test loss: [0.15141998]
# Train loss in epoch 124: [0.12697347], Test loss: [0.14616732]
# Train loss in epoch 125: [0.12232091], Test loss: [0.14155096]
# Train loss in epoch 126: [0.11835149], Test loss: [0.13754658]
# Train loss in epoch 127: [0.11484437], Test loss: [0.13401286]
# Train loss in epoch 128: [0.11172406], Test loss: [0.13087897]
# Train loss in epoch 129: [0.10893601], Test loss: [0.12809046]
# Train loss in epoch 130: [0.1064361], Test loss: [0.12560177]
# Train loss in epoch 131: [0.1041877], Test loss: [0.12337433]
# Train loss in epoch 132: [0.10215927], Test loss: [0.12137473]
# Train loss in epoch 133: [0.10032407], Test loss: [0.11957466]
# Train loss in epoch 134: [0.098658837], Test loss: [0.11794851]
# Train loss in epoch 135: [0.097143352], Test loss: [0.11647479]
# Train loss in epoch 136: [0.095760018], Test loss: [0.1151341]
# Train loss in epoch 137: [0.094493575], Test loss: [0.11390977]
# Train loss in epoch 138: [0.09333086], Test loss: [0.11278612]
# Train loss in epoch 139: [0.092260465], Test loss: [0.11175106]
# Train loss in epoch 140: [0.091272764], Test loss: [0.11079246]
# Train loss in epoch 141: [0.090359524], Test loss: [0.10990024]
# Train loss in epoch 142: [0.089513481], Test loss: [0.10906533]
# Train loss in epoch 143: [0.088728696], Test loss: [0.10827998]
# Train loss in epoch 144: [0.087999433], Test loss: [0.10753661]
# Train loss in epoch 145: [0.087321095], Test loss: [0.10682891]
# Train loss in epoch 146: [0.086689018], Test loss: [0.10615066]
# Train loss in epoch 147: [0.086098894], Test loss: [0.1054972]
# Train loss in epoch 148: [0.085545644], Test loss: [0.10486215]
# Train loss in epoch 149: [0.085024595], Test loss: [0.10424186]
# Train loss in epoch 150: [0.084534973], Test loss: [0.10363457]
# Train loss in epoch 151: [0.084056579], Test loss: [0.10303287]
# Train loss in epoch 152: [0.083631895], Test loss: [0.10242134]
# Train loss in epoch 153: [0.083187222], Test loss: [0.10181145]
# Train loss in epoch 154: [0.082757883], Test loss: [0.10120653]
# Train loss in epoch 155: [0.08240892], Test loss: [0.10061456]
# Train loss in epoch 156: [0.082080647], Test loss: [0.10002805]
# Train loss in epoch 157: [0.081764042], Test loss: [0.09944243]
# Train loss in epoch 158: [0.081477873], Test loss: [0.098864868]
# Train loss in epoch 159: [0.081221431], Test loss: [0.098298505]
# Train loss in epoch 160: [0.080983073], Test loss: [0.097739816]
# Train loss in epoch 161: [0.080760032], Test loss: [0.097188711]
# Train loss in epoch 162: [0.080551788], Test loss: [0.09664575]
# Train loss in epoch 163: [0.080356956], Test loss: [0.096111394]
# Train loss in epoch 164: [0.080170281], Test loss: [0.095584676]
# Train loss in epoch 165: [0.079986796], Test loss: [0.095061779]
# Train loss in epoch 166: [0.079807892], Test loss: [0.094554685]
# Train loss in epoch 167: [0.079683885], Test loss: [0.09405598]
# Train loss in epoch 168: [0.079556927], Test loss: [0.093572669]
# Train loss in epoch 169: [0.079432003], Test loss: [0.093108073]
# Train loss in epoch 170: [0.079311922], Test loss: [0.092649423]
# Train loss in epoch 171: [0.079197586], Test loss: [0.092196614]
# Train loss in epoch 172: [0.079088144], Test loss: [0.091749057]
# Train loss in epoch 173: [0.078983568], Test loss: [0.091307148]
# Train loss in epoch 174: [0.078882709], Test loss: [0.090870067]
# Train loss in epoch 175: [0.078784868], Test loss: [0.090437278]
# Train loss in epoch 176: [0.078689538], Test loss: [0.090008654]
# Train loss in epoch 177: [0.07859531], Test loss: [0.089583069]
# Train loss in epoch 178: [0.078500703], Test loss: [0.089159951]
# Train loss in epoch 179: [0.078404807], Test loss: [0.088738516]
# Train loss in epoch 180: [0.078310676], Test loss: [0.088318586]
# Train loss in epoch 181: [0.078228623], Test loss: [0.08789748]
# Train loss in epoch 182: [0.078122459], Test loss: [0.087473407]
# Train loss in epoch 183: [0.078020781], Test loss: [0.087046422]
# Train loss in epoch 184: [0.077924892], Test loss: [0.086626843]
# Train loss in epoch 185: [0.077826098], Test loss: [0.08620508]
# Train loss in epoch 186: [0.077722602], Test loss: [0.085783757]
# Train loss in epoch 187: [0.077613696], Test loss: [0.085365221]
# Train loss in epoch 188: [0.077499956], Test loss: [0.084949642]
# Train loss in epoch 189: [0.077381358], Test loss: [0.084536202]
# Train loss in epoch 190: [0.077258244], Test loss: [0.084124841]
# Train loss in epoch 191: [0.077130646], Test loss: [0.083715573]
# Train loss in epoch 192: [0.0769981], Test loss: [0.083307557]
# Train loss in epoch 193: [0.076860636], Test loss: [0.082900897]
# Train loss in epoch 194: [0.076718003], Test loss: [0.082495734]
# Train loss in epoch 195: [0.076569699], Test loss: [0.082091726]
# Train loss in epoch 196: [0.076415971], Test loss: [0.081689]
# Train loss in epoch 197: [0.076256119], Test loss: [0.081287295]
# Train loss in epoch 198: [0.076090217], Test loss: [0.080887035]
# Train loss in epoch 199: [0.075917691], Test loss: [0.080487587]
# Train loss in epoch 200: [0.075738832], Test loss: [0.08008939]
# Train loss in epoch 201: [0.075553268], Test loss: [0.079692036]
# Train loss in epoch 202: [0.075360402], Test loss: [0.079295442]
# Train loss in epoch 203: [0.075161032], Test loss: [0.078900054]
# Train loss in epoch 204: [0.074954651], Test loss: [0.078505397]
# Train loss in epoch 205: [0.074741639], Test loss: [0.078111596]
# Train loss in epoch 206: [0.07452184], Test loss: [0.077718161]
# Train loss in epoch 207: [0.074296296], Test loss: [0.077325545]
# Train loss in epoch 208: [0.074065268], Test loss: [0.076932825]
# Train loss in epoch 209: [0.0738291], Test loss: [0.076539174]
# Train loss in epoch 210: [0.073585533], Test loss: [0.07614217]
# Train loss in epoch 211: [0.073331058], Test loss: [0.075739816]
# Train loss in epoch 212: [0.073078319], Test loss: [0.075354964]
# Train loss in epoch 213: [0.072820723], Test loss: [0.074962072]
# Train loss in epoch 214: [0.072585739], Test loss: [0.07459639]
# Train loss in epoch 215: [0.072344646], Test loss: [0.074232809]
# Train loss in epoch 216: [0.072094083], Test loss: [0.073867619]
# Train loss in epoch 217: [0.071837075], Test loss: [0.073500901]
# Train loss in epoch 218: [0.071571968], Test loss: [0.073129691]
# Train loss in epoch 219: [0.071294889], Test loss: [0.072749935]
# Train loss in epoch 220: [0.071000636], Test loss: [0.072356008]
# Train loss in epoch 221: [0.070687398], Test loss: [0.071945637]
# Train loss in epoch 222: [0.07035476], Test loss: [0.071517617]
# Train loss in epoch 223: [0.069997981], Test loss: [0.071068585]
# Train loss in epoch 224: [0.069620699], Test loss: [0.070604935]
# Train loss in epoch 225: [0.069260091], Test loss: [0.070160486]
# Train loss in epoch 226: [0.068914846], Test loss: [0.069730408]
# Train loss in epoch 227: [0.0685867], Test loss: [0.06931664]
# Train loss in epoch 228: [0.068265751], Test loss: [0.068928167]
# Train loss in epoch 229: [0.067882791], Test loss: [0.068483002]
# Train loss in epoch 230: [0.067506261], Test loss: [0.06804847]
# Train loss in epoch 231: [0.067131951], Test loss: [0.067616075]
# Train loss in epoch 232: [0.066754431], Test loss: [0.067181714]
# Train loss in epoch 233: [0.066371121], Test loss: [0.066743322]
# Train loss in epoch 234: [0.065981805], Test loss: [0.066301048]
# Train loss in epoch 235: [0.065584272], Test loss: [0.065852322]
# Train loss in epoch 236: [0.065178789], Test loss: [0.065397538]
# Train loss in epoch 237: [0.064766705], Test loss: [0.06493777]
# Train loss in epoch 238: [0.064346761], Test loss: [0.064471513]
# Train loss in epoch 239: [0.063920103], Test loss: [0.063999504]
# Train loss in epoch 240: [0.063485824], Test loss: [0.063520432]
# Train loss in epoch 241: [0.063046187], Test loss: [0.063036434]
# Train loss in epoch 242: [0.062600762], Test loss: [0.062546656]
# Train loss in epoch 243: [0.062150538], Test loss: [0.062051728]
# Train loss in epoch 244: [0.061696395], Test loss: [0.061552316]
# Train loss in epoch 245: [0.061239377], Test loss: [0.061049134]
# Train loss in epoch 246: [0.060780123], Test loss: [0.060542468]
# Train loss in epoch 247: [0.060320303], Test loss: [0.060033575]
# Train loss in epoch 248: [0.059861682], Test loss: [0.059524294]
# Train loss in epoch 249: [0.05940444], Test loss: [0.059014305]
# Train loss in epoch 250: [0.058951724], Test loss: [0.058506843]
# Train loss in epoch 251: [0.058504332], Test loss: [0.058002267]
# Train loss in epoch 252: [0.058063813], Test loss: [0.057502009]
# Train loss in epoch 253: [0.057638787], Test loss: [0.057017379]
# Train loss in epoch 254: [0.057187475], Test loss: [0.056489497]
# Train loss in epoch 255: [0.056763269], Test loss: [0.055986926]
# Train loss in epoch 256: [0.056375291], Test loss: [0.055528995]
# Train loss in epoch 257: [0.056009058], Test loss: [0.055092685]
# Train loss in epoch 258: [0.055663031], Test loss: [0.054675862]
# Train loss in epoch 259: [0.055337273], Test loss: [0.0542797]
# Train loss in epoch 260: [0.055030867], Test loss: [0.053904459]
# Train loss in epoch 261: [0.054742299], Test loss: [0.0535492]
# Train loss in epoch 262: [0.05447007], Test loss: [0.053213138]
# Train loss in epoch 263: [0.054212071], Test loss: [0.052894823]
# Train loss in epoch 264: [0.053965338], Test loss: [0.052592367]
# Train loss in epoch 265: [0.053720374], Test loss: [0.052304119]
# Train loss in epoch 266: [0.053488102], Test loss: [0.052032068]
# Train loss in epoch 267: [0.053246364], Test loss: [0.051772878]
# Train loss in epoch 268: [0.053032912], Test loss: [0.05151901]
# Train loss in epoch 269: [0.05282522], Test loss: [0.051276729]
# Train loss in epoch 270: [0.052622363], Test loss: [0.051044025]
# Train loss in epoch 271: [0.05242338], Test loss: [0.050819207]
# Train loss in epoch 272: [0.052228153], Test loss: [0.050601289]
# Train loss in epoch 273: [0.052036241], Test loss: [0.050389357]
# Train loss in epoch 274: [0.051847309], Test loss: [0.050182752]
# Train loss in epoch 275: [0.051660895], Test loss: [0.049981087]
# Train loss in epoch 276: [0.051476784], Test loss: [0.049783848]
# Train loss in epoch 277: [0.051294595], Test loss: [0.049590465]
# Train loss in epoch 278: [0.05111457], Test loss: [0.049400989]
# Train loss in epoch 279: [0.050936386], Test loss: [0.0492149]
# Train loss in epoch 280: [0.050760183], Test loss: [0.049032293]
# Train loss in epoch 281: [0.050585672], Test loss: [0.04885269]
# Train loss in epoch 282: [0.050413266], Test loss: [0.048676267]
# Train loss in epoch 283: [0.050242692], Test loss: [0.048502747]
# Train loss in epoch 284: [0.050074451], Test loss: [0.048332155]
# Train loss in epoch 285: [0.049908124], Test loss: [0.048164532]
# Train loss in epoch 286: [0.0497442], Test loss: [0.04799971]
# Train loss in epoch 287: [0.049582589], Test loss: [0.047837727]
# Train loss in epoch 288: [0.0494233], Test loss: [0.047678515]
# Train loss in epoch 289: [0.04926648], Test loss: [0.047522105]
# Train loss in epoch 290: [0.049112074], Test loss: [0.047368355]
# Train loss in epoch 291: [0.048960276], Test loss: [0.047217455]
# Train loss in epoch 292: [0.048811018], Test loss: [0.047069259]
# Train loss in epoch 293: [0.04866432], Test loss: [0.046923682]
# Train loss in epoch 294: [0.048520096], Test loss: [0.046780705]
# Train loss in epoch 295: [0.048378631], Test loss: [0.046640426]
# Train loss in epoch 296: [0.048239611], Test loss: [0.046502646]
# Train loss in epoch 297: [0.048103258], Test loss: [0.046367429]
# Train loss in epoch 298: [0.047969293], Test loss: [0.04623463]
# Train loss in epoch 299: [0.047837965], Test loss: [0.046104293]
# Train loss in epoch 300: [0.047708981], Test loss: [0.045976348]
# Train loss in epoch 301: [0.047582515], Test loss: [0.045850731]
# Train loss in epoch 302: [0.047458269], Test loss: [0.045727387]
# Train loss in epoch 303: [0.047336459], Test loss: [0.045606188]
# Train loss in epoch 304: [0.04721684], Test loss: [0.045487233]
# Train loss in epoch 305: [0.047099367], Test loss: [0.045370337]
# Train loss in epoch 306: [0.046984252], Test loss: [0.045255546]
# Train loss in epoch 307: [0.046870969], Test loss: [0.045142643]
# Train loss in epoch 308: [0.046759747], Test loss: [0.045031648]
# Train loss in epoch 309: [0.046650447], Test loss: [0.044922512]
# Train loss in epoch 310: [0.046543121], Test loss: [0.044815261]
# Train loss in epoch 311: [0.046437532], Test loss: [0.04470966]
# Train loss in epoch 312: [0.046333589], Test loss: [0.044605676]
# Train loss in epoch 313: [0.04623162], Test loss: [0.044503443]
# Train loss in epoch 314: [0.046131108], Test loss: [0.044402778]
# Train loss in epoch 315: [0.046032261], Test loss: [0.044303559]
# Train loss in epoch 316: [0.045934889], Test loss: [0.044205844]
# Train loss in epoch 317: [0.045838967], Test loss: [0.044109531]
# Train loss in epoch 318: [0.045744404], Test loss: [0.044014502]
# Train loss in epoch 319: [0.045651149], Test loss: [0.043920789]
# Train loss in epoch 320: [0.04555925], Test loss: [0.043828376]
# Train loss in epoch 321: [0.045468673], Test loss: [0.043737177]
# Train loss in epoch 322: [0.045379158], Test loss: [0.043647125]
# Train loss in epoch 323: [0.045290776], Test loss: [0.043558143]
# Train loss in epoch 324: [0.045203604], Test loss: [0.043470331]
# Train loss in epoch 325: [0.045117378], Test loss: [0.043383449]
# Train loss in epoch 326: [0.045032226], Test loss: [0.043297671]
# Train loss in epoch 327: [0.044947982], Test loss: [0.043212838]
# Train loss in epoch 328: [0.044864729], Test loss: [0.0431289]
# Train loss in epoch 329: [0.044782184], Test loss: [0.043045782]
# Train loss in epoch 330: [0.04470066], Test loss: [0.042963624]
# Train loss in epoch 331: [0.044619747], Test loss: [0.042882219]
# Train loss in epoch 332: [0.04453972], Test loss: [0.042801671]
# Train loss in epoch 333: [0.044460319], Test loss: [0.042721745]
# Train loss in epoch 334: [0.044381697], Test loss: [0.042642638]
# Train loss in epoch 335: [0.044303745], Test loss: [0.042564251]
# Train loss in epoch 336: [0.044226237], Test loss: [0.042486414]
# Train loss in epoch 337: [0.044149581], Test loss: [0.042409386]
# Train loss in epoch 338: [0.044073399], Test loss: [0.042332932]
# Train loss in epoch 339: [0.043997765], Test loss: [0.042257052]
# Train loss in epoch 340: [0.043922625], Test loss: [0.042181723]
# Train loss in epoch 341: [0.043848168], Test loss: [0.042107102]
# Train loss in epoch 342: [0.043774143], Test loss: [0.04203292]
# Train loss in epoch 343: [0.043700535], Test loss: [0.041959289]
# Train loss in epoch 344: [0.043627657], Test loss: [0.041886229]
# Train loss in epoch 345: [0.043555297], Test loss: [0.041813739]
# Train loss in epoch 346: [0.043483354], Test loss: [0.041741744]
# Train loss in epoch 347: [0.043412022], Test loss: [0.0416703]
# Train loss in epoch 348: [0.043341085], Test loss: [0.041599303]
# Train loss in epoch 349: [0.043270793], Test loss: [0.041528873]
# Train loss in epoch 350: [0.043201096], Test loss: [0.041458987]
# Train loss in epoch 351: [0.043131799], Test loss: [0.041389585]
# Train loss in epoch 352: [0.043063164], Test loss: [0.041320708]
# Train loss in epoch 353: [0.042995013], Test loss: [0.04125233]
# Train loss in epoch 354: [0.042927548], Test loss: [0.041184444]
# Train loss in epoch 355: [0.042860575], Test loss: [0.041117154]
# Train loss in epoch 356: [0.042794198], Test loss: [0.04105027]
# Train loss in epoch 357: [0.042728644], Test loss: [0.040984057]
# Train loss in epoch 358: [0.042663701], Test loss: [0.040918276]
# Train loss in epoch 359: [0.042599883], Test loss: [0.040853299]
# Train loss in epoch 360: [0.042537268], Test loss: [0.040789068]
# Train loss in epoch 361: [0.042476326], Test loss: [0.040725991]
# Train loss in epoch 362: [0.042417306], Test loss: [0.040664218]
# Train loss in epoch 363: [0.042361014], Test loss: [0.040604156]
# Train loss in epoch 364: [0.042305715], Test loss: [0.040544979]
# Train loss in epoch 365: [0.042251371], Test loss: [0.040486556]
# Train loss in epoch 366: [0.042197518], Test loss: [0.040428579]
# Train loss in epoch 367: [0.042146105], Test loss: [0.040372051]
# Train loss in epoch 368: [0.042087555], Test loss: [0.040311709]
# Train loss in epoch 369: [0.04205342], Test loss: [0.040265307]
# Train loss in epoch 370: [0.041929245], Test loss: [0.040168419]
# Train loss in epoch 371: [0.042010456], Test loss: [0.040189896]
# Train loss in epoch 372: [0.041743461], Test loss: [0.040011454]
# Train loss in epoch 373: [0.041874722], Test loss: [0.04006125]
# Train loss in epoch 374: [0.041604251], Test loss: [0.039880205]
# Train loss in epoch 375: [0.041744687], Test loss: [0.039935771]
# Train loss in epoch 376: [0.041474175], Test loss: [0.039754197]
# Train loss in epoch 377: [0.041614562], Test loss: [0.039810762]
# Train loss in epoch 378: [0.041344278], Test loss: [0.039628971]
# Train loss in epoch 379: [0.041484274], Test loss: [0.039686248]
# Train loss in epoch 380: [0.041214794], Test loss: [0.039504461]
# Train loss in epoch 381: [0.041354351], Test loss: [0.039562412]
# Train loss in epoch 382: [0.041084982], Test loss: [0.03938026]
# Train loss in epoch 383: [0.041224644], Test loss: [0.039439116]
# Train loss in epoch 384: [0.04095627], Test loss: [0.039257102]
# Train loss in epoch 385: [0.041095473], Test loss: [0.039316565]
# Train loss in epoch 386: [0.040827341], Test loss: [0.039134271]
# Train loss in epoch 387: [0.040966775], Test loss: [0.039194793]
# Train loss in epoch 388: [0.040697802], Test loss: [0.039011404]
# Train loss in epoch 389: [0.040838003], Test loss: [0.039073188]
# Train loss in epoch 390: [0.040569074], Test loss: [0.038889378]
# Train loss in epoch 391: [0.040709034], Test loss: [0.038951874]
# Train loss in epoch 392: [0.040440463], Test loss: [0.038767815]
# Train loss in epoch 393: [0.040580019], Test loss: [0.038830854]
# Train loss in epoch 394: [0.040313654], Test loss: [0.038647518]
# Train loss in epoch 395: [0.040450852], Test loss: [0.038710088]
# Train loss in epoch 396: [0.040187888], Test loss: [0.038528159]
# Train loss in epoch 397: [0.040321186], Test loss: [0.038589358]
# Train loss in epoch 398: [0.040066794], Test loss: [0.038411722]
# Train loss in epoch 399: [0.040190909], Test loss: [0.038468413]
# Train loss in epoch 400: [0.039958227], Test loss: [0.03830253]
# Train loss in epoch 401: [0.04005944], Test loss: [0.038346685]
# Train loss in epoch 402: [0.039863937], Test loss: [0.038202979]
# Train loss in epoch 403: [0.039922945], Test loss: [0.038222231]
# Train loss in epoch 404: [0.039780952], Test loss: [0.038110197]
# Train loss in epoch 405: [0.039788432], Test loss: [0.0380987]
# Train loss in epoch 406: [0.039658319], Test loss: [0.037995391]
# Train loss in epoch 407: [0.039653458], Test loss: [0.037975706]
# Train loss in epoch 408: [0.03953556], Test loss: [0.037880935]
# Train loss in epoch 409: [0.039517056], Test loss: [0.03785212]
# Train loss in epoch 410: [0.039412662], Test loss: [0.037766729]
# Train loss in epoch 411: [0.03937912], Test loss: [0.037727967]
# Train loss in epoch 412: [0.039290681], Test loss: [0.037653133]
# Train loss in epoch 413: [0.039243668], Test loss: [0.037605628]
# Train loss in epoch 414: [0.039167933], Test loss: [0.037539251]
# Train loss in epoch 415: [0.039110895], Test loss: [0.037485331]
# Train loss in epoch 416: [0.039042901], Test loss: [0.037424207]
# Train loss in epoch 417: [0.038980499], Test loss: [0.037366904]
# Train loss in epoch 418: [0.038915649], Test loss: [0.037308104]
# Train loss in epoch 419: [0.038851671], Test loss: [0.037250001]
# Train loss in epoch 420: [0.038787305], Test loss: [0.037191693]
# Train loss in epoch 421: [0.03872288], Test loss: [0.03713353]
# Train loss in epoch 422: [0.038658846], Test loss: [0.037075683]
# Train loss in epoch 423: [0.03859482], Test loss: [0.037017953]
# Train loss in epoch 424: [0.038530931], Test loss: [0.036960408]
# Train loss in epoch 425: [0.038467035], Test loss: [0.036902908]
# Train loss in epoch 426: [0.038403951], Test loss: [0.036846057]
# Train loss in epoch 427: [0.038341001], Test loss: [0.036789425]
# Train loss in epoch 428: [0.038278483], Test loss: [0.036733095]
# Train loss in epoch 429: [0.038216606], Test loss: [0.036677334]
# Train loss in epoch 430: [0.038155168], Test loss: [0.036621872]
# Train loss in epoch 431: [0.038094357], Test loss: [0.036566969]
# Train loss in epoch 432: [0.038034514], Test loss: [0.036512766]
# Train loss in epoch 433: [0.037974652], Test loss: [0.036458667]
# Train loss in epoch 434: [0.037915863], Test loss: [0.036405332]
# Train loss in epoch 435: [0.037857298], Test loss: [0.036352232]
# Train loss in epoch 436: [0.037799452], Test loss: [0.03629972]
# Train loss in epoch 437: [0.037741691], Test loss: [0.036247365]
# Train loss in epoch 438: [0.037685268], Test loss: [0.036195993]
# Train loss in epoch 439: [0.037628047], Test loss: [0.036144137]
# Train loss in epoch 440: [0.037571654], Test loss: [0.036092937]
# Train loss in epoch 441: [0.03751573], Test loss: [0.036042184]
# Train loss in epoch 442: [0.037459537], Test loss: [0.035991348]
# Train loss in epoch 443: [0.037403967], Test loss: [0.035940982]
# Train loss in epoch 444: [0.037348397], Test loss: [0.03589071]
# Train loss in epoch 445: [0.03729289], Test loss: [0.035840578]
# Train loss in epoch 446: [0.037237622], Test loss: [0.035790704]
# Train loss in epoch 447: [0.037182264], Test loss: [0.0357408]
# Train loss in epoch 448: [0.037126582], Test loss: [0.035690781]
# Train loss in epoch 449: [0.03707125], Test loss: [0.035641067]
# Train loss in epoch 450: [0.037016343], Test loss: [0.035591785]
# Train loss in epoch 451: [0.036960229], Test loss: [0.035541631]
# Train loss in epoch 452: [0.036904875], Test loss: [0.035492167]
# Train loss in epoch 453: [0.036849346], Test loss: [0.035442553]
# Train loss in epoch 454: [0.036793664], Test loss: [0.035393015]
# Train loss in epoch 455: [0.036737844], Test loss: [0.035343338]
# Train loss in epoch 456: [0.036682174], Test loss: [0.035293892]
# Train loss in epoch 457: [0.036626082], Test loss: [0.03524413]
# Train loss in epoch 458: [0.036570199], Test loss: [0.035194643]
# Train loss in epoch 459: [0.036514163], Test loss: [0.035145134]
# Train loss in epoch 460: [0.036457997], Test loss: [0.03509555]
# Train loss in epoch 461: [0.036401518], Test loss: [0.035045739]
# Train loss in epoch 462: [0.03634556], Test loss: [0.034996442]
# Train loss in epoch 463: [0.036289051], Test loss: [0.034946717]
# Train loss in epoch 464: [0.036232539], Test loss: [0.034897074]
# Train loss in epoch 465: [0.036176044], Test loss: [0.034847524]
# Train loss in epoch 466: [0.036119722], Test loss: [0.034798123]
# Train loss in epoch 467: [0.036062837], Test loss: [0.034748286]
# Train loss in epoch 468: [0.03600648], Test loss: [0.034698945]
# Train loss in epoch 469: [0.03594961], Test loss: [0.034649245]
# Train loss in epoch 470: [0.035893299], Test loss: [0.034600064]
# Train loss in epoch 471: [0.035836078], Test loss: [0.034550127]
# Train loss in epoch 472: [0.035779532], Test loss: [0.034500815]
# Train loss in epoch 473: [0.035722934], Test loss: [0.0344515]
# Train loss in epoch 474: [0.03566584], Test loss: [0.034401786]
# Train loss in epoch 475: [0.035609543], Test loss: [0.034352746]
# Train loss in epoch 476: [0.035553023], Test loss: [0.034303587]
# Train loss in epoch 477: [0.035496157], Test loss: [0.034254134]
# Train loss in epoch 478: [0.03543945], Test loss: [0.034204844]
# Train loss in epoch 479: [0.035383016], Test loss: [0.034155823]
# Train loss in epoch 480: [0.03532619], Test loss: [0.034106456]
# Train loss in epoch 481: [0.035269544], Test loss: [0.034057282]
# Train loss in epoch 482: [0.035213064], Test loss: [0.034008276]
# Train loss in epoch 483: [0.035156637], Test loss: [0.033959329]
# Train loss in epoch 484: [0.035100415], Test loss: [0.033910576]
# Train loss in epoch 485: [0.035043634], Test loss: [0.033861347]
# Train loss in epoch 486: [0.034987804], Test loss: [0.033812914]
# Train loss in epoch 487: [0.034930892], Test loss: [0.03376364]
# Train loss in epoch 488: [0.034875087], Test loss: [0.033715244]
# Train loss in epoch 489: [0.034819271], Test loss: [0.033666838]
# Train loss in epoch 490: [0.034763008], Test loss: [0.033618085]
# Train loss in epoch 491: [0.034707367], Test loss: [0.033569846]
# Train loss in epoch 492: [0.034651455], Test loss: [0.033521418]
# Train loss in epoch 493: [0.034595057], Test loss: [0.033472553]
# Train loss in epoch 494: [0.034540027], Test loss: [0.033424843]
# Train loss in epoch 495: [0.034484141], Test loss: [0.033376411]
# Train loss in epoch 496: [0.034428801], Test loss: [0.033328444]
# Train loss in epoch 497: [0.034373127], Test loss: [0.033280142]
# Train loss in epoch 498: [0.034317836], Test loss: [0.03323222]
# Train loss in epoch 499: [0.034262553], Test loss: [0.033184271]
# Train loss in epoch 500: [0.034207202], Test loss: [0.033136219]
# Train loss in epoch 501: [0.034152243], Test loss: [0.033088539]
# Train loss in epoch 502: [0.034097012], Test loss: [0.033040605]
# Train loss in epoch 503: [0.03404215], Test loss: [0.032992925]
# Train loss in epoch 504: [0.033987038], Test loss: [0.032945104]
# Train loss in epoch 505: [0.033932477], Test loss: [0.032897692]
# Train loss in epoch 506: [0.033877816], Test loss: [0.032850169]
# Train loss in epoch 507: [0.033822808], Test loss: [0.032802332]
# Train loss in epoch 508: [0.033768132], Test loss: [0.032754764]
# Train loss in epoch 509: [0.03371365], Test loss: [0.032707334]
# Train loss in epoch 510: [0.033659112], Test loss: [0.032659866]
# Train loss in epoch 511: [0.033604596], Test loss: [0.032612342]
# Train loss in epoch 512: [0.03355002], Test loss: [0.032564797]
# Train loss in epoch 513: [0.03349597], Test loss: [0.032517612]
# Train loss in epoch 514: [0.033441402], Test loss: [0.032470033]
# Train loss in epoch 515: [0.033386651], Test loss: [0.032422226]
# Train loss in epoch 516: [0.033332847], Test loss: [0.032375172]
# Train loss in epoch 517: [0.03327778], Test loss: [0.032327056]
# Train loss in epoch 518: [0.033223517], Test loss: [0.032279596]
# Train loss in epoch 519: [0.033169027], Test loss: [0.032231897]
# Train loss in epoch 520: [0.033115], Test loss: [0.032184608]
# Train loss in epoch 521: [0.033060402], Test loss: [0.032136749]
# Train loss in epoch 522: [0.033006296], Test loss: [0.032089286]
# Train loss in epoch 523: [0.032951474], Test loss: [0.032041192]
# Train loss in epoch 524: [0.032896698], Test loss: [0.031993054]
# Train loss in epoch 525: [0.032842781], Test loss: [0.03194572]
# Train loss in epoch 526: [0.032787714], Test loss: [0.03189728]
# Train loss in epoch 527: [0.032733425], Test loss: [0.031849481]
# Train loss in epoch 528: [0.032678936], Test loss: [0.031801496]
# Train loss in epoch 529: [0.032625206], Test loss: [0.03175408]
# Train loss in epoch 530: [0.032570716], Test loss: [0.031706005]
# Train loss in epoch 531: [0.032515701], Test loss: [0.031657431]
# Train loss in epoch 532: [0.032460697], Test loss: [0.031608824]
# Train loss in epoch 533: [0.032406673], Test loss: [0.031560965]
# Train loss in epoch 534: [0.032352172], Test loss: [0.03151273]
# Train loss in epoch 535: [0.032297276], Test loss: [0.03146401]
# Train loss in epoch 536: [0.032242976], Test loss: [0.031415835]
# Train loss in epoch 537: [0.032188848], Test loss: [0.031367686]
# Train loss in epoch 538: [0.03213378], Test loss: [0.03131872]
# Train loss in epoch 539: [0.032080673], Test loss: [0.031271342]
# Train loss in epoch 540: [0.032025915], Test loss: [0.031222485]
# Train loss in epoch 541: [0.031971991], Test loss: [0.03117425]
# Train loss in epoch 542: [0.031918321], Test loss: [0.031126171]
# Train loss in epoch 543: [0.031864412], Test loss: [0.031077817]
# Train loss in epoch 544: [0.031810429], Test loss: [0.031029277]
# Train loss in epoch 545: [0.031757139], Test loss: [0.03098128]
# Train loss in epoch 546: [0.031702865], Test loss: [0.030932277]
# Train loss in epoch 547: [0.031649016], Test loss: [0.030883554]
# Train loss in epoch 548: [0.031595334], Test loss: [0.030834857]
# Train loss in epoch 549: [0.031542026], Test loss: [0.030786335]
# Train loss in epoch 550: [0.031487528], Test loss: [0.030736636]
# Train loss in epoch 551: [0.031434715], Test loss: [0.030688267]
# Train loss in epoch 552: [0.031381313], Test loss: [0.030639194]
# Train loss in epoch 553: [0.031327743], Test loss: [0.030589797]
# Train loss in epoch 554: [0.031273931], Test loss: [0.030540032]
# Train loss in epoch 555: [0.031219412], Test loss: [0.030489396]
# Train loss in epoch 556: [0.031165298], Test loss: [0.030438866]
# Train loss in epoch 557: [0.031111117], Test loss: [0.030388072]
# Train loss in epoch 558: [0.031056695], Test loss: [0.030336771]
# Train loss in epoch 559: [0.031001393], Test loss: [0.03028439]
# Train loss in epoch 560: [0.03094586], Test loss: [0.030231517]
# Train loss in epoch 561: [0.030888878], Test loss: [0.030177088]
# Train loss in epoch 562: [0.030831719], Test loss: [0.030122079]
# Train loss in epoch 563: [0.030773217], Test loss: [0.030065546]
# Train loss in epoch 564: [0.030714076], Test loss: [0.030008107]
# Train loss in epoch 565: [0.030653572], Test loss: [0.029949021]
# Train loss in epoch 566: [0.030591324], Test loss: [0.029888006]
# Train loss in epoch 567: [0.030526575], Test loss: [0.029824421]
# Train loss in epoch 568: [0.030460179], Test loss: [0.02975902]
# Train loss in epoch 569: [0.030390635], Test loss: [0.029690541]
# Train loss in epoch 570: [0.030319497], Test loss: [0.029620362]
# Train loss in epoch 571: [0.030244235], Test loss: [0.029546402]
# Train loss in epoch 572: [0.030163694], Test loss: [0.029467743]
# Train loss in epoch 573: [0.030079124], Test loss: [0.0293856]
# Train loss in epoch 574: [0.029990014], Test loss: [0.029299695]
# Train loss in epoch 575: [0.029896004], Test loss: [0.029209867]
# Train loss in epoch 576: [0.029796891], Test loss: [0.029116061]
# Train loss in epoch 577: [0.029690161], Test loss: [0.029016368]
# Train loss in epoch 578: [0.029579867], Test loss: [0.028914228]
# Train loss in epoch 579: [0.029464478], Test loss: [0.028808553]
# Train loss in epoch 580: [0.02934497], Test loss: [0.028700169]
# Train loss in epoch 581: [0.029224558], Test loss: [0.028591799]
# Train loss in epoch 582: [0.029104695], Test loss: [0.028484598]
# Train loss in epoch 583: [0.028984969], Test loss: [0.02837825]
# Train loss in epoch 584: [0.02886652], Test loss: [0.028273605]
# Train loss in epoch 585: [0.028753279], Test loss: [0.02817378]
# Train loss in epoch 586: [0.028645497], Test loss: [0.028078917]
# Train loss in epoch 587: [0.028541075], Test loss: [0.027987318]
# Train loss in epoch 588: [0.028442938], Test loss: [0.027901184]
# Train loss in epoch 589: [0.028351376], Test loss: [0.027820727]
# Train loss in epoch 590: [0.02826447], Test loss: [0.027744316]
# Train loss in epoch 591: [0.028184274], Test loss: [0.027673593]
# Train loss in epoch 592: [0.028109174], Test loss: [0.027607203]
# Train loss in epoch 593: [0.028039277], Test loss: [0.027545214]
# Train loss in epoch 594: [0.027973201], Test loss: [0.027486475]
# Train loss in epoch 595: [0.027912503], Test loss: [0.02743225]
# Train loss in epoch 596: [0.027855964], Test loss: [0.027381517]
# Train loss in epoch 597: [0.027804293], Test loss: [0.027334817]
# Train loss in epoch 598: [0.027755689], Test loss: [0.027290734]
# Train loss in epoch 599: [0.02771109], Test loss: [0.027249999]
# Train loss in epoch 600: [0.027670275], Test loss: [0.027212428]
# Train loss in epoch 601: [0.02763167], Test loss: [0.027176719]
# Train loss in epoch 602: [0.02759666], Test loss: [0.027144026]
# Train loss in epoch 603: [0.027563617], Test loss: [0.027113037]
# Train loss in epoch 604: [0.027533785], Test loss: [0.027084697]
# Train loss in epoch 605: [0.027506102], Test loss: [0.027058218]
# Train loss in epoch 606: [0.027480716], Test loss: [0.027033642]
# Train loss in epoch 607: [0.02745817], Test loss: [0.027011488]
# Train loss in epoch 608: [0.027436979], Test loss: [0.026990477]
# Train loss in epoch 609: [0.027417872], Test loss: [0.026971273]
# Train loss in epoch 610: [0.027400609], Test loss: [0.0269536]
# Train loss in epoch 611: [0.027384553], Test loss: [0.026937015]
# Train loss in epoch 612: [0.027371496], Test loss: [0.026922917]
# Train loss in epoch 613: [0.02736], Test loss: [0.026910169]
# Train loss in epoch 614: [0.027349677], Test loss: [0.026898492]
# Train loss in epoch 615: [0.027341038], Test loss: [0.026888229]
# Train loss in epoch 616: [0.027333898], Test loss: [0.026879288]
# Train loss in epoch 617: [0.027328199], Test loss: [0.026871577]
# Train loss in epoch 618: [0.027324196], Test loss: [0.026865361]
# Train loss in epoch 619: [0.027322184], Test loss: [0.026860878]
# Train loss in epoch 620: [0.027321246], Test loss: [0.026857335]
# Train loss in epoch 621: [0.027323125], Test loss: [0.026856238]
# Train loss in epoch 622: [0.027326081], Test loss: [0.026856173]
# Train loss in epoch 623: [0.027330518], Test loss: [0.026857413]
# Train loss in epoch 624: [0.027337354], Test loss: [0.026860781]
# Train loss in epoch 625: [0.027345184], Test loss: [0.02686511]
# Train loss in epoch 626: [0.027354602], Test loss: [0.026870903]
# Train loss in epoch 627: [0.027365591], Test loss: [0.026878173]
# Train loss in epoch 628: [0.027375927], Test loss: [0.026885059]
# Train loss in epoch 629: [0.027385684], Test loss: [0.026891615]
# Train loss in epoch 630: [0.027397087], Test loss: [0.026899831]
# Train loss in epoch 631: [0.027405404], Test loss: [0.026905704]
# Train loss in epoch 632: [0.027408343], Test loss: [0.026907226]
# Train loss in epoch 633: [0.027404532], Test loss: [0.026903342]
# Train loss in epoch 634: [0.027389534], Test loss: [0.026890349]
# Train loss in epoch 635: [0.027358007], Test loss: [0.026863569]
# Train loss in epoch 636: [0.027305504], Test loss: [0.026819339]
# Train loss in epoch 637: [0.027233206], Test loss: [0.026758283]
# Train loss in epoch 638: [0.027151447], Test loss: [0.026688781]
# Train loss in epoch 639: [0.027062533], Test loss: [0.026612995]
# Train loss in epoch 640: [0.026982877], Test loss: [0.026544411]
# Train loss in epoch 641: [0.026894588], Test loss: [0.026468545]
# Train loss in epoch 642: [0.026819859], Test loss: [0.026403628]
# Train loss in epoch 643: [0.026733849], Test loss: [0.026329357]
# Train loss in epoch 644: [0.026658386], Test loss: [0.026263721]
# Train loss in epoch 645: [0.026582116], Test loss: [0.026197452]
# Train loss in epoch 646: [0.026510492], Test loss: [0.026135042]
# Train loss in epoch 647: [0.0264205], Test loss: [0.026057668]
# Train loss in epoch 648: [0.026448697], Test loss: [0.026076803]
# Train loss in epoch 649: [0.02547662], Test loss: [0.025302492]
# Train loss in epoch 650: [0.026042391], Test loss: [0.025698148]
# Train loss in epoch 651: [0.025600508], Test loss: [0.025385372]
# Train loss in epoch 652: [0.02636325], Test loss: [0.025953993]
# Train loss in epoch 653: [0.024348211], Test loss: [0.024523109]
# Train loss in epoch 654: [0.025989195], Test loss: [0.025641683]
# Train loss in epoch 655: [0.024506899], Test loss: [0.02458398]
# Train loss in epoch 656: [0.025147561], Test loss: [0.024981914]
# Train loss in epoch 657: [0.024251718], Test loss: [0.024425827]
# Train loss in epoch 658: [0.026922781], Test loss: [0.026417138]
# Train loss in epoch 659: [0.024687953], Test loss: [0.025382608]
# Train loss in epoch 660: [0.028066976], Test loss: [0.029203406]
# Train loss in epoch 661: [0.028034411], Test loss: [0.029165346]
# Train loss in epoch 662: [0.028003741], Test loss: [0.029130794]
# Train loss in epoch 663: [0.027972043], Test loss: [0.02909583]
# Train loss in epoch 664: [0.027948517], Test loss: [0.029070355]
# Train loss in epoch 665: [0.027919156], Test loss: [0.029038683]
# Train loss in epoch 666: [0.02789914], Test loss: [0.029017445]
# Train loss in epoch 667: [0.027870629], Test loss: [0.028986912]
# Train loss in epoch 668: [0.027851798], Test loss: [0.028967198]
# Train loss in epoch 669: [0.027825937], Test loss: [0.028939702]
# Train loss in epoch 670: [0.027806163], Test loss: [0.028918922]
# Train loss in epoch 671: [0.027781405], Test loss: [0.028892629]
# Train loss in epoch 672: [0.027761895], Test loss: [0.028872184]
# Train loss in epoch 673: [0.027737834], Test loss: [0.028846696]
# Train loss in epoch 674: [0.02771827], Test loss: [0.028826151]
# Train loss in epoch 675: [0.027695131], Test loss: [0.028801601]
# Train loss in epoch 676: [0.027675461], Test loss: [0.028780945]
# Train loss in epoch 677: [0.027653789], Test loss: [0.028757945]
# Train loss in epoch 678: [0.027634338], Test loss: [0.028737482]
# Train loss in epoch 679: [0.027612504], Test loss: [0.02871432]
# Train loss in epoch 680: [0.027593583], Test loss: [0.028694358]
# Train loss in epoch 681: [0.027572388], Test loss: [0.028671868]
# Train loss in epoch 682: [0.027553502], Test loss: [0.028651878]
# Train loss in epoch 683: [0.027532682], Test loss: [0.028629791]
# Train loss in epoch 684: [0.027514771], Test loss: [0.028610855]
# Train loss in epoch 685: [0.027494267], Test loss: [0.028589047]
# Train loss in epoch 686: [0.027476832], Test loss: [0.028570637]
# Train loss in epoch 687: [0.027456569], Test loss: [0.028549034]
# Train loss in epoch 688: [0.027439397], Test loss: [0.028530888]
# Train loss in epoch 689: [0.027419828], Test loss: [0.028510004]
# Train loss in epoch 690: [0.027402777], Test loss: [0.028491946]
# Train loss in epoch 691: [0.027384032], Test loss: [0.028471956]
# Train loss in epoch 692: [0.027366476], Test loss: [0.028453264]
# Train loss in epoch 693: [0.027348481], Test loss: [0.028434098]
# Train loss in epoch 694: [0.027331067], Test loss: [0.028415559]
# Train loss in epoch 695: [0.02731416], Test loss: [0.028397549]
# Train loss in epoch 696: [0.027296986], Test loss: [0.028379211]
# Train loss in epoch 697: [0.027280379], Test loss: [0.028361499]
# Train loss in epoch 698: [0.027263407], Test loss: [0.02834335]
# Train loss in epoch 699: [0.027247343], Test loss: [0.02832621]
# Train loss in epoch 700: [0.027230596], Test loss: [0.028308287]
# Train loss in epoch 701: [0.02721433], Test loss: [0.028290907]
# Train loss in epoch 702: [0.027198944], Test loss: [0.028274441]
# Train loss in epoch 703: [0.027182488], Test loss: [0.028256815]
# Train loss in epoch 704: [0.027167141], Test loss: [0.02824039]
# Train loss in epoch 705: [0.027151512], Test loss: [0.028223619]
# Train loss in epoch 706: [0.027136547], Test loss: [0.028207604]
# Train loss in epoch 707: [0.027121693], Test loss: [0.028191661]
# Train loss in epoch 708: [0.027106334], Test loss: [0.028175175]
# Train loss in epoch 709: [0.027091209], Test loss: [0.028158918]
# Train loss in epoch 710: [0.027076954], Test loss: [0.028143629]
# Train loss in epoch 711: [0.027062777], Test loss: [0.0281284]
# Train loss in epoch 712: [0.027048226], Test loss: [0.028112713]
# Train loss in epoch 713: [0.027033977], Test loss: [0.028097387]
# Train loss in epoch 714: [0.027019875], Test loss: [0.028082199]
# Train loss in epoch 715: [0.027006187], Test loss: [0.028067492]
# Train loss in epoch 716: [0.026992191], Test loss: [0.028052378]
# Train loss in epoch 717: [0.0269784], Test loss: [0.028037531]
# Train loss in epoch 718: [0.0269656], Test loss: [0.028023696]
# Train loss in epoch 719: [0.026952485], Test loss: [0.028009562]
# Train loss in epoch 720: [0.026938824], Test loss: [0.027994798]
# Train loss in epoch 721: [0.026925709], Test loss: [0.027980629]
# Train loss in epoch 722: [0.026913051], Test loss: [0.027966913]
# Train loss in epoch 723: [0.026900461], Test loss: [0.027953291]
# Train loss in epoch 724: [0.026887245], Test loss: [0.027938979]
# Train loss in epoch 725: [0.026874604], Test loss: [0.027925292]
# Train loss in epoch 726: [0.026862033], Test loss: [0.027911663]
# Train loss in epoch 727: [0.026849996], Test loss: [0.027898615]
# Train loss in epoch 728: [0.02683744], Test loss: [0.027885012]
# Train loss in epoch 729: [0.026825517], Test loss: [0.027872037]
# Train loss in epoch 730: [0.026813742], Test loss: [0.027859271]
# Train loss in epoch 731: [0.02680159], Test loss: [0.027846063]
# Train loss in epoch 732: [0.026789863], Test loss: [0.027833275]
# Train loss in epoch 733: [0.026778001], Test loss: [0.027820362]
# Train loss in epoch 734: [0.026766803], Test loss: [0.027808176]
# Train loss in epoch 735: [0.026755359], Test loss: [0.02779571]
# Train loss in epoch 736: [0.026743578], Test loss: [0.027782872]
# Train loss in epoch 737: [0.026732719], Test loss: [0.027770992]
# Train loss in epoch 738: [0.026721481], Test loss: [0.027758718]
# Train loss in epoch 739: [0.026709931], Test loss: [0.027746145]
# Train loss in epoch 740: [0.026699228], Test loss: [0.027734434]
# Train loss in epoch 741: [0.026688464], Test loss: [0.027722655]
# Train loss in epoch 742: [0.026677504], Test loss: [0.02771062]
# Train loss in epoch 743: [0.026666716], Test loss: [0.027698811]
# Train loss in epoch 744: [0.026655998], Test loss: [0.027687082]
# Train loss in epoch 745: [0.026645444], Test loss: [0.027675509]
# Train loss in epoch 746: [0.026634853], Test loss: [0.027663872]
# Train loss in epoch 747: [0.026624396], Test loss: [0.027652383]
# Train loss in epoch 748: [0.026613902], Test loss: [0.027640851]
# ...
# Train loss in epoch 753: [0.026562966], Test loss: [0.027584743]
# Train loss in epoch 754: [0.026553392], Test loss: [0.027574118]
# Train loss in epoch 755: [0.026542768], Test loss: [0.027562391]
# Train loss in epoch 756: [0.026533108], Test loss: [0.027551703]
# Train loss in epoch 757: [0.026522875], Test loss: [0.027540378]
# Train loss in epoch 758: [0.026513431], Test loss: [0.02752992]
# Train loss in epoch 759: [0.026503719], Test loss: [0.027519137]
# Train loss in epoch 760: [0.026493974], Test loss: [0.027508324]
# Train loss in epoch 761: [0.026484193], Test loss: [0.027497448]
# Train loss in epoch 762: [0.026474457], Test loss: [0.027486604]
# Train loss in epoch 763: [0.026465148], Test loss: [0.027476266]
# Train loss in epoch 764: [0.026455972], Test loss: [0.027466036]
# Train loss in epoch 765: [0.026446104], Test loss: [0.027455043]
# Train loss in epoch 766: [0.026436955], Test loss: [0.027444847]
# Train loss in epoch 767: [0.026427433], Test loss: [0.027434207]
# Train loss in epoch 768: [0.026417769], Test loss: [0.027423427]
# Train loss in epoch 769: [0.026408941], Test loss: [0.027413528]
# Train loss in epoch 770: [0.026399525], Test loss: [0.027402978]
# Train loss in epoch 771: [0.026390381], Test loss: [0.027392723]
# Train loss in epoch 772: [0.026381224], Test loss: [0.027382445]
# Train loss in epoch 773: [0.026371848], Test loss: [0.027371921]
# Train loss in epoch 774: [0.026362918], Test loss: [0.027361879]
# Train loss in epoch 775: [0.02635349], Test loss: [0.027351294]
# Train loss in epoch 776: [0.026344836], Test loss: [0.027341496]
# Train loss in epoch 777: [0.026335679], Test loss: [0.027331203]
# Train loss in epoch 778: [0.026326671], Test loss: [0.027321015]
# Train loss in epoch 779: [0.026317576], Test loss: [0.027310744]
# Train loss in epoch 780: [0.026309039], Test loss: [0.027301081]
# Train loss in epoch 781: [0.026299972], Test loss: [0.027290793]
# Train loss in epoch 782: [0.026291467], Test loss: [0.02728113]
# Train loss in epoch 783: [0.026282875], Test loss: [0.027271358]
# Train loss in epoch 784: [0.026273228], Test loss: [0.027260449]
# Train loss in epoch 785: [0.026265025], Test loss: [0.027251057]
# Train loss in epoch 786: [0.026256423], Test loss: [0.027241252]
# Train loss in epoch 787: [0.026247624], Test loss: [0.027231261]
# Train loss in epoch 788: [0.026238738], Test loss: [0.02722113]
# Train loss in epoch 789: [0.026230358], Test loss: [0.027211552]
# Train loss in epoch 790: [0.026221488], Test loss: [0.027201422]
# Train loss in epoch 791: [0.026213039], Test loss: [0.027191728]
# Train loss in epoch 792: [0.026204824], Test loss: [0.027182288]
# Train loss in epoch 793: [0.026196187], Test loss: [0.027172353]
# Train loss in epoch 794: [0.026187621], Test loss: [0.027162522]
# Train loss in epoch 795: [0.026179351], Test loss: [0.027153002]
# Train loss in epoch 796: [0.026170906], Test loss: [0.02714326]
# Train loss in epoch 797: [0.026162505], Test loss: [0.027133569]
# Train loss in epoch 798: [0.026154457], Test loss: [0.027124261]
# Train loss in epoch 799: [0.026146473], Test loss: [0.027115]
# Train loss in epoch 800: [0.026138099], Test loss: [0.02710532]
# Train loss in epoch 801: [0.026129903], Test loss: [0.027095798]
# Train loss in epoch 802: [0.026122116], Test loss: [0.027086712]
# Train loss in epoch 803: [0.026113797], Test loss: [0.027077071]
# Train loss in epoch 804: [0.026105598], Test loss: [0.027067531]
# Train loss in epoch 805: [0.026097238], Test loss: [0.027057806]
# Train loss in epoch 806: [0.02608946], Test loss: [0.027048707]
# Train loss in epoch 807: [0.02608132], Test loss: [0.027039187]
# Train loss in epoch 808: [0.026073514], Test loss: [0.027030054]
# Train loss in epoch 809: [0.02606572], Test loss: [0.027020905]
# Train loss in epoch 810: [0.026057472], Test loss: [0.027011251]
# Train loss in epoch 811: [0.026050244], Test loss: [0.0270027]
# Train loss in epoch 812: [0.026041679], Test loss: [0.026992701]
# Train loss in epoch 813: [0.026034541], Test loss: [0.026984233]
# Train loss in epoch 814: [0.026026597], Test loss: [0.026974883]
# Train loss in epoch 815: [0.026019227], Test loss: [0.02696614]
# Train loss in epoch 816: [0.026011502], Test loss: [0.026957037]
# Train loss in epoch 817: [0.02600364], Test loss: [0.026947735]
# Train loss in epoch 818: [0.02599607], Test loss: [0.026938751]
# Train loss in epoch 819: [0.025989138], Test loss: [0.02693047]
# Train loss in epoch 820: [0.025981456], Test loss: [0.02692136]
# Train loss in epoch 821: [0.025974039], Test loss: [0.026912505]
# Train loss in epoch 822: [0.025966678], Test loss: [0.026903709]
# Train loss in epoch 823: [0.02595916], Test loss: [0.026894756]
# Train loss in epoch 824: [0.025951598], Test loss: [0.02688574]
# Train loss in epoch 825: [0.025944605], Test loss: [0.026877342]
# Train loss in epoch 826: [0.0259376], Test loss: [0.026868913]
# Train loss in epoch 827: [0.025929892], Test loss: [0.026859708]
# Train loss in epoch 828: [0.02592276], Test loss: [0.026851151]
# Train loss in epoch 829: [0.025915716], Test loss: [0.026842682]
# Train loss in epoch 830: [0.025908552], Test loss: [0.026834052]
# Train loss in epoch 831: [0.025901759], Test loss: [0.026825834]
# Train loss in epoch 832: [0.0258947], Test loss: [0.026817344]
# Train loss in epoch 833: [0.0258875], Test loss: [0.026808642]
# Train loss in epoch 834: [0.025880471], Test loss: [0.026800174]
# Train loss in epoch 835: [0.025873644], Test loss: [0.026791852]
# Train loss in epoch 836: [0.025866885], Test loss: [0.026783656]
# Train loss in epoch 837: [0.025859931], Test loss: [0.026775222]
# Train loss in epoch 838: [0.025853004], Test loss: [0.026766801]
# Train loss in epoch 839: [0.025846016], Test loss: [0.026758354]
# Train loss in epoch 840: [0.025839051], Test loss: [0.026749875]
# Train loss in epoch 841: [0.025832582], Test loss: [0.026741961]
# Train loss in epoch 842: [0.025825996], Test loss: [0.026733909]
# Train loss in epoch 843: [0.025818994], Test loss: [0.026725393]
# Train loss in epoch 844: [0.025812421], Test loss: [0.026717354]
# Train loss in epoch 845: [0.025806025], Test loss: [0.026709488]
# Train loss in epoch 846: [0.025799643], Test loss: [0.026701629]
# Train loss in epoch 847: [0.025792848], Test loss: [0.026693372]
# Train loss in epoch 848: [0.025786249], Test loss: [0.026685277]
# Train loss in epoch 849: [0.025779674], Test loss: [0.02667721]
# Train loss in epoch 850: [0.025773112], Test loss: [0.026669137]
# Train loss in epoch 851: [0.025766559], Test loss: [0.026661083]
# Train loss in epoch 852: [0.025760105], Test loss: [0.026653141]
# Train loss in epoch 853: [0.025753831], Test loss: [0.026645418]
# Train loss in epoch 854: [0.025747439], Test loss: [0.026637504]
# Train loss in epoch 855: [0.025740873], Test loss: [0.026629448]
# Train loss in epoch 856: [0.0257346], Test loss: [0.026621696]
# Train loss in epoch 857: [0.025728112], Test loss: [0.026613697]
# Train loss in epoch 858: [0.025722273], Test loss: [0.026606381]
# Train loss in epoch 859: [0.025715666], Test loss: [0.026598267]
# Train loss in epoch 860: [0.0257091], Test loss: [0.026590187]
# Train loss in epoch 861: [0.025702953], Test loss: [0.026582569]
# Train loss in epoch 862: [0.025696151], Test loss: [0.026574194]
# Train loss in epoch 863: [0.025690526], Test loss: [0.02656715]
# Train loss in epoch 864: [0.025684327], Test loss: [0.026559455]
# Train loss in epoch 865: [0.025678255], Test loss: [0.026551876]
# Train loss in epoch 866: [0.025671687], Test loss: [0.026543804]
# Train loss in epoch 867: [0.02566544], Test loss: [0.026536057]
# Train loss in epoch 868: [0.025659464], Test loss: [0.026528616]
# Train loss in epoch 869: [0.025653247], Test loss: [0.026520882]
# Train loss in epoch 870: [0.025647119], Test loss: [0.026513286]
# Train loss in epoch 871: [0.025640629], Test loss: [0.026505258]
# Train loss in epoch 872: [0.025634313], Test loss: [0.026497453]
# Train loss in epoch 873: [0.02562836], Test loss: [0.026489988]
# Train loss in epoch 874: [0.025622662], Test loss: [0.02648285]
# Train loss in epoch 875: [0.025616344], Test loss: [0.026475027]
# Train loss in epoch 876: [0.025610011], Test loss: [0.026467189]
# Train loss in epoch 877: [0.025603965], Test loss: [0.02645966]
# Train loss in epoch 878: [0.025597945], Test loss: [0.026452139]
# Train loss in epoch 879: [0.025592018], Test loss: [0.026444757]
# Train loss in epoch 880: [0.025586177], Test loss: [0.026437413]
# Train loss in epoch 881: [0.02558], Test loss: [0.026429735]
# Train loss in epoch 882: [0.0255742], Test loss: [0.026422467]
# Train loss in epoch 883: [0.025567856], Test loss: [0.026414607]
# Train loss in epoch 884: [0.025561903], Test loss: [0.026407186]
# Train loss in epoch 885: [0.025555898], Test loss: [0.026399693]
# Train loss in epoch 886: [0.025550012], Test loss: [0.026392311]
# Train loss in epoch 887: [0.025543902], Test loss: [0.026384734]
# Train loss in epoch 888: [0.025537543], Test loss: [0.026376847]
# Train loss in epoch 889: [0.025531705], Test loss: [0.026369542]
# Train loss in epoch 890: [0.025526047], Test loss: [0.02636243]
# Train loss in epoch 891: [0.025520217], Test loss: [0.026355116]
# Train loss in epoch 892: [0.025513913], Test loss: [0.026347324]
# Train loss in epoch 893: [0.025507845], Test loss: [0.026339743]
# Train loss in epoch 894: [0.025502279], Test loss: [0.02633277]
# Train loss in epoch 895: [0.025496259], Test loss: [0.026325241]
# Train loss in epoch 896: [0.025490098], Test loss: [0.026317596]
# Train loss in epoch 897: [0.025483992], Test loss: [0.026309997]
# Train loss in epoch 898: [0.025478449], Test loss: [0.026303019]
# Train loss in epoch 899: [0.025472689], Test loss: [0.026295796]
# Train loss in epoch 900: [0.025466258], Test loss: [0.026287843]
# Train loss in epoch 901: [0.025460165], Test loss: [0.026280293]
# Train loss in epoch 902: [0.025454406], Test loss: [0.026273075]
# Train loss in epoch 903: [0.025448622], Test loss: [0.026265811]
# Train loss in epoch 904: [0.025442606], Test loss: [0.026258364]
# Train loss in epoch 905: [0.025436953], Test loss: [0.026251234]
# Train loss in epoch 906: [0.025430795], Test loss: [0.026243579]
# Train loss in epoch 907: [0.02542497], Test loss: [0.026236305]
# Train loss in epoch 908: [0.025418974], Test loss: [0.026228879]
# Train loss in epoch 909: [0.025413129], Test loss: [0.026221544]
# Train loss in epoch 910: [0.025407147], Test loss: [0.026214113]
# Train loss in epoch 911: [0.025401451], Test loss: [0.026206985]
# Train loss in epoch 912: [0.025395654], Test loss: [0.026199751]
# Train loss in epoch 913: [0.025389407], Test loss: [0.026192011]
# Train loss in epoch 914: [0.025383551], Test loss: [0.026184723]
# Train loss in epoch 915: [0.025378007], Test loss: [0.026177745]
# Train loss in epoch 916: [0.025371989], Test loss: [0.026170269]
# Train loss in epoch 917: [0.025366083], Test loss: [0.026162911]
# Train loss in epoch 918: [0.025360167], Test loss: [0.026155569]
# Train loss in epoch 919: [0.025354071], Test loss: [0.026147999]
# Train loss in epoch 920: [0.025348555], Test loss: [0.026141059]
# Train loss in epoch 921: [0.025342457], Test loss: [0.026133496]
# Train loss in epoch 922: [0.025336515], Test loss: [0.026126102]
# Train loss in epoch 923: [0.025330754], Test loss: [0.02611896]
# Train loss in epoch 924: [0.025324905], Test loss: [0.026111647]
# Train loss in epoch 925: [0.025319023], Test loss: [0.026104312]
# Train loss in epoch 926: [0.025313413], Test loss: [0.026097294]
# Train loss in epoch 927: [0.025307473], Test loss: [0.026089925]
# Train loss in epoch 928: [0.025301248], Test loss: [0.026082244]
# Train loss in epoch 929: [0.02529582], Test loss: [0.026075445]
# Train loss in epoch 930: [0.025289841], Test loss: [0.026068032]
# Train loss in epoch 931: [0.025283851], Test loss: [0.026060618]
# Train loss in epoch 932: [0.025277905], Test loss: [0.026053205]
# Train loss in epoch 933: [0.025272354], Test loss: [0.026046291]
# Train loss in epoch 934: [0.02526667], Test loss: [0.026039189]
# Train loss in epoch 935: [0.025260588], Test loss: [0.026031662]
# Train loss in epoch 936: [0.025254695], Test loss: [0.026024371]
# Train loss in epoch 937: [0.025249019], Test loss: [0.02601726]
# Train loss in epoch 938: [0.025243286], Test loss: [0.026010148]
# Train loss in epoch 939: [0.025237337], Test loss: [0.026002789]
# Train loss in epoch 940: [0.025231369], Test loss: [0.025995407]
# Train loss in epoch 941: [0.025225608], Test loss: [0.025988244]
# Train loss in epoch 942: [0.025219958], Test loss: [0.025981177]
# Train loss in epoch 943: [0.025213972], Test loss: [0.025973788]
# Train loss in epoch 944: [0.025208317], Test loss: [0.02596675]
# Train loss in epoch 945: [0.025202561], Test loss: [0.025959603]
# Train loss in epoch 946: [0.025196645], Test loss: [0.02595228]
# Train loss in epoch 947: [0.02519089], Test loss: [0.025945129]
# Train loss in epoch 948: [0.025185309], Test loss: [0.025938196]
# Train loss in epoch 949: [0.025179558], Test loss: [0.025931044]
# Train loss in epoch 950: [0.025173619], Test loss: [0.025923733]
# Train loss in epoch 951: [0.025167653], Test loss: [0.025916349]
# Train loss in epoch 952: [0.025162196], Test loss: [0.02590955]
# Train loss in epoch 953: [0.025156287], Test loss: [0.025902238]
# Train loss in epoch 954: [0.025150733], Test loss: [0.025895339]
# Train loss in epoch 955: [0.025144806], Test loss: [0.025888003]
# Train loss in epoch 956: [0.02513903], Test loss: [0.025880862]
# Train loss in epoch 957: [0.02513322], Test loss: [0.025873672]
# Train loss in epoch 958: [0.025127437], Test loss: [0.025866508]
# Train loss in epoch 959: [0.025121927], Test loss: [0.025859687]
# Train loss in epoch 960: [0.025116052], Test loss: [0.025852405]
# Train loss in epoch 961: [0.025110256], Test loss: [0.025845243]
# Train loss in epoch 962: [0.025104702], Test loss: [0.025838353]
# Train loss in epoch 963: [0.025098626], Test loss: [0.025830902]
# Train loss in epoch 964: [0.025093189], Test loss: [0.025824133]
# Train loss in epoch 965: [0.02508761], Test loss: [0.025817204]
# Train loss in epoch 966: [0.025081832], Test loss: [0.025810078]
# Train loss in epoch 967: [0.02507589], Test loss: [0.02580275]
# Train loss in epoch 968: [0.025070274], Test loss: [0.025795814]
# Train loss in epoch 969: [0.025064502], Test loss: [0.02578868]
# Train loss in epoch 970: [0.02505867], Test loss: [0.025781505]
# Train loss in epoch 971: [0.025053088], Test loss: [0.025774589]
# Train loss in epoch 972: [0.025047572], Test loss: [0.02576777]
# Train loss in epoch 973: [0.02504199], Test loss: [0.025760842]
# Train loss in epoch 974: [0.025036119], Test loss: [0.025753625]
# Train loss in epoch 975: [0.02503055], Test loss: [0.025746763]
# Train loss in epoch 976: [0.025024986], Test loss: [0.025739841]
# Train loss in epoch 977: [0.025019184], Test loss: [0.025732726]
# Train loss in epoch 978: [0.025013428], Test loss: [0.025725607]
# Train loss in epoch 979: [0.025007866], Test loss: [0.025718767]
# Train loss in epoch 980: [0.02500217], Test loss: [0.025711745]
# Train loss in epoch 981: [0.024996676], Test loss: [0.025704937]
# Train loss in epoch 982: [0.024990842], Test loss: [0.02569776]
# Train loss in epoch 983: [0.024985172], Test loss: [0.025690787]
# Train loss in epoch 984: [0.024979787], Test loss: [0.025684118]
# Train loss in epoch 985: [0.024973935], Test loss: [0.025676951]
# Train loss in epoch 986: [0.024968415], Test loss: [0.025670147]
# Train loss in epoch 987: [0.024963006], Test loss: [0.025663398]
# Train loss in epoch 988: [0.024957344], Test loss: [0.025656443]
# Train loss in epoch 989: [0.024951678], Test loss: [0.025649477]
# Train loss in epoch 990: [0.024946127], Test loss: [0.025642656]
# Train loss in epoch 991: [0.024940647], Test loss: [0.025635876]
# Train loss in epoch 992: [0.024934759], Test loss: [0.025628671]
# Train loss in epoch 993: [0.024929354], Test loss: [0.025621984]
# Train loss in epoch 994: [0.024923855], Test loss: [0.025615226]
# Train loss in epoch 995: [0.024918318], Test loss: [0.025608383]
# Train loss in epoch 996: [0.024912734], Test loss: [0.025601517]
# Train loss in epoch 997: [0.024907237], Test loss: [0.025594756]
# Train loss in epoch 998: [0.024901681], Test loss: [0.025587924]
# Train loss in epoch 999: [0.024896193], Test loss: [0.025581155]

# %%
#Saving function checking..
dnn_inst.layers[0].w.name
# Out:
# 'Layer0/Matrix/read:0'

# %%
tf.trainable_variables()
# Out:
# [<tensorflow.python.ops.variables.Variable at 0x7f6b95beff60>,
#  <tensorflow.python.ops.variables.Variable at 0x7f6b690cbc50>,
#  <tensorflow.python.ops.variables.Variable at 0x7f6b68e15d30>,
#  <tensorflow.python.ops.variables.Variable at 0x7f6b68e15860>,
#  <tensorflow.python.ops.variables.Variable at 0x7f6b68e1fa20>,
#  <tensorflow.python.ops.variables.Variable at 0x7f6b68e1fb38>]

# %%
dnn_inst.save_variables_for_rnn("WEIGHTS_FOLDER/REWARD_NET.chkp")
# Out:
# RNN/FullNetworkCell/Reward/Layer1/Matrix
# Tensor("Layer1/Matrix/read:0", shape=(32, 32), dtype=float32)
# RNN/FullNetworkCell/Reward/Layer0/Bias
# Tensor("Layer0/Bias/read:0", shape=(32,), dtype=float32)
# RNN/FullNetworkCell/Reward/Layer1/Bias
# Tensor("Layer1/Bias/read:0", shape=(32,), dtype=float32)
# RNN/FullNetworkCell/Reward/Layer2/Bias
# Tensor("Layer2/Bias/read:0", shape=(1,), dtype=float32)
# RNN/FullNetworkCell/Reward/Layer2/Matrix
# Tensor("Layer2/Matrix/read:0", shape=(32, 1), dtype=float32)
# RNN/FullNetworkCell/Reward/Layer0/Matrix
# Tensor("Layer0/Matrix/read:0", shape=(4, 32), dtype=float32)
# /home/wuga/Documents/Notebook/VAE-PLANNING/WEIGHTS_FOLDER/REWARD_NET.chkp

# %%
dnn_inst.predict_test([[1,1,6,6]])
# Out:
# [array([[-2.1166749]], dtype=float32)]
