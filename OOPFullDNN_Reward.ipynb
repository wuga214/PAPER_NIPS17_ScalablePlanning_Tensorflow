# %% [markdown]
# # Fully Connected Network
#
# This is the second part of our whole deep learning planning structure.
#
# The Data in this experiments is generated from RDDL simulator [Github](https://github.com/ssanner/rddlsim), which is written by Prof.Scott Sanner at University of Toronto.
#
# In the section, we need a fully connected network to compute the reward of each (STATE,ACTION,STATE') tuple, that is (STATE,ACTION,STATE') -> Reward. Since this part is deterministic, fully connected network is capable to solve.
#
# Problem list:
# 1. Data normalization will highly impact the network performance, we need to normalize the input. However, the input of this section is an output of VAE, which is unnormalized. And since everything is working under tensorflow environment, we need to build normalizer inside tensorflow graph.
# 2. For reward function R(s,a), in nondeterministic domain, R(s,a) is stochastic. We need a deterministic function. Therefore, we rewrite the reward function as R(s,a,s'). This requires us to concate s,a,s' as single input matrix(also under tensorflow).

# %% [markdown]
# ### Import Packages
# We do note provide pip installation commands, please search this package and install it through pip install. Please upgrade your pip before installing, since old pip would cause errors.

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import tensorflow as tf
import numpy as np
from sklearn.metrics import confusion_matrix
import time
from datetime import timedelta
import math
import os
import pandas as pd
#Functional coding
import functools
from functools import partial
import re

# %% [markdown]
# ### Load Data
# We load data from csv files. The following code shows how to load data through pandas and numpy. Result of this progress can be feed into tensorflow with "feed_dict" argument.

# %%
#Data Path..
Datapath="DATA/Navigation/Navigation_Data.txt"
Labelpath="DATA/Navigation/Navigation_Label.txt"
Rewardpath="DATA/Navigation/Navigation_Reward.txt"

# %%
#Given local path, find full path
def PathFinder(path):
    #python 2
    #script_dir = os.path.dirname('__file__')
    #fullpath = os.path.join(script_dir,path)
    #python 3
    fullpath=os.path.abspath(path)
    print(fullpath)
    return fullpath

#Read Data for Deep Learning
def ReadData(path):
    fullpath=PathFinder(path)
    return pd.read_csv(fullpath, sep=',', header=0)

#Won't use this one to normalize
#Input Normalization
def Normalize(features, mean = [], std = []):
    if mean == []:
        mean = np.mean(features, axis = 0)
        std = np.std(features, axis = 0)
#     print std
#     print std[:,None]
    new_feature = (features.T - mean[:,None]).T
    new_feature = (new_feature.T / std[:,None]).T
    new_feature[np.isnan(new_feature)]=0
#     print new_feature
    return new_feature, mean, std

# %%
x_pd = ReadData(Datapath)
r_pd = ReadData(Rewardpath)
# Out:
# /home/wuga/Documents/Notebook/VAE-PLANNING/DATA/Navigation/Navigation_Data.txt
# /home/wuga/Documents/Notebook/VAE-PLANNING/DATA/Navigation/Navigation_Reward.txt

# %%
#Get Numpy Arrays
x_matrix=x_pd.as_matrix()
x_train = x_matrix[:100000]
x_valid = x_matrix[100000:]
r_matrix=r_pd.as_matrix()
r_train = r_matrix[:100000]
r_valid = r_matrix[100000:]

# %%
len(x_matrix)
# Out:
# 250000

# %%
data_size=len(x_matrix)
# Uppercase for constants
INPUT_S_A_SIZE = 4
OUTPUT_SIZE = 1

# %% [markdown]
# ### Support Functions
# The following functions allows us passthrough multiple functions without explicitly assign intermediate output variables.

# %%
def compose(f,g):
    return lambda x:g(f(x))
    
def composeAll(*args):
    """
    composeAll([f,g,h])(x): f(g(h(x)))
    """
    return partial(functools.reduce, compose)(*args)

# %% [markdown]
# ## Tensorflow
# ### Input tensor place holders

# %%
# Input features s,a
x = tf.placeholder(tf.float32,[None, INPUT_S_A_SIZE],name="Features_S_A")

# Input label
r = tf.placeholder(tf.float32, [None, OUTPUT_SIZE],name="Labels")

# %% [markdown]
# ### Variable Generating functions

# %%
#Weight constructing function
def weight_variable(shape):
    initial = tf.truncated_normal(shape,stddev=0.001)
    return tf.Variable(initial,name="Matrix")

#Bias constructing function
def bias_variable(shape):
    initial = tf.constant(0.,shape=shape)
    return tf.Variable(initial,name="Bias")

# %% [markdown]
# ### Fully Connected Layer Defination

# %%
class Dense():
    """Fully Connected Layer"""
    def __init__(self, scope="fully_connected_layer", output_dim =None, dropout=1.0, activation=tf.identity):
        assert output_dim, "Missing output dimension specification!"
        self.scope = scope
        self.output_dim = output_dim
        self.dropout = dropout
        self.activation = activation
        
    def __call__(self,x):
        with tf.name_scope(self.scope):
            while True:
                try:
                    return self.activation(tf.matmul(x,self.w)+self.b)
                except(AttributeError):
                    self.w = tf.nn.dropout(weight_variable([x.get_shape()[1].value, self.output_dim]),self.dropout)
                    self.b = bias_variable([self.output_dim])
    
    def set_parameters(self, weight, bias):
        self.w.assign(weight)
        self.b.assign(bias)
        
    def get_l2_loss(self):
        return tf.nn.l2_loss(self.w)

# %% [markdown]
# ### Full Deep Network Class
# The following class define a complete deep network, which include:
# 1. Network structure specification
# 2. Loss function specification
# 3. Prediction specification
# 4. Optimization method specification
# 5. Training function
# 6. Saving function(not tensorflow variable saving, but numpy weight dumping!)
# 7. Loading function(not tensorflow variable loading, but numpy weight assignment!)
# 8. Mini-Batch generation function

# %%
class DeepNet(object):
    
    def __init__(self, 
                 x, #Input Features for S,A
                 r, #Output Label for R
                 num_hidden_layers, #number of layers for both encoder and decoder
                 num_hidden_nodes, #number of nodes in each layer
                 activation, #nonlinear activation function
                 learning_rate=0.001, #Learning rate
                 dropout = 1,
                 batch_size=1000, 
                 l2_lambda = 1E-4): #Batch size        
#        self.mean = tf.Variable(tf.zeros([x.get_shape()[1]]),trainable=False,name="NORM_MEAN")
#        self.var = tf.Variable(tf.ones([x.get_shape()[1]]),trainable=False,name="NORM_VAR")
#        self.f = self._p_normalize(x)
        self.f = x
        self.r = r
        self.num_hidden_layers = num_hidden_layers
        self.num_hidden_nodes = num_hidden_nodes
        self.activation = activation
        self.learning_rate = learning_rate
        self.batch_size = batch_size
        self.l2_lambda = l2_lambda
        self.dropout = dropout
        self._p_create_dnn_graph()
        self._p_create_loss()
        self.sess = tf.InteractiveSession()
        self.sess.run(tf.global_variables_initializer())
        
    def _p_create_dnn_graph(self):

        layers = []
        for i in range(self.num_hidden_layers):
            layers.append(Dense("Layer"+str(i),self.num_hidden_nodes,self.dropout,self.activation))
        layers.append(Dense("Layer"+str(self.num_hidden_layers),self.r.get_shape()[1].value,self.dropout))
        self.r_pred = composeAll(layers)(self.f)
        self.layers = layers 
    
    def _p_normalize(self, unnormed):
        epsilon = 1e-3
        normed = tf.nn.batch_normalization(unnormed,self.mean,self.var,None,None,epsilon)
        return normed
        
    def _p_create_loss(self): #lambda for l2 regularization

        #L2 regularization loss
        l2_loss = tf.constant(0.0)
        for layer in self.layers:
            l2_loss += layer.get_l2_loss()

        #Mean Squared Error
        mse_r = tf.reduce_mean(tf.square(tf.sub(self.r,self.r_pred)), reduction_indices=1)

        #loss
        self.loss = tf.reduce_mean(mse_r)+self.l2_lambda*l2_loss
        self.optimizer = tf.train.RMSPropOptimizer(self.learning_rate).minimize(self.loss)   
        
    def update_normalization(self,x_matrix):
        tf_mean,tf_var = tf.nn.moments(x, axes = [0])
        feed_dict = {x:x_matrix}
        np_mean,np_var = self.sess.run([tf_mean,tf_var],feed_dict=feed_dict)
        print(np_mean)
        self.sess.run(self.mean.assign(np_mean))
        self.sess.run(self.var.assign(np_var))
        print(self.mean.eval())
        
    
    def train_model(self,train_s_a,train_r,test_s_a,test_r,epoch=100):
        
#        self.update_normalization(train_s_a)
        
        batches = self._p_get_batches(train_s_a,train_r,self.batch_size)
        
#        self.mean = tf.Variable(tf.zeros([x.get_shape()[1]]),trainable=False)
#        self.var = tf.Variable(tf.ones([x.get_shape()[1]]),trainable=False)
        
        summary_writer = tf.summary.FileWriter('experiment', graph=self.sess.graph)
        feed_test={x:test_s_a,r:test_r}
        feed_train={x:train_s_a, r:train_r}

        #Training
        for epoch in range(epoch):
            for step in range(len(batches)):
                feed_dict = {x: batches[step][0],r: batches[step][1]}
                training = self.sess.run([self.optimizer], feed_dict=feed_dict)
            train_loss = self.sess.run([self.loss],feed_dict=feed_dict)
            test_loss = self.sess.run([self.loss],feed_dict=feed_test)
            print('Train loss in epoch {0}: {1}, Test loss: {2}'.format(epoch, train_loss, test_loss)) 
            
    def predict_test(self, test_s_a):
        feed_dict={x:test_s_a}
        return self.sess.run([self.r_pred],feed_dict=feed_dict)
            
    def _p_get_batches(self,x_matrix,r_matrix,batch_size):
        remaining_size = len(x_matrix)
        batch_index=0
        batches = []
        while(remaining_size>0):
            batch = []
            if remaining_size<batch_size:
                batch.append(x_matrix[batch_index*batch_size:-1])
                batch.append(r_matrix[batch_index*batch_size:-1])
            else:
                batch.append(x_matrix[batch_index*batch_size:(batch_index+1)*batch_size]) 
                batch.append(r_matrix[batch_index*batch_size:(batch_index+1)*batch_size]) 
            batch_index+=1
            remaining_size-=batch_size
            batches.append(batch)
        return batches
    
    def _p_extract_weights(self):
        # a hashmap maps from layer name to weights and biases
        mp_layer_weights = {}

        #iteratively save values
        for dense in self.layers:
            values = {'weights':dense.w, 'biases':dense.b}
            mp_layer_weights[layer.scope] = values
        
        norms = {'mean':self.mean, 'var':self.var}
        mp_layer_weights['normalizations'] = norms

        return mp_layer_weights
    
    def save_weights(self,path):
        #extract weights from trained model
        layer_weights = self.sess.run(_p_extract_weights())
        print('Whole layer weights: {0}'.format(layer_weights))
        np.save(path,layer_weights)
    
    def load_weights(self,path):
        layer_weights = np.load(path)
        for dense in self.layers:
            print('Scope:{0}'.format(dense.scope))
            values = layer_weights.get(dense.scope)
            weights = values.get('weights')
            biases = values.get('biases')
            dense.set_parameters(weights,biases)
        print('Done!')
        
    def save_variables_for_rnn(self,path,prefix="RNN/FullNetworkCell/Reward/"):
        variables = tf.trainable_variables()
        var_dict = {}
        for v in variables:
            if "/read" in v.name:
                name = prefix+re.sub("/read", "", v.name)
                name = re.sub(":0", "", name)
                var_dict[name] = v
            else:
                name = prefix+v.name
                name = re.sub(":0", "", name)
                var_dict[name] = v
        for k,v in var_dict.items():
            print(k)
            print(v)
        saver = tf.train.Saver(var_dict)
        saver.save(self.sess, PathFinder(path))

# %%
#Instantiate a network
dnn_inst = DeepNet(x,r,2,32,tf.nn.sigmoid)

# %% [markdown]
# ### Tensorflow graph visualization function

# %%
from IPython.display import clear_output, Image, display, HTML

def strip_consts(graph_def, max_const_size=32):
    """Strip large constant values from graph_def."""
    strip_def = tf.GraphDef()
    for n0 in graph_def.node:
        n = strip_def.node.add() 
        n.MergeFrom(n0)
        if n.op == 'Const':
            tensor = n.attr['value'].tensor
            size = len(tensor.tensor_content)
            if size > max_const_size:
                tensor.tensor_content = "<stripped %d bytes>"%size
    return strip_def

def show_graph(graph_def, max_const_size=32):
    """Visualize TensorFlow graph."""
    if hasattr(graph_def, 'as_graph_def'):
        graph_def = graph_def.as_graph_def()
    strip_def = strip_consts(graph_def, max_const_size=max_const_size)
    code = """
        <script>
          function load() {{
            document.getElementById("{id}").pbtxt = {data};
          }}
        </script>
        <link rel="import" href="https://tensorboard.appspot.com/tf-graph-basic.build.html" onload=load()>
        <div style="height:600px">
          <tf-graph-basic id="{id}"></tf-graph-basic>
        </div>
    """.format(data=repr(str(strip_def)), id='graph'+str(np.random.rand()))

    iframe = """
        <iframe seamless style="width:960px;height:600px;border:0" srcdoc="{}"></iframe>
    """.format(code.replace('"', '&quot;'))
    display(HTML(iframe))

# %%
show_graph(tf.get_default_graph().as_graph_def())
# Out:
#         <iframe seamless style="width:960px;height:600px;border:0" srcdoc="
#         <script>
#           function load() {
#             document.getElementById(&quot;graph0.7063942718122713&quot;).pbtxt = 'node {\n  name: &quot;Features_S_A&quot;\n  op: &quot;Placeholder&quot;\n  attr {\n    key: &quot;dtype&quot;\n    value {\n      type: DT_FLOAT\n    }\n  }\n  attr {\n    key: &quot;shape&quot;\n    value {\n      shape {\n      }\n    }\n  }\n}\nnode {\n  name: &quot;Labels&quot;\n  op: &quot;Placeholder&quot;\n  attr {\n    key: &quot;dtype&quot;\n    value {\n      type: DT_FLOAT\n    }\n  }\n  attr {\n    key: &quot;shape&quot;\n    value {\n      shape {\n      }\n    }\n  }\n}\nnode {\n  name: &quot;Layer0/truncated_normal/shape&quot;\n  op: &quot;Const&quot;\n  attr {\n    key: &quot;dtype&quot;\n    value {\n      type: DT_INT32\n    }\n  }\n  attr {\n    key: &quot;value&quot;\n    value {\n      tensor {\n        dtype: DT_INT32\n        tensor_shape {\n          dim {\n            size: 2\n          }\n        }\n        tensor_content: &quot;\\004\\000\\000\\000 \\000\\000\\000&quot;\n      }\n    }\n  }\n}\nnode {\n  name: &quot;Layer0/truncated_normal/mean&quot;\n  op: &quot;Const&quot;\n  attr {\n    key: &quot;dtype&quot;\n    value {\n      type: DT_FLOAT\n    }\n  }\n  attr {\n    key: &quot;value&quot;\n    value {\n      tensor {\n        dtype: DT_FLOAT\n        tensor_shape {\n        }\n        float_val: 0.0\n      }\n    }\n  }\n}\nnode {\n  name: &quot;Layer0/truncated_normal/stddev&quot;\n  op: &quot;Const&quot;\n  attr {\n    key: &quot;dtype&quot;\n    value {\n      type: DT_FLOAT\n    }\n  }\n  attr {\n    key: &quot;value&quot;\n    value {\n      tensor {\n        dtype: DT_FLOAT\n        tensor_shape {\n        }\n        float_val: 0.0010000000474974513\n      }\n    }\n  }\n}\nnode {\n  name: &quot;Layer0/truncated_normal/TruncatedNormal&quot;\n  op: &quot;TruncatedNormal&quot;\n  input: &quot;Layer0/truncated_normal/shape&quot;\n  attr {\n    key: &quot;T&quot;\n    value {\n      type: DT_INT32\n    }\n  }\n  attr {\n    key: &quot;dtype&quot;\n    value {\n      type: DT_FLOAT\n    }\n  }\n  attr {\n    key: &quot;seed&quot;\n    value {\n      i: 0\n    }\n  }\n  attr {\n    key: &quot;seed2&quot;\n    value {\n      i: 0\n    }\n  }\n}\nnode {\n  name: &quot;Layer0/truncated_normal/mul&quot;\n  op: &quot;Mul&quot;\n  input: &quot;Layer0/truncated_normal/TruncatedNormal&quot;\n  input: &quot;Layer0/truncated_normal/stddev&quot;\n  attr {\n    key: &quot;T&quot;\n    value {\n      type: DT_FLOAT\n    }\n  }\n}\nnode {\n  name: &quot;Layer0/truncated_normal&quot;\n  op: &quot;Add&quot;\n  input: &quot;Layer0/truncated_normal/mul&quot;\n  input: &quot;Layer0/truncated_normal/mean&quot;\n  attr {\n    key: &quot;T&quot;\n    value {\n      type: DT_FLOAT\n    }\n  }\n}\nnode {\n  name: &quot;Layer0/Matrix&quot;\n  op: &quot;Variable&quot;\n  attr {\n    key: &quot;container&quot;\n    value {\n      s: &quot;&quot;\n    }\n  }\n  attr {\n    key: &quot;dtype&quot;\n    value {\n      type: DT_FLOAT\n    }\n  }\n  attr {\n    key: &quot;shape&quot;\n    value {\n      shape {\n        dim {\n          size: 4\n        }\n        dim {\n          size: 32\n        }\n      }\n    }\n  }\n  attr {\n    key: &quot;shared_name&quot;\n    value {\n      s: &quot;&quot;\n    }\n  }\n}\nnode {\n  name: &quot;Layer0/Matrix/Assign&quot;\n  op: &quot;Assign&quot;\n  input: &quot;Layer0/Matrix&quot;\n  input: &quot;Layer0/truncated_normal&quot;\n  attr {\n    key: &quot;T&quot;\n    value {\n      type: DT_FLOAT\n    }\n  }\n  attr {\n    key: &quot;_class&quot;\n    value {\n      list {\n        s: &quot;loc:@Layer0/Matrix&quot;\n      }\n    }\n  }\n  attr {\n    key: &quot;use_locking&quot;\n    value {\n      b: true\n    }\n  }\n  attr {\n    key: &quot;validate_shape&quot;\n    value {\n      b: true\n    }\n  }\n}\nnode {\n  name: &quot;Layer0/Matrix/read&quot;\n  op: &quot;Identity&quot;\n  input: &quot;Layer0/Matrix&quot;\n  attr {\n    key: &quot;T&quot;\n    value {\n      type: DT_FLOAT\n    }\n  }\n  attr { ...

# %% [markdown]
# ### Training

# %%
dnn_inst.train_model(x_train,r_train,x_valid,r_valid,1000)
# Out:
# Train loss in epoch 0: [27.766888], Test loss: [27.875677]
# Train loss in epoch 1: [17.635971], Test loss: [17.541296]
# Train loss in epoch 2: [17.060371], Test loss: [16.973631]
# Train loss in epoch 3: [16.976715], Test loss: [16.89142]
# Train loss in epoch 4: [16.968601], Test loss: [16.883375]
# Train loss in epoch 5: [16.967974], Test loss: [16.882729]
# Train loss in epoch 6: [16.967426], Test loss: [16.882168]
# Train loss in epoch 7: [16.96693], Test loss: [16.881666]
# Train loss in epoch 8: [16.966486], Test loss: [16.881207]
# Train loss in epoch 9: [16.966072], Test loss: [16.880785]
# Train loss in epoch 10: [16.965691], Test loss: [16.880398]
# Train loss in epoch 11: [16.965338], Test loss: [16.880043]
# Train loss in epoch 12: [16.965015], Test loss: [16.879717]
# Train loss in epoch 13: [16.964708], Test loss: [16.879408]
# Train loss in epoch 14: [16.964437], Test loss: [16.879105]
# Train loss in epoch 15: [16.964169], Test loss: [16.878811]
# Train loss in epoch 16: [16.963913], Test loss: [16.878519]
# Train loss in epoch 17: [16.963673], Test loss: [16.878248]
# Train loss in epoch 18: [16.963446], Test loss: [16.877995]
# Train loss in epoch 19: [16.963232], Test loss: [16.877775]
# Train loss in epoch 20: [16.963022], Test loss: [16.877571]
# Train loss in epoch 21: [16.962826], Test loss: [16.877384]
# Train loss in epoch 22: [16.962635], Test loss: [16.877207]
# Train loss in epoch 23: [16.962458], Test loss: [16.877035]
# Train loss in epoch 24: [16.962284], Test loss: [16.876871]
# Train loss in epoch 25: [16.962112], Test loss: [16.876711]
# Train loss in epoch 26: [16.961941], Test loss: [16.876535]
# Train loss in epoch 27: [16.961494], Test loss: [16.87608]
# Train loss in epoch 28: [16.864805], Test loss: [16.786999]
# Train loss in epoch 29: [16.135008], Test loss: [16.094698]
# Train loss in epoch 30: [15.453997], Test loss: [15.422705]
# Train loss in epoch 31: [15.000848], Test loss: [14.959992]
# Train loss in epoch 32: [14.673556], Test loss: [14.624878]
# Train loss in epoch 33: [14.376603], Test loss: [14.326728]
# Train loss in epoch 34: [14.069817], Test loss: [14.021111]
# Train loss in epoch 35: [13.738751], Test loss: [13.693336]
# Train loss in epoch 36: [13.378798], Test loss: [13.337673]
# Train loss in epoch 37: [12.986407], Test loss: [12.949687]
# Train loss in epoch 38: [12.558914], Test loss: [12.528208]
# Train loss in epoch 39: [12.09447], Test loss: [12.069279]
# Train loss in epoch 40: [11.591933], Test loss: [11.573971]
# Train loss in epoch 41: [11.050851], Test loss: [11.041225]
# Train loss in epoch 42: [10.471544], Test loss: [10.470337]
# Train loss in epoch 43: [9.8552904], Test loss: [9.8633747]
# Train loss in epoch 44: [9.2045002], Test loss: [9.2228546]
# Train loss in epoch 45: [8.522953], Test loss: [8.5516043]
# Train loss in epoch 46: [7.8160286], Test loss: [7.856761]
# Train loss in epoch 47: [7.0908489], Test loss: [7.1433544]
# Train loss in epoch 48: [6.3564143], Test loss: [6.4214849]
# Train loss in epoch 49: [5.6235628], Test loss: [5.7004056]
# Train loss in epoch 50: [4.9046035], Test loss: [4.9931059]
# Train loss in epoch 51: [4.2124443], Test loss: [4.3114944]
# Train loss in epoch 52: [3.5591526], Test loss: [3.6660109]
# Train loss in epoch 53: [2.9549696], Test loss: [3.0679011]
# Train loss in epoch 54: [2.414737], Test loss: [2.530952]
# Train loss in epoch 55: [1.958092], Test loss: [2.0743713]
# Train loss in epoch 56: [1.5895604], Test loss: [1.7018678]
# Train loss in epoch 57: [1.2846042], Test loss: [1.3876036]
# Train loss in epoch 58: [1.0064366], Test loss: [1.0966913]
# Train loss in epoch 59: [0.80876625], Test loss: [0.88477188]
# Train loss in epoch 60: [0.7025854], Test loss: [0.75993532]
# Train loss in epoch 61: [0.65587127], Test loss: [0.69899577]
# Train loss in epoch 62: [0.63488901], Test loss: [0.67101228]
# Train loss in epoch 63: [0.62723249], Test loss: [0.66130906]
# Train loss in epoch 64: [0.62407368], Test loss: [0.65799582]
# Train loss in epoch 65: [0.6217432], Test loss: [0.65566397]
# Train loss in epoch 66: [0.61955285], Test loss: [0.65347022]
# Train loss in epoch 67: [0.61733311], Test loss: [0.65114564]
# Train loss in epoch 68: [0.61509615], Test loss: [0.64885181]
# Train loss in epoch 69: [0.61292535], Test loss: [0.64661717]
# Train loss in epoch 70: [0.61089885], Test loss: [0.64451623]
# Train loss in epoch 71: [0.60904765], Test loss: [0.64255738]
# Train loss in epoch 72: [0.60735929], Test loss: [0.64077818]
# Train loss in epoch 73: [0.60579026], Test loss: [0.63898438]
# Train loss in epoch 74: [0.60425854], Test loss: [0.63719857]
# Train loss in epoch 75: [0.60268021], Test loss: [0.63526028]
# Train loss in epoch 76: [0.60094923], Test loss: [0.63299108]
# Train loss in epoch 77: [0.59896308], Test loss: [0.63021618]
# Train loss in epoch 78: [0.59667391], Test loss: [0.62678277]
# Train loss in epoch 79: [0.59412754], Test loss: [0.62260979]
# Train loss in epoch 80: [0.59144491], Test loss: [0.61769402]
# Train loss in epoch 81: [0.58874804], Test loss: [0.61208612]
# Train loss in epoch 82: [0.58603466], Test loss: [0.60575491]
# Train loss in epoch 83: [0.58251792], Test loss: [0.5981741]
# Train loss in epoch 84: [0.56974185], Test loss: [0.58275062]
# Train loss in epoch 85: [0.53174919], Test loss: [0.54557419]
# Train loss in epoch 86: [0.49727532], Test loss: [0.51303673]
# Train loss in epoch 87: [0.47052217], Test loss: [0.48617247]
# Train loss in epoch 88: [0.44649792], Test loss: [0.46099541]
# Train loss in epoch 89: [0.42385337], Test loss: [0.43703005]
# Train loss in epoch 90: [0.40216014], Test loss: [0.41426042]
# Train loss in epoch 91: [0.38115636], Test loss: [0.39258286]
# Train loss in epoch 92: [0.36045873], Test loss: [0.37170702]
# Train loss in epoch 93: [0.33988649], Test loss: [0.35138926]
# Train loss in epoch 94: [0.31601566], Test loss: [0.32837269]
# Train loss in epoch 95: [0.28514719], Test loss: [0.29950154]
# Train loss in epoch 96: [0.25777602], Test loss: [0.27390102]
# Train loss in epoch 97: [0.23700073], Test loss: [0.25414026]
# Train loss in epoch 98: [0.2183639], Test loss: [0.23633644]
# Train loss in epoch 99: [0.19964375], Test loss: [0.21859872]
# Train loss in epoch 100: [0.18246625], Test loss: [0.20226143]
# Train loss in epoch 101: [0.1689796], Test loss: [0.18912588]
# Train loss in epoch 102: [0.15765218], Test loss: [0.17793976]
# Train loss in epoch 103: [0.14758293], Test loss: [0.16794772]
# Train loss in epoch 104: [0.13847664], Test loss: [0.15888153]
# Train loss in epoch 105: [0.13018557], Test loss: [0.15059647]
# Train loss in epoch 106: [0.12261081], Test loss: [0.14299257]
# Train loss in epoch 107: [0.11568167], Test loss: [0.13599993]
# Train loss in epoch 108: [0.10935111], Test loss: [0.12956841]
# Train loss in epoch 109: [0.10357738], Test loss: [0.12365893]
# Train loss in epoch 110: [0.098295689], Test loss: [0.11821224]
# Train loss in epoch 111: [0.093426317], Test loss: [0.11315448]
# Train loss in epoch 112: [0.088865578], Test loss: [0.10838734]
# Train loss in epoch 113: [0.084768347], Test loss: [0.10404465]
# Train loss in epoch 114: [0.081015967], Test loss: [0.10002889]
# Train loss in epoch 115: [0.077567078], Test loss: [0.096294977]
# Train loss in epoch 116: [0.074390009], Test loss: [0.092808314]
# Train loss in epoch 117: [0.071459979], Test loss: [0.089542344]
# Train loss in epoch 118: [0.068757609], Test loss: [0.086476579]
# Train loss in epoch 119: [0.066267654], Test loss: [0.083596319]
# Train loss in epoch 120: [0.063978016], Test loss: [0.080891743]
# Train loss in epoch 121: [0.061877266], Test loss: [0.078357056]
# Train loss in epoch 122: [0.059953481], Test loss: [0.075988673]
# Train loss in epoch 123: [0.058192883], Test loss: [0.073782384]
# Train loss in epoch 124: [0.05658064], Test loss: [0.071733803]
# Train loss in epoch 125: [0.055103198], Test loss: [0.069837078]
# Train loss in epoch 126: [0.053750053], Test loss: [0.068086065]
# Train loss in epoch 127: [0.052511003], Test loss: [0.066471212]
# Train loss in epoch 128: [0.051351838], Test loss: [0.064961337]
# Train loss in epoch 129: [0.050036058], Test loss: [0.063332342]
# Train loss in epoch 130: [0.048766531], Test loss: [0.061757263]
# Train loss in epoch 131: [0.049461596], Test loss: [0.061995581]
# Train loss in epoch 132: [0.050481237], Test loss: [0.0625453]
# Train loss in epoch 133: [0.050729975], Test loss: [0.06239133]
# Train loss in epoch 134: [0.055824678], Test loss: [0.066889614]
# Train loss in epoch 135: [0.054920524], Test loss: [0.066047885]
# Train loss in epoch 136: [0.04940924], Test loss: [0.060423769]
# Train loss in epoch 137: [0.047625937], Test loss: [0.058466561]
# Train loss in epoch 138: [0.04807971], Test loss: [0.058681138]
# Train loss in epoch 139: [0.050341297], Test loss: [0.060669597]
# Train loss in epoch 140: [0.054805472], Test loss: [0.064833231]
# Train loss in epoch 141: [0.059516422], Test loss: [0.06937141]
# Train loss in epoch 142: [0.041328214], Test loss: [0.051552452]
# Train loss in epoch 143: [0.041340075], Test loss: [0.050924949]
# Train loss in epoch 144: [0.05616729], Test loss: [0.064413741]
# Train loss in epoch 145: [0.052631151], Test loss: [0.060887501]
# Train loss in epoch 146: [0.050566703], Test loss: [0.058731198]
# Train loss in epoch 147: [0.048902467], Test loss: [0.056962162]
# Train loss in epoch 148: [0.047609787], Test loss: [0.055550549]
# Train loss in epoch 149: [0.046521418], Test loss: [0.054339226]
# Train loss in epoch 150: [0.045584314], Test loss: [0.053277403]
# Train loss in epoch 151: [0.044762157], Test loss: [0.052330136]
# Train loss in epoch 152: [0.044019766], Test loss: [0.051464643]
# Train loss in epoch 153: [0.043298971], Test loss: [0.050627388]
# Train loss in epoch 154: [0.042533435], Test loss: [0.049757183]
# Train loss in epoch 155: [0.041565616], Test loss: [0.048708711]
# Train loss in epoch 156: [0.039000414], Test loss: [0.046224326]
# Train loss in epoch 157: [0.041110829], Test loss: [0.047951542]
# Train loss in epoch 158: [0.034751859], Test loss: [0.0425428]
# Train loss in epoch 159: [0.039806552], Test loss: [0.046450645]
# Train loss in epoch 160: [0.034269854], Test loss: [0.041840181]
# Train loss in epoch 161: [0.038934097], Test loss: [0.045372009]
# Train loss in epoch 162: [0.035887819], Test loss: [0.043363743]
# Train loss in epoch 163: [0.03645638], Test loss: [0.043830641]
# Train loss in epoch 164: [0.037889756], Test loss: [0.044007376]
# Train loss in epoch 165: [0.035559386], Test loss: [0.042732731]
# Train loss in epoch 166: [0.035611175], Test loss: [0.042679392]
# Train loss in epoch 167: [0.036653366], Test loss: [0.042517833]
# Train loss in epoch 168: [0.035594866], Test loss: [0.042489085]
# Train loss in epoch 169: [0.036105514], Test loss: [0.041797109]
# Train loss in epoch 170: [0.035204012], Test loss: [0.041931994]
# Train loss in epoch 171: [0.034651712], Test loss: [0.041285008]
# Train loss in epoch 172: [0.034257025], Test loss: [0.039846398]
# Train loss in epoch 173: [0.035742033], Test loss: [0.041020609]
# Train loss in epoch 174: [0.034467645], Test loss: [0.040863149]
# Train loss in epoch 175: [0.033604726], Test loss: [0.038973302]
# Train loss in epoch 176: [0.035179064], Test loss: [0.04022339]
# Train loss in epoch 177: [0.033966161], Test loss: [0.040135305]
# Train loss in epoch 178: [0.033416349], Test loss: [0.03950505]
# Train loss in epoch 179: [0.033626191], Test loss: [0.039659217]
# Train loss in epoch 180: [0.033409409], Test loss: [0.039377451]
# Train loss in epoch 181: [0.03330946], Test loss: [0.039214082]
# Train loss in epoch 182: [0.033180386], Test loss: [0.039021514]
# Train loss in epoch 183: [0.033058122], Test loss: [0.038836665]
# Train loss in epoch 184: [0.032935165], Test loss: [0.038652193]
# Train loss in epoch 185: [0.032813031], Test loss: [0.038469639]
# Train loss in epoch 186: [0.03269159], Test loss: [0.038288988]
# Train loss in epoch 187: [0.032570489], Test loss: [0.038109742]
# Train loss in epoch 188: [0.032450117], Test loss: [0.037932374]
# Train loss in epoch 189: [0.032330066], Test loss: [0.037756272]
# Train loss in epoch 190: [0.032211076], Test loss: [0.037582301]
# Train loss in epoch 191: [0.032092854], Test loss: [0.037410021]
# Train loss in epoch 192: [0.031975895], Test loss: [0.03723982]
# Train loss in epoch 193: [0.03186157], Test loss: [0.037073258]
# Train loss in epoch 194: [0.03174971], Test loss: [0.036910098]
# Train loss in epoch 195: [0.031640045], Test loss: [0.036750205]
# Train loss in epoch 196: [0.031529237], Test loss: [0.036590122]
# Train loss in epoch 197: [0.031408213], Test loss: [0.036419056]
# Train loss in epoch 198: [0.031229714], Test loss: [0.036181092]
# Train loss in epoch 199: [0.03251908], Test loss: [0.036242701]
# Train loss in epoch 200: [0.031143155], Test loss: [0.036006168]
# Train loss in epoch 201: [0.032194786], Test loss: [0.035852037]
# Train loss in epoch 202: [0.030967779], Test loss: [0.03573671]
# Train loss in epoch 203: [0.031366438], Test loss: [0.035043679]
# Train loss in epoch 204: [0.030809585], Test loss: [0.035488568]
# Train loss in epoch 205: [0.031061824], Test loss: [0.034682535]
# Train loss in epoch 206: [0.030657243], Test loss: [0.035250552]
# Train loss in epoch 207: [0.030864513], Test loss: [0.034414925]
# Train loss in epoch 208: [0.030501839], Test loss: [0.035011895]
# Train loss in epoch 209: [0.030705899], Test loss: [0.034182929]
# Train loss in epoch 210: [0.030344751], Test loss: [0.034773577]
# Train loss in epoch 211: [0.030570254], Test loss: [0.033973031]
# Train loss in epoch 212: [0.030186607], Test loss: [0.034535799]
# Train loss in epoch 213: [0.030450389], Test loss: [0.033778872]
# Train loss in epoch 214: [0.030028649], Test loss: [0.034299843]
# Train loss in epoch 215: [0.030340984], Test loss: [0.033596054]
# Train loss in epoch 216: [0.02987184], Test loss: [0.034066714]
# Train loss in epoch 217: [0.030238129], Test loss: [0.03342095]
# Train loss in epoch 218: [0.029717423], Test loss: [0.033837721]
# Train loss in epoch 219: [0.030139791], Test loss: [0.033251934]
# Train loss in epoch 220: [0.029564481], Test loss: [0.033611953]
# Train loss in epoch 221: [0.030045651], Test loss: [0.033088744]
# Train loss in epoch 222: [0.029414097], Test loss: [0.033390496]
# Train loss in epoch 223: [0.029954184], Test loss: [0.032929845]
# Train loss in epoch 224: [0.029266192], Test loss: [0.033173282]
# Train loss in epoch 225: [0.029864874], Test loss: [0.032774821]
# Train loss in epoch 226: [0.029120097], Test loss: [0.032959588]
# Train loss in epoch 227: [0.029778093], Test loss: [0.032623924]
# Train loss in epoch 228: [0.028976053], Test loss: [0.032749563]
# Train loss in epoch 229: [0.029693872], Test loss: [0.032477148]
# Train loss in epoch 230: [0.028833942], Test loss: [0.032543145]
# Train loss in epoch 231: [0.029611569], Test loss: [0.032333884]
# Train loss in epoch 232: [0.028693624], Test loss: [0.032340094]
# Train loss in epoch 233: [0.029530957], Test loss: [0.032193832]
# Train loss in epoch 234: [0.028555367], Test loss: [0.03214062]
# Train loss in epoch 235: [0.029452983], Test loss: [0.032057833]
# Train loss in epoch 236: [0.028419353], Test loss: [0.031944863]
# Train loss in epoch 237: [0.029376619], Test loss: [0.031924713]
# Train loss in epoch 238: [0.028284688], Test loss: [0.031751897]
# Train loss in epoch 239: [0.029302483], Test loss: [0.031795193]
# Train loss in epoch 240: [0.028152533], Test loss: [0.031562734]
# Train loss in epoch 241: [0.029229712], Test loss: [0.031668201]
# Train loss in epoch 242: [0.028021924], Test loss: [0.031376384]
# Train loss in epoch 243: [0.029159727], Test loss: [0.031545065]
# Train loss in epoch 244: [0.027893383], Test loss: [0.031193279]
# Train loss in epoch 245: [0.02909122], Test loss: [0.031424422]
# Train loss in epoch 246: [0.027766753], Test loss: [0.031013172]
# Train loss in epoch 247: [0.029025152], Test loss: [0.031307157]
# Train loss in epoch 248: [0.027641751], Test loss: [0.030835606]
# Train loss in epoch 249: [0.02896075], Test loss: [0.031192359]
# Train loss in epoch 250: [0.02751876], Test loss: [0.030661043]
# Train loss in epoch 251: [0.028898863], Test loss: [0.031080825]
# Train loss in epoch 252: [0.027397141], Test loss: [0.030488646]
# Train loss in epoch 253: [0.028839335], Test loss: [0.030972295]
# Train loss in epoch 254: [0.027277395], Test loss: [0.030318897]
# Train loss in epoch 255: [0.02878171], Test loss: [0.030866371]
# Train loss in epoch 256: [0.027159259], Test loss: [0.030151524]
# Train loss in epoch 257: [0.028726745], Test loss: [0.030763585]
# Train loss in epoch 258: [0.027042497], Test loss: [0.029986132]
# Train loss in epoch 259: [0.028673928], Test loss: [0.030663522]
# Train loss in epoch 260: [0.026927277], Test loss: [0.029822987]
# Train loss in epoch 261: [0.028624255], Test loss: [0.030566964]
# Train loss in epoch 262: [0.026813541], Test loss: [0.029661931]
# Train loss in epoch 263: [0.028576486], Test loss: [0.030472919]
# Train loss in epoch 264: [0.026701082], Test loss: [0.029502772]
# Train loss in epoch 265: [0.028531894], Test loss: [0.030382358]
# Train loss in epoch 266: [0.026589878], Test loss: [0.029345419]
# Train loss in epoch 267: [0.028490327], Test loss: [0.030295182]
# Train loss in epoch 268: [0.02648003], Test loss: [0.029190077]
# Train loss in epoch 269: [0.028451817], Test loss: [0.030211449]
# Train loss in epoch 270: [0.026371328], Test loss: [0.029036429]
# Train loss in epoch 271: [0.02841666], Test loss: [0.030131456]
# Train loss in epoch 272: [0.026263746], Test loss: [0.028884575]
# Train loss in epoch 273: [0.028384559], Test loss: [0.030054899]
# Train loss in epoch 274: [0.026157275], Test loss: [0.028734373]
# Train loss in epoch 275: [0.028356051], Test loss: [0.029982347]
# Train loss in epoch 276: [0.026051775], Test loss: [0.028585875]
# Train loss in epoch 277: [0.028331311], Test loss: [0.029913936]
# Train loss in epoch 278: [0.025947457], Test loss: [0.028439209]
# Train loss in epoch 279: [0.028310221], Test loss: [0.029849617]
# Train loss in epoch 280: [0.02584408], Test loss: [0.028294183]
# Train loss in epoch 281: [0.028292906], Test loss: [0.029789448]
# Train loss in epoch 282: [0.025741749], Test loss: [0.028151061]
# Train loss in epoch 283: [0.02827936], Test loss: [0.029733654]
# Train loss in epoch 284: [0.02564043], Test loss: [0.028009713]
# Train loss in epoch 285: [0.028270043], Test loss: [0.029682497]
# Train loss in epoch 286: [0.025540218], Test loss: [0.027870242]
# Train loss in epoch 287: [0.028265495], Test loss: [0.029636588]
# Train loss in epoch 288: [0.025441064], Test loss: [0.027732793]
# Train loss in epoch 289: [0.028265182], Test loss: [0.029595489]
# Train loss in epoch 290: [0.025342938], Test loss: [0.027597338]
# Train loss in epoch 291: [0.028269758], Test loss: [0.02955978]
# Train loss in epoch 292: [0.025246015], Test loss: [0.027463965]
# Train loss in epoch 293: [0.028279517], Test loss: [0.029529786]
# Train loss in epoch 294: [0.025150191], Test loss: [0.027332705]
# Train loss in epoch 295: [0.028294727], Test loss: [0.029505759]
# Train loss in epoch 296: [0.025055438], Test loss: [0.027203457]
# Train loss in epoch 297: [0.028314956], Test loss: [0.029487386]
# Train loss in epoch 298: [0.024961974], Test loss: [0.027076557]
# Train loss in epoch 299: [0.028342638], Test loss: [0.029476726]
# Train loss in epoch 300: [0.024869695], Test loss: [0.026951935]
# Train loss in epoch 301: [0.028377257], Test loss: [0.029473491]
# Train loss in epoch 302: [0.024778809], Test loss: [0.026829807]
# Train loss in epoch 303: [0.028419461], Test loss: [0.029478118]
# Train loss in epoch 304: [0.024689134], Test loss: [0.026710007]
# Train loss in epoch 305: [0.028469689], Test loss: [0.029491134]
# Train loss in epoch 306: [0.024600826], Test loss: [0.02659264]
# Train loss in epoch 307: [0.028529033], Test loss: [0.029513471]
# Train loss in epoch 308: [0.024514057], Test loss: [0.02647797]
# Train loss in epoch 309: [0.028599389], Test loss: [0.029546808]
# Train loss in epoch 310: [0.024428578], Test loss: [0.026365582]
# Train loss in epoch 311: [0.028679965], Test loss: [0.029590458]
# Train loss in epoch 312: [0.024344511], Test loss: [0.026255658]
# Train loss in epoch 313: [0.028771874], Test loss: [0.029645417]
# Train loss in epoch 314: [0.024262004], Test loss: [0.026148329]
# Train loss in epoch 315: [0.028876118], Test loss: [0.029712588]
# Train loss in epoch 316: [0.024181087], Test loss: [0.026043642]
# Train loss in epoch 317: [0.028994216], Test loss: [0.02979335]
# Train loss in epoch 318: [0.024101697], Test loss: [0.025941538]
# Train loss in epoch 319: [0.02912559], Test loss: [0.029887147]
# Train loss in epoch 320: [0.024023755], Test loss: [0.025841758]
# Train loss in epoch 321: [0.029270831], Test loss: [0.029994575]
# Train loss in epoch 322: [0.023947366], Test loss: [0.02574442]
# Train loss in epoch 323: [0.029431451], Test loss: [0.03011699]
# Train loss in epoch 324: [0.023872528], Test loss: [0.025649536]
# Train loss in epoch 325: [0.029607713], Test loss: [0.030254703]
# Train loss in epoch 326: [0.023799062], Test loss: [0.025556743]
# Train loss in epoch 327: [0.02980065], Test loss: [0.030408628]
# Train loss in epoch 328: [0.023727138], Test loss: [0.025466297]
# Train loss in epoch 329: [0.030009285], Test loss: [0.030578036]
# Train loss in epoch 330: [0.023656683], Test loss: [0.025378056]
# Train loss in epoch 331: [0.030235469], Test loss: [0.030764554]
# Train loss in epoch 332: [0.023587454], Test loss: [0.025291702]
# Train loss in epoch 333: [0.030481778], Test loss: [0.030970644]
# Train loss in epoch 334: [0.023519628], Test loss: [0.025207382]
# Train loss in epoch 335: [0.030746812], Test loss: [0.031195149]
# Train loss in epoch 336: [0.02345299], Test loss: [0.025124829]
# Train loss in epoch 337: [0.031033754], Test loss: [0.031441029]
# Train loss in epoch 338: [0.023387671], Test loss: [0.025044238]
# Train loss in epoch 339: [0.031343602], Test loss: [0.031709235]
# Train loss in epoch 340: [0.023323402], Test loss: [0.024965152]
# Train loss in epoch 341: [0.031677969], Test loss: [0.03200154]
# Train loss in epoch 342: [0.023260253], Test loss: [0.024887737]
# Train loss in epoch 343: [0.032043926], Test loss: [0.032324351]
# Train loss in epoch 344: [0.023198098], Test loss: [0.024811689]
# Train loss in epoch 345: [0.032439262], Test loss: [0.032675944]
# Train loss in epoch 346: [0.023136985], Test loss: [0.024737172]
# Train loss in epoch 347: [0.032871716], Test loss: [0.033063672]
# Train loss in epoch 348: [0.023076819], Test loss: [0.024663925]
# Train loss in epoch 349: [0.033341542], Test loss: [0.033487886]
# Train loss in epoch 350: [0.023017459], Test loss: [0.024591966]
# Train loss in epoch 351: [0.03385568], Test loss: [0.033955298]
# Train loss in epoch 352: [0.022958996], Test loss: [0.024521254]
# Train loss in epoch 353: [0.034422241], Test loss: [0.03447371]
# Train loss in epoch 354: [0.022901347], Test loss: [0.024451692]
# Train loss in epoch 355: [0.035030957], Test loss: [0.035034046]
# Train loss in epoch 356: [0.022844434], Test loss: [0.024383159]
# Train loss in epoch 357: [0.035699837], Test loss: [0.035653405]
# Train loss in epoch 358: [0.022788271], Test loss: [0.024315741]
# Train loss in epoch 359: [0.036412098], Test loss: [0.036316782]
# Train loss in epoch 360: [0.022732791], Test loss: [0.024249243]
# Train loss in epoch 361: [0.03715736], Test loss: [0.0370152]
# Train loss in epoch 362: [0.022677949], Test loss: [0.024183691]
# Train loss in epoch 363: [0.037895843], Test loss: [0.037712164]
# Train loss in epoch 364: [0.022623766], Test loss: [0.024119044]
# Train loss in epoch 365: [0.038552016], Test loss: [0.038338114]
# Train loss in epoch 366: [0.022570167], Test loss: [0.024055235]
# Train loss in epoch 367: [0.038990032], Test loss: [0.038767114]
# Train loss in epoch 368: [0.022517163], Test loss: [0.023992289]
# Train loss in epoch 369: [0.038938429], Test loss: [0.038745448]
# Train loss in epoch 370: [0.022464637], Test loss: [0.023930017]
# Train loss in epoch 371: [0.037936058], Test loss: [0.03784132]
# Train loss in epoch 372: [0.022412622], Test loss: [0.02386846]
# Train loss in epoch 373: [0.035313264], Test loss: [0.035426579]
# Train loss in epoch 374: [0.022361051], Test loss: [0.023807501]
# Train loss in epoch 375: [0.030454155], Test loss: [0.030931605]
# Train loss in epoch 376: [0.022309974], Test loss: [0.023747105]
# Train loss in epoch 377: [0.024379518], Test loss: [0.025364149]
# Train loss in epoch 378: [0.022259906], Test loss: [0.023687966]
# Train loss in epoch 379: [0.022508383], Test loss: [0.023966763]
# Train loss in epoch 380: [0.022197306], Test loss: [0.023610599]
# Train loss in epoch 381: [0.025132578], Test loss: [0.02674973]
# Train loss in epoch 382: [0.022159506], Test loss: [0.02356967]
# Train loss in epoch 383: [0.031970784], Test loss: [0.033739157]
# Train loss in epoch 384: [0.022109637], Test loss: [0.023511641]
# Train loss in epoch 385: [0.037050996], Test loss: [0.038890142]
# Train loss in epoch 386: [0.022060497], Test loss: [0.023454102]
# Train loss in epoch 387: [0.040074717], Test loss: [0.041949622]
# Train loss in epoch 388: [0.022012431], Test loss: [0.023397729]
# Train loss in epoch 389: [0.041200116], Test loss: [0.043084051]
# Train loss in epoch 390: [0.021965198], Test loss: [0.023342349]
# Train loss in epoch 391: [0.041106101], Test loss: [0.04298187]
# Train loss in epoch 392: [0.021918699], Test loss: [0.023287851]
# Train loss in epoch 393: [0.040392768], Test loss: [0.042251021]
# Train loss in epoch 394: [0.0218729], Test loss: [0.023234311]
# Train loss in epoch 395: [0.039402924], Test loss: [0.04123893]
# Train loss in epoch 396: [0.021827606], Test loss: [0.023181487]
# Train loss in epoch 397: [0.038339745], Test loss: [0.040151685]
# Train loss in epoch 398: [0.021782868], Test loss: [0.023129389]
# Train loss in epoch 399: [0.03729552], Test loss: [0.039083026]
# Train loss in epoch 400: [0.021738572], Test loss: [0.023077901]
# Train loss in epoch 401: [0.036304135], Test loss: [0.038067374]
# Train loss in epoch 402: [0.021694722], Test loss: [0.023027048]
# Train loss in epoch 403: [0.035396218], Test loss: [0.037136242]
# Train loss in epoch 404: [0.021651255], Test loss: [0.022976756]
# Train loss in epoch 405: [0.03455206], Test loss: [0.036269665]
# Train loss in epoch 406: [0.021608181], Test loss: [0.022927038]
# Train loss in epoch 407: [0.033770751], Test loss: [0.035466809]
# Train loss in epoch 408: [0.021565471], Test loss: [0.022877857]
# Train loss in epoch 409: [0.033057995], Test loss: [0.034733839]
# Train loss in epoch 410: [0.021523092], Test loss: [0.022829173]
# Train loss in epoch 411: [0.032403991], Test loss: [0.034060828]
# Train loss in epoch 412: [0.021481099], Test loss: [0.022781016]
# Train loss in epoch 413: [0.031792715], Test loss: [0.033431336]
# Train loss in epoch 414: [0.021439403], Test loss: [0.022733349]
# Train loss in epoch 415: [0.031223761], Test loss: [0.032845154]
# Train loss in epoch 416: [0.021397986], Test loss: [0.022686139]
# Train loss in epoch 417: [0.030685721], Test loss: [0.032290649]
# Train loss in epoch 418: [0.021356311], Test loss: [0.022638615]
# Train loss in epoch 419: [0.030166619], Test loss: [0.031755552]
# Train loss in epoch 420: [0.021309836], Test loss: [0.022583481]
# Train loss in epoch 421: [0.029630743], Test loss: [0.031202804]
# Train loss in epoch 422: [0.034765121], Test loss: [0.034739651]
# Train loss in epoch 423: [0.021248519], Test loss: [0.022514015]
# Train loss in epoch 424: [0.029196169], Test loss: [0.030756805]
# Train loss in epoch 425: [0.030423794], Test loss: [0.032013863]
# Train loss in epoch 426: [0.021190181], Test loss: [0.022449177]
# Train loss in epoch 427: [0.028533382], Test loss: [0.030071931]
# Train loss in epoch 428: [0.025419734], Test loss: [0.026890337]
# Train loss in epoch 429: [0.028435867], Test loss: [0.029964659]
# Train loss in epoch 430: [0.02512211], Test loss: [0.026581105]
# Train loss in epoch 431: [0.028649453], Test loss: [0.030178664]
# Train loss in epoch 432: [0.024938658], Test loss: [0.026389705]
# Train loss in epoch 433: [0.028509062], Test loss: [0.030031689]
# Train loss in epoch 434: [0.024797872], Test loss: [0.026242159]
# Train loss in epoch 435: [0.028416373], Test loss: [0.02993376]
# Train loss in epoch 436: [0.024692412], Test loss: [0.026130743]
# Train loss in epoch 437: [0.028261323], Test loss: [0.02977203]
# Train loss in epoch 438: [0.024640031], Test loss: [0.026073506]
# Train loss in epoch 439: [0.028055646], Test loss: [0.029558389]
# Train loss in epoch 440: [0.024647079], Test loss: [0.026076866]
# Train loss in epoch 441: [0.02779646], Test loss: [0.029290009]
# Train loss in epoch 442: [0.024715211], Test loss: [0.026142599]
# Train loss in epoch 443: [0.02749357], Test loss: [0.028976988]
# Train loss in epoch 444: [0.024836773], Test loss: [0.026262853]
# Train loss in epoch 445: [0.027152348], Test loss: [0.028624754]
# Train loss in epoch 446: [0.024998082], Test loss: [0.026423693]
# Train loss in epoch 447: [0.026798466], Test loss: [0.028259642]
# Train loss in epoch 448: [0.025162529], Test loss: [0.026587859]
# Train loss in epoch 449: [0.026459809], Test loss: [0.027910359]
# Train loss in epoch 450: [0.025304727], Test loss: [0.026729427]
# Train loss in epoch 451: [0.026159566], Test loss: [0.027600396]
# Train loss in epoch 452: [0.0254029], Test loss: [0.026826262]
# Train loss in epoch 453: [0.025913363], Test loss: [0.027345793]
# Train loss in epoch 454: [0.025447134], Test loss: [0.026868131]
# Train loss in epoch 455: [0.025718234], Test loss: [0.027143376]
# Train loss in epoch 456: [0.025446918], Test loss: [0.026864795]
# Train loss in epoch 457: [0.025564222], Test loss: [0.026983052]
# Train loss in epoch 458: [0.025409948], Test loss: [0.026823938]
# Train loss in epoch 459: [0.025441462], Test loss: [0.026854638]
# Train loss in epoch 460: [0.025348322], Test loss: [0.026758002]
# Train loss in epoch 461: [0.025337936], Test loss: [0.026745921]
# Train loss in epoch 462: [0.025272883], Test loss: [0.026678011]
# Train loss in epoch 463: [0.025242116], Test loss: [0.026645143]
# Train loss in epoch 464: [0.025191549], Test loss: [0.026592076]
# Train loss in epoch 465: [0.02515208], Test loss: [0.026550312]
# Train loss in epoch 466: [0.025106603], Test loss: [0.026502468]
# Train loss in epoch 467: [0.02506458], Test loss: [0.026458118]
# Train loss in epoch 468: [0.025020836], Test loss: [0.026412042]
# Train loss in epoch 469: [0.024978021], Test loss: [0.026366927]
# Train loss in epoch 470: [0.024935953], Test loss: [0.026322611]
# Train loss in epoch 471: [0.024892014], Test loss: [0.026276335]
# Train loss in epoch 472: [0.024850067], Test loss: [0.026232161]
# Train loss in epoch 473: [0.024806635], Test loss: [0.026186451]
# Train loss in epoch 474: [0.024764437], Test loss: [0.026142027]
# Train loss in epoch 475: [0.024721218], Test loss: [0.026096575]
# Train loss in epoch 476: [0.024678644], Test loss: [0.02605178]
# Train loss in epoch 477: [0.024636302], Test loss: [0.026007233]
# Train loss in epoch 478: [0.024594683], Test loss: [0.025963426]
# Train loss in epoch 479: [0.024550896], Test loss: [0.025917444]
# Train loss in epoch 480: [0.024510998], Test loss: [0.025875393]
# Train loss in epoch 481: [0.024468541], Test loss: [0.025830746]
# Train loss in epoch 482: [0.024426758], Test loss: [0.025786821]
# Train loss in epoch 483: [0.02438594], Test loss: [0.025743939]
# Train loss in epoch 484: [0.024343826], Test loss: [0.025699634]
# Train loss in epoch 485: [0.024303455], Test loss: [0.025657184]
# Train loss in epoch 486: [0.024261981], Test loss: [0.025613632]
# Train loss in epoch 487: [0.024221387], Test loss: [0.025570937]
# Train loss in epoch 488: [0.024181474], Test loss: [0.025528952]
# Train loss in epoch 489: [0.024140291], Test loss: [0.025485728]
# Train loss in epoch 490: [0.024099505], Test loss: [0.025442882]
# Train loss in epoch 491: [0.024059106], Test loss: [0.0254004]
# Train loss in epoch 492: [0.024021231], Test loss: [0.025360551]
# Train loss in epoch 493: [0.02398105], Test loss: [0.025318321]
# Train loss in epoch 494: [0.023941409], Test loss: [0.025276707]
# Train loss in epoch 495: [0.023901939], Test loss: [0.025235236]
# Train loss in epoch 496: [0.023862805], Test loss: [0.025194097]
# Train loss in epoch 497: [0.023823965], Test loss: [0.025153302]
# Train loss in epoch 498: [0.023785526], Test loss: [0.025112916]
# Train loss in epoch 499: [0.023746885], Test loss: [0.025072286]
# Train loss in epoch 500: [0.023708127], Test loss: [0.025031634]
# Train loss in epoch 501: [0.02367039], Test loss: [0.024991985]
# Train loss in epoch 502: [0.023632478], Test loss: [0.024952088]
# Train loss in epoch 503: [0.023595855], Test loss: [0.024913602]
# Train loss in epoch 504: [0.023558782], Test loss: [0.024874613]
# Train loss in epoch 505: [0.023521788], Test loss: [0.024835829]
# Train loss in epoch 506: [0.023484629], Test loss: [0.024796706]
# Train loss in epoch 507: [0.02344849], Test loss: [0.024758726]
# Train loss in epoch 508: [0.023411551], Test loss: [0.024719939]
# Train loss in epoch 509: [0.02337656], Test loss: [0.024683103]
# Train loss in epoch 510: [0.023339804], Test loss: [0.024644515]
# Train loss in epoch 511: [0.023304749], Test loss: [0.024607595]
# Train loss in epoch 512: [0.023270003], Test loss: [0.024571104]
# Train loss in epoch 513: [0.023233738], Test loss: [0.024532942]
# Train loss in epoch 514: [0.02320002], Test loss: [0.024497502]
# Train loss in epoch 515: [0.023165472], Test loss: [0.024461139]
# Train loss in epoch 516: [0.023130614], Test loss: [0.024424527]
# Train loss in epoch 517: [0.023097087], Test loss: [0.024389192]
# Train loss in epoch 518: [0.023062419], Test loss: [0.024352804]
# Train loss in epoch 519: [0.023029337], Test loss: [0.024317969]
# Train loss in epoch 520: [0.022995519], Test loss: [0.024282418]
# Train loss in epoch 521: [0.022963148], Test loss: [0.024248291]
# Train loss in epoch 522: [0.022930443], Test loss: [0.024213914]
# Train loss in epoch 523: [0.022897581], Test loss: [0.024179306]
# Train loss in epoch 524: [0.022865277], Test loss: [0.024145354]
# Train loss in epoch 525: [0.022833649], Test loss: [0.024111984]
# Train loss in epoch 526: [0.022801418], Test loss: [0.024078127]
# Train loss in epoch 527: [0.022769736], Test loss: [0.024044726]
# Train loss in epoch 528: [0.022738904], Test loss: [0.02401229]
# Train loss in epoch 529: [0.022707164], Test loss: [0.023978848]
# Train loss in epoch 530: [0.02267739], Test loss: [0.023947474]
# Train loss in epoch 531: [0.02264628], Test loss: [0.023914702]
# Train loss in epoch 532: [0.022615902], Test loss: [0.0238827]
# Train loss in epoch 533: [0.022585705], Test loss: [0.023850897]
# Train loss in epoch 534: [0.022555938], Test loss: [0.023819491]
# Train loss in epoch 535: [0.022526037], Test loss: [0.023788055]
# Train loss in epoch 536: [0.022496942], Test loss: [0.02375732]
# Train loss in epoch 537: [0.02246723], Test loss: [0.023726009]
# Train loss in epoch 538: [0.022438286], Test loss: [0.023695517]
# Train loss in epoch 539: [0.022409867], Test loss: [0.023665499]
# Train loss in epoch 540: [0.022381317], Test loss: [0.023635415]
# Train loss in epoch 541: [0.022352759], Test loss: [0.023605302]
# Train loss in epoch 542: [0.022325184], Test loss: [0.023576174]
# Train loss in epoch 543: [0.02229728], Test loss: [0.023546757]
# Train loss in epoch 544: [0.022269599], Test loss: [0.023517549]
# Train loss in epoch 545: [0.022242203], Test loss: [0.023488618]
# Train loss in epoch 546: [0.022214994], Test loss: [0.023459896]
# Train loss in epoch 547: [0.022187579], Test loss: [0.023430983]
# Train loss in epoch 548: [0.022161033], Test loss: [0.023402929]
# Train loss in epoch 549: [0.022134334], Test loss: [0.02337474]
# Train loss in epoch 550: [0.022108253], Test loss: [0.023347184]
# Train loss in epoch 551: [0.022081669], Test loss: [0.023319112]
# Train loss in epoch 552: [0.022056015], Test loss: [0.023292001]
# Train loss in epoch 553: [0.022030186], Test loss: [0.02326473]
# Train loss in epoch 554: [0.022004191], Test loss: [0.023237251]
# Train loss in epoch 555: [0.021978129], Test loss: [0.023209717]
# Train loss in epoch 556: [0.021953568], Test loss: [0.023183718]
# Train loss in epoch 557: [0.021928284], Test loss: [0.023157004]
# Train loss in epoch 558: [0.021903019], Test loss: [0.023130311]
# Train loss in epoch 559: [0.021878505], Test loss: [0.023104377]
# Train loss in epoch 560: [0.021853494], Test loss: [0.023077909]
# Train loss in epoch 561: [0.021829739], Test loss: [0.023052789]
# Train loss in epoch 562: [0.021805607], Test loss: [0.023027254]
# Train loss in epoch 563: [0.021781426], Test loss: [0.023001667]
# Train loss in epoch 564: [0.021757333], Test loss: [0.022976169]
# Train loss in epoch 565: [0.021733828], Test loss: [0.022951266]
# Train loss in epoch 566: [0.021710757], Test loss: [0.022926863]
# Train loss in epoch 567: [0.021686904], Test loss: [0.022901569]
# Train loss in epoch 568: [0.021663472], Test loss: [0.022876792]
# Train loss in epoch 569: [0.02164066], Test loss: [0.022852629]
# Train loss in epoch 570: [0.02161717], Test loss: [0.022827759]
# Train loss in epoch 571: [0.021595025], Test loss: [0.022804268]
# Train loss in epoch 572: [0.021572161], Test loss: [0.022780068]
# Train loss in epoch 573: [0.021549623], Test loss: [0.022756178]
# Train loss in epoch 574: [0.021527592], Test loss: [0.022732802]
# Train loss in epoch 575: [0.021505387], Test loss: [0.022709288]
# Train loss in epoch 576: [0.021483019], Test loss: [0.022685576]
# Train loss in epoch 577: [0.021460952], Test loss: [0.022662202]
# Train loss in epoch 578: [0.021439601], Test loss: [0.022639532]
# Train loss in epoch 579: [0.021417776], Test loss: [0.022616373]
# Train loss in epoch 580: [0.021396335], Test loss: [0.022593632]
# Train loss in epoch 581: [0.021375198], Test loss: [0.022571214]
# Train loss in epoch 582: [0.021353666], Test loss: [0.022548374]
# Train loss in epoch 583: [0.021332953], Test loss: [0.022526361]
# Train loss in epoch 584: [0.021312073], Test loss: [0.022504196]
# Train loss in epoch 585: [0.0212905], Test loss: [0.022481315]
# Train loss in epoch 586: [0.021270268], Test loss: [0.022459857]
# Train loss in epoch 587: [0.021249738], Test loss: [0.022438034]
# Train loss in epoch 588: [0.021229252], Test loss: [0.022416249]
# Train loss in epoch 589: [0.021209104], Test loss: [0.022394851]
# Train loss in epoch 590: [0.021188565], Test loss: [0.022373028]
# Train loss in epoch 591: [0.021168848], Test loss: [0.022352085]
# Train loss in epoch 592: [0.02114851], Test loss: [0.022330448]
# Train loss in epoch 593: [0.021128714], Test loss: [0.022309421]
# Train loss in epoch 594: [0.021108922], Test loss: [0.022288393]
# Train loss in epoch 595: [0.021089567], Test loss: [0.022267815]
# Train loss in epoch 596: [0.021069692], Test loss: [0.022246677]
# Train loss in epoch 597: [0.021050289], Test loss: [0.022226069]
# Train loss in epoch 598: [0.021030992], Test loss: [0.022205496]
# Train loss in epoch 599: [0.021011692], Test loss: [0.022184994]
# Train loss in epoch 600: [0.020992381], Test loss: [0.022164427]
# Train loss in epoch 601: [0.020973768], Test loss: [0.022144653]
# Train loss in epoch 602: [0.020955103], Test loss: [0.02212476]
# Train loss in epoch 603: [0.020936035], Test loss: [0.022104479]
# Train loss in epoch 604: [0.020917069], Test loss: [0.022084285]
# Train loss in epoch 605: [0.020898795], Test loss: [0.02206482]
# Train loss in epoch 606: [0.020880204], Test loss: [0.022045016]
# Train loss in epoch 607: [0.020861723], Test loss: [0.022025354]
# Train loss in epoch 608: [0.020843349], Test loss: [0.022005785]
# Train loss in epoch 609: [0.020825302], Test loss: [0.02198657]
# Train loss in epoch 610: [0.020807156], Test loss: [0.02196721]
# Train loss in epoch 611: [0.020789323], Test loss: [0.021948215]
# Train loss in epoch 612: [0.020771205], Test loss: [0.021928912]
# Train loss in epoch 613: [0.020753521], Test loss: [0.021910027]
# Train loss in epoch 614: [0.020735579], Test loss: [0.021890935]
# Train loss in epoch 615: [0.020717815], Test loss: [0.021871997]
# Train loss in epoch 616: [0.020700384], Test loss: [0.021853389]
# Train loss in epoch 617: [0.020682907], Test loss: [0.021834776]
# Train loss in epoch 618: [0.020665698], Test loss: [0.021816393]
# Train loss in epoch 619: [0.020648241], Test loss: [0.021797759]
# Train loss in epoch 620: [0.020631077], Test loss: [0.021779466]
# Train loss in epoch 621: [0.0206137], Test loss: [0.021760914]
# Train loss in epoch 622: [0.020596553], Test loss: [0.021742634]
# Train loss in epoch 623: [0.020579789], Test loss: [0.021724723]
# Train loss in epoch 624: [0.020563003], Test loss: [0.02170679]
# Train loss in epoch 625: [0.020545982], Test loss: [0.021688651]
# Train loss in epoch 626: [0.020529317], Test loss: [0.02167085]
# Train loss in epoch 627: [0.020512426], Test loss: [0.02165281]
# Train loss in epoch 628: [0.020496175], Test loss: [0.021635436]
# Train loss in epoch 629: [0.02047943], Test loss: [0.021617536]
# Train loss in epoch 630: [0.020463109], Test loss: [0.021600101]
# Train loss in epoch 631: [0.020446759], Test loss: [0.02158263]
# Train loss in epoch 632: [0.020430153], Test loss: [0.021564888]
# Train loss in epoch 633: [0.020414248], Test loss: [0.021547887]
# Train loss in epoch 634: [0.020398], Test loss: [0.021530513]
# Train loss in epoch 635: [0.020381868], Test loss: [0.021513289]
# Train loss in epoch 636: [0.020365885], Test loss: [0.021496171]
# Train loss in epoch 637: [0.02034976], Test loss: [0.02147894]
# Train loss in epoch 638: [0.020333817], Test loss: [0.021461904]
# Train loss in epoch 639: [0.020317975], Test loss: [0.021444974]
# Train loss in epoch 640: [0.020302411], Test loss: [0.021428309]
# Train loss in epoch 641: [0.020286707], Test loss: [0.021411503]
# Train loss in epoch 642: [0.020271068], Test loss: [0.021394774]
# Train loss in epoch 643: [0.020255571], Test loss: [0.021378191]
# Train loss in epoch 644: [0.020240024], Test loss: [0.021361541]
# Train loss in epoch 645: [0.020224651], Test loss: [0.021345092]
# Train loss in epoch 646: [0.020209361], Test loss: [0.02132869]
# Train loss in epoch 647: [0.020193975], Test loss: [0.021312242]
# Train loss in epoch 648: [0.020178813], Test loss: [0.021296013]
# Train loss in epoch 649: [0.020163497], Test loss: [0.021279603]
# Train loss in epoch 650: [0.020148255], Test loss: [0.021263281]
# Train loss in epoch 651: [0.020133276], Test loss: [0.021247242]
# Train loss in epoch 652: [0.020118471], Test loss: [0.021231353]
# Train loss in epoch 653: [0.020103419], Test loss: [0.021215227]
# Train loss in epoch 654: [0.020088725], Test loss: [0.021199472]
# Train loss in epoch 655: [0.020073952], Test loss: [0.021183666]
# Train loss in epoch 656: [0.020059122], Test loss: [0.021167766]
# Train loss in epoch 657: [0.020044323], Test loss: [0.021151897]
# Train loss in epoch 658: [0.020029683], Test loss: [0.021136189]
# Train loss in epoch 659: [0.020015199], Test loss: [0.021120656]
# Train loss in epoch 660: [0.020000666], Test loss: [0.021105072]
# Train loss in epoch 661: [0.019986048], Test loss: [0.021089427]
# Train loss in epoch 662: [0.019971693], Test loss: [0.021074003]
# Train loss in epoch 663: [0.01995768], Test loss: [0.021058965]
# Train loss in epoch 664: [0.019943237], Test loss: [0.021043453]
# Train loss in epoch 665: [0.019928955], Test loss: [0.021028146]
# Train loss in epoch 666: [0.019914549], Test loss: [0.021012681]
# Train loss in epoch 667: [0.019900622], Test loss: [0.020997729]
# Train loss in epoch 668: [0.019886419], Test loss: [0.020982493]
# Train loss in epoch 669: [0.019872567], Test loss: [0.020967592]
# Train loss in epoch 670: [0.019858282], Test loss: [0.020952284]
# Train loss in epoch 671: [0.019844424], Test loss: [0.020937413]
# Train loss in epoch 672: [0.01983048], Test loss: [0.02092243]
# Train loss in epoch 673: [0.019816715], Test loss: [0.020907644]
# Train loss in epoch 674: [0.019802943], Test loss: [0.020892838]
# Train loss in epoch 675: [0.019789113], Test loss: [0.020877998]
# Train loss in epoch 676: [0.019775076], Test loss: [0.020862931]
# Train loss in epoch 677: [0.019761873], Test loss: [0.020848714]
# Train loss in epoch 678: [0.019748058], Test loss: [0.020833865]
# Train loss in epoch 679: [0.019734286], Test loss: [0.020819094]
# Train loss in epoch 680: [0.019721188], Test loss: [0.020804981]
# Train loss in epoch 681: [0.019707605], Test loss: [0.020790411]
# Train loss in epoch 682: [0.019694379], Test loss: [0.020776192]
# Train loss in epoch 683: [0.019680895], Test loss: [0.020761691]
# Train loss in epoch 684: [0.019667715], Test loss: [0.020747509]
# Train loss in epoch 685: [0.019654183], Test loss: [0.020732976]
# Train loss in epoch 686: [0.019640947], Test loss: [0.020718738]
# Train loss in epoch 687: [0.019627864], Test loss: [0.020704657]
# Train loss in epoch 688: [0.019614568], Test loss: [0.020690352]
# Train loss in epoch 689: [0.019601617], Test loss: [0.020676425]
# Train loss in epoch 690: [0.019588435], Test loss: [0.020662254]
# Train loss in epoch 691: [0.019575514], Test loss: [0.020648327]
# Train loss in epoch 692: [0.019562364], Test loss: [0.02063418]
# Train loss in epoch 693: [0.019549552], Test loss: [0.020620389]
# Train loss in epoch 694: [0.0195366], Test loss: [0.020606462]
# Train loss in epoch 695: [0.019523742], Test loss: [0.020592628]
# Train loss in epoch 696: [0.019510943], Test loss: [0.020578852]
# Train loss in epoch 697: [0.019498071], Test loss: [0.020564983]
# Train loss in epoch 698: [0.019485541], Test loss: [0.020551484]
# Train loss in epoch 699: [0.019472895], Test loss: [0.020537874]
# Train loss in epoch 700: [0.019460153], Test loss: [0.020524133]
# Train loss in epoch 701: [0.019447386], Test loss: [0.02051039]
# Train loss in epoch 702: [0.019434996], Test loss: [0.020497046]
# Train loss in epoch 703: [0.019422257], Test loss: [0.020483332]
# Train loss in epoch 704: [0.019409811], Test loss: [0.020469915]
# Train loss in epoch 705: [0.01939729], Test loss: [0.020456428]
# Train loss in epoch 706: [0.019384973], Test loss: [0.020443158]
# Train loss in epoch 707: [0.019372633], Test loss: [0.020429853]
# Train loss in epoch 708: [0.019360201], Test loss: [0.02041647]
# Train loss in epoch 709: [0.019347968], Test loss: [0.020403277]
# Train loss in epoch 710: [0.01933565], Test loss: [0.020389998]
# Train loss in epoch 711: [0.019323481], Test loss: [0.020376882]
# Train loss in epoch 712: [0.019311193], Test loss: [0.020363621]
# Train loss in epoch 713: [0.019299151], Test loss: [0.020350626]
# Train loss in epoch 714: [0.019286908], Test loss: [0.020337436]
# Train loss in epoch 715: [0.019274825], Test loss: [0.020324428]
# Train loss in epoch 716: [0.019262796], Test loss: [0.020311441]
# Train loss in epoch 717: [0.019250827], Test loss: [0.020298535]
# Train loss in epoch 718: [0.01923871], Test loss: [0.02028548]
# Train loss in epoch 719: [0.019226685], Test loss: [0.020272506]
# Train loss in epoch 720: [0.019214695], Test loss: [0.020259559]
# Train loss in epoch 721: [0.019202877], Test loss: [0.020246813]
# Train loss in epoch 722: [0.019191079], Test loss: [0.020234078]
# Train loss in epoch 723: [0.019179199], Test loss: [0.020221254]
# Train loss in epoch 724: [0.019167433], Test loss: [0.020208551]
# Train loss in epoch 725: [0.019155566], Test loss: [0.020195751]
# Train loss in epoch 726: [0.019143978], Test loss: [0.020183247]
# Train loss in epoch 727: [0.019132191], Test loss: [0.020170519]
# Train loss in epoch 728: [0.019120624], Test loss: [0.020158038]
# Train loss in epoch 729: [0.019108783], Test loss: [0.020145265]
# Train loss in epoch 730: [0.019097235], Test loss: [0.020132776]
# Train loss in epoch 731: [0.019085795], Test loss: [0.020120431]
# Train loss in epoch 732: [0.019074222], Test loss: [0.020107942]
# Train loss in epoch 733: [0.019062731], Test loss: [0.02009554]
# Train loss in epoch 734: [0.019051144], Test loss: [0.020083005]
# Train loss in epoch 735: [0.019039704], Test loss: [0.020070646]
# Train loss in epoch 736: [0.019028276], Test loss: [0.020058315]
# Train loss in epoch 737: [0.019016929], Test loss: [0.020046059]
# Train loss in epoch 738: [0.019005567], Test loss: [0.020033769]
# Train loss in epoch 739: [0.018994223], Test loss: [0.020021517]
# Train loss in epoch 740: [0.018982947], Test loss: [0.020009333]
# Train loss in epoch 741: [0.0189717], Test loss: [0.019997183]
# Train loss in epoch 742: [0.018960455], Test loss: [0.019985016]
# Train loss in epoch 743: [0.018949337], Test loss: [0.019972999]
# Train loss in epoch 744: [0.018938093], Test loss: [0.019960854]
# Train loss in epoch 745: [0.018926945], Test loss: [0.019948822]
# Train loss in epoch 746: [0.018915696], Test loss: [0.019936644]
# ...
# Train loss in epoch 753: [0.018838605], Test loss: [0.019853273]
# Train loss in epoch 754: [0.018827703], Test loss: [0.019841477]
# Train loss in epoch 755: [0.018816885], Test loss: [0.019829778]
# Train loss in epoch 756: [0.018805763], Test loss: [0.019817756]
# Train loss in epoch 757: [0.01879501], Test loss: [0.019806135]
# Train loss in epoch 758: [0.01878421], Test loss: [0.019794445]
# Train loss in epoch 759: [0.018773474], Test loss: [0.019782813]
# Train loss in epoch 760: [0.018762592], Test loss: [0.019771054]
# Train loss in epoch 761: [0.018751925], Test loss: [0.01975951]
# Train loss in epoch 762: [0.018741138], Test loss: [0.01974784]
# Train loss in epoch 763: [0.018730504], Test loss: [0.019736316]
# Train loss in epoch 764: [0.018719837], Test loss: [0.01972476]
# Train loss in epoch 765: [0.018709036], Test loss: [0.019713074]
# Train loss in epoch 766: [0.018698612], Test loss: [0.019701796]
# Train loss in epoch 767: [0.018687941], Test loss: [0.01969023]
# Train loss in epoch 768: [0.018677339], Test loss: [0.019678757]
# Train loss in epoch 769: [0.018666666], Test loss: [0.019667221]
# Train loss in epoch 770: [0.018656293], Test loss: [0.019655967]
# Train loss in epoch 771: [0.018645728], Test loss: [0.01964451]
# Train loss in epoch 772: [0.018635325], Test loss: [0.019633237]
# Train loss in epoch 773: [0.018624758], Test loss: [0.019621814]
# Train loss in epoch 774: [0.018614274], Test loss: [0.019610463]
# Train loss in epoch 775: [0.018603962], Test loss: [0.019599274]
# Train loss in epoch 776: [0.018593559], Test loss: [0.019588018]
# Train loss in epoch 777: [0.018583301], Test loss: [0.019576903]
# Train loss in epoch 778: [0.018572813], Test loss: [0.019565552]
# Train loss in epoch 779: [0.018562626], Test loss: [0.019554507]
# Train loss in epoch 780: [0.018552229], Test loss: [0.019543238]
# Train loss in epoch 781: [0.018541932], Test loss: [0.019532066]
# Train loss in epoch 782: [0.018531606], Test loss: [0.019520886]
# Train loss in epoch 783: [0.018521508], Test loss: [0.019509945]
# Train loss in epoch 784: [0.018511401], Test loss: [0.019498987]
# Train loss in epoch 785: [0.018501084], Test loss: [0.019487804]
# Train loss in epoch 786: [0.018490689], Test loss: [0.01947652]
# Train loss in epoch 787: [0.018480875], Test loss: [0.019465875]
# Train loss in epoch 788: [0.018470597], Test loss: [0.019454747]
# Train loss in epoch 789: [0.018460408], Test loss: [0.01944368]
# Train loss in epoch 790: [0.018450461], Test loss: [0.019432908]
# Train loss in epoch 791: [0.01844034], Test loss: [0.01942192]
# Train loss in epoch 792: [0.01843033], Test loss: [0.019411057]
# Train loss in epoch 793: [0.018420182], Test loss: [0.019400053]
# Train loss in epoch 794: [0.018410251], Test loss: [0.019389285]
# Train loss in epoch 795: [0.018400237], Test loss: [0.019378416]
# Train loss in epoch 796: [0.01839016], Test loss: [0.019367484]
# Train loss in epoch 797: [0.018380124], Test loss: [0.019356608]
# Train loss in epoch 798: [0.018370356], Test loss: [0.019346006]
# Train loss in epoch 799: [0.018360602], Test loss: [0.0193354]
# Train loss in epoch 800: [0.018350508], Test loss: [0.019324467]
# Train loss in epoch 801: [0.01834067], Test loss: [0.019313775]
# Train loss in epoch 802: [0.018330827], Test loss: [0.019303098]
# Train loss in epoch 803: [0.018320914], Test loss: [0.019292332]
# Train loss in epoch 804: [0.018311074], Test loss: [0.019281644]
# Train loss in epoch 805: [0.018301247], Test loss: [0.019270968]
# Train loss in epoch 806: [0.018291488], Test loss: [0.019260377]
# Train loss in epoch 807: [0.018281776], Test loss: [0.019249838]
# Train loss in epoch 808: [0.018271938], Test loss: [0.019239148]
# Train loss in epoch 809: [0.018262319], Test loss: [0.019228699]
# Train loss in epoch 810: [0.01825262], Test loss: [0.019218145]
# Train loss in epoch 811: [0.018242758], Test loss: [0.019207451]
# Train loss in epoch 812: [0.018233156], Test loss: [0.019197006]
# Train loss in epoch 813: [0.01822353], Test loss: [0.019186549]
# Train loss in epoch 814: [0.018213946], Test loss: [0.019176137]
# Train loss in epoch 815: [0.018204153], Test loss: [0.01916549]
# Train loss in epoch 816: [0.018194463], Test loss: [0.019154966]
# Train loss in epoch 817: [0.018184859], Test loss: [0.019144539]
# Train loss in epoch 818: [0.018175358], Test loss: [0.019134201]
# Train loss in epoch 819: [0.018165838], Test loss: [0.019123843]
# Train loss in epoch 820: [0.018156257], Test loss: [0.019113436]
# Train loss in epoch 821: [0.018146692], Test loss: [0.019103024]
# Train loss in epoch 822: [0.01813723], Test loss: [0.019092733]
# Train loss in epoch 823: [0.018127693], Test loss: [0.019082379]
# Train loss in epoch 824: [0.018118236], Test loss: [0.019072091]
# Train loss in epoch 825: [0.018108651], Test loss: [0.01906167]
# Train loss in epoch 826: [0.018099144], Test loss: [0.019051339]
# Train loss in epoch 827: [0.018089781], Test loss: [0.019041136]
# Train loss in epoch 828: [0.018080397], Test loss: [0.019030936]
# Train loss in epoch 829: [0.018071143], Test loss: [0.019020863]
# Train loss in epoch 830: [0.01806163], Test loss: [0.019010516]
# Train loss in epoch 831: [0.018052315], Test loss: [0.019000364]
# Train loss in epoch 832: [0.018042944], Test loss: [0.018990196]
# Train loss in epoch 833: [0.018033531], Test loss: [0.018979939]
# Train loss in epoch 834: [0.018024059], Test loss: [0.018969631]
# Train loss in epoch 835: [0.018014962], Test loss: [0.018959709]
# Train loss in epoch 836: [0.018005455], Test loss: [0.018949367]
# Train loss in epoch 837: [0.017996168], Test loss: [0.018939275]
# Train loss in epoch 838: [0.017986979], Test loss: [0.018929251]
# Train loss in epoch 839: [0.017977871], Test loss: [0.018919332]
# Train loss in epoch 840: [0.017968498], Test loss: [0.018909123]
# Train loss in epoch 841: [0.017959272], Test loss: [0.018899098]
# Train loss in epoch 842: [0.017950099], Test loss: [0.018889086]
# Train loss in epoch 843: [0.017940786], Test loss: [0.018878948]
# Train loss in epoch 844: [0.01793162], Test loss: [0.018868959]
# Train loss in epoch 845: [0.017922493], Test loss: [0.018859003]
# Train loss in epoch 846: [0.017913315], Test loss: [0.018848998]
# Train loss in epoch 847: [0.017904205], Test loss: [0.018839065]
# Train loss in epoch 848: [0.017895048], Test loss: [0.018829104]
# Train loss in epoch 849: [0.017885908], Test loss: [0.01881914]
# Train loss in epoch 850: [0.017876735], Test loss: [0.018809138]
# Train loss in epoch 851: [0.017867696], Test loss: [0.018799275]
# Train loss in epoch 852: [0.017858651], Test loss: [0.018789411]
# Train loss in epoch 853: [0.017849572], Test loss: [0.018779526]
# Train loss in epoch 854: [0.01784054], Test loss: [0.018769652]
# Train loss in epoch 855: [0.017831454], Test loss: [0.018759746]
# Train loss in epoch 856: [0.017822383], Test loss: [0.018749859]
# Train loss in epoch 857: [0.017813256], Test loss: [0.018739894]
# Train loss in epoch 858: [0.017804511], Test loss: [0.018730352]
# Train loss in epoch 859: [0.017795499], Test loss: [0.018720513]
# Train loss in epoch 860: [0.017786447], Test loss: [0.01871066]
# Train loss in epoch 861: [0.017777512], Test loss: [0.018700892]
# Train loss in epoch 862: [0.017768539], Test loss: [0.0186911]
# Train loss in epoch 863: [0.017759595], Test loss: [0.018681329]
# Train loss in epoch 864: [0.017750645], Test loss: [0.018671555]
# Train loss in epoch 865: [0.017741663], Test loss: [0.018661764]
# Train loss in epoch 866: [0.017732803], Test loss: [0.018652083]
# Train loss in epoch 867: [0.017724013], Test loss: [0.01864248]
# Train loss in epoch 868: [0.017715093], Test loss: [0.018632734]
# Train loss in epoch 869: [0.017706217], Test loss: [0.018623026]
# Train loss in epoch 870: [0.017697349], Test loss: [0.018613355]
# Train loss in epoch 871: [0.017688643], Test loss: [0.018603843]
# Train loss in epoch 872: [0.017679749], Test loss: [0.018594131]
# Train loss in epoch 873: [0.01767084], Test loss: [0.018584386]
# Train loss in epoch 874: [0.017662145], Test loss: [0.018574871]
# Train loss in epoch 875: [0.017653327], Test loss: [0.018565241]
# Train loss in epoch 876: [0.017644426], Test loss: [0.018555513]
# Train loss in epoch 877: [0.01763575], Test loss: [0.018546017]
# Train loss in epoch 878: [0.017626915], Test loss: [0.01853637]
# Train loss in epoch 879: [0.017618185], Test loss: [0.018526828]
# Train loss in epoch 880: [0.01760952], Test loss: [0.018517345]
# Train loss in epoch 881: [0.017600825], Test loss: [0.018507823]
# Train loss in epoch 882: [0.017592099], Test loss: [0.018498275]
# Train loss in epoch 883: [0.01758335], Test loss: [0.018488714]
# Train loss in epoch 884: [0.017574545], Test loss: [0.018479072]
# Train loss in epoch 885: [0.017566018], Test loss: [0.018469725]
# Train loss in epoch 886: [0.017557416], Test loss: [0.018460313]
# Train loss in epoch 887: [0.017548697], Test loss: [0.018450776]
# Train loss in epoch 888: [0.017540064], Test loss: [0.018441316]
# Train loss in epoch 889: [0.01753141], Test loss: [0.018431867]
# Train loss in epoch 890: [0.017522831], Test loss: [0.018422445]
# Train loss in epoch 891: [0.017514151], Test loss: [0.018412948]
# Train loss in epoch 892: [0.017505756], Test loss: [0.018403746]
# Train loss in epoch 893: [0.017497007], Test loss: [0.018394168]
# Train loss in epoch 894: [0.017488372], Test loss: [0.018384708]
# Train loss in epoch 895: [0.017479809], Test loss: [0.018375333]
# Train loss in epoch 896: [0.017471371], Test loss: [0.018366065]
# Train loss in epoch 897: [0.017462678], Test loss: [0.018356547]
# Train loss in epoch 898: [0.017454095], Test loss: [0.018347135]
# Train loss in epoch 899: [0.017445615], Test loss: [0.018337838]
# Train loss in epoch 900: [0.017437225], Test loss: [0.018328639]
# Train loss in epoch 901: [0.017428551], Test loss: [0.018319121]
# Train loss in epoch 902: [0.017420238], Test loss: [0.018309999]
# Train loss in epoch 903: [0.017411597], Test loss: [0.018300544]
# Train loss in epoch 904: [0.017403146], Test loss: [0.018291265]
# Train loss in epoch 905: [0.017394796], Test loss: [0.018282095]
# Train loss in epoch 906: [0.017386362], Test loss: [0.018272826]
# Train loss in epoch 907: [0.017377773], Test loss: [0.018263426]
# Train loss in epoch 908: [0.017369501], Test loss: [0.018254319]
# Train loss in epoch 909: [0.01736089], Test loss: [0.018244892]
# Train loss in epoch 910: [0.017352518], Test loss: [0.018235698]
# Train loss in epoch 911: [0.017344203], Test loss: [0.018226566]
# Train loss in epoch 912: [0.017335718], Test loss: [0.018217251]
# Train loss in epoch 913: [0.017327474], Test loss: [0.018208183]
# Train loss in epoch 914: [0.017319005], Test loss: [0.018198891]
# Train loss in epoch 915: [0.017310526], Test loss: [0.018189581]
# Train loss in epoch 916: [0.017302256], Test loss: [0.018180495]
# Train loss in epoch 917: [0.017294001], Test loss: [0.018171418]
# Train loss in epoch 918: [0.017285556], Test loss: [0.018162148]
# Train loss in epoch 919: [0.017277312], Test loss: [0.018153079]
# Train loss in epoch 920: [0.017268993], Test loss: [0.018143937]
# Train loss in epoch 921: [0.017260602], Test loss: [0.018134724]
# Train loss in epoch 922: [0.017252307], Test loss: [0.018125588]
# Train loss in epoch 923: [0.017244061], Test loss: [0.018116523]
# Train loss in epoch 924: [0.017235758], Test loss: [0.018107386]
# Train loss in epoch 925: [0.017227605], Test loss: [0.01809841]
# Train loss in epoch 926: [0.017219275], Test loss: [0.01808925]
# Train loss in epoch 927: [0.017210882], Test loss: [0.018080026]
# Train loss in epoch 928: [0.01720266], Test loss: [0.018070973]
# Train loss in epoch 929: [0.017194491], Test loss: [0.018061975]
# Train loss in epoch 930: [0.017186251], Test loss: [0.01805291]
# Train loss in epoch 931: [0.017177995], Test loss: [0.018043824]
# Train loss in epoch 932: [0.017169889], Test loss: [0.018034892]
# Train loss in epoch 933: [0.017161667], Test loss: [0.018025853]
# Train loss in epoch 934: [0.017153513], Test loss: [0.018016864]
# Train loss in epoch 935: [0.017145334], Test loss: [0.018007837]
# Train loss in epoch 936: [0.01713714], Test loss: [0.01799882]
# Train loss in epoch 937: [0.017128972], Test loss: [0.01798984]
# Train loss in epoch 938: [0.017120855], Test loss: [0.017980885]
# Train loss in epoch 939: [0.017112728], Test loss: [0.017971925]
# Train loss in epoch 940: [0.01710452], Test loss: [0.01796288]
# Train loss in epoch 941: [0.017096531], Test loss: [0.01795407]
# Train loss in epoch 942: [0.017088369], Test loss: [0.017945083]
# Train loss in epoch 943: [0.017080117], Test loss: [0.017935999]
# Train loss in epoch 944: [0.017072072], Test loss: [0.01792711]
# Train loss in epoch 945: [0.017063996], Test loss: [0.017918218]
# Train loss in epoch 946: [0.017055988], Test loss: [0.01790938]
# Train loss in epoch 947: [0.01704786], Test loss: [0.017900415]
# Train loss in epoch 948: [0.017039798], Test loss: [0.017891515]
# Train loss in epoch 949: [0.017031919], Test loss: [0.01788282]
# Train loss in epoch 950: [0.017023709], Test loss: [0.017873762]
# Train loss in epoch 951: [0.017015707], Test loss: [0.017864924]
# Train loss in epoch 952: [0.017007669], Test loss: [0.017856048]
# Train loss in epoch 953: [0.016999725], Test loss: [0.017847275]
# Train loss in epoch 954: [0.016991612], Test loss: [0.017838331]
# Train loss in epoch 955: [0.016983684], Test loss: [0.017829567]
# Train loss in epoch 956: [0.016975619], Test loss: [0.017820666]
# Train loss in epoch 957: [0.01696768], Test loss: [0.017811902]
# Train loss in epoch 958: [0.016959716], Test loss: [0.017803108]
# Train loss in epoch 959: [0.016951751], Test loss: [0.017794302]
# Train loss in epoch 960: [0.016943686], Test loss: [0.017785404]
# Train loss in epoch 961: [0.016935773], Test loss: [0.017776648]
# Train loss in epoch 962: [0.016927961], Test loss: [0.017768003]
# Train loss in epoch 963: [0.016920032], Test loss: [0.017759232]
# Train loss in epoch 964: [0.016912058], Test loss: [0.017750412]
# Train loss in epoch 965: [0.016904099], Test loss: [0.017741619]
# Train loss in epoch 966: [0.016896209], Test loss: [0.017732885]
# Train loss in epoch 967: [0.016888319], Test loss: [0.017724155]
# Train loss in epoch 968: [0.016880402], Test loss: [0.017715406]
# Train loss in epoch 969: [0.016872579], Test loss: [0.017706752]
# Train loss in epoch 970: [0.016864568], Test loss: [0.017697887]
# Train loss in epoch 971: [0.016856764], Test loss: [0.017689245]
# Train loss in epoch 972: [0.016848858], Test loss: [0.017680524]
# Train loss in epoch 973: [0.016841032], Test loss: [0.017671846]
# Train loss in epoch 974: [0.016833181], Test loss: [0.017663158]
# Train loss in epoch 975: [0.01682538], Test loss: [0.01765452]
# Train loss in epoch 976: [0.01681759], Test loss: [0.017645892]
# Train loss in epoch 977: [0.016809653], Test loss: [0.017637115]
# Train loss in epoch 978: [0.016801892], Test loss: [0.017628511]
# Train loss in epoch 979: [0.016794104], Test loss: [0.017619876]
# Train loss in epoch 980: [0.016786389], Test loss: [0.017611323]
# Train loss in epoch 981: [0.016778497], Test loss: [0.017602589]
# Train loss in epoch 982: [0.016770754], Test loss: [0.017594026]
# Train loss in epoch 983: [0.016762877], Test loss: [0.017585283]
# Train loss in epoch 984: [0.016755158], Test loss: [0.017576721]
# Train loss in epoch 985: [0.016747372], Test loss: [0.017568089]
# Train loss in epoch 986: [0.01673968], Test loss: [0.017559553]
# Train loss in epoch 987: [0.016731957], Test loss: [0.017550983]
# Train loss in epoch 988: [0.016724247], Test loss: [0.017542433]
# Train loss in epoch 989: [0.016716443], Test loss: [0.017533809]
# Train loss in epoch 990: [0.016708788], Test loss: [0.017525308]
# Train loss in epoch 991: [0.016701089], Test loss: [0.017516758]
# Train loss in epoch 992: [0.016693449], Test loss: [0.017508287]
# Train loss in epoch 993: [0.016685672], Test loss: [0.017499669]
# Train loss in epoch 994: [0.016677953], Test loss: [0.01749111]
# Train loss in epoch 995: [0.016670296], Test loss: [0.017482601]
# Train loss in epoch 996: [0.016662585], Test loss: [0.017474033]
# Train loss in epoch 997: [0.016655006], Test loss: [0.017465619]
# Train loss in epoch 998: [0.016647371], Test loss: [0.017457146]
# Train loss in epoch 999: [0.016639667], Test loss: [0.017448597]

# %%
#Saving function checking..
dnn_inst.layers[0].w.name
# Out:
# 'Layer0/Matrix/read:0'

# %%
tf.trainable_variables()
# Out:
# [<tensorflow.python.ops.variables.Variable at 0x7fac5f10e748>,
#  <tensorflow.python.ops.variables.Variable at 0x7fac5dc5bef0>,
#  <tensorflow.python.ops.variables.Variable at 0x7fac5d9dbda0>,
#  <tensorflow.python.ops.variables.Variable at 0x7fac5d9db780>,
#  <tensorflow.python.ops.variables.Variable at 0x7fac5da12a20>,
#  <tensorflow.python.ops.variables.Variable at 0x7fac5da12cc0>]

# %%
dnn_inst.save_variables_for_rnn("WEIGHTS_FOLDER/REWARD_NET.chkp")
# Out:
# RNN/FullNetworkCell/Reward/Layer0/Bias
# Tensor("Layer0/Bias/read:0", shape=(32,), dtype=float32)
# RNN/FullNetworkCell/Reward/Layer2/Bias
# Tensor("Layer2/Bias/read:0", shape=(1,), dtype=float32)
# RNN/FullNetworkCell/Reward/Layer0/Matrix
# Tensor("Layer0/Matrix/read:0", shape=(4, 32), dtype=float32)
# RNN/FullNetworkCell/Reward/Layer1/Matrix
# Tensor("Layer1/Matrix/read:0", shape=(32, 32), dtype=float32)
# RNN/FullNetworkCell/Reward/Layer2/Matrix
# Tensor("Layer2/Matrix/read:0", shape=(32, 1), dtype=float32)
# RNN/FullNetworkCell/Reward/Layer1/Bias
# Tensor("Layer1/Bias/read:0", shape=(32,), dtype=float32)
# /home/wuga/Documents/Notebook/VAE-PLANNING/WEIGHTS_FOLDER/REWARD_NET.chkp

# %%
#dnn_inst.predict_test([[1,1,6,6]])
