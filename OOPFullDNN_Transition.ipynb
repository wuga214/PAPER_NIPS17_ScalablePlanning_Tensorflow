# %% [markdown]
# # Fully Connected Network
#
# This is the second part of our whole deep learning planning structure.
#
# The Data in this experiments is generated from RDDL simulator [Github](https://github.com/ssanner/rddlsim), which is written by Prof.Scott Sanner at University of Toronto.
#
# In the section, we need a fully connected network to compute the reward of each (STATE,ACTION,STATE') tuple, that is (STATE,ACTION,STATE') -> Reward. Since this part is deterministic, fully connected network is capable to solve.
#
# Problem list:
# 1. Data normalization will highly impact the network performance, we need to normalize the input. However, the input of this section is an output of VAE, which is unnormalized. And since everything is working under tensorflow environment, we need to build normalizer inside tensorflow graph.
# 2. For reward function R(s,a), in nondeterministic domain, R(s,a) is stochastic. We need a deterministic function. Therefore, we rewrite the reward function as R(s,a,s'). This requires us to concate s,a,s' as single input matrix(also under tensorflow).

# %% [markdown]
# ### Import Packages
# We do note provide pip installation commands, please search this package and install it through pip install. Please upgrade your pip before installing, since old pip would cause errors.

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import tensorflow as tf
import numpy as np
from sklearn.metrics import confusion_matrix
import time
from datetime import timedelta
import math
import os
import pandas as pd
#Functional coding
import functools
from functools import partial
import re

# %% [markdown]
# ### Load Data
# We load data from csv files. The following code shows how to load data through pandas and numpy. Result of this progress can be feed into tensorflow with "feed_dict" argument.

# %%
#Data Path..
Datapath="DATA/Navigation/Nav_RDDL_Data.txt"
Labelpath="DATA/Navigation/Nav_RDDL_Label.txt"
Rewardpath="DATA/Navigation/Nav_RDDL_Reward.txt"

# %%
#Given local path, find full path
def PathFinder(path):
    #python 2
    #script_dir = os.path.dirname('__file__')
    #fullpath = os.path.join(script_dir,path)
    #python 3
    fullpath=os.path.abspath(path)
    print(fullpath)
    return fullpath

#Read Data for Deep Learning
def ReadData(path):
    fullpath=PathFinder(path)
    return pd.read_csv(fullpath, sep=',', header=0)

#Won't use this one to normalize
#Input Normalization
def Normalize(features, mean = [], std = []):
    if mean == []:
        mean = np.mean(features, axis = 0)
        std = np.std(features, axis = 0)
#     print std
#     print std[:,None]
    new_feature = (features.T - mean[:,None]).T
    new_feature = (new_feature.T / std[:,None]).T
    new_feature[np.isnan(new_feature)]=0
#     print new_feature
    return new_feature, mean, std

# %%
x_pd = ReadData(Datapath)
y_pd = ReadData(Labelpath)
# Out:
# /home/wuga/Documents/Notebook/VAE-PLANNING/DATA/Navigation/Nav_RDDL_Data.txt
# /home/wuga/Documents/Notebook/VAE-PLANNING/DATA/Navigation/Nav_RDDL_Label.txt

# %%
#Get Numpy Arrays
x_matrix=x_pd.as_matrix()
x_train = x_matrix[:100000]
x_valid = x_matrix[100000:]
y_matrix=y_pd.as_matrix()
y_train = y_matrix[:100000]
y_valid = y_matrix[100000:]

# %%
len(x_matrix)
# Out:
# 150000

# %%
data_size=len(x_matrix)
# Uppercase for constants
INPUT_S_A_SIZE = 4
OUTPUT_SIZE = 2

# %% [markdown]
# ### Support Functions
# The following functions allows us passthrough multiple functions without explicitly assign intermediate output variables.

# %%
def compose(f,g):
    return lambda x:g(f(x))
    
def composeAll(*args):
    """
    composeAll([f,g,h])(x): f(g(h(x)))
    """
    return partial(functools.reduce, compose)(*args)

# %% [markdown]
# ## Tensorflow
# ### Input tensor place holders

# %%
# Input features s,a
x = tf.placeholder(tf.float32,[None, INPUT_S_A_SIZE],name="Features_S_A")

# Input label
y = tf.placeholder(tf.float32, [None, OUTPUT_SIZE],name="Labels")

# %% [markdown]
# ### Variable Generating functions

# %%
#Weight constructing function
def weight_variable(shape):
    initial = tf.truncated_normal(shape,stddev=0.001)
    return tf.Variable(initial,name="Matrix")

#Bias constructing function
def bias_variable(shape):
    initial = tf.constant(0.,shape=shape)
    return tf.Variable(initial,name="Bias")

# %% [markdown]
# ### Fully Connected Layer Defination

# %%
class Dense():
    """Fully Connected Layer"""
    def __init__(self, scope="fully_connected_layer", output_dim =None, dropout=1.0, activation=tf.identity):
        assert output_dim, "Missing output dimension specification!"
        self.scope = scope
        self.output_dim = output_dim
        self.dropout = dropout
        self.activation = activation
        
    def __call__(self,x):
        with tf.name_scope(self.scope):
            while True:
                try:
                    return self.activation(tf.matmul(x,self.w)+self.b)
                except(AttributeError):
                    self.w = tf.nn.dropout(weight_variable([x.get_shape()[1].value, self.output_dim]),self.dropout)
                    self.b = bias_variable([self.output_dim])
    
    def set_parameters(self, weight, bias):
        self.w.assign(weight)
        self.b.assign(bias)
        
    def get_l2_loss(self):
        return tf.nn.l2_loss(self.w)

# %% [markdown]
# ### Full Deep Network Class
# The following class define a complete deep network, which include:
# 1. Network structure specification
# 2. Loss function specification
# 3. Prediction specification
# 4. Optimization method specification
# 5. Training function
# 6. Saving function(not tensorflow variable saving, but numpy weight dumping!)
# 7. Loading function(not tensorflow variable loading, but numpy weight assignment!)
# 8. Mini-Batch generation function

# %%
class DeepNet(object):
    
    def __init__(self, 
                 x, #Input Features for S,A
                 y, #Output Label for R
                 num_hidden_layers, #number of layers for both encoder and decoder
                 num_hidden_nodes, #number of nodes in each layer
                 activation, #nonlinear activation function
                 learning_rate=0.003, #Learning rate
                 batch_size=1000, 
                 dropout = 1,
                 l2_lambda = 1E-4): #Batch size        
#        self.mean = tf.Variable(tf.zeros([x.get_shape()[1]]),trainable=False,name="NORM_MEAN")
#        self.var = tf.Variable(tf.ones([x.get_shape()[1]]),trainable=False,name="NORM_VAR")
#        self.f = self._p_normalize(x)
        self.f = x
        self.y = y
        self.num_hidden_layers = num_hidden_layers
        self.num_hidden_nodes = num_hidden_nodes
        self.activation = activation
        self.learning_rate = learning_rate
        self.batch_size = batch_size
        self.l2_lambda = l2_lambda
        self.dropout = dropout
        self._p_create_dnn_graph()
        self._p_create_loss()
        self.sess = tf.InteractiveSession()
        self.sess.run(tf.global_variables_initializer())
        
    def _p_create_dnn_graph(self):

        layers = []
        for i in range(self.num_hidden_layers):
            layers.append(Dense("Layer"+str(i),self.num_hidden_nodes,self.dropout,self.activation))
        layers.append(Dense("Layer"+str(self.num_hidden_layers),self.y.get_shape()[1].value,self.dropout))
        self.y_pred = composeAll(layers)(self.f)
        self.layers = layers 
    
    def _p_normalize(self, unnormed):
        epsilon = 1e-3
        normed = tf.nn.batch_normalization(unnormed,self.mean,self.var,None,None,epsilon)
        return normed
        
    def _p_create_loss(self): #lambda for l2 regularization

        #L2 regularization loss
        l2_loss = tf.constant(0.0)
        for layer in self.layers:
            l2_loss += layer.get_l2_loss()

        #Mean Squared Error
        mse_r = tf.reduce_mean(tf.square(tf.sub(self.y,self.y_pred)), reduction_indices=1)

        #loss
        self.loss = tf.reduce_mean(mse_r)+self.l2_lambda*l2_loss
        self.optimizer = tf.train.RMSPropOptimizer(self.learning_rate).minimize(self.loss)   
        
    def update_normalization(self,x_matrix):
        tf_mean,tf_var = tf.nn.moments(x, axes = [0])
        feed_dict = {x:x_matrix}
        np_mean,np_var = self.sess.run([tf_mean,tf_var],feed_dict=feed_dict)
        print(np_mean)
        self.sess.run(self.mean.assign(np_mean))
        self.sess.run(self.var.assign(np_var))
        print(self.mean.eval())
        
    
    def train_model(self,train_s_a,train_r,test_s_a,test_r,epoch=100):
        
#        self.update_normalization(train_s_a)
        
        batches = self._p_get_batches(train_s_a,train_r,self.batch_size)
        
#        self.mean = tf.Variable(tf.zeros([x.get_shape()[1]]),trainable=False)
#        self.var = tf.Variable(tf.ones([x.get_shape()[1]]),trainable=False)
        
        summary_writer = tf.summary.FileWriter('experiment', graph=self.sess.graph)
        feed_test={x:test_s_a,y:test_r}
        feed_train={x:train_s_a, y:train_r}

        #Training
        for epoch in range(epoch):
            for step in range(len(batches)):
                feed_dict = {x: batches[step][0],y: batches[step][1]}
                training = self.sess.run([self.optimizer], feed_dict=feed_dict)
            train_loss = self.sess.run([self.loss],feed_dict=feed_dict)
            test_loss = self.sess.run([self.loss],feed_dict=feed_test)
            print('Train loss in epoch {0}: {1}, Test loss: {2}'.format(epoch, train_loss, test_loss)) 
    
    def predict_test(self, test_s_a):
        feed_dict={x:test_s_a}
        return self.sess.run([self.y_pred],feed_dict=feed_dict)
            
    def _p_get_batches(self,x_matrix,r_matrix,batch_size):
        remaining_size = len(x_matrix)
        batch_index=0
        batches = []
        while(remaining_size>0):
            batch = []
            if remaining_size<batch_size:
                batch.append(x_matrix[batch_index*batch_size:-1])
                batch.append(r_matrix[batch_index*batch_size:-1])
            else:
                batch.append(x_matrix[batch_index*batch_size:(batch_index+1)*batch_size]) 
                batch.append(r_matrix[batch_index*batch_size:(batch_index+1)*batch_size]) 
            batch_index+=1
            remaining_size-=batch_size
            batches.append(batch)
        return batches
    
    def _p_extract_weights(self):
        # a hashmap maps from layer name to weights and biases
        mp_layer_weights = {}

        #iteratively save values
        for dense in self.layers:
            values = {'weights':dense.w, 'biases':dense.b}
            mp_layer_weights[layer.scope] = values
        
        norms = {'mean':self.mean, 'var':self.var}
        mp_layer_weights['normalizations'] = norms

        return mp_layer_weights
    
    def save_weights(self,path):
        #extract weights from trained model
        layer_weights = self.sess.run(_p_extract_weights())
        print('Whole layer weights: {0}'.format(layer_weights))
        np.save(path,layer_weights)
    
    def load_weights(self,path):
        layer_weights = np.load(path)
        for dense in self.layers:
            print('Scope:{0}'.format(dense.scope))
            values = layer_weights.get(dense.scope)
            weights = values.get('weights')
            biases = values.get('biases')
            dense.set_parameters(weights,biases)
        print('Done!')
        
    def save_variables_for_rnn(self,path,prefix="RNN/FullNetworkCell/Transition/"):
        variables = tf.trainable_variables()
        var_dict = {}
        for v in variables:
            if "/read" in v.name:
                name = prefix+re.sub("/read", "", v.name)
                name = re.sub(":0", "", name)
                var_dict[name] = v
            else:
                name = prefix+v.name
                name = re.sub(":0", "", name)
                var_dict[name] = v
        for k,v in var_dict.items():
            print(k)
            print(v)
        saver = tf.train.Saver(var_dict)
        saver.save(self.sess, PathFinder(path))

# %%
#Instantiate a network
dnn_inst = DeepNet(x,y,2,32,tf.nn.sigmoid)

# %% [markdown]
# ### Tensorflow graph visualization function

# %%
from IPython.display import clear_output, Image, display, HTML

def strip_consts(graph_def, max_const_size=32):
    """Strip large constant values from graph_def."""
    strip_def = tf.GraphDef()
    for n0 in graph_def.node:
        n = strip_def.node.add() 
        n.MergeFrom(n0)
        if n.op == 'Const':
            tensor = n.attr['value'].tensor
            size = len(tensor.tensor_content)
            if size > max_const_size:
                tensor.tensor_content = "<stripped %d bytes>"%size
    return strip_def

def show_graph(graph_def, max_const_size=32):
    """Visualize TensorFlow graph."""
    if hasattr(graph_def, 'as_graph_def'):
        graph_def = graph_def.as_graph_def()
    strip_def = strip_consts(graph_def, max_const_size=max_const_size)
    code = """
        <script>
          function load() {{
            document.getElementById("{id}").pbtxt = {data};
          }}
        </script>
        <link rel="import" href="https://tensorboard.appspot.com/tf-graph-basic.build.html" onload=load()>
        <div style="height:600px">
          <tf-graph-basic id="{id}"></tf-graph-basic>
        </div>
    """.format(data=repr(str(strip_def)), id='graph'+str(np.random.rand()))

    iframe = """
        <iframe seamless style="width:960px;height:600px;border:0" srcdoc="{}"></iframe>
    """.format(code.replace('"', '&quot;'))
    display(HTML(iframe))

# %%
show_graph(tf.get_default_graph().as_graph_def())
# Out:
#         <iframe seamless style="width:960px;height:600px;border:0" srcdoc="
#         <script>
#           function load() {
#             document.getElementById(&quot;graph0.8085943810388142&quot;).pbtxt = 'node {\n  name: &quot;Features_S_A&quot;\n  op: &quot;Placeholder&quot;\n  attr {\n    key: &quot;dtype&quot;\n    value {\n      type: DT_FLOAT\n    }\n  }\n  attr {\n    key: &quot;shape&quot;\n    value {\n      shape {\n      }\n    }\n  }\n}\nnode {\n  name: &quot;Labels&quot;\n  op: &quot;Placeholder&quot;\n  attr {\n    key: &quot;dtype&quot;\n    value {\n      type: DT_FLOAT\n    }\n  }\n  attr {\n    key: &quot;shape&quot;\n    value {\n      shape {\n      }\n    }\n  }\n}\nnode {\n  name: &quot;Layer0/truncated_normal/shape&quot;\n  op: &quot;Const&quot;\n  attr {\n    key: &quot;dtype&quot;\n    value {\n      type: DT_INT32\n    }\n  }\n  attr {\n    key: &quot;value&quot;\n    value {\n      tensor {\n        dtype: DT_INT32\n        tensor_shape {\n          dim {\n            size: 2\n          }\n        }\n        tensor_content: &quot;\\004\\000\\000\\000 \\000\\000\\000&quot;\n      }\n    }\n  }\n}\nnode {\n  name: &quot;Layer0/truncated_normal/mean&quot;\n  op: &quot;Const&quot;\n  attr {\n    key: &quot;dtype&quot;\n    value {\n      type: DT_FLOAT\n    }\n  }\n  attr {\n    key: &quot;value&quot;\n    value {\n      tensor {\n        dtype: DT_FLOAT\n        tensor_shape {\n        }\n        float_val: 0.0\n      }\n    }\n  }\n}\nnode {\n  name: &quot;Layer0/truncated_normal/stddev&quot;\n  op: &quot;Const&quot;\n  attr {\n    key: &quot;dtype&quot;\n    value {\n      type: DT_FLOAT\n    }\n  }\n  attr {\n    key: &quot;value&quot;\n    value {\n      tensor {\n        dtype: DT_FLOAT\n        tensor_shape {\n        }\n        float_val: 0.0010000000474974513\n      }\n    }\n  }\n}\nnode {\n  name: &quot;Layer0/truncated_normal/TruncatedNormal&quot;\n  op: &quot;TruncatedNormal&quot;\n  input: &quot;Layer0/truncated_normal/shape&quot;\n  attr {\n    key: &quot;T&quot;\n    value {\n      type: DT_INT32\n    }\n  }\n  attr {\n    key: &quot;dtype&quot;\n    value {\n      type: DT_FLOAT\n    }\n  }\n  attr {\n    key: &quot;seed&quot;\n    value {\n      i: 0\n    }\n  }\n  attr {\n    key: &quot;seed2&quot;\n    value {\n      i: 0\n    }\n  }\n}\nnode {\n  name: &quot;Layer0/truncated_normal/mul&quot;\n  op: &quot;Mul&quot;\n  input: &quot;Layer0/truncated_normal/TruncatedNormal&quot;\n  input: &quot;Layer0/truncated_normal/stddev&quot;\n  attr {\n    key: &quot;T&quot;\n    value {\n      type: DT_FLOAT\n    }\n  }\n}\nnode {\n  name: &quot;Layer0/truncated_normal&quot;\n  op: &quot;Add&quot;\n  input: &quot;Layer0/truncated_normal/mul&quot;\n  input: &quot;Layer0/truncated_normal/mean&quot;\n  attr {\n    key: &quot;T&quot;\n    value {\n      type: DT_FLOAT\n    }\n  }\n}\nnode {\n  name: &quot;Layer0/Matrix&quot;\n  op: &quot;Variable&quot;\n  attr {\n    key: &quot;container&quot;\n    value {\n      s: &quot;&quot;\n    }\n  }\n  attr {\n    key: &quot;dtype&quot;\n    value {\n      type: DT_FLOAT\n    }\n  }\n  attr {\n    key: &quot;shape&quot;\n    value {\n      shape {\n        dim {\n          size: 4\n        }\n        dim {\n          size: 32\n        }\n      }\n    }\n  }\n  attr {\n    key: &quot;shared_name&quot;\n    value {\n      s: &quot;&quot;\n    }\n  }\n}\nnode {\n  name: &quot;Layer0/Matrix/Assign&quot;\n  op: &quot;Assign&quot;\n  input: &quot;Layer0/Matrix&quot;\n  input: &quot;Layer0/truncated_normal&quot;\n  attr {\n    key: &quot;T&quot;\n    value {\n      type: DT_FLOAT\n    }\n  }\n  attr {\n    key: &quot;_class&quot;\n    value {\n      list {\n        s: &quot;loc:@Layer0/Matrix&quot;\n      }\n    }\n  }\n  attr {\n    key: &quot;use_locking&quot;\n    value {\n      b: true\n    }\n  }\n  attr {\n    key: &quot;validate_shape&quot;\n    value {\n      b: true\n    }\n  }\n}\nnode {\n  name: &quot;Layer0/Matrix/read&quot;\n  op: &quot;Identity&quot;\n  input: &quot;Layer0/Matrix&quot;\n  attr {\n    key: &quot;T&quot;\n    value {\n      type: DT_FLOAT\n    }\n  }\n  attr { ...

# %% [markdown]
# ### Training

# %%
dnn_inst.train_model(x_train,y_train,x_valid,y_valid,1000)
# Out:
# Train loss in epoch 0: [8.7156229], Test loss: [8.7292614]
# Train loss in epoch 1: [7.4338923], Test loss: [7.4453249]
# Train loss in epoch 2: [5.9877605], Test loss: [6.0102625]
# Train loss in epoch 3: [4.5866718], Test loss: [4.652782]
# Train loss in epoch 4: [3.269871], Test loss: [3.4212689]
# Train loss in epoch 5: [2.0256276], Test loss: [2.2706032]
# Train loss in epoch 6: [1.1153305], Test loss: [1.4078084]
# Train loss in epoch 7: [0.72872305], Test loss: [1.0241549]
# Train loss in epoch 8: [0.66878819], Test loss: [0.96386343]
# Train loss in epoch 9: [0.66241813], Test loss: [0.95824307]
# Train loss in epoch 10: [0.66012257], Test loss: [0.95642662]
# Train loss in epoch 11: [0.65842026], Test loss: [0.95500541]
# Train loss in epoch 12: [0.65689057], Test loss: [0.95367706]
# Train loss in epoch 13: [0.65545046], Test loss: [0.95241588]
# Train loss in epoch 14: [0.65407842], Test loss: [0.9512102]
# Train loss in epoch 15: [0.65276581], Test loss: [0.95006371]
# Train loss in epoch 16: [0.65150774], Test loss: [0.94896889]
# Train loss in epoch 17: [0.65030217], Test loss: [0.94792312]
# Train loss in epoch 18: [0.64914465], Test loss: [0.94692451]
# Train loss in epoch 19: [0.64803433], Test loss: [0.94596666]
# Train loss in epoch 20: [0.64696664], Test loss: [0.94504941]
# Train loss in epoch 21: [0.64594012], Test loss: [0.94417048]
# Train loss in epoch 22: [0.64495182], Test loss: [0.94332355]
# Train loss in epoch 23: [0.64399892], Test loss: [0.94251001]
# Train loss in epoch 24: [0.64307845], Test loss: [0.94172633]
# Train loss in epoch 25: [0.642187], Test loss: [0.94096231]
# Train loss in epoch 26: [0.64132118], Test loss: [0.9402225]
# Train loss in epoch 27: [0.64047629], Test loss: [0.93949962]
# Train loss in epoch 28: [0.63964772], Test loss: [0.93878853]
# Train loss in epoch 29: [0.63882685], Test loss: [0.93808132]
# Train loss in epoch 30: [0.63800341], Test loss: [0.93736649]
# Train loss in epoch 31: [0.63716334], Test loss: [0.936634]
# Train loss in epoch 32: [0.63628143], Test loss: [0.93585372]
# Train loss in epoch 33: [0.63531846], Test loss: [0.93499404]
# Train loss in epoch 34: [0.63420373], Test loss: [0.93398249]
# Train loss in epoch 35: [0.63279492], Test loss: [0.93268389]
# Train loss in epoch 36: [0.63077241], Test loss: [0.93080193]
# Train loss in epoch 37: [0.62736928], Test loss: [0.92759937]
# Train loss in epoch 38: [0.62143052], Test loss: [0.9219566]
# Train loss in epoch 39: [0.61454087], Test loss: [0.91548818]
# Train loss in epoch 40: [0.60888964], Test loss: [0.91038132]
# Train loss in epoch 41: [0.60377783], Test loss: [0.90572643]
# Train loss in epoch 42: [0.59932548], Test loss: [0.90157789]
# Train loss in epoch 43: [0.59608072], Test loss: [0.89857376]
# Train loss in epoch 44: [0.59382707], Test loss: [0.89653867]
# Train loss in epoch 45: [0.59214348], Test loss: [0.89502615]
# Train loss in epoch 46: [0.59084111], Test loss: [0.89384651]
# Train loss in epoch 47: [0.58983535], Test loss: [0.89292616]
# Train loss in epoch 48: [0.58906257], Test loss: [0.89221257]
# Train loss in epoch 49: [0.58846915], Test loss: [0.89166576]
# Train loss in epoch 50: [0.58801061], Test loss: [0.8912496]
# Train loss in epoch 51: [0.58765155], Test loss: [0.89092517]
# Train loss in epoch 52: [0.58736509], Test loss: [0.89067167]
# Train loss in epoch 53: [0.58713037], Test loss: [0.89047241]
# Train loss in epoch 54: [0.58693337], Test loss: [0.89030778]
# Train loss in epoch 55: [0.58676368], Test loss: [0.89016831]
# Train loss in epoch 56: [0.58661342], Test loss: [0.89004582]
# Train loss in epoch 57: [0.58647716], Test loss: [0.88993639]
# Train loss in epoch 58: [0.58635116], Test loss: [0.88983577]
# Train loss in epoch 59: [0.58623242], Test loss: [0.88974172]
# Train loss in epoch 60: [0.58611965], Test loss: [0.88965034]
# Train loss in epoch 61: [0.58601046], Test loss: [0.88956231]
# Train loss in epoch 62: [0.58590478], Test loss: [0.8894763]
# Train loss in epoch 63: [0.58580101], Test loss: [0.88938731]
# Train loss in epoch 64: [0.5856992], Test loss: [0.88930023]
# Train loss in epoch 65: [0.58559841], Test loss: [0.8892138]
# Train loss in epoch 66: [0.58549803], Test loss: [0.88912618]
# Train loss in epoch 67: [0.58539766], Test loss: [0.88903487]
# Train loss in epoch 68: [0.58529663], Test loss: [0.88894403]
# Train loss in epoch 69: [0.58519369], Test loss: [0.88884825]
# Train loss in epoch 70: [0.58508795], Test loss: [0.88875151]
# Train loss in epoch 71: [0.58497828], Test loss: [0.88864911]
# Train loss in epoch 72: [0.58486342], Test loss: [0.88854128]
# Train loss in epoch 73: [0.58474374], Test loss: [0.88842744]
# Train loss in epoch 74: [0.58461881], Test loss: [0.88830739]
# Train loss in epoch 75: [0.58449036], Test loss: [0.88818622]
# Train loss in epoch 76: [0.5843603], Test loss: [0.88806057]
# Train loss in epoch 77: [0.58422995], Test loss: [0.88793433]
# Train loss in epoch 78: [0.58410287], Test loss: [0.88780898]
# Train loss in epoch 79: [0.58397877], Test loss: [0.88768435]
# Train loss in epoch 80: [0.58385938], Test loss: [0.88756436]
# Train loss in epoch 81: [0.58374494], Test loss: [0.8874495]
# Train loss in epoch 82: [0.58363521], Test loss: [0.88733488]
# Train loss in epoch 83: [0.58353031], Test loss: [0.88722301]
# Train loss in epoch 84: [0.58342916], Test loss: [0.88711518]
# Train loss in epoch 85: [0.58333242], Test loss: [0.88700801]
# Train loss in epoch 86: [0.58323979], Test loss: [0.88690495]
# Train loss in epoch 87: [0.58315086], Test loss: [0.88680404]
# Train loss in epoch 88: [0.58306515], Test loss: [0.8867051]
# Train loss in epoch 89: [0.58298308], Test loss: [0.8866083]
# Train loss in epoch 90: [0.58290476], Test loss: [0.88651341]
# Train loss in epoch 91: [0.58282924], Test loss: [0.88641846]
# Train loss in epoch 92: [0.58275717], Test loss: [0.88632625]
# Train loss in epoch 93: [0.58268797], Test loss: [0.88623518]
# Train loss in epoch 94: [0.58262163], Test loss: [0.88614523]
# Train loss in epoch 95: [0.58255821], Test loss: [0.88605714]
# Train loss in epoch 96: [0.58249724], Test loss: [0.88596833]
# Train loss in epoch 97: [0.58243871], Test loss: [0.88588172]
# Train loss in epoch 98: [0.58238292], Test loss: [0.88579553]
# Train loss in epoch 99: [0.58232957], Test loss: [0.88570976]
# Train loss in epoch 100: [0.58227772], Test loss: [0.88562357]
# Train loss in epoch 101: [0.58222777], Test loss: [0.88553971]
# Train loss in epoch 102: [0.58217937], Test loss: [0.88545322]
# Train loss in epoch 103: [0.58213192], Test loss: [0.88536733]
# Train loss in epoch 104: [0.58208507], Test loss: [0.88528198]
# Train loss in epoch 105: [0.5820384], Test loss: [0.88519156]
# Train loss in epoch 106: [0.58199215], Test loss: [0.88510251]
# Train loss in epoch 107: [0.58194482], Test loss: [0.88501048]
# Train loss in epoch 108: [0.58189756], Test loss: [0.88491976]
# Train loss in epoch 109: [0.5818488], Test loss: [0.88482553]
# Train loss in epoch 110: [0.58179885], Test loss: [0.8847273]
# Train loss in epoch 111: [0.58174706], Test loss: [0.88462704]
# Train loss in epoch 112: [0.58169454], Test loss: [0.88452733]
# Train loss in epoch 113: [0.58164036], Test loss: [0.88442582]
# Train loss in epoch 114: [0.58158481], Test loss: [0.88432109]
# Train loss in epoch 115: [0.5815289], Test loss: [0.884215]
# Train loss in epoch 116: [0.58147258], Test loss: [0.88410962]
# Train loss in epoch 117: [0.58141607], Test loss: [0.88400292]
# Train loss in epoch 118: [0.5813598], Test loss: [0.88389581]
# Train loss in epoch 119: [0.58130425], Test loss: [0.88378841]
# Train loss in epoch 120: [0.58124989], Test loss: [0.88368207]
# Train loss in epoch 121: [0.58119678], Test loss: [0.88357413]
# Train loss in epoch 122: [0.58114487], Test loss: [0.88346672]
# Train loss in epoch 123: [0.58109438], Test loss: [0.88336098]
# Train loss in epoch 124: [0.58104587], Test loss: [0.88325512]
# Train loss in epoch 125: [0.58099806], Test loss: [0.88314885]
# Train loss in epoch 126: [0.58095181], Test loss: [0.88304472]
# Train loss in epoch 127: [0.58090627], Test loss: [0.88293856]
# Train loss in epoch 128: [0.58086127], Test loss: [0.88283265]
# Train loss in epoch 129: [0.58081633], Test loss: [0.8827278]
# Train loss in epoch 130: [0.58077163], Test loss: [0.88262093]
# Train loss in epoch 131: [0.58072639], Test loss: [0.88251406]
# Train loss in epoch 132: [0.58068043], Test loss: [0.88240737]
# Train loss in epoch 133: [0.58063388], Test loss: [0.88229913]
# Train loss in epoch 134: [0.58058667], Test loss: [0.88219076]
# Train loss in epoch 135: [0.58053839], Test loss: [0.88207972]
# Train loss in epoch 136: [0.58049011], Test loss: [0.88197064]
# Train loss in epoch 137: [0.58044165], Test loss: [0.8818624]
# Train loss in epoch 138: [0.58039421], Test loss: [0.8817535]
# Train loss in epoch 139: [0.58034754], Test loss: [0.88164693]
# Train loss in epoch 140: [0.58030266], Test loss: [0.88154167]
# Train loss in epoch 141: [0.5802595], Test loss: [0.88143772]
# Train loss in epoch 142: [0.58021873], Test loss: [0.88133717]
# Train loss in epoch 143: [0.58018076], Test loss: [0.88123691]
# Train loss in epoch 144: [0.58014542], Test loss: [0.88113701]
# Train loss in epoch 145: [0.58011293], Test loss: [0.88104111]
# Train loss in epoch 146: [0.58008301], Test loss: [0.88094652]
# Train loss in epoch 147: [0.58005607], Test loss: [0.88085318]
# Train loss in epoch 148: [0.58003193], Test loss: [0.88076264]
# Train loss in epoch 149: [0.58000982], Test loss: [0.88067281]
# Train loss in epoch 150: [0.57998973], Test loss: [0.88058281]
# Train loss in epoch 151: [0.57997173], Test loss: [0.88049453]
# Train loss in epoch 152: [0.57995486], Test loss: [0.88040787]
# Train loss in epoch 153: [0.57993895], Test loss: [0.88031876]
# Train loss in epoch 154: [0.57992315], Test loss: [0.88023078]
# Train loss in epoch 155: [0.579907], Test loss: [0.88014215]
# Train loss in epoch 156: [0.57988954], Test loss: [0.88005024]
# Train loss in epoch 157: [0.57987076], Test loss: [0.8799597]
# Train loss in epoch 158: [0.57984996], Test loss: [0.87986708]
# Train loss in epoch 159: [0.57982761], Test loss: [0.87977266]
# Train loss in epoch 160: [0.57980251], Test loss: [0.87967724]
# Train loss in epoch 161: [0.57977635], Test loss: [0.8795827]
# Train loss in epoch 162: [0.57974827], Test loss: [0.87948602]
# Train loss in epoch 163: [0.57971936], Test loss: [0.8793897]
# Train loss in epoch 164: [0.57969004], Test loss: [0.87929308]
# Train loss in epoch 165: [0.57966071], Test loss: [0.8791973]
# Train loss in epoch 166: [0.57963151], Test loss: [0.87910342]
# Train loss in epoch 167: [0.57960284], Test loss: [0.8790074]
# Train loss in epoch 168: [0.57957512], Test loss: [0.87891519]
# Train loss in epoch 169: [0.57954806], Test loss: [0.8788228]
# Train loss in epoch 170: [0.57952213], Test loss: [0.87873101]
# Train loss in epoch 171: [0.57949704], Test loss: [0.87864035]
# Train loss in epoch 172: [0.57947254], Test loss: [0.87855113]
# Train loss in epoch 173: [0.57944846], Test loss: [0.8784616]
# Train loss in epoch 174: [0.57942492], Test loss: [0.87837338]
# Train loss in epoch 175: [0.57940137], Test loss: [0.87828612]
# Train loss in epoch 176: [0.57937831], Test loss: [0.87820041]
# Train loss in epoch 177: [0.57935458], Test loss: [0.87811375]
# Train loss in epoch 178: [0.57933122], Test loss: [0.87802917]
# Train loss in epoch 179: [0.57930708], Test loss: [0.87794369]
# Train loss in epoch 180: [0.579283], Test loss: [0.87785923]
# Train loss in epoch 181: [0.57925957], Test loss: [0.87777621]
# Train loss in epoch 182: [0.57923621], Test loss: [0.87769473]
# Train loss in epoch 183: [0.57921505], Test loss: [0.87761402]
# Train loss in epoch 184: [0.57919538], Test loss: [0.87753695]
# Train loss in epoch 185: [0.57917923], Test loss: [0.87746179]
# Train loss in epoch 186: [0.57916671], Test loss: [0.87739038]
# Train loss in epoch 187: [0.57915848], Test loss: [0.8773194]
# Train loss in epoch 188: [0.57915455], Test loss: [0.87725312]
# Train loss in epoch 189: [0.57915556], Test loss: [0.87719077]
# Train loss in epoch 190: [0.57916152], Test loss: [0.8771295]
# Train loss in epoch 191: [0.57917196], Test loss: [0.87707037]
# Train loss in epoch 192: [0.57918686], Test loss: [0.87701559]
# Train loss in epoch 193: [0.57920521], Test loss: [0.87695992]
# Train loss in epoch 194: [0.57922745], Test loss: [0.87690383]
# Train loss in epoch 195: [0.57925153], Test loss: [0.87685078]
# Train loss in epoch 196: [0.57927787], Test loss: [0.87679797]
# Train loss in epoch 197: [0.57930547], Test loss: [0.87674356]
# Train loss in epoch 198: [0.57933342], Test loss: [0.87668848]
# Train loss in epoch 199: [0.57936192], Test loss: [0.87663442]
# Train loss in epoch 200: [0.57939017], Test loss: [0.87657547]
# Train loss in epoch 201: [0.579418], Test loss: [0.87651914]
# Train loss in epoch 202: [0.57944494], Test loss: [0.87645978]
# Train loss in epoch 203: [0.57947117], Test loss: [0.87639874]
# Train loss in epoch 204: [0.57949698], Test loss: [0.87633634]
# Train loss in epoch 205: [0.57952243], Test loss: [0.87627429]
# Train loss in epoch 206: [0.57954735], Test loss: [0.8762098]
# Train loss in epoch 207: [0.57957155], Test loss: [0.87614548]
# Train loss in epoch 208: [0.57959533], Test loss: [0.87608033]
# Train loss in epoch 209: [0.57961881], Test loss: [0.87601215]
# Train loss in epoch 210: [0.57964063], Test loss: [0.87594509]
# Train loss in epoch 211: [0.57966089], Test loss: [0.87587404]
# Train loss in epoch 212: [0.57967877], Test loss: [0.87580186]
# Train loss in epoch 213: [0.57969338], Test loss: [0.8757273]
# Train loss in epoch 214: [0.57970369], Test loss: [0.87564993]
# Train loss in epoch 215: [0.5797084], Test loss: [0.87556988]
# Train loss in epoch 216: [0.57970691], Test loss: [0.87548554]
# Train loss in epoch 217: [0.57969743], Test loss: [0.8753975]
# Train loss in epoch 218: [0.57967949], Test loss: [0.87530416]
# Train loss in epoch 219: [0.57965225], Test loss: [0.87520742]
# Train loss in epoch 220: [0.57961535], Test loss: [0.87510604]
# Train loss in epoch 221: [0.57956839], Test loss: [0.87499994]
# Train loss in epoch 222: [0.57951164], Test loss: [0.87489361]
# Train loss in epoch 223: [0.57944649], Test loss: [0.87478524]
# Train loss in epoch 224: [0.57937324], Test loss: [0.87467426]
# Train loss in epoch 225: [0.57929379], Test loss: [0.87456387]
# Train loss in epoch 226: [0.57920992], Test loss: [0.87445563]
# Train loss in epoch 227: [0.57912302], Test loss: [0.87434918]
# Train loss in epoch 228: [0.57903397], Test loss: [0.87424672]
# Train loss in epoch 229: [0.57894349], Test loss: [0.87414551]
# Train loss in epoch 230: [0.57885057], Test loss: [0.87404895]
# Train loss in epoch 231: [0.57875466], Test loss: [0.87395537]
# Train loss in epoch 232: [0.5786522], Test loss: [0.87385875]
# Train loss in epoch 233: [0.57853889], Test loss: [0.87376404]
# Train loss in epoch 234: [0.57840645], Test loss: [0.87366223]
# Train loss in epoch 235: [0.57824135], Test loss: [0.87354559]
# Train loss in epoch 236: [0.57801884], Test loss: [0.87339759]
# Train loss in epoch 237: [0.57769704], Test loss: [0.87317485]
# Train loss in epoch 238: [0.57720482], Test loss: [0.87274581]
# Train loss in epoch 239: [0.57646191], Test loss: [0.87164551]
# Train loss in epoch 240: [0.57530433], Test loss: [0.86813134]
# Train loss in epoch 241: [0.57069063], Test loss: [0.85566759]
# Train loss in epoch 242: [0.53916574], Test loss: [0.80335647]
# Train loss in epoch 243: [0.35645962], Test loss: [0.55195266]
# Train loss in epoch 244: [0.10596323], Test loss: [0.17674811]
# Train loss in epoch 245: [0.062222537], Test loss: [0.090422459]
# Train loss in epoch 246: [0.081890501], Test loss: [0.10242109]
# Train loss in epoch 247: [0.059190139], Test loss: [0.074716441]
# Train loss in epoch 248: [0.064233787], Test loss: [0.077346779]
# Train loss in epoch 249: [0.11267387], Test loss: [0.12476136]
# Train loss in epoch 250: [0.047907539], Test loss: [0.056141637]
# Train loss in epoch 251: [0.051946014], Test loss: [0.056994602]
# Train loss in epoch 252: [0.034259897], Test loss: [0.04051543]
# Train loss in epoch 253: [0.031092234], Test loss: [0.035756133]
# Train loss in epoch 254: [0.029884985], Test loss: [0.034488276]
# Train loss in epoch 255: [0.03355056], Test loss: [0.038215827]
# Train loss in epoch 256: [0.034673836], Test loss: [0.039739508]
# Train loss in epoch 257: [0.046705838], Test loss: [0.051965062]
# Train loss in epoch 258: [0.038230021], Test loss: [0.042937417]
# Train loss in epoch 259: [0.03312061], Test loss: [0.037296481]
# Train loss in epoch 260: [0.039490916], Test loss: [0.043931969]
# Train loss in epoch 261: [0.052415766], Test loss: [0.057221718]
# Train loss in epoch 262: [0.031923831], Test loss: [0.035796866]
# Train loss in epoch 263: [0.038615514], Test loss: [0.042634796]
# Train loss in epoch 264: [0.039445251], Test loss: [0.043425668]
# Train loss in epoch 265: [0.03831875], Test loss: [0.042058546]
# Train loss in epoch 266: [0.036451608], Test loss: [0.040147644]
# Train loss in epoch 267: [0.032419633], Test loss: [0.035774566]
# Train loss in epoch 268: [0.039899539], Test loss: [0.043465544]
# Train loss in epoch 269: [0.032789581], Test loss: [0.035871711]
# Train loss in epoch 270: [0.043613765], Test loss: [0.046113342]
# Train loss in epoch 271: [0.025070224], Test loss: [0.027232938]
# Train loss in epoch 272: [0.029507421], Test loss: [0.032032028]
# Train loss in epoch 273: [0.027073665], Test loss: [0.029051108]
# Train loss in epoch 274: [0.024637435], Test loss: [0.026544861]
# Train loss in epoch 275: [0.029635839], Test loss: [0.031883549]
# Train loss in epoch 276: [0.024967417], Test loss: [0.026666444]
# Train loss in epoch 277: [0.027412795], Test loss: [0.029379582]
# Train loss in epoch 278: [0.028187135], Test loss: [0.02955577]
# Train loss in epoch 279: [0.028514806], Test loss: [0.030600991]
# Train loss in epoch 280: [0.033942532], Test loss: [0.036016397]
# Train loss in epoch 281: [0.03442841], Test loss: [0.036429085]
# Train loss in epoch 282: [0.030860487], Test loss: [0.03273695]
# Train loss in epoch 283: [0.034370493], Test loss: [0.036178537]
# Train loss in epoch 284: [0.035382062], Test loss: [0.037447728]
# Train loss in epoch 285: [0.032723691], Test loss: [0.034423698]
# Train loss in epoch 286: [0.030066136], Test loss: [0.03170836]
# Train loss in epoch 287: [0.038048059], Test loss: [0.04020723]
# Train loss in epoch 288: [0.032233536], Test loss: [0.033809077]
# Train loss in epoch 289: [0.033367306], Test loss: [0.034828186]
# Train loss in epoch 290: [0.029778996], Test loss: [0.031288985]
# Train loss in epoch 291: [0.02998168], Test loss: [0.031477708]
# Train loss in epoch 292: [0.030239064], Test loss: [0.031699166]
# Train loss in epoch 293: [0.03101898], Test loss: [0.032461807]
# Train loss in epoch 294: [0.031259976], Test loss: [0.032682937]
# Train loss in epoch 295: [0.030008797], Test loss: [0.031307548]
# Train loss in epoch 296: [0.030136645], Test loss: [0.031423911]
# Train loss in epoch 297: [0.030235097], Test loss: [0.031475253]
# Train loss in epoch 298: [0.030675944], Test loss: [0.031856786]
# Train loss in epoch 299: [0.031283163], Test loss: [0.032402717]
# Train loss in epoch 300: [0.030814547], Test loss: [0.031903382]
# Train loss in epoch 301: [0.030273627], Test loss: [0.031412512]
# Train loss in epoch 302: [0.029940447], Test loss: [0.031041922]
# Train loss in epoch 303: [0.029798917], Test loss: [0.030868944]
# Train loss in epoch 304: [0.029655954], Test loss: [0.030687403]
# Train loss in epoch 305: [0.02953919], Test loss: [0.030535698]
# Train loss in epoch 306: [0.029453278], Test loss: [0.030414984]
# Train loss in epoch 307: [0.029388437], Test loss: [0.030319292]
# Train loss in epoch 308: [0.02934904], Test loss: [0.030250648]
# Train loss in epoch 309: [0.029317115], Test loss: [0.030193157]
# Train loss in epoch 310: [0.029302137], Test loss: [0.030154413]
# Train loss in epoch 311: [0.029283896], Test loss: [0.03011544]
# Train loss in epoch 312: [0.029273983], Test loss: [0.030086409]
# Train loss in epoch 313: [0.029256001], Test loss: [0.030051675]
# Train loss in epoch 314: [0.029237743], Test loss: [0.03001824]
# Train loss in epoch 315: [0.029210564], Test loss: [0.029977567]
# Train loss in epoch 316: [0.029178053], Test loss: [0.029932909]
# Train loss in epoch 317: [0.029137131], Test loss: [0.029881118]
# Train loss in epoch 318: [0.029089255], Test loss: [0.029823419]
# Train loss in epoch 319: [0.029034499], Test loss: [0.029759821]
# Train loss in epoch 320: [0.028973892], Test loss: [0.029691126]
# Train loss in epoch 321: [0.028908724], Test loss: [0.029618707]
# Train loss in epoch 322: [0.028839964], Test loss: [0.029543182]
# Train loss in epoch 323: [0.028768484], Test loss: [0.029465543]
# Train loss in epoch 324: [0.028695362], Test loss: [0.029386694]
# Train loss in epoch 325: [0.028621476], Test loss: [0.029307514]
# Train loss in epoch 326: [0.028547302], Test loss: [0.029228363]
# Train loss in epoch 327: [0.028473664], Test loss: [0.029150028]
# Train loss in epoch 328: [0.028400404], Test loss: [0.029072415]
# Train loss in epoch 329: [0.028328348], Test loss: [0.0289963]
# Train loss in epoch 330: [0.028257489], Test loss: [0.028921522]
# Train loss in epoch 331: [0.028188024], Test loss: [0.028848402]
# Train loss in epoch 332: [0.028120022], Test loss: [0.02877688]
# Train loss in epoch 333: [0.028053805], Test loss: [0.028707331]
# Train loss in epoch 334: [0.027989317], Test loss: [0.028639661]
# Train loss in epoch 335: [0.027926391], Test loss: [0.028573688]
# Train loss in epoch 336: [0.027865674], Test loss: [0.028510045]
# Train loss in epoch 337: [0.027806517], Test loss: [0.028448075]
# Train loss in epoch 338: [0.027749203], Test loss: [0.028388053]
# Train loss in epoch 339: [0.027693482], Test loss: [0.02832976]
# Train loss in epoch 340: [0.027639359], Test loss: [0.028273195]
# Train loss in epoch 341: [0.027586274], Test loss: [0.028217863]
# Train loss in epoch 342: [0.027534232], Test loss: [0.028163752]
# Train loss in epoch 343: [0.027482867], Test loss: [0.028110508]
# Train loss in epoch 344: [0.027432067], Test loss: [0.028057998]
# Train loss in epoch 345: [0.027382018], Test loss: [0.028006431]
# Train loss in epoch 346: [0.027332619], Test loss: [0.027955692]
# Train loss in epoch 347: [0.027284134], Test loss: [0.027905975]
# Train loss in epoch 348: [0.027236467], Test loss: [0.0278573]
# Train loss in epoch 349: [0.027189903], Test loss: [0.027809747]
# Train loss in epoch 350: [0.027144438], Test loss: [0.02776343]
# Train loss in epoch 351: [0.027100086], Test loss: [0.027718337]
# Train loss in epoch 352: [0.027056653], Test loss: [0.027674235]
# Train loss in epoch 353: [0.027014239], Test loss: [0.027631205]
# Train loss in epoch 354: [0.026972683], Test loss: [0.027589181]
# Train loss in epoch 355: [0.026932184], Test loss: [0.027548293]
# Train loss in epoch 356: [0.026892418], Test loss: [0.027508173]
# Train loss in epoch 357: [0.026853509], Test loss: [0.027468979]
# Train loss in epoch 358: [0.0268154], Test loss: [0.027430654]
# Train loss in epoch 359: [0.026777912], Test loss: [0.027393077]
# Train loss in epoch 360: [0.026740983], Test loss: [0.027356111]
# Train loss in epoch 361: [0.026704649], Test loss: [0.027319858]
# Train loss in epoch 362: [0.026668604], Test loss: [0.027283939]
# Train loss in epoch 363: [0.026633203], Test loss: [0.027248755]
# Train loss in epoch 364: [0.026598465], Test loss: [0.027214248]
# Train loss in epoch 365: [0.026563738], Test loss: [0.02717983]
# Train loss in epoch 366: [0.026529439], Test loss: [0.02714593]
# Train loss in epoch 367: [0.026495334], Test loss: [0.027112283]
# Train loss in epoch 368: [0.02646156], Test loss: [0.027079035]
# Train loss in epoch 369: [0.026428025], Test loss: [0.027046025]
# Train loss in epoch 370: [0.026394652], Test loss: [0.027013248]
# Train loss in epoch 371: [0.026361292], Test loss: [0.026980536]
# Train loss in epoch 372: [0.026327997], Test loss: [0.026947878]
# Train loss in epoch 373: [0.026295185], Test loss: [0.0269158]
# Train loss in epoch 374: [0.026261903], Test loss: [0.026883222]
# Train loss in epoch 375: [0.026228974], Test loss: [0.026850997]
# Train loss in epoch 376: [0.026196029], Test loss: [0.026818784]
# Train loss in epoch 377: [0.026163202], Test loss: [0.026786666]
# Train loss in epoch 378: [0.026130218], Test loss: [0.026754346]
# Train loss in epoch 379: [0.026097277], Test loss: [0.026722088]
# Train loss in epoch 380: [0.026064396], Test loss: [0.026689801]
# Train loss in epoch 381: [0.026031561], Test loss: [0.026657566]
# Train loss in epoch 382: [0.025998656], Test loss: [0.026625209]
# Train loss in epoch 383: [0.025965799], Test loss: [0.026592821]
# Train loss in epoch 384: [0.025932765], Test loss: [0.026560167]
# Train loss in epoch 385: [0.025899727], Test loss: [0.026527487]
# Train loss in epoch 386: [0.025866877], Test loss: [0.026494879]
# Train loss in epoch 387: [0.025833981], Test loss: [0.026462136]
# Train loss in epoch 388: [0.025801241], Test loss: [0.026429433]
# Train loss in epoch 389: [0.025768386], Test loss: [0.026396528]
# Train loss in epoch 390: [0.025735576], Test loss: [0.026363607]
# Train loss in epoch 391: [0.025702789], Test loss: [0.026330553]
# Train loss in epoch 392: [0.025670197], Test loss: [0.026297614]
# Train loss in epoch 393: [0.0256375], Test loss: [0.026264422]
# Train loss in epoch 394: [0.025605123], Test loss: [0.026231434]
# Train loss in epoch 395: [0.025572596], Test loss: [0.026198186]
# Train loss in epoch 396: [0.025540475], Test loss: [0.026165199]
# Train loss in epoch 397: [0.02550837], Test loss: [0.026132133]
# Train loss in epoch 398: [0.025476296], Test loss: [0.026098967]
# Train loss in epoch 399: [0.025444344], Test loss: [0.026065821]
# Train loss in epoch 400: [0.025412749], Test loss: [0.026032852]
# Train loss in epoch 401: [0.025381168], Test loss: [0.025999844]
# Train loss in epoch 402: [0.025349975], Test loss: [0.025967048]
# Train loss in epoch 403: [0.025318973], Test loss: [0.025934383]
# Train loss in epoch 404: [0.025288126], Test loss: [0.025901683]
# Train loss in epoch 405: [0.025257459], Test loss: [0.025869096]
# Train loss in epoch 406: [0.025227211], Test loss: [0.025836831]
# Train loss in epoch 407: [0.02519705], Test loss: [0.025804523]
# Train loss in epoch 408: [0.025167221], Test loss: [0.025772415]
# Train loss in epoch 409: [0.025137613], Test loss: [0.025740486]
# Train loss in epoch 410: [0.025108313], Test loss: [0.025708703]
# Train loss in epoch 411: [0.025079507], Test loss: [0.025677338]
# Train loss in epoch 412: [0.025050938], Test loss: [0.025646146]
# Train loss in epoch 413: [0.025022382], Test loss: [0.025614854]
# Train loss in epoch 414: [0.024994399], Test loss: [0.025584064]
# Train loss in epoch 415: [0.024966571], Test loss: [0.02555332]
# Train loss in epoch 416: [0.024939487], Test loss: [0.025523273]
# Train loss in epoch 417: [0.024912491], Test loss: [0.025493283]
# Train loss in epoch 418: [0.024885816], Test loss: [0.025463477]
# Train loss in epoch 419: [0.02485963], Test loss: [0.025434114]
# Train loss in epoch 420: [0.024833778], Test loss: [0.025405051]
# Train loss in epoch 421: [0.024808444], Test loss: [0.025376443]
# Train loss in epoch 422: [0.024783373], Test loss: [0.025348023]
# Train loss in epoch 423: [0.024758689], Test loss: [0.025319984]
# Train loss in epoch 424: [0.024734564], Test loss: [0.025292411]
# Train loss in epoch 425: [0.024710875], Test loss: [0.025265262]
# Train loss in epoch 426: [0.024687614], Test loss: [0.025238482]
# Train loss in epoch 427: [0.024664551], Test loss: [0.025211908]
# Train loss in epoch 428: [0.024642106], Test loss: [0.025185868]
# Train loss in epoch 429: [0.02462003], Test loss: [0.025160179]
# Train loss in epoch 430: [0.024598354], Test loss: [0.025134914]
# Train loss in epoch 431: [0.024577247], Test loss: [0.025110174]
# Train loss in epoch 432: [0.024556451], Test loss: [0.025085721]
# Train loss in epoch 433: [0.024536058], Test loss: [0.025061652]
# Train loss in epoch 434: [0.024516309], Test loss: [0.025038226]
# Train loss in epoch 435: [0.024496928], Test loss: [0.025015153]
# Train loss in epoch 436: [0.024478048], Test loss: [0.024992535]
# Train loss in epoch 437: [0.02445953], Test loss: [0.024970334]
# Train loss in epoch 438: [0.024441514], Test loss: [0.024948593]
# Train loss in epoch 439: [0.024423881], Test loss: [0.024927247]
# Train loss in epoch 440: [0.024406504], Test loss: [0.024906177]
# Train loss in epoch 441: [0.024389893], Test loss: [0.024885835]
# Train loss in epoch 442: [0.024373408], Test loss: [0.024865646]
# Train loss in epoch 443: [0.024357425], Test loss: [0.024845982]
# Train loss in epoch 444: [0.024341848], Test loss: [0.024826724]
# Train loss in epoch 445: [0.024326868], Test loss: [0.024808057]
# Train loss in epoch 446: [0.024311839], Test loss: [0.024789382]
# Train loss in epoch 447: [0.024297524], Test loss: [0.024771426]
# Train loss in epoch 448: [0.024283517], Test loss: [0.0247538]
# Train loss in epoch 449: [0.024269868], Test loss: [0.024736512]
# Train loss in epoch 450: [0.024256591], Test loss: [0.024719667]
# Train loss in epoch 451: [0.024243373], Test loss: [0.024702884]
# Train loss in epoch 452: [0.024230815], Test loss: [0.024686761]
# Train loss in epoch 453: [0.024218306], Test loss: [0.024670733]
# Train loss in epoch 454: [0.024206258], Test loss: [0.024655163]
# Train loss in epoch 455: [0.024194343], Test loss: [0.024639785]
# Train loss in epoch 456: [0.024182791], Test loss: [0.024624787]
# Train loss in epoch 457: [0.024171574], Test loss: [0.024610123]
# Train loss in epoch 458: [0.024160422], Test loss: [0.024595592]
# Train loss in epoch 459: [0.024149554], Test loss: [0.024581317]
# Train loss in epoch 460: [0.024139002], Test loss: [0.024567455]
# Train loss in epoch 461: [0.024128437], Test loss: [0.024553541]
# Train loss in epoch 462: [0.024118382], Test loss: [0.024540203]
# Train loss in epoch 463: [0.02410835], Test loss: [0.024526909]
# Train loss in epoch 464: [0.024098439], Test loss: [0.024513792]
# Train loss in epoch 465: [0.024088793], Test loss: [0.02450094]
# Train loss in epoch 466: [0.024079222], Test loss: [0.024488144]
# Train loss in epoch 467: [0.024069838], Test loss: [0.024475669]
# Train loss in epoch 468: [0.024060577], Test loss: [0.024463281]
# Train loss in epoch 469: [0.024051469], Test loss: [0.024451051]
# Train loss in epoch 470: [0.02404236], Test loss: [0.024438923]
# Train loss in epoch 471: [0.024033666], Test loss: [0.024427183]
# Train loss in epoch 472: [0.024024803], Test loss: [0.024415344]
# Train loss in epoch 473: [0.024016313], Test loss: [0.024403829]
# Train loss in epoch 474: [0.024007581], Test loss: [0.024392182]
# Train loss in epoch 475: [0.023999132], Test loss: [0.024380799]
# Train loss in epoch 476: [0.023990886], Test loss: [0.024369672]
# Train loss in epoch 477: [0.023982352], Test loss: [0.024358254]
# Train loss in epoch 478: [0.023974258], Test loss: [0.024347348]
# Train loss in epoch 479: [0.023966124], Test loss: [0.024336375]
# Train loss in epoch 480: [0.023957981], Test loss: [0.024325438]
# Train loss in epoch 481: [0.023949878], Test loss: [0.024314616]
# Train loss in epoch 482: [0.023941927], Test loss: [0.024303908]
# Train loss in epoch 483: [0.023933893], Test loss: [0.02429316]
# Train loss in epoch 484: [0.023926014], Test loss: [0.024282593]
# Train loss in epoch 485: [0.023918003], Test loss: [0.024271976]
# Train loss in epoch 486: [0.023910107], Test loss: [0.024261415]
# Train loss in epoch 487: [0.023902155], Test loss: [0.024250872]
# Train loss in epoch 488: [0.023894299], Test loss: [0.024240475]
# Train loss in epoch 489: [0.023886416], Test loss: [0.024230009]
# Train loss in epoch 490: [0.023878429], Test loss: [0.024219524]
# Train loss in epoch 491: [0.023870561], Test loss: [0.02420916]
# Train loss in epoch 492: [0.023862574], Test loss: [0.024198703]
# Train loss in epoch 493: [0.023854543], Test loss: [0.024188239]
# Train loss in epoch 494: [0.023846563], Test loss: [0.024177879]
# Train loss in epoch 495: [0.023838345], Test loss: [0.024167258]
# Train loss in epoch 496: [0.023830267], Test loss: [0.024156813]
# Train loss in epoch 497: [0.023822132], Test loss: [0.024146389]
# Train loss in epoch 498: [0.023813784], Test loss: [0.02413574]
# Train loss in epoch 499: [0.023805475], Test loss: [0.02412517]
# Train loss in epoch 500: [0.023796909], Test loss: [0.024114341]
# Train loss in epoch 501: [0.023788404], Test loss: [0.024103653]
# Train loss in epoch 502: [0.023779897], Test loss: [0.024093008]
# Train loss in epoch 503: [0.023770977], Test loss: [0.024081919]
# Train loss in epoch 504: [0.023762193], Test loss: [0.024071053]
# Train loss in epoch 505: [0.023753205], Test loss: [0.024059966]
# Train loss in epoch 506: [0.023744173], Test loss: [0.024048895]
# Train loss in epoch 507: [0.023734771], Test loss: [0.024037465]
# Train loss in epoch 508: [0.023725398], Test loss: [0.024026107]
# Train loss in epoch 509: [0.023715748], Test loss: [0.024014488]
# Train loss in epoch 510: [0.023706077], Test loss: [0.024002908]
# Train loss in epoch 511: [0.023696139], Test loss: [0.023991119]
# Train loss in epoch 512: [0.023686036], Test loss: [0.023979178]
# Train loss in epoch 513: [0.02367579], Test loss: [0.023967125]
# Train loss in epoch 514: [0.023665501], Test loss: [0.023955032]
# Train loss in epoch 515: [0.023654789], Test loss: [0.023942567]
# Train loss in epoch 516: [0.023643833], Test loss: [0.023929927]
# Train loss in epoch 517: [0.023632897], Test loss: [0.023917308]
# Train loss in epoch 518: [0.023621639], Test loss: [0.023904435]
# Train loss in epoch 519: [0.02361015], Test loss: [0.023891319]
# Train loss in epoch 520: [0.02359866], Test loss: [0.023878288]
# Train loss in epoch 521: [0.023586843], Test loss: [0.023864929]
# Train loss in epoch 522: [0.023574587], Test loss: [0.023851212]
# Train loss in epoch 523: [0.023562323], Test loss: [0.02383751]
# Train loss in epoch 524: [0.023549676], Test loss: [0.023823449]
# Train loss in epoch 525: [0.023536924], Test loss: [0.023809325]
# Train loss in epoch 526: [0.023523994], Test loss: [0.023795038]
# Train loss in epoch 527: [0.023510739], Test loss: [0.023780528]
# Train loss in epoch 528: [0.023497295], Test loss: [0.023765791]
# Train loss in epoch 529: [0.023483615], Test loss: [0.02375089]
# Train loss in epoch 530: [0.023469822], Test loss: [0.023735926]
# Train loss in epoch 531: [0.023455707], Test loss: [0.023720652]
# Train loss in epoch 532: [0.023441222], Test loss: [0.023705088]
# Train loss in epoch 533: [0.023426645], Test loss: [0.02368946]
# Train loss in epoch 534: [0.023411855], Test loss: [0.023673663]
# Train loss in epoch 535: [0.023396926], Test loss: [0.023657756]
# Train loss in epoch 536: [0.02338158], Test loss: [0.023641482]
# Train loss in epoch 537: [0.023365878], Test loss: [0.023624852]
# Train loss in epoch 538: [0.023350464], Test loss: [0.023608614]
# Train loss in epoch 539: [0.023334622], Test loss: [0.023591924]
# Train loss in epoch 540: [0.023318782], Test loss: [0.02357531]
# Train loss in epoch 541: [0.023302253], Test loss: [0.023558063]
# Train loss in epoch 542: [0.023286227], Test loss: [0.023541322]
# Train loss in epoch 543: [0.023269285], Test loss: [0.023523742]
# Train loss in epoch 544: [0.023252675], Test loss: [0.023506494]
# Train loss in epoch 545: [0.02323571], Test loss: [0.023488931]
# Train loss in epoch 546: [0.023218518], Test loss: [0.023471219]
# Train loss in epoch 547: [0.023201212], Test loss: [0.023453413]
# Train loss in epoch 548: [0.023183644], Test loss: [0.023435343]
# Train loss in epoch 549: [0.023166338], Test loss: [0.023417637]
# Train loss in epoch 550: [0.0231486], Test loss: [0.023399495]
# Train loss in epoch 551: [0.023130517], Test loss: [0.023381062]
# Train loss in epoch 552: [0.023112748], Test loss: [0.023363005]
# Train loss in epoch 553: [0.023094468], Test loss: [0.023344424]
# Train loss in epoch 554: [0.023076586], Test loss: [0.023326313]
# Train loss in epoch 555: [0.023057928], Test loss: [0.023307493]
# Train loss in epoch 556: [0.023039564], Test loss: [0.023288935]
# Train loss in epoch 557: [0.023021143], Test loss: [0.023270387]
# Train loss in epoch 558: [0.023002431], Test loss: [0.023251573]
# Train loss in epoch 559: [0.022983506], Test loss: [0.0232326]
# Train loss in epoch 560: [0.022964802], Test loss: [0.023213886]
# Train loss in epoch 561: [0.022945754], Test loss: [0.023194853]
# Train loss in epoch 562: [0.022926763], Test loss: [0.023175897]
# Train loss in epoch 563: [0.022907896], Test loss: [0.023157096]
# Train loss in epoch 564: [0.022888763], Test loss: [0.023138065]
# Train loss in epoch 565: [0.022869503], Test loss: [0.023118939]
# Train loss in epoch 566: [0.022850197], Test loss: [0.023099799]
# Train loss in epoch 567: [0.022830736], Test loss: [0.023080572]
# Train loss in epoch 568: [0.022811491], Test loss: [0.023061562]
# Train loss in epoch 569: [0.022791665], Test loss: [0.023041993]
# Train loss in epoch 570: [0.02277239], Test loss: [0.023023011]
# Train loss in epoch 571: [0.022752635], Test loss: [0.023003593]
# Train loss in epoch 572: [0.022733159], Test loss: [0.022984423]
# Train loss in epoch 573: [0.02271321], Test loss: [0.022964859]
# Train loss in epoch 574: [0.022693379], Test loss: [0.022945464]
# Train loss in epoch 575: [0.022673249], Test loss: [0.022925764]
# Train loss in epoch 576: [0.022653319], Test loss: [0.022906262]
# Train loss in epoch 577: [0.022633422], Test loss: [0.022886852]
# Train loss in epoch 578: [0.022612991], Test loss: [0.022866925]
# Train loss in epoch 579: [0.02259266], Test loss: [0.022847135]
# Train loss in epoch 580: [0.022572365], Test loss: [0.022827361]
# Train loss in epoch 581: [0.022551874], Test loss: [0.022807432]
# Train loss in epoch 582: [0.022531155], Test loss: [0.022787323]
# Train loss in epoch 583: [0.022510605], Test loss: [0.022767399]
# Train loss in epoch 584: [0.022489548], Test loss: [0.022746909]
# Train loss in epoch 585: [0.022468638], Test loss: [0.02272661]
# Train loss in epoch 586: [0.0224474], Test loss: [0.022706039]
# Train loss in epoch 587: [0.022425763], Test loss: [0.02268509]
# Train loss in epoch 588: [0.022404693], Test loss: [0.022664689]
# Train loss in epoch 589: [0.022382919], Test loss: [0.022643555]
# Train loss in epoch 590: [0.022360947], Test loss: [0.022622295]
# Train loss in epoch 591: [0.022338534], Test loss: [0.022600621]
# Train loss in epoch 592: [0.022316143], Test loss: [0.022578953]
# Train loss in epoch 593: [0.022293737], Test loss: [0.022557229]
# Train loss in epoch 594: [0.022270642], Test loss: [0.022534903]
# Train loss in epoch 595: [0.022247527], Test loss: [0.022512492]
# Train loss in epoch 596: [0.02222402], Test loss: [0.022489727]
# Train loss in epoch 597: [0.022200106], Test loss: [0.02246654]
# Train loss in epoch 598: [0.022176284], Test loss: [0.022443444]
# Train loss in epoch 599: [0.022151608], Test loss: [0.022419546]
# Train loss in epoch 600: [0.022126887], Test loss: [0.022395486]
# Train loss in epoch 601: [0.02210201], Test loss: [0.022371342]
# Train loss in epoch 602: [0.022076568], Test loss: [0.022346605]
# Train loss in epoch 603: [0.022051187], Test loss: [0.022321947]
# Train loss in epoch 604: [0.022025473], Test loss: [0.022296958]
# Train loss in epoch 605: [0.021998823], Test loss: [0.022270992]
# Train loss in epoch 606: [0.021972492], Test loss: [0.022245295]
# Train loss in epoch 607: [0.021945994], Test loss: [0.022219442]
# Train loss in epoch 608: [0.021918729], Test loss: [0.022192791]
# Train loss in epoch 609: [0.021891564], Test loss: [0.022166299]
# Train loss in epoch 610: [0.021864178], Test loss: [0.022139492]
# Train loss in epoch 611: [0.021836679], Test loss: [0.022112541]
# Train loss in epoch 612: [0.021809088], Test loss: [0.022085451]
# Train loss in epoch 613: [0.021781396], Test loss: [0.022058342]
# Train loss in epoch 614: [0.021753538], Test loss: [0.022030957]
# Train loss in epoch 615: [0.02172545], Test loss: [0.022003353]
# Train loss in epoch 616: [0.021697568], Test loss: [0.02197589]
# Train loss in epoch 617: [0.021669324], Test loss: [0.021948006]
# Train loss in epoch 618: [0.02164124], Test loss: [0.02192029]
# Train loss in epoch 619: [0.021612594], Test loss: [0.021891985]
# Train loss in epoch 620: [0.021585416], Test loss: [0.021865111]
# Train loss in epoch 621: [0.021556482], Test loss: [0.021836441]
# Train loss in epoch 622: [0.021528471], Test loss: [0.021808606]
# Train loss in epoch 623: [0.021500085], Test loss: [0.021780482]
# Train loss in epoch 624: [0.021472197], Test loss: [0.021752693]
# Train loss in epoch 625: [0.021444058], Test loss: [0.021724686]
# Train loss in epoch 626: [0.02141479], Test loss: [0.02169548]
# Train loss in epoch 627: [0.02138753], Test loss: [0.021668278]
# Train loss in epoch 628: [0.02135749], Test loss: [0.021638216]
# Train loss in epoch 629: [0.021329977], Test loss: [0.02161066]
# Train loss in epoch 630: [0.021300578], Test loss: [0.021581233]
# Train loss in epoch 631: [0.021272335], Test loss: [0.021552814]
# Train loss in epoch 632: [0.021242432], Test loss: [0.02152271]
# Train loss in epoch 633: [0.021213744], Test loss: [0.021493878]
# Train loss in epoch 634: [0.02118396], Test loss: [0.021463795]
# Train loss in epoch 635: [0.021154542], Test loss: [0.021434136]
# Train loss in epoch 636: [0.021124143], Test loss: [0.02140341]
# Train loss in epoch 637: [0.021094527], Test loss: [0.021373454]
# Train loss in epoch 638: [0.021063309], Test loss: [0.021341834]
# Train loss in epoch 639: [0.021033121], Test loss: [0.02131125]
# Train loss in epoch 640: [0.021001432], Test loss: [0.021279044]
# Train loss in epoch 641: [0.0209709], Test loss: [0.021248022]
# Train loss in epoch 642: [0.020938445], Test loss: [0.021215053]
# Train loss in epoch 643: [0.020906676], Test loss: [0.021182757]
# Train loss in epoch 644: [0.020874545], Test loss: [0.021150008]
# Train loss in epoch 645: [0.02084139], Test loss: [0.021116246]
# Train loss in epoch 646: [0.020809202], Test loss: [0.021083429]
# Train loss in epoch 647: [0.020775253], Test loss: [0.021048822]
# Train loss in epoch 648: [0.020742215], Test loss: [0.021015128]
# Train loss in epoch 649: [0.020707812], Test loss: [0.020980056]
# Train loss in epoch 650: [0.020674367], Test loss: [0.020945903]
# Train loss in epoch 651: [0.020639801], Test loss: [0.020910673]
# Train loss in epoch 652: [0.020605724], Test loss: [0.020875905]
# Train loss in epoch 653: [0.02057107], Test loss: [0.020840557]
# Train loss in epoch 654: [0.020536812], Test loss: [0.020805582]
# Train loss in epoch 655: [0.020502001], Test loss: [0.020770127]
# Train loss in epoch 656: [0.020467903], Test loss: [0.020735379]
# Train loss in epoch 657: [0.020433929], Test loss: [0.02070074]
# Train loss in epoch 658: [0.020400189], Test loss: [0.020666368]
# Train loss in epoch 659: [0.02036684], Test loss: [0.020632397]
# Train loss in epoch 660: [0.020333722], Test loss: [0.020598691]
# Train loss in epoch 661: [0.020302398], Test loss: [0.020566799]
# Train loss in epoch 662: [0.020270903], Test loss: [0.020534776]
# Train loss in epoch 663: [0.020241439], Test loss: [0.020504763]
# Train loss in epoch 664: [0.020212391], Test loss: [0.020475168]
# Train loss in epoch 665: [0.020185523], Test loss: [0.020447761]
# Train loss in epoch 666: [0.020160235], Test loss: [0.020421907]
# Train loss in epoch 667: [0.020137593], Test loss: [0.02039871]
# Train loss in epoch 668: [0.020117331], Test loss: [0.020377858]
# Train loss in epoch 669: [0.020099495], Test loss: [0.020359449]
# Train loss in epoch 670: [0.02008621], Test loss: [0.020345431]
# Train loss in epoch 671: [0.020075999], Test loss: [0.020334413]
# Train loss in epoch 672: [0.02007103], Test loss: [0.020328473]
# Train loss in epoch 673: [0.020071192], Test loss: [0.020327577]
# Train loss in epoch 674: [0.020078387], Test loss: [0.020333495]
# Train loss in epoch 675: [0.020092852], Test loss: [0.020346433]
# Train loss in epoch 676: [0.02011716], Test loss: [0.02036899]
# Train loss in epoch 677: [0.020152915], Test loss: [0.020402618]
# Train loss in epoch 678: [0.020202968], Test loss: [0.020450274]
# Train loss in epoch 679: [0.020271506], Test loss: [0.020515919]
# Train loss in epoch 680: [0.0203621], Test loss: [0.020603303]
# Train loss in epoch 681: [0.020481855], Test loss: [0.020719403]
# Train loss in epoch 682: [0.02063949], Test loss: [0.020872924]
# Train loss in epoch 683: [0.020846713], Test loss: [0.021075778]
# Train loss in epoch 684: [0.021116916], Test loss: [0.021341864]
# Train loss in epoch 685: [0.021446867], Test loss: [0.021669105]
# Train loss in epoch 686: [0.021774787], Test loss: [0.021996651]
# Train loss in epoch 687: [0.021991024], Test loss: [0.022211311]
# Train loss in epoch 688: [0.022074712], Test loss: [0.022289336]
# Train loss in epoch 689: [0.022053031], Test loss: [0.022263899]
# Train loss in epoch 690: [0.021939311], Test loss: [0.022152398]
# Train loss in epoch 691: [0.021777265], Test loss: [0.021997349]
# Train loss in epoch 692: [0.021605771], Test loss: [0.021835536]
# Train loss in epoch 693: [0.021445315], Test loss: [0.021686126]
# Train loss in epoch 694: [0.021304015], Test loss: [0.021556389]
# Train loss in epoch 695: [0.021183446], Test loss: [0.021447379]
# Train loss in epoch 696: [0.021081507], Test loss: [0.021356678]
# Train loss in epoch 697: [0.020995617], Test loss: [0.021281466]
# Train loss in epoch 698: [0.020923156], Test loss: [0.021219201]
# Train loss in epoch 699: [0.020861931], Test loss: [0.021167517]
# Train loss in epoch 700: [0.020810546], Test loss: [0.021125108]
# Train loss in epoch 701: [0.020767737], Test loss: [0.021090541]
# Train loss in epoch 702: [0.020732325], Test loss: [0.021062586]
# Train loss in epoch 703: [0.020703468], Test loss: [0.021040186]
# Train loss in epoch 704: [0.020680051], Test loss: [0.021022215]
# Train loss in epoch 705: [0.020661058], Test loss: [0.021007566]
# Train loss in epoch 706: [0.020645466], Test loss: [0.020995239]
# Train loss in epoch 707: [0.02063242], Test loss: [0.020984489]
# Train loss in epoch 708: [0.020621134], Test loss: [0.020974699]
# Train loss in epoch 709: [0.020610943], Test loss: [0.020965364]
# Train loss in epoch 710: [0.020601492], Test loss: [0.020956287]
# Train loss in epoch 711: [0.020592786], Test loss: [0.020947671]
# Train loss in epoch 712: [0.020584177], Test loss: [0.02093889]
# Train loss in epoch 713: [0.020576093], Test loss: [0.020930525]
# Train loss in epoch 714: [0.020567998], Test loss: [0.020922072]
# Train loss in epoch 715: [0.020560019], Test loss: [0.020913698]
# Train loss in epoch 716: [0.02055227], Test loss: [0.020905502]
# Train loss in epoch 717: [0.020544462], Test loss: [0.02089728]
# Train loss in epoch 718: [0.020536859], Test loss: [0.020889267]
# Train loss in epoch 719: [0.020529171], Test loss: [0.02088115]
# Train loss in epoch 720: [0.020521676], Test loss: [0.020873245]
# Train loss in epoch 721: [0.020514101], Test loss: [0.020865293]
# Train loss in epoch 722: [0.02050662], Test loss: [0.020857409]
# Train loss in epoch 723: [0.020499319], Test loss: [0.020849746]
# Train loss in epoch 724: [0.020492004], Test loss: [0.020842059]
# Train loss in epoch 725: [0.020484639], Test loss: [0.020834323]
# Train loss in epoch 726: [0.020477334], Test loss: [0.020826692]
# Train loss in epoch 727: [0.020470098], Test loss: [0.020819113]
# Train loss in epoch 728: [0.020462882], Test loss: [0.020811543]
# Train loss in epoch 729: [0.020455629], Test loss: [0.020803964]
# Train loss in epoch 730: [0.020448551], Test loss: [0.020796558]
# Train loss in epoch 731: [0.020441402], Test loss: [0.020789068]
# Train loss in epoch 732: [0.02043435], Test loss: [0.020781696]
# Train loss in epoch 733: [0.020427279], Test loss: [0.020774292]
# Train loss in epoch 734: [0.02042035], Test loss: [0.020767048]
# Train loss in epoch 735: [0.020413313], Test loss: [0.020759702]
# Train loss in epoch 736: [0.020406276], Test loss: [0.020752355]
# Train loss in epoch 737: [0.020399567], Test loss: [0.020745311]
# Train loss in epoch 738: [0.020392561], Test loss: [0.020737994]
# Train loss in epoch 739: [0.020385694], Test loss: [0.020730816]
# Train loss in epoch 740: [0.020378929], Test loss: [0.02072374]
# Train loss in epoch 741: [0.020372197], Test loss: [0.020716716]
# Train loss in epoch 742: [0.020365395], Test loss: [0.020709621]
# Train loss in epoch 743: [0.020358743], Test loss: [0.020702673]
# Train loss in epoch 744: [0.020351969], Test loss: [0.020695589]
# Train loss in epoch 745: [0.020345196], Test loss: [0.020688567]
# Train loss in epoch 746: [0.020338545], Test loss: [0.020681636]
# Train loss in epoch 747: [0.020331975], Test loss: [0.020674767]
# Train loss in epoch 748: [0.020325296], Test loss: [0.020667851]
# Train loss in epoch 749: [0.020318713], Test loss: [0.02066103]
# ...
# Train loss in epoch 754: [0.020285873], Test loss: [0.020627085]
# Train loss in epoch 755: [0.020279273], Test loss: [0.020620262]
# Train loss in epoch 756: [0.020272717], Test loss: [0.020613555]
# Train loss in epoch 757: [0.020266268], Test loss: [0.020606959]
# Train loss in epoch 758: [0.020259716], Test loss: [0.020600274]
# Train loss in epoch 759: [0.020253181], Test loss: [0.020593587]
# Train loss in epoch 760: [0.020246662], Test loss: [0.02058693]
# Train loss in epoch 761: [0.020240126], Test loss: [0.020580266]
# Train loss in epoch 762: [0.020233618], Test loss: [0.020573653]
# Train loss in epoch 763: [0.020227142], Test loss: [0.020567078]
# Train loss in epoch 764: [0.020220514], Test loss: [0.020560395]
# Train loss in epoch 765: [0.020213947], Test loss: [0.020553753]
# Train loss in epoch 766: [0.020207386], Test loss: [0.020547124]
# Train loss in epoch 767: [0.020200912], Test loss: [0.02054061]
# Train loss in epoch 768: [0.020194335], Test loss: [0.020533975]
# Train loss in epoch 769: [0.020187704], Test loss: [0.020527333]
# Train loss in epoch 770: [0.020181175], Test loss: [0.020520804]
# Train loss in epoch 771: [0.020174541], Test loss: [0.020514149]
# Train loss in epoch 772: [0.020168042], Test loss: [0.02050768]
# Train loss in epoch 773: [0.020161308], Test loss: [0.020500969]
# Train loss in epoch 774: [0.020154685], Test loss: [0.020494388]
# Train loss in epoch 775: [0.020148005], Test loss: [0.020487769]
# Train loss in epoch 776: [0.02014121], Test loss: [0.02048103]
# Train loss in epoch 777: [0.020134453], Test loss: [0.020474326]
# Train loss in epoch 778: [0.020127743], Test loss: [0.020467725]
# Train loss in epoch 779: [0.020120971], Test loss: [0.020461053]
# Train loss in epoch 780: [0.020113975], Test loss: [0.020454153]
# Train loss in epoch 781: [0.020107152], Test loss: [0.020447481]
# Train loss in epoch 782: [0.020100109], Test loss: [0.020440593]
# Train loss in epoch 783: [0.02009318], Test loss: [0.020433828]
# Train loss in epoch 784: [0.020086046], Test loss: [0.020426895]
# Train loss in epoch 785: [0.020078793], Test loss: [0.020419851]
# Train loss in epoch 786: [0.020071555], Test loss: [0.020412842]
# Train loss in epoch 787: [0.020064209], Test loss: [0.020405754]
# Train loss in epoch 788: [0.020056689], Test loss: [0.020398483]
# Train loss in epoch 789: [0.020049214], Test loss: [0.020391338]
# Train loss in epoch 790: [0.020041302], Test loss: [0.020383747]
# Train loss in epoch 791: [0.020033464], Test loss: [0.020376254]
# Train loss in epoch 792: [0.020025471], Test loss: [0.020368662]
# Train loss in epoch 793: [0.020017255], Test loss: [0.020360835]
# Train loss in epoch 794: [0.020008735], Test loss: [0.020352755]
# Train loss in epoch 795: [0.020000078], Test loss: [0.02034457]
# Train loss in epoch 796: [0.019991165], Test loss: [0.020336129]
# Train loss in epoch 797: [0.019982062], Test loss: [0.020327533]
# Train loss in epoch 798: [0.01997241], Test loss: [0.020318437]
# Train loss in epoch 799: [0.019962519], Test loss: [0.0203091]
# Train loss in epoch 800: [0.019952152], Test loss: [0.020299312]
# Train loss in epoch 801: [0.019941119], Test loss: [0.020288847]
# Train loss in epoch 802: [0.019929634], Test loss: [0.020277947]
# Train loss in epoch 803: [0.01991735], Test loss: [0.020266216]
# Train loss in epoch 804: [0.019904356], Test loss: [0.020253733]
# Train loss in epoch 805: [0.019890334], Test loss: [0.02024018]
# Train loss in epoch 806: [0.019875299], Test loss: [0.020225517]
# Train loss in epoch 807: [0.019859012], Test loss: [0.020209473]
# Train loss in epoch 808: [0.019841561], Test loss: [0.020192139]
# Train loss in epoch 809: [0.019823123], Test loss: [0.020173689]
# Train loss in epoch 810: [0.019804092], Test loss: [0.020154558]
# Train loss in epoch 811: [0.019784972], Test loss: [0.020135302]
# Train loss in epoch 812: [0.019766863], Test loss: [0.020117082]
# Train loss in epoch 813: [0.019750448], Test loss: [0.020100642]
# Train loss in epoch 814: [0.019736379], Test loss: [0.020086631]
# Train loss in epoch 815: [0.019725041], Test loss: [0.020075358]
# Train loss in epoch 816: [0.019715717], Test loss: [0.020066101]
# Train loss in epoch 817: [0.019707868], Test loss: [0.020058345]
# Train loss in epoch 818: [0.019700833], Test loss: [0.020051304]
# Train loss in epoch 819: [0.019693855], Test loss: [0.020044252]
# Train loss in epoch 820: [0.01968722], Test loss: [0.020037431]
# Train loss in epoch 821: [0.019680642], Test loss: [0.02003067]
# Train loss in epoch 822: [0.019673381], Test loss: [0.020023473]
# Train loss in epoch 823: [0.019665455], Test loss: [0.020015877]
# Train loss in epoch 824: [0.019657101], Test loss: [0.020007897]
# Train loss in epoch 825: [0.019648548], Test loss: [0.019999735]
# Train loss in epoch 826: [0.019639723], Test loss: [0.019991253]
# Train loss in epoch 827: [0.019630726], Test loss: [0.019982617]
# Train loss in epoch 828: [0.019621518], Test loss: [0.019973729]
# Train loss in epoch 829: [0.019611996], Test loss: [0.01996449]
# Train loss in epoch 830: [0.01960199], Test loss: [0.019954748]
# Train loss in epoch 831: [0.019591529], Test loss: [0.019944552]
# Train loss in epoch 832: [0.019580504], Test loss: [0.019933771]
# Train loss in epoch 833: [0.019568939], Test loss: [0.01992243]
# Train loss in epoch 834: [0.019556537], Test loss: [0.019910196]
# Train loss in epoch 835: [0.019543111], Test loss: [0.019896926]
# Train loss in epoch 836: [0.019528773], Test loss: [0.019882776]
# Train loss in epoch 837: [0.019513119], Test loss: [0.019867301]
# Train loss in epoch 838: [0.019496221], Test loss: [0.019850645]
# Train loss in epoch 839: [0.019478135], Test loss: [0.019832905]
# Train loss in epoch 840: [0.019459283], Test loss: [0.019814592]
# Train loss in epoch 841: [0.019440077], Test loss: [0.019796137]
# Train loss in epoch 842: [0.019421924], Test loss: [0.0197789]
# Train loss in epoch 843: [0.019405328], Test loss: [0.019763293]
# Train loss in epoch 844: [0.019391175], Test loss: [0.019750047]
# Train loss in epoch 845: [0.019379683], Test loss: [0.019739216]
# Train loss in epoch 846: [0.019370764], Test loss: [0.019730691]
# Train loss in epoch 847: [0.019363713], Test loss: [0.019723747]
# Train loss in epoch 848: [0.019357879], Test loss: [0.019717721]
# Train loss in epoch 849: [0.019352818], Test loss: [0.019712266]
# Train loss in epoch 850: [0.019347802], Test loss: [0.019706696]
# Train loss in epoch 851: [0.019342646], Test loss: [0.019701054]
# Train loss in epoch 852: [0.019336816], Test loss: [0.019694895]
# Train loss in epoch 853: [0.019330215], Test loss: [0.019688163]
# Train loss in epoch 854: [0.019323021], Test loss: [0.019680958]
# Train loss in epoch 855: [0.019315332], Test loss: [0.019673368]
# Train loss in epoch 856: [0.019307403], Test loss: [0.019665502]
# Train loss in epoch 857: [0.019299041], Test loss: [0.019657224]
# Train loss in epoch 858: [0.019290129], Test loss: [0.019648414]
# Train loss in epoch 859: [0.019281082], Test loss: [0.019639425]
# Train loss in epoch 860: [0.019271364], Test loss: [0.019629752]
# Train loss in epoch 861: [0.019260887], Test loss: [0.019619295]
# Train loss in epoch 862: [0.019249778], Test loss: [0.019608216]
# Train loss in epoch 863: [0.019237675], Test loss: [0.019596208]
# Train loss in epoch 864: [0.019224569], Test loss: [0.019583218]
# Train loss in epoch 865: [0.019210067], Test loss: [0.019568907]
# Train loss in epoch 866: [0.019194199], Test loss: [0.019553471]
# Train loss in epoch 867: [0.019177165], Test loss: [0.019537106]
# Train loss in epoch 868: [0.019159075], Test loss: [0.019520011]
# Train loss in epoch 869: [0.019140819], Test loss: [0.019503109]
# Train loss in epoch 870: [0.019123372], Test loss: [0.019487277]
# Train loss in epoch 871: [0.019107811], Test loss: [0.019473452]
# Train loss in epoch 872: [0.019094886], Test loss: [0.019462056]
# Train loss in epoch 873: [0.01908497], Test loss: [0.019453377]
# Train loss in epoch 874: [0.019077759], Test loss: [0.019446984]
# Train loss in epoch 875: [0.019072898], Test loss: [0.019442502]
# Train loss in epoch 876: [0.019069113], Test loss: [0.019438677]
# Train loss in epoch 877: [0.019066181], Test loss: [0.019435428]
# Train loss in epoch 878: [0.01906346], Test loss: [0.019432249]
# Train loss in epoch 879: [0.019060526], Test loss: [0.01942889]
# Train loss in epoch 880: [0.019057274], Test loss: [0.019425325]
# Train loss in epoch 881: [0.019053645], Test loss: [0.019421533]
# Train loss in epoch 882: [0.019049872], Test loss: [0.019417712]
# Train loss in epoch 883: [0.019045662], Test loss: [0.019413553]
# Train loss in epoch 884: [0.01904144], Test loss: [0.019409418]
# Train loss in epoch 885: [0.019037217], Test loss: [0.019405268]
# Train loss in epoch 886: [0.019032899], Test loss: [0.019401055]
# Train loss in epoch 887: [0.019028641], Test loss: [0.01939689]
# Train loss in epoch 888: [0.01902448], Test loss: [0.019392833]
# Train loss in epoch 889: [0.019020272], Test loss: [0.019388709]
# Train loss in epoch 890: [0.019016031], Test loss: [0.019384524]
# Train loss in epoch 891: [0.019011945], Test loss: [0.019380534]
# Train loss in epoch 892: [0.019007858], Test loss: [0.01937649]
# Train loss in epoch 893: [0.019003708], Test loss: [0.019372419]
# Train loss in epoch 894: [0.018999696], Test loss: [0.019368453]
# Train loss in epoch 895: [0.018995702], Test loss: [0.019364519]
# Train loss in epoch 896: [0.018991545], Test loss: [0.019360414]
# Train loss in epoch 897: [0.018987641], Test loss: [0.019356558]
# Train loss in epoch 898: [0.018983644], Test loss: [0.019352555]
# Train loss in epoch 899: [0.018979659], Test loss: [0.01934861]
# Train loss in epoch 900: [0.018975863], Test loss: [0.019344836]
# Train loss in epoch 901: [0.01897205], Test loss: [0.019341052]
# Train loss in epoch 902: [0.01896815], Test loss: [0.019337147]
# Train loss in epoch 903: [0.018964339], Test loss: [0.019333316]
# Train loss in epoch 904: [0.018960662], Test loss: [0.019329645]
# Train loss in epoch 905: [0.018956874], Test loss: [0.019325834]
# Train loss in epoch 906: [0.018953234], Test loss: [0.019322176]
# Train loss in epoch 907: [0.018949606], Test loss: [0.019318501]
# Train loss in epoch 908: [0.01894594], Test loss: [0.019314785]
# Train loss in epoch 909: [0.018942453], Test loss: [0.019311253]
# Train loss in epoch 910: [0.018938877], Test loss: [0.019307621]
# Train loss in epoch 911: [0.018935349], Test loss: [0.019304024]
# Train loss in epoch 912: [0.018932004], Test loss: [0.019300573]
# Train loss in epoch 913: [0.018928502], Test loss: [0.019297004]
# Train loss in epoch 914: [0.018925164], Test loss: [0.019293593]
# Train loss in epoch 915: [0.018921757], Test loss: [0.019290071]
# Train loss in epoch 916: [0.018918362], Test loss: [0.019286573]
# Train loss in epoch 917: [0.018914999], Test loss: [0.019283116]
# Train loss in epoch 918: [0.018911773], Test loss: [0.019279771]
# Train loss in epoch 919: [0.018908521], Test loss: [0.019276427]
# Train loss in epoch 920: [0.018905235], Test loss: [0.01927302]
# Train loss in epoch 921: [0.018902164], Test loss: [0.019269824]
# Train loss in epoch 922: [0.018898897], Test loss: [0.019266434]
# Train loss in epoch 923: [0.018895678], Test loss: [0.019263096]
# Train loss in epoch 924: [0.018892499], Test loss: [0.019259797]
# Train loss in epoch 925: [0.01888947], Test loss: [0.019256666]
# Train loss in epoch 926: [0.018886402], Test loss: [0.019253459]
# Train loss in epoch 927: [0.018883292], Test loss: [0.019250218]
# Train loss in epoch 928: [0.018880211], Test loss: [0.019247003]
# Train loss in epoch 929: [0.018877119], Test loss: [0.019243782]
# Train loss in epoch 930: [0.018874222], Test loss: [0.019240763]
# Train loss in epoch 931: [0.018871039], Test loss: [0.019237436]
# Train loss in epoch 932: [0.018868107], Test loss: [0.019234382]
# Train loss in epoch 933: [0.018865082], Test loss: [0.019231219]
# Train loss in epoch 934: [0.018862192], Test loss: [0.019228205]
# Train loss in epoch 935: [0.018859116], Test loss: [0.019224981]
# Train loss in epoch 936: [0.018856306], Test loss: [0.019222077]
# Train loss in epoch 937: [0.018853351], Test loss: [0.019218974]
# Train loss in epoch 938: [0.018850449], Test loss: [0.019215919]
# Train loss in epoch 939: [0.018847536], Test loss: [0.019212879]
# Train loss in epoch 940: [0.01884466], Test loss: [0.019209862]
# Train loss in epoch 941: [0.018841796], Test loss: [0.01920687]
# Train loss in epoch 942: [0.01883897], Test loss: [0.019203903]
# Train loss in epoch 943: [0.018836061], Test loss: [0.019200856]
# Train loss in epoch 944: [0.018833216], Test loss: [0.019197859]
# Train loss in epoch 945: [0.018830426], Test loss: [0.019194935]
# Train loss in epoch 946: [0.018827645], Test loss: [0.019192014]
# Train loss in epoch 947: [0.018824812], Test loss: [0.019189036]
# Train loss in epoch 948: [0.018822068], Test loss: [0.019186132]
# Train loss in epoch 949: [0.018819366], Test loss: [0.019183297]
# Train loss in epoch 950: [0.018816561], Test loss: [0.019180354]
# Train loss in epoch 951: [0.018813819], Test loss: [0.019177457]
# Train loss in epoch 952: [0.018811028], Test loss: [0.019174522]
# Train loss in epoch 953: [0.018808292], Test loss: [0.019171637]
# Train loss in epoch 954: [0.018805623], Test loss: [0.019168798]
# Train loss in epoch 955: [0.018802956], Test loss: [0.019165991]
# Train loss in epoch 956: [0.018800309], Test loss: [0.019163184]
# Train loss in epoch 957: [0.018797569], Test loss: [0.019160289]
# Train loss in epoch 958: [0.018795053], Test loss: [0.019157635]
# Train loss in epoch 959: [0.018792465], Test loss: [0.01915488]
# Train loss in epoch 960: [0.018789839], Test loss: [0.019152097]
# Train loss in epoch 961: [0.018787224], Test loss: [0.019149326]
# Train loss in epoch 962: [0.018784687], Test loss: [0.01914661]
# Train loss in epoch 963: [0.018782027], Test loss: [0.019143788]
# Train loss in epoch 964: [0.018779514], Test loss: [0.019141104]
# Train loss in epoch 965: [0.018776961], Test loss: [0.019138388]
# Train loss in epoch 966: [0.018774461], Test loss: [0.019135717]
# Train loss in epoch 967: [0.018771917], Test loss: [0.019133]
# Train loss in epoch 968: [0.018769456], Test loss: [0.01913039]
# Train loss in epoch 969: [0.018766971], Test loss: [0.01912771]
# Train loss in epoch 970: [0.018764481], Test loss: [0.019125041]
# Train loss in epoch 971: [0.018762143], Test loss: [0.01912253]
# Train loss in epoch 972: [0.018759664], Test loss: [0.01911987]
# Train loss in epoch 973: [0.018757191], Test loss: [0.019117218]
# Train loss in epoch 974: [0.018754769], Test loss: [0.019114623]
# Train loss in epoch 975: [0.018752402], Test loss: [0.019112062]
# Train loss in epoch 976: [0.018749993], Test loss: [0.019109465]
# Train loss in epoch 977: [0.018747635], Test loss: [0.019106913]
# Train loss in epoch 978: [0.018745316], Test loss: [0.019104395]
# Train loss in epoch 979: [0.018742982], Test loss: [0.019101862]
# Train loss in epoch 980: [0.018740751], Test loss: [0.019099437]
# Train loss in epoch 981: [0.018738367], Test loss: [0.01909687]
# Train loss in epoch 982: [0.018736197], Test loss: [0.019094482]
# Train loss in epoch 983: [0.018733986], Test loss: [0.019092068]
# Train loss in epoch 984: [0.018731683], Test loss: [0.019089552]
# Train loss in epoch 985: [0.018729536], Test loss: [0.019087199]
# Train loss in epoch 986: [0.018727317], Test loss: [0.019084763]
# Train loss in epoch 987: [0.018725121], Test loss: [0.019082364]
# Train loss in epoch 988: [0.018722881], Test loss: [0.019079927]
# Train loss in epoch 989: [0.018720709], Test loss: [0.019077521]
# Train loss in epoch 990: [0.018718559], Test loss: [0.01907514]
# Train loss in epoch 991: [0.018716555], Test loss: [0.019072918]
# Train loss in epoch 992: [0.018714428], Test loss: [0.019070514]
# Train loss in epoch 993: [0.018712431], Test loss: [0.019068321]
# Train loss in epoch 994: [0.018710319], Test loss: [0.019065987]
# Train loss in epoch 995: [0.018708188], Test loss: [0.019063614]
# Train loss in epoch 996: [0.018706203], Test loss: [0.019061387]
# Train loss in epoch 997: [0.018704258], Test loss: [0.019059181]
# Train loss in epoch 998: [0.018702433], Test loss: [0.019057114]
# Train loss in epoch 999: [0.018700395], Test loss: [0.01905483]

# %%
#Saving function checking..
dnn_inst.layers[0].w.name
# Out:
# 'Layer0/Matrix/read:0'

# %%
tf.trainable_variables()
# Out:
# [<tensorflow.python.ops.variables.Variable at 0x7f8ea2c410f0>,
#  <tensorflow.python.ops.variables.Variable at 0x7f8e9fcb39b0>,
#  <tensorflow.python.ops.variables.Variable at 0x7f8e9f7c6710>,
#  <tensorflow.python.ops.variables.Variable at 0x7f8e9f7c6cf8>,
#  <tensorflow.python.ops.variables.Variable at 0x7f8e9f7c1cf8>,
#  <tensorflow.python.ops.variables.Variable at 0x7f8e9f7c1c88>]

# %%
dnn_inst.save_variables_for_rnn("WEIGHTS_FOLDER/TRANSITION_NET.chkp")
# Out:
# RNN/FullNetworkCell/Transition/Layer0/Bias
# Tensor("Layer0/Bias/read:0", shape=(32,), dtype=float32)
# RNN/FullNetworkCell/Transition/Layer2/Bias
# Tensor("Layer2/Bias/read:0", shape=(2,), dtype=float32)
# RNN/FullNetworkCell/Transition/Layer2/Matrix
# Tensor("Layer2/Matrix/read:0", shape=(32, 2), dtype=float32)
# RNN/FullNetworkCell/Transition/Layer0/Matrix
# Tensor("Layer0/Matrix/read:0", shape=(4, 32), dtype=float32)
# RNN/FullNetworkCell/Transition/Layer1/Matrix
# Tensor("Layer1/Matrix/read:0", shape=(32, 32), dtype=float32)
# RNN/FullNetworkCell/Transition/Layer1/Bias
# Tensor("Layer1/Bias/read:0", shape=(32,), dtype=float32)
# /home/wuga/Documents/Notebook/VAE-PLANNING/WEIGHTS_FOLDER/TRANSITION_NET.chkp

# %%
dnn_inst.predict_test([[1,1,2,2]])
# Out:
# [array([[ 3.13339972,  3.11902666]], dtype=float32)]
